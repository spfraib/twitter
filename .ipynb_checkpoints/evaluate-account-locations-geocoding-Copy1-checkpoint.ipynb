# %%
import pandas as pd
from timeit import default_timer as timer
import reverse_geocoder as rg
from iso3166 import countries
import numpy as np
import more_itertools as mit
from fuzzywuzzy import fuzz
import itertools
# %matplotlib inline

# %%
path_to_data = '../data/decahose/parsed/locations/'

# %%
print('Import Location Data...')
start = timer()

# Account Location, Average User Geolocation, Number of Users
account_locations  = pd.read_pickle(path_to_data+'selected-locations.pkl')
print('# Selected Account locations (After String Cleaning):', account_locations.shape[0])

# Account Locations Geocoded Using the Google API
geocoded_locations = pd.read_pickle(path_to_data+'geocoded-locations.pkl')
print('# Geocoded locations:', geocoded_locations.shape[0])

print("Done in", round(timer()-start), "sec")
# Out:
# Import Location Data...
# # Selected Account locations (After String Cleaning): 3362049
# # Geocoded locations: 428400
# Done in 16 sec

# %% [markdown]
# # Geocoded Account Locations

# %%
print('% Users at geocoded locations among selected locations:',
round(account_locations[
account_locations['LOCATION'].isin(list(geocoded_locations['input_string']))]['N'].sum()/\
account_locations['N'].sum(),2))
# Out:
# % Users at geocoded locations among selected locations: 0.79

# %%
print('Max # sampled users at selected but non-geocoded location:',
account_locations[(-account_locations['LOCATION'].isin(list(geocoded_locations['input_string'])))]['N'].max())
# Out:
# Max # sampled users at selected but non-geocoded location: 6

# %%
account_locations = account_locations[
account_locations['LOCATION'].isin(list(geocoded_locations['input_string']))].reset_index(drop=True).copy()
print('# Geocoded locations:', account_locations.shape[0])
# Out:
# # Geocoded locations: 428399

# %%
account_locations.head()
# Out:
#       LOCATION                         POINT      N
# 0    Indonesia         (-5.53034, 106.54255)  98240
# 1       London     (49.01730709, 1.43906842)  88896
# 2       Brasil  (-17.99120486, -45.60141543)  70885
# 3      Jakarta   (-5.19392835, 103.92920358)  55842
# 4  Philippines       (14.604133, 120.017236)  51989

# %% [markdown]
# # Reversed Geocode For Validation

# %%
print("Reverse geocode representative point...")
start = timer()

reversed_geocodes = pd.DataFrame(rg.search(list(account_locations['POINT'].values))).drop(
['lat','lon','name','admin1','admin2'],1).rename(columns=lambda x:x.upper())
print('# Geocodes:',reversed_geocodes.shape[0])

# reversed_geocodes['COUNTRY'] = reversed_geocodes['CC'].apply(lambda x:countries.get(x).name)

account_locations = pd.concat([account_locations,reversed_geocodes],1).drop('POINT',1)
del reversed_geocodes

print("Done in", round(timer()-start), "sec")
# Out:
# Reverse geocode representative point...
# Loading formatted geocoded file...
# # Geocodes: 428399
# Done in 6 sec

# %%
account_locations.head(10)
# Out:
#       LOCATION      N  CC
# 0    Indonesia  98240  ID
# 1       London  88896  FR
# 2       Brasil  70885  BR
# 3      Jakarta  55842  ID
# 4  Philippines  51989  PH
# 5     İstanbul  50755  TR
# 6     istanbul  39241  TR
# 7    indonesia  39057  ID
# 8    Argentina  36977  AR
# 9      Bandung  33295  ID

# %% [markdown]
# # Clean Geocodes

# %%
print('Drop duplicated geocodes:')
geocoded_locations.drop_duplicates('input_string',inplace=True)
geocoded_locations.reset_index(drop=True,inplace=True)
print('# Geocoded locations:', geocoded_locations.shape[0])
# Out:
# Drop duplicated geocodes:
# # Geocoded locations: 428399

# %%
print('# Geocoded locations with results:', geocoded_locations[
geocoded_locations['status']=='OK'].shape[0])

missing_geocodes = geocoded_locations[geocoded_locations['status']!='OK']['input_string']
print('# Locations with missing geocode:', missing_geocodes.shape[0])

print('% Users at locations with missing geocode:', 
round(account_locations[
account_locations['LOCATION'].isin(missing_geocodes)]['N'].sum()/account_locations['N'].sum(),3))

print('Max # sampled users at locations with missing geocode:', 
account_locations[
account_locations['LOCATION'].isin(missing_geocodes)]['N'].max())
# Out:
# # Geocoded locations with results: 402832
# # Locations with missing geocode: 25567
# % Users at locations with missing geocode: 0.016
# Max # sampled users at locations with missing geocode: 1459

# %%
types_of_interest = frozenset([
'country',
'locality',
'sublocality',
'neighborhood',
'administrative_area_level_1',
'administrative_area_level_2',
'administrative_area_level_3',
'administrative_area_level_4',
])

def nth_result(response,n):

    formatted_result = {}
    
    #Only Consider First result
    nth_result = mit.nth(response['results'], n, None)
    
    if not nth_result:
        return pd.Series()
        
    for component in nth_result['address_components']:

        for type_of_interest in types_of_interest:

            if type_of_interest in component['types']:

                formatted_result[type_of_interest+'_long'] = component['long_name']
                formatted_result[type_of_interest+'_short'] = component['short_name']
            
    return pd.Series(formatted_result)

# %%
# Discarded 173 locations with 2238 users matched with secondary results
print('Format First Result:')
start = timer()

geocoded_locations = pd.concat([geocoded_locations,
geocoded_locations['response'].apply(lambda x: nth_result(x, 0))],1)

print("Done in", round(timer()-start), "sec")
# Out:
# Format First Result:
# Done in 211 sec

# %%
geocoded_locations.count().sort_values(ascending=False)
# Out:
# input_string                         428399
# number_of_results                    428399
# response                             428399
# status                               428399
# accuracy                             402832
# formatted_address                    402832
# google_place_id                      402832
# latitude                             402832
# longitude                            402832
# postcode                             402832
# type                                 402832
# country_long                         401462
# country_short                        401462
# administrative_area_level_1_short    386605
# administrative_area_level_1_long     386605
# locality_long                        321513
# locality_short                       321513
# administrative_area_level_2_long     305600
# administrative_area_level_2_short    305600
# administrative_area_level_3_long      60747
# administrative_area_level_3_short     60747
# neighborhood_long                     21713
# neighborhood_short                    21713
# administrative_area_level_4_long      16422
# administrative_area_level_4_short     16422
# sublocality_long                      16291
# sublocality_short                     16291
# dtype: int64

# %% [markdown]
# # Merge Results

# %%
print('Merge Location Data...')
start = timer()

locations = pd.merge(
account_locations,
geocoded_locations.drop([
'accuracy',
'google_place_id',
'postcode',
'latitude', 
'longitude',
'number_of_results', 
'response',
],
1,
errors='ignore'),
left_on='LOCATION',
right_on='input_string').drop('input_string',1)
print('# Tested Locations:',locations.shape[0])

print("Done in", round(timer()-start), "sec")
# Out:
# Merge Location Data...
# # Tested Locations: 428399
# Done in 3 sec

# %%
locations.count().sort_values(ascending=False)
# Out:
# LOCATION                             428399
# N                                    428399
# CC                                   428399
# status                               428399
# formatted_address                    402832
# type                                 402832
# country_long                         401462
# country_short                        401462
# administrative_area_level_1_short    386605
# administrative_area_level_1_long     386605
# locality_short                       321513
# locality_long                        321513
# administrative_area_level_2_long     305600
# administrative_area_level_2_short    305600
# administrative_area_level_3_long      60747
# administrative_area_level_3_short     60747
# neighborhood_long                     21713
# neighborhood_short                    21713
# administrative_area_level_4_long      16422
# administrative_area_level_4_short     16422
# sublocality_long                      16291
# sublocality_short                     16291
# dtype: int64

# %% [markdown]
# # Evaluate Results

# %%
print('Compute String Match...')
start = timer()

def match(x):
    try:
        return fuzz.token_set_ratio(x['LOCATION'].lower(),x['formatted_address'].lower())
    except:
        return None

locations['MATCH'] = locations.apply(match,1)

print("Done in", round(timer()-start), "sec")
# Out:
# Compute String Match...
# Done in 25 sec

# %%
print('Check if a string contains special characters...')
start = timer()

def is_ascii(x):
    try:
        return int(x==x.encode('utf-8').decode('ascii'))
    except:
        return 0
    
locations['ASCII'] = locations['LOCATION'].apply(is_ascii)
print("Done in", round(timer()-start), "sec")
# Out:
# Check if a string contains special characters...
# Done in 0 sec

# %%
print('Check if a location contains types of interest...')
start = timer()

def of_interest(x):
    try: 
        return int(len(list(set(x.split(',')).intersection(list(types_of_interest)+['airport','political'])))>0)
    except:
        return None
    
locations['INTEREST'] = locations['type'].apply(of_interest)

print("Done in", round(timer()-start), "sec")
# Out:
# Check if a location contains types of interest...
# Done in 1 sec

# %%
locations.count()
# Out:
# LOCATION                             428399
# N                                    428399
# CC                                   428399
# formatted_address                    402832
# status                               428399
# type                                 402832
# country_long                         401462
# country_short                        401462
# locality_long                        321513
# locality_short                       321513
# administrative_area_level_2_long     305600
# administrative_area_level_2_short    305600
# administrative_area_level_1_long     386605
# administrative_area_level_1_short    386605
# administrative_area_level_3_long      60747
# administrative_area_level_3_short     60747
# sublocality_long                      16291
# sublocality_short                     16291
# neighborhood_long                     21713
# neighborhood_short                    21713
# administrative_area_level_4_long      16422
# administrative_area_level_4_short     16422
# MATCH                                402832
# ASCII                                428399
# INTEREST                             402832
# dtype: int64

# %%
verified_locations = []

# %%
# Checked bottom 100 N and Match
verified_locations += list(
locations[
(locations['N']>=25)& # Remove 18% 
(locations['status']=='OK')& # Removes 1% 
(locations['INTEREST']==1)& # Remove 1%
# (locations['ASCII']==1)& # To check string matching
(locations['CC']==locations['country_short'])
]['LOCATION'])

# %%
locations[
(locations['N']>=25)& # Remove 18% 
(locations['status']=='OK')& # Removes 1% 
(locations['INTEREST']==0)& # Remove 1%
# (locations['ASCII']==1)& # To check string matching
(locations['CC']==locations['country_short'])
].sort_values(by='N')[
['LOCATION','CC','N','country_short','country_long','formatted_address','type','MATCH']].tail(50)
# Out:
#                        LOCATION  CC     N country_short   country_long  \
# 6430                      DM(V)  US   190            US  United States
# 6414           Puerto Rico, USA  PR   190            PR    Puerto Rico
# 6336             Paris Van Java  ID   193            ID      Indonesia
# 6331                Moscow city  RU   193            RU         Russia
# 6315                  The South  US   193            US  United States
# 6166  Michigan State University  US   198            US  United States
# 6023          Jakarta - Bandung  ID   203            ID      Indonesia
# 5960         Sweet Home Alabama  US   206            US  United States
# 5852                   My House  US   209            US  United States
# 5792                       NOVA  US   211            US  United States
# 5731                       さっぽろ  JP   214            JP          Japan
# 5717        New York, New York   US   214            US  United States
# 5625                     Lombok  ID   218            ID      Indonesia
# 5562                         BC  US   221            US  United States
# 5463                North Texas  US   225            US  United States
# 5384                      Tejas  US   228            US  United States
# 5272                    'Merica  US   234            US  United States
# 5257                        htx  US   234            US  United States
# 5183                       D.C.  US   237            US  United States
# 5065                         九州  JP   243            JP          Japan
# 5087                 The Mitten  US   243            US  United States
# 4932                         CO  US   250            US  United States
# 4882          Isla de Margarita  VE   253            VE      Venezuela
# 4753           Upstate New York  US   261            US  United States
# 4692                   Columbia  US   264            US  United States
# 4217                         MS  US   297            US  United States
# 4172                       SATX  US   300            US  United States
# 4071                        PNW  US   310            US  United States
# 4017                        CLE  US   314            US  United States
# 3982                      D(M)V  US   317            US  United States
# 3870                        Mty  US   326            US  United States
# 3780                 Nationwide  US   333            US  United States
# 3770                     H-Town  US   334            US  United States
# 3598                 Upstate NY  US   350            US  United States
# 3595                   Sin City  US   350            US  United States
# 3467          Pacific Northwest  US   365            US  United States
# 3214                      Ambon  ID   397            ID      Indonesia
# 2535                        HTX  US   507            US  United States
# 2187                       Indy  US   580            US  United States
# 2182                         MI  US   581            US  United States
# 2148             City of Angels  US   587            US  United States
# 2140                    Midwest  US   590            US  United States
# 2133          Northern Virginia  US   591            US  United States
# 1918                   Hamilton  US   656            US  United States
# 1462               South Jersey  US   864            US  United States
# 1165                        ATX  US  1092            US  United States
# 1163                         MA  US  1094            US  United States
# 796                          DC  US  1564            US  United States
# 631                         DMV  US  2014            US  United States
# 323          New York, New York  US  3679            US  United States
#
#                                       formatted_address  \
# 6430         404 N 14th St, Independence, KS 67301, USA
# 6414             9227 Marina, Ponce, 00730, Puerto Rico
# 6336  Jl. Sukajadi No.131-139, Cipedes, Kec. Sukajad...
# 6331      Presnenskaya nab., 12, Moskva, Russia, 123317
# 6315       627 E Silas Brown St, Jackson, MS 39201, USA
# 6166     220 Trowbridge Rd, East Lansing, MI 48824, USA
# 6023  Jl. Sandang No.2, RT.11/RW.17, Klender, sandan...
# 5960  4400 Watercrest Rd Suite 101, Killeen, TX 7654...
# 5852     3036 S Fremont Ave, Springfield, MO 65804, USA
# 5792   21306 Signal Hill Plaza, Sterling, VA 20164, USA
# 5731  1 Chome Odorinishi, Chuo Ward, Sapporo, Hokkai...
# 5717    3790 S Las Vegas Blvd, Las Vegas, NV 89109, USA
# 5625              Lombok, West Nusa Tenggara, Indonesia
# 5562       1801 Panorama Dr, Bakersfield, CA 93305, USA
# 5463          410 Avenue C #308j, Denton, TX 76201, USA
# 5384  855 Pierremont Rd #149, Shreveport, LA 71106, USA
# 5272     6501 Kissena Blvd # 4, Flushing, NY 11367, USA
# 5257           1156 Fox Meadow Dr, Alvin, TX 77511, USA
# 5183                        Independence, KS 67301, USA
# 5065                                      Kyushu, Japan
# 5087     527 Leonard St NW, Grand Rapids, MI 49504, USA
# 4932                        Independence, KS 67301, USA
# 4882           Isla Margarita, Nueva Esparta, Venezuela
# 4753            750 E Adams St, Syracuse, NY 13210, USA
# 4692               2651 E 21st St, Tulsa, OK 74114, USA
# 4217                        Independence, KS 67301, USA
# 4172  5139 N Loop 1604 W Suite 110, San Antonio, TX ...
# 4071              1401 US-421, Westville, IN 46391, USA
# 4017               2301 Main St, Houston, TX 77002, USA
# 3982         404 N 14th St, Independence, KS 67301, USA
# 3870       7801 N Lamar Blvd #38, Austin, TX 78752, USA
# 3780  3075 N Market Ave #1, Fayetteville, AR 72703, USA
# 3770            4702 Airline Dr, Houston, TX 77022, USA
# 3598            750 E Adams St, Syracuse, NY 13210, USA
# 3595            2520 Park Ave, The Bronx, NY 10451, USA
# 3467           511 NW Broadway, Portland, OR 97209, USA
# 3214                    Ambon Island, Maluku, Indonesia
# 2535           1156 Fox Meadow Dr, Alvin, TX 77511, USA
# 2187        4790 W 16th St, Indianapolis, IN 46222, USA
# 2182        12412 East 86th St N, Owasso, OK 74055, USA
# 2148      221 S Eastman Ave, Los Angeles, CA 90063, USA
# 2140        912 S Walnut St, Coffeyville, KS 67337, USA
# 2133  6699 Springfield Center Dr, Springfield, VA 22...
# 1918             911 58 Rd, Independence, KS 67301, USA
# 1462  1501 John Tipton Blvd, Pennsauken Township, NJ...
# 1165  225 Chastain Meadows Pkwy NW #200, Kennesaw, G...
# 1163              27 Midstate Dr, Auburn, MA 01501, USA
# 796                         Independence, KS 67301, USA
# 631          404 N 14th St, Independence, KS 67301, USA
# 323     3790 S Las Vegas Blvd, Las Vegas, NV 89109, USA
#
#                                                    type  MATCH
# 6430  establishment,local_government_office,point_of...    9.0
# 6414              establishment,point_of_interest,store   85.0
# 6336      establishment,point_of_interest,shopping_mall   20.0
# 6331                    establishment,point_of_interest   16.0
# 6315                    establishment,point_of_interest   16.0
# 6166  establishment,point_of_interest,school,university   26.0
# 6023                    establishment,point_of_interest   64.0
# 5960    establishment,food,point_of_interest,restaurant   27.0
# 5852  clothing_store,establishment,point_of_interest...   16.0
# 5792         establishment,point_of_interest,university   12.0
# 5731                    establishment,point_of_interest    0.0
# 5717     casino,establishment,lodging,point_of_interest   10.0
# 5625                      establishment,natural_feature  100.0
# 5562         establishment,point_of_interest,university    9.0
# 5463                    establishment,point_of_interest   25.0
# 5384    establishment,food,point_of_interest,restaurant   12.0
# 5272                    establishment,point_of_interest    9.0
# 5257                    establishment,point_of_interest   10.0
# 5183             establishment,health,point_of_interest   14.0
# 5065                      establishment,natural_feature    0.0
# 5087  bar,establishment,food,point_of_interest,resta...   19.0
# 4932  establishment,furniture_store,home_goods_store...    7.0
# 4882                      establishment,natural_feature   90.0
# 4753         establishment,point_of_interest,university   27.0
# 4692           establishment,hospital,point_of_interest   20.0
# 4217             establishment,health,point_of_interest    7.0
# 4172  establishment,home_goods_store,point_of_intere...   14.0
# 4071         establishment,point_of_interest,university   11.0
# 4017         establishment,night_club,point_of_interest    0.0
# 3982  establishment,local_government_office,point_of...   14.0
# 3870             establishment,point_of_interest,school    9.0
# 3780   establishment,insurance_agency,point_of_interest   15.0
# 3770  car_repair,electronics_store,establishment,fur...   19.0
# 3598  doctor,establishment,health,point_of_interest,...   33.0
# 3595         establishment,night_club,point_of_interest   14.0
# 3467         establishment,point_of_interest,university   22.0
# 3214                      establishment,natural_feature  100.0
# 2535                    establishment,point_of_interest   10.0
# 2187                    establishment,point_of_interest   14.0
# 2182  establishment,food,grocery_or_supermarket,poin...    0.0
# 2148             establishment,point_of_interest,school   39.0
# 2140             establishment,health,point_of_interest   17.0
# 2133  establishment,health,point_of_interest,university   36.0
# 1918            establishment,point_of_interest,storage    9.0
# 1462               establishment,food,point_of_interest   24.0
# 1165            establishment,finance,point_of_interest    7.0
# 1163  establishment,local_government_office,point_of...  100.0
# 796              establishment,health,point_of_interest   15.0
# 631   establishment,local_government_office,point_of...    5.0
# 323      casino,establishment,lodging,point_of_interest   10.0

# %% [markdown]
# When N reaches ~50 users average geolocation differ from their account location, it sometimes indicates that users manually entered a location that might be identified by geocoding but does correspond to their actual location. Their account location might the city they are from or that they identify with.

# %%
fix2country={
'AUS':'Australia',
'Almagro':'Argentina',
'Bayonne':'France',
'Carolina':'Spain',
'carolina':'Spain',
'CORDOBA':'Argentina',
'Cordoba':'Argentina', 
'Cordoba ':'Argentina',
'Córdoba':'Argentina',
'Córdoba ':'Argentina',
'córdoba':'Argentina',
'córdoba ':'Argentina',
'cordoba':'Argentina',
'cordoba ':'Argentina',
'Dunedin':'New Zealand',
'Halifax ':'United Kingdom',
'halifax':'United Kingdom',
'KOREA':'South Korea',
'Korea':'South Korea',
'Korea ':'South Korea',
'korea':'South Korea',
'korea ':'South Korea',
'Laguna':'Philippines',
'laguna':'Philippines',
'Lucena':'Spain',
'Merida':'Venezuela',
'Mérida ':'Venezuela',
'Naples':'Italy',
'Toledo ':'Portugal',
'tripoli':'Lebanon',
'Miramar':'Argentina',
'PHL':'Philippines',
'SC':'Brazil',
'SC ':'Brazil',
'sc':'Brazil',
'San isidro':'Argentina',
'St Petersburg':'Russia',
'Woodlands':'Singapore',
'cali':'Mexico',
'cali ':'Mexico',
}

# %%
locations[
(locations['N']>=50)& # Remove 18% 
(locations['status']=='OK')& # Removes 1%
(locations['INTEREST']==0)& # Remove 1%
# (locations['ASCII']==1)& # To check string matching
(locations['CC']!=locations['country_short'])
].sort_values(by='N')[
['LOCATION','CC','N','country_short','country_long','formatted_address','type','MATCH']].tail(50)
# Out:
#                   LOCATION  CC      N country_short   country_long  \
# 1744  All around the world  NG    730            US  United States
# 1710                 Sampa  BR    748            US  United States
# 1669                   INA  ID    762            US  United States
# 1655                   D.F  MX    767            US  United States
# 1618                   LDN  GB    786            US  United States
# 1609                    MG  BR    788            US  United States
# 1583                    Rj  BR    800            US  United States
# 1529              Somerset  GB    828            US  United States
# 1500                    df  MX    842            US  United States
# 1469                napoli  IT    859            US  United States
# 1468                 ADANA  TR    859            US  United States
# 1414                Santos  BR    899            CA         Canada
# 1344                   cwb  BR    940            CA         Canada
# 1298                    sp  BR    974            US  United States
# 1218                 Bahia  BR   1044            US  United States
# 1214       Capital Federal  AR   1049            US  United States
# 1204                  solo  ID   1057            US  United States
# 1171                    RS  BR   1085            US  United States
# 1126                  Cork  IE   1130            US  United States
# 1089             Santander  PT   1161            US  United States
# 1056              Bradford  GB   1190            US  United States
# 1027                 adana  TR   1228            US  United States
# 1018             Yorkshire  GB   1238            US  United States
# 989                     BH  BR   1279            US  United States
# 966               Paradise  ES   1313            US  United States
# 911                   roma  IT   1386            US  United States
# 881                Maracay  VE   1425            US  United States
# 853                   D.F.  MX   1470            US  United States
# 785                 milano  IT   1605            US  United States
# 783                   Solo  ID   1609            US  United States
# 735                 italia  IT   1679            US  United States
# 624              barcelona  ES   2024            US  United States
# 621               Coventry  GB   2028            US  United States
# 588   All Around The World  SA   2145            US  United States
# 580                 Torino  IT   2171            US  United States
# 562               valencia  ES   2227            US  United States
# 533                     DF  MX   2358            US  United States
# 497               Hogwarts  ES   2526            US  United States
# 491                     RJ  BR   2539            US  United States
# 467                 Napoli  IT   2661            US  United States
# 424                     SP  BR   2868            US  United States
# 420                     PH  PH   2893            US  United States
# 374                Rosario  AR   3214            US  United States
# 339               Brighton  FR   3534            US  United States
# 317                  Adana  TR   3746            US  United States
# 229                 Italia  IT   4969            US  United States
# 147                 Milano  IT   7547            US  United States
# 144                   Roma  IT   7650            US  United States
# 130               Valencia  PT   8305            US  United States
# 30               Barcelona  ES  19609            US  United States
#
#                                       formatted_address  \
# 1744           541 W McDermott Dr, Allen, TX 75013, USA
# 1710            2321 W Evans Ave, Denver, CO 80223, USA
# 1669             110 E 13th St, New York, NY 10003, USA
# 1655      2978 State St, South Salt Lake, UT 84115, USA
# 1618  8600 Commodity Cir No 164, Orlando, FL 32819, USA
# 1609           4747 S 102nd E Ave, Tulsa, OK 74146, USA
# 1583             5835 Lamar Ave, Mission, KS 66202, USA
# 1529          2800 W Big Beaver Rd, Troy, MI 48084, USA
# 1500        4119 Culebra Rd, San Antonio, TX 78228, USA
# 1469          1301 N Broadway, Pittsburg, KS 66762, USA
# 1468             1449 E Pine St, Seattle, WA 98122, USA
# 1414  191 Rue Saint-Paul O, Montréal, QC H2Y 1Z5, Ca...
# 1344       8260 Parkhill Dr, Milton, ON L9T 5V7, Canada
# 1298       500 4th St, South Coffeyville, OK 74072, USA
# 1218     998 W Mission Bay Dr, San Diego, CA 92109, USA
# 1214         301 W Main St, Independence, KS 67301, USA
# 1204          408 E 2nd St, Bartlesville, OK 74003, USA
# 1171          412 E Don Tyler Ave, Dewey, OK 74029, USA
# 1126               3295 30th St, Boulder, CO 80301, USA
# 1089                 1601 Elm St, Dallas, TX 75201, USA
# 1056         3700 Washington Rd, Kenosha, WI 53144, USA
# 1027             1449 E Pine St, Seattle, WA 98122, USA
# 1018               4613 E 91st St, Tulsa, OK 74137, USA
# 989                420 9th Ave, New York, NY 10001, USA
# 966                         Independence, KS 67301, USA
# 911            6027 S Sheridan Rd, Tulsa, OK 74145, USA
# 881   15279 N Scottsdale Rd #300, Scottsdale, AZ 852...
# 853       2978 State St, South Salt Lake, UT 84115, USA
# 785   1509 Spring Garden St, Philadelphia, PA 19130,...
# 783           408 E 2nd St, Bartlesville, OK 74003, USA
# 735            2957 Michelson Dr, Irvine, CA 92612, USA
# 624               5160 S Yale Ave, Tulsa, OK 74135, USA
# 621                7 S 1st St, Louisburg, KS 66053, USA
# 588            541 W McDermott Dr, Allen, TX 75013, USA
# 580          1162 Wilmette Ave, Wilmette, IL 60091, USA
# 562           1800 S Kirkman Rd, Orlando, FL 32811, USA
# 533         4119 Culebra Rd, San Antonio, TX 78228, USA
# 497   63 Earthquake Backstage Rd, Orlando, FL 32819,...
# 491              5835 Lamar Ave, Mission, KS 66202, USA
# 467           1301 N Broadway, Pittsburg, KS 66762, USA
# 424        500 4th St, South Coffeyville, OK 74072, USA
# 420   pH Community Garden, 309 S Phoenix Ave, Tulsa,...
# 374           1400 Rosario Rd, Eastsound, WA 98245, USA
# 339    8302 S Brighton Loop Rd, Brighton, UT 84121, USA
# 317              1449 E Pine St, Seattle, WA 98122, USA
# 229            2957 Michelson Dr, Irvine, CA 92612, USA
# 147   1509 Spring Garden St, Philadelphia, PA 19130,...
# 144            6027 S Sheridan Rd, Tulsa, OK 74145, USA
# 130           1800 S Kirkman Rd, Orlando, FL 32811, USA
# 30                5160 S Yale Ave, Tulsa, OK 74135, USA
#
#                                                    type  MATCH
# 1744      establishment,point_of_interest,travel_agency   35.0
# 1710                bar,establishment,point_of_interest   10.0
# 1669  clothing_store,establishment,point_of_interest...   11.0
# 1655             establishment,point_of_interest,school    4.0
# 1618            establishment,finance,point_of_interest    8.0
# 1609   car_dealer,establishment,point_of_interest,store    0.0
# 1583    establishment,food,point_of_interest,restaurant    5.0
# 1529      establishment,point_of_interest,shopping_mall   13.0
# 1500    establishment,food,point_of_interest,restaurant    5.0
# 1469    establishment,food,point_of_interest,restaurant   14.0
# 1468    establishment,food,point_of_interest,restaurant   15.0
# 1414  bar,establishment,food,point_of_interest,resta...   19.0
# 1344                    establishment,point_of_interest    5.0
# 1298                    establishment,point_of_interest    5.0
# 1218            establishment,lodging,point_of_interest   17.0
# 1214        atm,establishment,finance,point_of_interest   22.0
# 1204  bar,establishment,food,point_of_interest,resta...   14.0
# 1171  establishment,general_contractor,point_of_inte...   10.0
# 1126    establishment,food,point_of_interest,restaurant   11.0
# 1089            establishment,finance,point_of_interest   15.0
# 1056             establishment,point_of_interest,school   13.0
# 1027    establishment,food,point_of_interest,restaurant   15.0
# 1018                    establishment,point_of_interest   14.0
# 989   electronics_store,establishment,home_goods_sto...    6.0
# 966     establishment,food,point_of_interest,restaurant   18.0
# 911     establishment,food,point_of_interest,restaurant   10.0
# 881   establishment,general_contractor,point_of_inte...   18.0
# 853              establishment,point_of_interest,school    4.0
# 785   clothing_store,establishment,point_of_interest...   15.0
# 783   bar,establishment,food,point_of_interest,resta...   14.0
# 735   bar,establishment,food,point_of_interest,resta...   14.0
# 624   establishment,point_of_interest,real_estate_ag...   19.0
# 621                     establishment,point_of_interest   10.0
# 588       establishment,point_of_interest,travel_agency   35.0
# 580     establishment,food,point_of_interest,restaurant    6.0
# 562   establishment,point_of_interest,school,university   17.0
# 533     establishment,food,point_of_interest,restaurant    5.0
# 497                     establishment,point_of_interest   18.0
# 491     establishment,food,point_of_interest,restaurant    5.0
# 467     establishment,food,point_of_interest,restaurant   14.0
# 424                     establishment,point_of_interest    5.0
# 420                establishment,park,point_of_interest  100.0
# 374         establishment,lodging,point_of_interest,spa  100.0
# 339   bar,establishment,food,lodging,point_of_intere...  100.0
# 317     establishment,food,point_of_interest,restaurant   15.0
# 229   bar,establishment,food,point_of_interest,resta...   14.0
# 147   clothing_store,establishment,point_of_interest...   15.0
# 144     establishment,food,point_of_interest,restaurant   10.0
# 130   establishment,point_of_interest,school,university   17.0
# 30    establishment,point_of_interest,real_estate_ag...   19.0

# %%
locations[
(locations['N']>=50)& # Remove 18% 
(locations['status']=='OK')& # Removes 1%
(locations['INTEREST']==1)& # Remove 1%
# (locations['ASCII']==1)& # To check string matching
(locations['CC']!=locations['country_short'])&
# (-locations['LOCATION'].apply(lambda x:x.strip().lower() in homonyms))&
# (locations['LOCATION'].apply(lambda x:x in fix2country))
# (-locations['LOCATION'].apply(lambda x:x.strip().lower() in drop))
].sort_values(by='LOCATION')[
['LOCATION','CC','N','country_short','country_long','formatted_address','type','MATCH']]
# Out:
#             LOCATION  CC     N country_short   country_long  \
# 18165            AUS  ID    63            US  United States
# 7414         Almagro  BR   162            US  United States
# 12712        Bayonne  ES    91            US  United States
# 6661         CORDOBA  BR   182            ES          Spain
# 7301        Carolina  PR   165            US  United States
# 486          Cordoba  BR  2562            ES          Spain
# 3990        Cordoba   PY   316            ES          Spain
# 272          Córdoba  BR  4229            ES          Spain
# 2105        Córdoba   BR   598            ES          Spain
# 13253        Dunedin  AU    88            US  United States
# 10949       Halifax   GB   107            CA         Canada
# 1635           KOREA  KR   776           NaN            NaN
# 379            Korea  CN  3202           NaN            NaN
# 7952          Korea   HK   151           NaN            NaN
# 2196          Laguna  VN   578            US  United States
# 7975          Lucena  FR   150            PH    Philippines
# 1139          Merida  CW  1116            MX         Mexico
# 7568         Miramar  BR   159            US  United States
# 9186         Mérida   US   130            MX         Mexico
# 4321          Naples  ES   289            US  United States
# 2430             PHL  KH   528            US  United States
# 848               SC  VE  1473            US  United States
# 16333            SC   VE    70            US  United States
# 14108     San isidro  PY    82            US  United States
# 15038  St Petersburg  PL    77            US  United States
# 12318        Toledo   PT    94            US  United States
# 18837      Woodlands  MY    60            US  United States
# 763             cali  HN  1635            CO       Colombia
# 5189           cali   GT   237            CO       Colombia
# 17985       carolina  PR    63            US  United States
# 784          cordoba  BR  1609            ES          Spain
# 7759        cordoba   AR   154            ES          Spain
# 5293         córdoba  BR   233            ES          Spain
# 17261       córdoba   BR    66            ES          Spain
# 4791         halifax  IE   258            CA         Canada
# 546            korea  CN  2290           NaN            NaN
# 14887         korea   KR    78           NaN            NaN
# 6531          laguna  KH   187            US  United States
# 3528              sc  VE   358            US  United States
# 20829        tripoli  GR    54            LY          Libya
#
#                                        formatted_address  \
# 18165  Austin-Bergstrom International Airport (AUS), ...
# 7414                    Almagro, Danville, VA 24541, USA
# 12712                                   Bayonne, NJ, USA
# 6661                                      Córdoba, Spain
# 7301                                 North Carolina, USA
# 486                                       Córdoba, Spain
# 3990                                      Córdoba, Spain
# 272                                       Córdoba, Spain
# 2105                                      Córdoba, Spain
# 13253                                   Dunedin, FL, USA
# 10949                                Halifax, NS, Canada
# 1635                                               Korea
# 379                                                Korea
# 7952                                               Korea
# 2196                               Laguna Beach, CA, USA
# 7975                    Lucena, 4301 Quezon, Philippines
# 1139                             Mérida, Yucatan, Mexico
# 7568                                    Miramar, FL, USA
# 9186                             Mérida, Yucatan, Mexico
# 4321                                     Naples, FL, USA
# 2430   Philadelphia International Airport (PHL), 8000...
# 848                                  South Carolina, USA
# 16333                                South Carolina, USA
# 14108                     San Ysidro, San Diego, CA, USA
# 15038                            St. Petersburg, FL, USA
# 12318                                    Toledo, OH, USA
# 18837                             The Woodlands, TX, USA
# 763                      Cali, Valle del Cauca, Colombia
# 5189                     Cali, Valle del Cauca, Colombia
# 17985                                North Carolina, USA
# 784                                       Córdoba, Spain
# 7759                                      Córdoba, Spain
# 5293                                      Córdoba, Spain
# 17261                                     Córdoba, Spain
# 4791                                 Halifax, NS, Canada
# 546                                                Korea
# 14887                                              Korea
# 6531                               Laguna Beach, CA, USA
# 3528                                 South Carolina, USA
# 20829                                     Tripoli, Libya
#
#                                                     type  MATCH
# 18165            airport,establishment,point_of_interest  100.0
# 7414                              neighborhood,political  100.0
# 12712                                 locality,political  100.0
# 6661                                  locality,political   63.0
# 7301               administrative_area_level_1,political  100.0
# 486                                   locality,political   63.0
# 3990                                  locality,political   63.0
# 272                                   locality,political  100.0
# 2105                                  locality,political  100.0
# 13253                                 locality,political  100.0
# 10949                                 locality,political  100.0
# 1635                           colloquial_area,political  100.0
# 379                            colloquial_area,political  100.0
# 7952                           colloquial_area,political  100.0
# 2196                                  locality,political  100.0
# 7975                                  locality,political  100.0
# 1139                                  locality,political   46.0
# 7568                                  locality,political  100.0
# 9186                                  locality,political  100.0
# 4321                                  locality,political  100.0
# 2430   airport,establishment,point_of_interest,political  100.0
# 848                administrative_area_level_1,political   10.0
# 16333              administrative_area_level_1,political   10.0
# 14108                             neighborhood,political   61.0
# 15038                                 locality,political  100.0
# 12318                                 locality,political  100.0
# 18837                                 locality,political  100.0
# 763                                   locality,political  100.0
# 5189                                  locality,political  100.0
# 17985              administrative_area_level_1,political  100.0
# 784                                   locality,political   63.0
# 7759                                  locality,political   63.0
# 5293                                  locality,political  100.0
# 17261                                 locality,political  100.0
# 4791                                  locality,political  100.0
# 546                            colloquial_area,political  100.0
# 14887                          colloquial_area,political  100.0
# 6531                                  locality,political  100.0
# 3528               administrative_area_level_1,political   10.0
# 20829                                 locality,political  100.0

# %%
from geopy.geocoders import GoogleV3
google_key = 'AIzaSyBuQhAq-vo_bPmdhhtbd48Ap7TDQ3HqWjE'
geocoder_google = GoogleV3(api_key=google_key)

# %%
geocoder_google.geocode()

# %%
drop = {
'ALL AROUND THE WORLD',
'Disneyland',
'i',
'Latina',
'I',
'Jüpiter',
'hell',
'o',
'Pluto',
'South',
'North West',
'Forks',
'Stratford',
'Transylvania',
'Júpiter',
'na sua',
'Newtown',
}

drop = set([x.strip().strip('.').lower() for x in drop])

# %%
homonyms = {
'abingdon',
'acre',
'airdrie',
'alberton',
'alex',
'alexandria',
'almonte',
'alton',
'amesbury',
'andover',
'ascot',
'ashford',
'atherton',
'aus',
'ayacucho',
'bangor',
'barneveld',
'barrow',
'batavia',
'bedford',
'belem',
'bella vista',
'berga',
'berkshire',
'berwick',
'bexley',
'birmingham',
'boa vista',
'bolivar',
'bolton',
'boulogne',
'bourne',
'braintree',
'brentford',
'brentwood',
'buckley',
'canton',
'carlisle',
'cartagena',
'chacabuco',
'chelmsford',
'cheltenham',
'chester',
'chesterfield',
'city bell',
'claypole',
'coalville',
'colon',
'darlington',
'deal',
'denbigh',
'derby',
'dolores',
'dover',
'dudley',
'dundalk',
'dundee',
'durango',
'durham',
'elgin',
'ely',
'emsworth',
'everton',
'evesham',
'exeter',
'falmouth',
'formosa',
'freeport',
'gloucester',
'grantham',
'guernica',
'haddington',
'hampshire',
'harlingen',
'harwich',
'hastings',
'haverhill',
'hawarden',
'hayes',
'hertford',
'hillsborough',
'hinckley',
'horsham',
'huntingdon',
'id',
'ind',
'ireland',
'isleworth',
'jersey',
'junin',
'junín',
'k-town',
'kenilworth',
'kent',
'kettering',
'kilmarnock',
'la calera',
'la florida',
'ladysmith',
'lancaster',
'las flores',
'las piedras',
'leominster',
'letterkenny',
'lewes',
'lincoln',
'liverpool',
'livingston',
'los angles',
'ludlow',
'madriz',
'maipu',
'maipú',
'malden',
'malvern',
'mansfield',
'margate',
'markham',
'martinez',
'matlock',
'medway',
'mexique',
'middlesex',
'middleton',
'midlands',
'montrose',
'moreno',
'mt',
'my',
'natal',
'nederland',
'new brunswick',
'newbury',
'newmarket',
'newport',
'norfolk',
'northampton',
'norwich',
'oakville',
'ocaña',
'oil city',
'oviedo',
'paisley',
'panama city',
'panamá city',
'parana',
'paraná',
'perthshire',
'pickering',
'plymouth',
'portsmouth',
'potsdam',
'preston',
'prince george',
'providencia',
'queen city of the south',
'ranelagh',
'renfrew',
'richmond hill',
'ringwood',
'rio claro',
'ripon',
'royston',
'rugby',
'rutland',
'salem',
'salinas',
'salisbury',
'san bernardo',
'san carlos',
'san cristobal',
'san cristóbal',
'san felipe',
'san fernando',
'san juan',
'san lorenzo',
'san luis',
'san martin',
'san martín',
'san miguel',
'san nicolas',
'san nicolás',
'san pablo city',
'san pedro',
'san rafael',
'sandy',
'santa ana',
'santa cruz',
'santa fe',
'santa maria',
'santa rosa',
'santarém',
'sarandi',
'sby',
'seaford',
'shrewsbury',
'sjc',
'smyrna',
'sonora',
'southport',
'sps',
'st-petersburg',
'st. petersburg',
'st.-petersburg',
'st.petersburg',
'stafford',
'stamford',
'suffolk',
'sussex',
'sutton',
'são vicente',
'tambun',
'tangamandapio',
'tanjung',
'taunton',
'tipton',
'tiverton',
'truro',
'uxbridge',
'valparaiso',
'van',
'villa elisa',
'villarrica',
'vitoria',
'wakefield',
'wallingford',
'wallington',
'wantage',
'ware',
'warminster',
'warwick',
'waterford',
'welling',
'westbury',
'westland',
'weymouth',
'whitehaven',
'wickford',
'worcester',
'york'}


homonyms = set([x.strip().strip('.').lower() for x in homonyms])

# %%
cols = [
'LOCATION',
'N',
# 'CC',
# 'formatted_address',
# 'status',
# 'type',
'country_long',
'country_short',
'locality_long',
'locality_short',
'sublocality_long',
'sublocality_short',
'neighborhood_long',
'neighborhood_short',
'administrative_area_level_1_long',
'administrative_area_level_1_short',
'administrative_area_level_2_long',
'administrative_area_level_2_short',
'administrative_area_level_3_long',
'administrative_area_level_3_short',
'administrative_area_level_4_long',
'administrative_area_level_4_short',
# 'MATCH',
# 'ASCII',
# 'INTEREST',
]
