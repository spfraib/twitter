# %% [markdown]
# Reference: https://developers.google.com/places/web-service/search

# %%
import pandas as pd
import requests
import logging
import time
import re
import string
from timeit import default_timer as timer
from glob import glob
from shapely.geometry import Polygon, Point

# %% [markdown]
# # Prepare Data

# %%
print('Import:')
start = timer()

files = glob('../data/decahose/parsed/locations/places.parquet/*.snappy.parquet')

pois = pd.DataFrame()
for file in files:
    pois = pd.concat([pois,pd.read_parquet(file)])

end = timer()
print('Computing Time:', round(end - start), 'sec')
# Out:
# Import:
# Computing Time: 84 sec

# %%
print('# Twitter Places',pois.shape[0])

# Select POIs
pois = pois[(pois['place_type']=='poi')].copy()
print('# Twitter Pois',pois.shape[0])

# Select POIs in Mexico
pois = pois[(pois['country_code']=='MX')].copy()
print('# Twitter Pois in Mexico',pois.shape[0])

pois.dropna(inplace=True)

# Geometry
pois['coordinates'] = pois['coordinates'].apply(lambda x:Polygon([list(y) for y in x[0]]))

# Collapse Area to Single Point
if not pois['coordinates'].apply(lambda x:x.area).sum():
    pois['coordinates'] = pois['coordinates'].apply(lambda x:x.centroid)
else:
    print('Check Geometry')
    
pois['longitude'] = pois['coordinates'].apply(lambda x:x.x)
pois['latitude'] = pois['coordinates'].apply(lambda x:x.y)

pois = pois.sort_values(by='n_obs',ascending=False).reset_index(drop=True)

pois.drop(['type','country','country_code','name','place_type','url','coordinates'],1,errors='ignore',inplace=True)
# Out:
# # Twitter Places 1744496
# # Twitter Pois 1441346
# # Twitter Pois in Mexico 12379

# %%
pois.head()
# Out:
#                  id                                          full_name  n_obs  \
# 0  0bf28c06951c907b  Aeropuerto Internacional de Monterrey Mariano ...   1375
# 1  900805b30f2ccef2                                    222, Cuauhtémoc   1355
# 2  cc98b151af9c4561                Plaza Satelite, Naucalpan de Juárez   1305
# 3  f9010d61e3b7b306                              PASEO ACOXPA, Tlalpan   1081
# 4  838fb18ac7d9ddbc  Aeropuerto Internacional de Guadalajara., Tlaj...   1070
#
#     longitude   latitude
# 0 -100.115861  25.776234
# 1  -99.161676  19.428425
# 2  -99.235817  19.509424
# 3  -99.137509  19.297972
# 4 -103.300773  20.525788

# %% [markdown]
# # API QUERY

# %%
# input_    = "Chilis Reforma 222, Cuauhtémoc"
inputtype = "textquery"
fields    = "formatted_address,geometry,icon,name,permanently_closed,photos,place_id,plus_code,types,opening_hours,price_level,rating,user_ratings_total"
radius    = 500
# latitude  = 19.429077
# longitude = -99.161886
api_key   = "AIzaSyDvbEv0t36wKwy5pvVq6r62xvyhG13qGFA"

# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30

output_file = '../data/decahose/parsed/locations/pois-twitter-mx-geocodes-google-place-api.pkl'

# %%
logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)

# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# %%
def google_place_search(input_, inputtype, fields, radius, latitude, longitude, api_key):
    
    # Set up place url
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"+\
    "input="+input_+"&inputtype="+inputtype+"&fields="+fields+"&"+\
    "locationbias=circle:"+str(radius)+"@"+str(latitude)+","+str(longitude)+"&"+\
    "key="+api_key

    # Ping google for the reuslts:
    results = requests.get(url)
    
    # Results will be in JSON format - convert to dict using requests functionality
    return results.json()

# %%
# Create a list to hold results
results = []

# Go through each place in turn
for idx, poi in pois.iterrows():
    
    # While the place geocoding is not finished:
    geocoded = False
    
    while geocoded is not True:
        
        # Geocode the place with google
        try:
            
            geocode_result = google_place_search(poi['full_name'], 
                                                 inputtype, 
                                                 fields, 
                                                 radius, 
                                                 poi['latitude'], 
                                                 poi['longitude'], 
                                                 api_key)
            
            geocode_result['id'] = poi['id']
            
        except Exception as e:
            
            logger.exception(e)
            
            logger.error("Major error with {}".format(poi['full_name']))
            
            logger.error("Skipping!")
            
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            
            logger.info("Hit Query Limit! Backing off for a bit.")
            
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            
            geocoded = False
            
        else:
            
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                
                logger.warning("Error geocoding {}: {}".format(poi['full_name'], geocode_result['status']))
                
            logger.debug("Geocoded: {}: {}".format(poi['full_name'], geocode_result['status']))
            
            results.append(geocode_result)           
            
            geocoded = True

    # Print status every 100 places
    if len(results) % 100 == 0:
        
        logger.info("Completed {} of {} places".format(len(results), len(pois)))
            
    # Every 1000 places, save progress to file (in case of a failure)
    if len(results) % 1000 == 0:
        
        pd.DataFrame(results).to_pickle("{}_bak".format(output_file))

# All done
logger.info("Finished geocoding all places")
# Out:
# Geocoded: Aeropuerto Internacional de Monterrey Mariano Escobedo, Apodaca: OK
# Geocoded: 222, Cuauhtémoc: OK
# Geocoded: Plaza Satelite, Naucalpan de Juárez: OK
# Geocoded: PASEO ACOXPA, Tlalpan: OK
# Geocoded: Aeropuerto Internacional de Guadalajara., Tlajomulco de Zúñiga: OK
# Geocoded: Universidad La Salle. Campus Benjamin Franklin, Cuauhtémoc: OK
# Geocoded: Plaza Carso, Miguel Hidalgo: OK
# Geocoded: Buenavista, Cuauhtémoc: OK
# Geocoded: Plaza Altabrisa, Mérida: OK
# Geocoded: aeropuerto internacional de México , Venustiano Carranza: OK
# Geocoded: Gran Plaza, Mérida: OK
# Geocoded: Coyoacán, México: OK
# Geocoded: Siemens Sucursal Mty, Santa Catarina: OK
# Geocoded: Chilis Reforma 222, Cuauhtémoc: OK
# Geocoded: Facultad De Contaduria Y Administracion, Coyoacán: OK
# Geocoded: UPIICSA, Iztacalco: OK
# Geocoded: Plaza Altabrisa , Centro: OK
# Geocoded: gran plaza, Zapopan: OK
# Geocoded: Cinemex, Benito Juárez: OK
# Geocoded: Cinemex Universidad, Benito Juárez: OK
# Geocoded: Parque Lindavista, Gustavo A. Madero: OK
# Geocoded: Cinemark, Cuauhtémoc: OK
# Geocoded: Cinemex Parque Delta, Benito Juárez: OK
# Geocoded: Cinépolis Diana, Cuauhtémoc: OK
# Geocoded: UNITEC Cuitláhuac, Azcapotzalco: OK
# Geocoded: Satélite, Naucalpan de Juárez: OK
# Geocoded: Cancún, Benito Juárez: OK
# Geocoded: Universidad del Valle de México Campus Tlalpan, Tlalpan: OK
# Geocoded: chillis Parque Tezontle , Iztapalapa: OK
# Geocoded: Facultad De Derecho, Coyoacán: OK
# Geocoded: Domino´s Pizza Chapultepec, Guadalajara: OK
# Geocoded: Starbucks Coffe, Cuauhtémoc: OK
# Geocoded: BULLDOG CAFÃ‰, Benito Juárez: OK
# Geocoded: Pabellón Polanco, Miguel Hidalgo: OK
# Geocoded: Centro Histórico, Cuauhtémoc: OK
# Geocoded: Torre Mayor, Cuauhtémoc: OK
# Geocoded: arena mexico, Azcapotzalco: OK
# Geocoded: Plaza Metropoli Patriotismo, Benito Juárez: OK
# Geocoded: central del norte, Gustavo A. Madero: OK
# Geocoded: Facultad De Ingenieria, Coyoacán: OK
# Geocoded: Starbucks Coffe, Benito Juárez: OK
# Geocoded: Cinépolis Angelopolis, Puebla: OK
# Geocoded: Upaep, Puebla: OK
# Geocoded: Monumento a la Revolución, Cuauhtémoc: OK
# Geocoded: Loreto, Álvaro Obregón: OK
# Geocoded: FES ACATLAN, Naucalpan de Juárez: OK
# Geocoded: STARBUCKS PARQUE LINDAVISTA, Gustavo A. Madero: OK
# Geocoded: Colonia Condesa, Cuauhtémoc: OK
# Geocoded: Centro comercial Angelopolis, Puebla: OK
# Geocoded: Big Blue Bar, Naucalpan de Juárez: OK
# Geocoded: Plaza Américas, Boca del Río: OK
# Geocoded: Estadio Omnilife, Zapopan: OK
# Geocoded: Escuela Superior De Computo Ipn, Gustavo A. Madero: OK
# Geocoded: Terminal B, Apodaca: OK
# Geocoded: San Pablo, Cuauhtémoc: OK
# Geocoded: Starbucks Coffe, Benito Juárez: OK
# Geocoded: plaza fiesta anauhac, San Nicolás de los Garza: OK
# Geocoded: Auditorio Nacional, Miguel Hidalgo: OK
# Geocoded: Facultad De Quimica, Coyoacán: OK
# Geocoded: parque mexico, Cuauhtémoc: OK
# Geocoded: La Casa de Toño, Benito Juárez: OK
# Geocoded: Argos, Tlalnepantla de Baz: OK
# Geocoded: Banamex Parques Polanco, Miguel Hidalgo: OK
# Geocoded: Torre Pemex, Miguel Hidalgo: OK
# Geocoded: hooters insurgentes, Álvaro Obregón: OK
# Geocoded: glorieta de insurgentes, Cuauhtémoc: OK
# Geocoded: Costco Tec de Monterrey, Tlalpan: OK
# Geocoded: Universidad Anahuac, Huixquilucan: OK
# Error geocoding Scotiabank Inverlat La Isla Shopping Village Cancun, Benito Juárez: ZERO_RESULTS
# Geocoded: Scotiabank Inverlat La Isla Shopping Village Cancun, Benito Juárez: ZERO_RESULTS
# Error geocoding JWT, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: JWT, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Balcones de la Huasteca, Monterrey: OK
# Geocoded: Starbucks Coffe, Cuauhtémoc: OK
# Geocoded: six flags, Tlalpan: OK
# Geocoded: UVM (Villahermosa), Centro: OK
# Geocoded: Starbucks Coffee Eugenia, Benito Juárez: OK
# Geocoded: Salón Pata Negra, Cuauhtémoc: OK
# Geocoded: Cinemex, Benito Juárez: OK
# Geocoded: Facultad de Artes Visuales, Monterrey: OK
# Geocoded: Facultad De Ciencias, Coyoacán: OK
# Geocoded: BBVA Bancomer León Plaza Mayor, León: OK
# Geocoded: aeropuerto internacional de Mérida, Mérida: OK
# Geocoded: Universidad Modelo, Mérida: OK
# Geocoded: Terminal C, Apodaca: OK
# Geocoded: mundo e stt, Tlalnepantla de Baz: OK
# Geocoded: Plaza Pabellon Del Valle, Benito Juárez: OK
# Geocoded: Veracruz airport, Veracruz: OK
# Geocoded: Metropolitan, Cuauhtémoc: OK
# Geocoded: Zócalo , Puebla: OK
# Geocoded: Museo Nacional de Antropología, Miguel Hidalgo: OK
# Geocoded: Televisa Chapultepec, Cuauhtémoc: OK
# Geocoded: Facultad De Arquitectura, Coyoacán: OK
# Geocoded: Sport City, Álvaro Obregón: OK
# Geocoded: Complejo Cultural Universitario, Puebla: OK
# Geocoded: Cinépolis, Atizapán de Zaragoza: OK
# Geocoded: unid, Mérida: OK
# Geocoded: Grupo Expansión, Distrito Federal: OK
# Geocoded: Galerías Guadalajara, Zapopan: OK
# Geocoded: Aeropuerto Internacional de Puerto Vallarta, Puerto Vallarta: OK
# Geocoded: Camino Real, Miguel Hidalgo: OK
# Geocoded: Wings Factory Condesa, Cuauhtémoc: OK
# Completed 100 of 12376 places
# Geocoded: paseo interlomas, Huixquilucan: OK
# Geocoded: Plaza Fiesta San Agustín , San Pedro Garza García: OK
# Geocoded: Fuente de la Diana Cazadora, Cuauhtémoc: OK
# Geocoded: Torre Latinoamericana, Cuauhtémoc: OK
# Geocoded: Cinépolis, Monterrey: OK
# Geocoded: Senado de la República, Cuauhtémoc: OK
# Geocoded: La Minerva, Guadalajara: OK
# Geocoded: Starbucks Rodriguez, Hermosillo: OK
# Geocoded: Centro de Tlalpan, Tlalpan: OK
# Geocoded: Aeropuerto Internacionacional de los Cabos, Los Cabos: OK
# Geocoded: TV Azteca Ajusco, Tlalpan: OK
# Geocoded: Starbucks, Mérida: OK
# Geocoded: Pericoapa, Tlalpan: OK
# Geocoded: Liverpool, Naucalpan de Juárez: OK
# Geocoded: Plaza de Toros México, Benito Juárez: OK
# Geocoded: Museo Nacional de Arte, Cuauhtémoc: OK
# Geocoded: Taqueria El Califa, Cuauhtémoc: OK
# Geocoded: El Hijo del Cuervo, Coyoacán: OK
# Geocoded: La Casa de Toño, Cuauhtémoc: OK
# Geocoded: Pabellón Cuauhtémoc, Cuauhtémoc: OK
# Geocoded: Sanborns Plaza Cuicuilco, Tlalpan: OK
# Geocoded: Instituto Tecnológico de Villahermosa (ITVH), Centro: OK
# Geocoded: Starbucks Coffe, Miguel Hidalgo: OK
# Geocoded: Pf Chang´s, Cuauhtémoc: OK
# Geocoded: tv azteca, Tlalpan: OK
# Geocoded: cinepolis plaza central, Iztapalapa: OK
# Geocoded: Hospital Angeles Metropolitano, Cuauhtémoc: OK
# Geocoded: Hospital General De Mexico, Cuauhtémoc: OK
# Geocoded: Plaza Galerias, Miguel Hidalgo: OK
# Geocoded: UAM-I, Iztapalapa: OK
# Geocoded: Starbucks, Gustavo A. Madero: OK
# Geocoded: aeropuerto de Villahermosa , Centro: OK
# Geocoded: Hospital Español, Miguel Hidalgo: OK
# Geocoded: Aeropuerto Internacional de Tampico, Tampico: OK
# Geocoded: Radio UDEM 90.5FM, San Pedro Garza García: OK
# Geocoded: Cinépolis, Monterrey: OK
# Geocoded: GNP Corporativo, Coyoacán: OK
# Geocoded: Cuspide Sky Mall, Naucalpan de Juárez: OK
# Geocoded: Chilis Lindavista, Gustavo A. Madero: OK
# Geocoded: Cinépolis Miramontes Vip, Coyoacán: OK
# Geocoded: Starbucks Coffe, Cuauhtémoc: OK
# Geocoded: Las Alitas Villahermosa, Centro: OK
# Geocoded: Facultad De Filosofia Y Letras, Coyoacán: OK
# Geocoded: Hospital Integral Playa del Carmen, Solidaridad: OK
# Geocoded: El Palacio de Hierro, Naucalpan de Juárez: OK
# Geocoded: Gran Café de La Parroquia Malecón, Veracruz: OK
# Geocoded: Estela de luz, Cuauhtémoc: OK
# Geocoded: Expo Guadalajara, Guadalajara: OK
# Geocoded: Esime Zacatenco, Gustavo A. Madero: OK
# Geocoded: Hooters Coapa, Tlalpan: OK
# Geocoded: Estadio Cuauhtémoc, Puebla: OK
# Geocoded: ESCOM, Gustavo A. Madero: OK
# Geocoded: Esime Culhuacan Ipn, Coyoacán: OK
# Geocoded: Parque de la Marimba, Tuxtla Gutiérrez: OK
# Geocoded: garibaldi, Cuauhtémoc: OK
# Geocoded: Central De Autobuses De Leon, León: OK
# Geocoded: Starbucks Coffe, Cuauhtémoc: OK
# Geocoded: 100 montaditos, Cuauhtémoc: OK
# Geocoded: Centro Universitario de Ciencias Económico Administrativas, Zapopan: OK
# Geocoded: Estadio Nemesio Diez, Toluca, México: OK
# Geocoded: Chilis Universidad, Benito Juárez: OK
# Geocoded: CUSur, Zapotlán el Grande: OK
# Geocoded: Zentralia, Colima: OK
# Geocoded: Plaza Cumbres, Monterrey: OK
# Geocoded: St Regis, Cuauhtémoc: OK
# Geocoded: Museo soumaya, Miguel Hidalgo: OK
# Error geocoding PwC, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: PwC, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Universidad Marista De Mérida, Mérida: OK
# Geocoded: big bola galerias metepec, Metepec: OK
# Geocoded: Galerias Saltillo, Saltillo: OK
# Geocoded: Metro Chabacano, Cuauhtémoc: OK
# Geocoded: Escuela Nacional De Artes Plasticas, Xochimilco: OK
# Geocoded: Starbucks Coffe, Cuauhtémoc: OK
# Geocoded: Universidad Juárez Autónoma de Tabasco, Centro: OK
# Geocoded: Starbucks Coffe, Miguel Hidalgo: OK
# Geocoded: Cinepolis plaza morelia , Morelia: OK
# Geocoded: Nearsoft, Hermosillo: OK
# Geocoded: Cafebrería El Péndulo, Cuauhtémoc: OK
# Geocoded: Jardines de la Higuera, Puerto Vallarta: OK
# Geocoded: Central de Autobuses de Aguascalientes, Aguascalientes: OK
# Geocoded: cinepolis Oaxaca , Oaxaca de Juárez: OK
# Geocoded: CENTRO de diseño cine y television, Miguel Hidalgo: OK
# Geocoded: Galerias Vallarta, Puerto Vallarta: OK
# Geocoded: Parque México, Cuauhtémoc: OK
# Geocoded: parque aleman, Mérida: OK
# Geocoded: Sierra Madre Brewing Co, Monterrey: OK
# Geocoded: starbucks condesa, Cuauhtémoc: OK
# Geocoded: Papalote, Miguel Hidalgo: OK
# Geocoded: chilanguita, Miguel Hidalgo: OK
# Geocoded: Bosque de Tlalpan, Tlalpan: OK
# Geocoded: smart fit, Miguel Hidalgo: OK
# Geocoded: Plaza Fiesta, Mérida: OK
# Geocoded: la coyoacana, Coyoacán: OK
# Geocoded: universidad de la salle bajío, Guanajuato: OK
# Geocoded: Instituto Tecnológico de Veracruz, Veracruz: OK
# Geocoded: T G I Friday's, Tampico: OK
# Geocoded: microsoft, Álvaro Obregón: OK
# Geocoded: Fuente de los Cibeles, Cuauhtémoc: OK
# Geocoded: Cinemark Polanco, Miguel Hidalgo: OK
# Geocoded: Central de autobuses Monterrey , Monterrey: OK
# Completed 200 of 12376 places
# Geocoded: Estadio La Corregidora, Querétaro: OK
# Geocoded: fabricas de francia plaza del sol, Zapopan: OK
# Geocoded: Universidad del Valle de México Campus Roma, Cuauhtémoc: OK
# Geocoded: El Palacio de Hierro, Cuauhtémoc: OK
# Geocoded: Terminal A, Apodaca: OK
# Geocoded: Starbucks Coffe, Coyoacán: OK
# Geocoded: Cintermex, Monterrey: OK
# Geocoded: Starbucks Coffe: OK
# Geocoded: Upiita Ipn, Gustavo A. Madero: OK
# Error geocoding La casa más grande con plantitas, Coyoacán: ZERO_RESULTS
# Geocoded: La casa más grande con plantitas, Coyoacán: ZERO_RESULTS
# Geocoded: coyoacan, Coyoacán: OK
# Geocoded: Café El Jarocho - Taxqueña, Coyoacán: OK
# Geocoded: Pabellon Altavista, Álvaro Obregón: OK
# Geocoded: universidad de la comunicacion, Cuauhtémoc: OK
# Error geocoding cuervo salon, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: cuervo salon, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Starbucks Coffee Plaza Boka, Boca del Río: OK
# Geocoded: Galerias Pachuca, Pachuca de Soto: OK
# Geocoded: Starbucks, Tuxtla Gutiérrez: OK
# Geocoded: Frutos Prohibidos y Otros Placeres, Cuauhtémoc: OK
# Geocoded: Liverpool Restaurante, Centro: OK
# Geocoded: Bolsa Mexicana de Valores, Cuauhtémoc: OK
# Geocoded: Plaza Patria, Zapopan: OK
# Geocoded: Starbucks Coffe, Guadalajara: OK
# Geocoded: Cinemex Real, Cuauhtémoc: OK
# Geocoded: Costco, Naucalpan de Juárez: OK
# Geocoded: Universum Museo De Ciencias, Coyoacán: OK
# Geocoded: Café de Tacuba Centro, Cuauhtémoc: OK
# Geocoded: Alberca Olimpica Frnacisco Marquez, Benito Juárez: OK
# Geocoded: Celtics Pub Irlandés, Cuauhtémoc: OK
# Geocoded: Liverpool, Puebla: OK
# Geocoded: Country sport Gym, Zapopan: OK
# Geocoded: Oasis Cancun, Benito Juárez: OK
# Geocoded: La Gran Plaza Cancun, Benito Juárez: OK
# Geocoded: Azcapotzalco, Azcapotzalco: OK
# Geocoded: Starbucks Coffe, Coyoacán: OK
# Geocoded: San Juan, Cuauhtémoc: OK
# Geocoded: Universidad del Valle de Mexico Campus San Angel, Álvaro Obregón: OK
# Geocoded: HSBC 610 Gran Sur, Coyoacán: OK
# Geocoded: Starbucks Plaza La Hacienda, Tlalpan: OK
# Geocoded: Starbucks Coffe, Monterrey: OK
# Geocoded: la polar cantina, Cuauhtémoc: OK
# Geocoded: Centro Cultural Universitario, Coyoacán: OK
# Geocoded: Starbucks, San Andrés Cholula: OK
# Geocoded: starbucks , Coyoacán: OK
# Geocoded: Universidad Del Noreste, Tampico: OK
# Geocoded: Facultad de Psicología, Coyoacán: OK
# Geocoded: ADO vilahermosa, Centro: OK
# Geocoded: cinepolis patio coatzacoalcos, Coatzacoalcos: OK
# Geocoded: starbucks, Mérida: OK
# Geocoded: aeropuerto chihuahua, Chihuahua: OK
# Geocoded: California Pizza Kitchen, Miguel Hidalgo: OK
# Geocoded: Chilis Antara, Miguel Hidalgo: OK
# Geocoded: chapultepec, Miguel Hidalgo: OK
# Geocoded: Hilton Mexico City Reforma, Cuauhtémoc: OK
# Geocoded: Hospital Star Medica, Mérida: OK
# Geocoded: citadel, San Nicolás de los Garza: OK
# Geocoded: Congreso del Estado de Aguascalientes, Aguascalientes: OK
# Geocoded: Arroyo, Tlalpan: OK
# Geocoded: Mercado De Jamaica, Venustiano Carranza: OK
# Geocoded: Facultad de Ingeniería Química, Puebla: OK
# Error geocoding Milenio, Cuauhtémoc: ZERO_RESULTS
# Geocoded: Milenio, Cuauhtémoc: ZERO_RESULTS
# Geocoded: Cinépolis VIP, Monterrey: OK
# Geocoded: galerias, Zapopan: OK
# Geocoded: Centro Comercial Interlomas, Huixquilucan: OK
# Geocoded: Facultad de Matemáticas UADY, Mérida: OK
# Geocoded: Facultad De Veterinaria, Coyoacán: OK
# Geocoded: Chilis Parque Lindavista, Gustavo A. Madero: OK
# Geocoded: Cinépolis Centromax, León: OK
# Geocoded: Museo Franz Mayer, Cuauhtémoc: OK
# Geocoded: esiqie, Gustavo A. Madero: OK
# Geocoded: FCA, Mérida: OK
# Geocoded: Edificio B UNITEC Campus Sur, Coyoacán: OK
# Geocoded: Starbucks Bonampak, Benito Juárez: OK
# Geocoded: Restaurante Centro Libanés, Álvaro Obregón: OK
# Geocoded: Xalapa, centro,plaza lerdo, Xalapa: OK
# Geocoded: lindavista, Gustavo A. Madero: OK
# Geocoded: Centro Comercial Paseo Durango, Durango: OK
# Geocoded: universidad ISEC, Benito Juárez: OK
# Error geocoding La casa más grande con plantitas. , Coyoacán: ZERO_RESULTS
# Geocoded: La casa más grande con plantitas. , Coyoacán: ZERO_RESULTS
# Error geocoding king's pup, Cuauhtémoc: ZERO_RESULTS
# Geocoded: king's pup, Cuauhtémoc: ZERO_RESULTS
# Geocoded: Cinepolis VIP, Benito Juárez: OK
# Geocoded: Universidad Panamericana Campus Guadalajara, Jalisco: OK
# Geocoded: Cinépolis La Noria, Puebla: OK
# Geocoded: Cinépolis, León: OK
# Geocoded: Casa, Monterrey: OK
# Geocoded: Starbucks Coffe, Miguel Hidalgo: OK
# Geocoded: Banorte Plaza Crystal, Puebla: OK
# Geocoded: starbucks huexotitla, Puebla: OK
# Geocoded: starbucks, Tlalpan: OK
# Geocoded: aeropuerto Hermosillo , Hermosillo: OK
# Geocoded: Barranca Del Muerto, Álvaro Obregón: OK
# Error geocoding barezzito.... auuuch, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: barezzito.... auuuch, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Hotel María Isabel Sheraton S A C V, Cuauhtémoc: OK
# Geocoded: Universidad Del Claustro De Sor Juana, Cuauhtémoc: OK
# Geocoded: Oxxo, Monterrey: OK
# Geocoded: Memoria y Tolerancia, Cuauhtémoc: OK
# Geocoded: Plaza Fiesta Anáhuac, San Nicolás de los Garza: OK
# Geocoded: guadalajara, Guadalajara: OK
# Geocoded: Starbucks Coffe, Miguel Hidalgo: OK
# Geocoded: Cinemex Centro Comercial Paseo de San Francisco, Puebla: OK
# Completed 300 of 12376 places
# Geocoded: big yellow, Álvaro Obregón: OK
# Geocoded: starbucks san jeronimo, La Magdalena Contreras: OK
# Geocoded: La Vida Argentina, Benito Juárez: OK
# Geocoded: FCAS, Xalapa: OK
# Geocoded: El Tizoncito, Cuauhtémoc: OK
# Geocoded: IBM Guadalajara, El Salto: OK
# Geocoded: Parque Alameda, Cuauhtémoc: OK
# Geocoded: Torres de Satélite, Naucalpan de Juárez: OK
# Geocoded: Rancho Digital, Condesa, Distrito Federal, Cuauhtémoc: OK
# Geocoded: Interlomas, Huixquilucan: OK
# Geocoded: Centro Universitario Incarnate word, Benito Juárez: OK
# Geocoded: starbucks, Centro: OK
# Geocoded: Puerto Madero, Miguel Hidalgo: OK
# Geocoded: Starbucks, Colima, Colima: OK
# Geocoded: Zentralia, Coacalco de Berriozábal: OK
# Geocoded: Bbva Bancomer Superama Narvarte, Benito Juárez: OK
# Geocoded: Hooters Bar, Naucalpan de Juárez: OK
# Geocoded: Instituto Campechano, Campeche: OK
# Geocoded: Starbucks Universidad, San Nicolás de los Garza: OK
# Geocoded: Zócalo Capitalino de la Ciudad de México, Cuauhtémoc: OK
# Geocoded: Freedom Insurgentes, Benito Juárez: OK
# Geocoded: mercado san juan de dios, Guadalajara: OK
# Geocoded: BUAP FACULTAD DE MEDICINA, Puebla: OK
# Geocoded: Aeropuerto Internacional de Acapulco Juan N. Alvárez, Acapulco de Juárez: OK
# Geocoded: Starbucks Coffee, Plaza Mía., Metepec: OK
# Geocoded: La Casa De lola, Monterrey: OK
# Error geocoding guilt, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: guilt, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Hospital Regional Adolfo Lopez Mateos, Coyoacán: OK
# Geocoded: Buenavista, Cuauhtémoc: OK
# Geocoded: Museo De Cera, Cuauhtémoc: OK
# Geocoded: Instituto Tecnológico de Ciudad Madero (ITCM), Ciudad Madero: OK
# Geocoded: Café El Popular de Don Luis, Cuauhtémoc: OK
# Geocoded: Sport City, Cuautitlán Izcalli: OK
# Geocoded: Santa Maria la Ribera, Cuauhtémoc: OK
# Geocoded: San Hipolito, Cuauhtémoc: OK
# Geocoded: auditorio, Miguel Hidalgo: OK
# Geocoded: centro cultural españa, Cuauhtémoc: OK
# Geocoded: Fiesta americana centro, Mérida: OK
# Geocoded: Starbucks Coffe, Atizapán de Zaragoza: OK
# Geocoded: Centro Médico ABC Santa Fe, Cuajimalpa de Morelos: OK
# Geocoded: Universidad Las Americas, Cuauhtémoc: OK
# Geocoded: Restaurante Los Panchos, Miguel Hidalgo: OK
# Geocoded: Universidad Tecnologica de Nezahualcoyotl, Nezahualcóyotl: OK
# Geocoded: Universidad Tecmilenio, Monterrey: OK
# Geocoded: Suprema Corte De Justicia, Cuauhtémoc: OK
# Geocoded: biblioteca central CU, Coyoacán: OK
# Geocoded: Starbucks Coffe, Venustiano Carranza: OK
# Geocoded: Cinépolis San Luis, San Luis Potosí: OK
# Geocoded: HEB Gonzalitos, Monterrey: OK
# Geocoded: Papa Bills, Benito Juárez: OK
# Geocoded: Plaza Valle, Orizaba: OK
# Geocoded: Friday's, Benito Juárez: OK
# Geocoded: Sala de Juntas Cinemex Santa Fe, Cuajimalpa de Morelos: OK
# Geocoded: expiatorio, Guadalajara: OK
# Geocoded: Teatro Degollado, Guadalajara: OK
# Geocoded: Cinemark Pericoapa, Tlalpan: OK
# Geocoded: Restaurante Bennigans, Boca del Río: OK
# Geocoded: living, Cuauhtémoc: OK
# Geocoded: Starbucks, Mega Plaza, Cuautitlán Izcalli, Cuautitlán Izcalli: OK
# Geocoded: La Vid Argentina Condesa, Cuauhtémoc: OK
# Geocoded: tequisquiapan, Tequisquiapan: OK
# Geocoded: Escuela Superior De Economia, Miguel Hidalgo: OK
# Geocoded: Parque de los Colomos, Guadalajara: OK
# Geocoded: Cinépolis, Morelia: OK
# Error geocoding El Gallinero, Monterrey: ZERO_RESULTS
# Geocoded: El Gallinero, Monterrey: ZERO_RESULTS
# Geocoded: Aeropuerto Internacional Licenciado Adolfo López Mateos, Toluca: OK
# Geocoded: Laboratorios UPAEP , Puebla: OK
# Geocoded: La Pagoda, Cuauhtémoc: OK
# Geocoded: La Cantinita, Xalapa: OK
# Geocoded: UNIVDEP, Benito Juárez: OK
# Geocoded: barezzito, Querétaro: OK
# Geocoded: Plaza Cuicuilco, Tlalpan: OK
# Geocoded: wings army , Centro: OK
# Geocoded: Universidad del valle de mexico, Tampico: OK
# Geocoded: CECC Pedregal!!!, Álvaro Obregón: OK
# Geocoded: Universidad de Xalapa, Xalapa, Xalapa: OK
# Geocoded: ITAM, Álvaro Obregón: OK
# Geocoded: Cafebrería El Péndulo, Miguel Hidalgo: OK
# Geocoded: Cinemex Palacio Chino, Cuauhtémoc: OK
# Geocoded: Gran Hotel Ciudad de México, Cuauhtémoc: OK
# Geocoded: Applebee's Linda Vista, Gustavo A. Madero: OK
# Geocoded: Plaza Cibeles, Irapuato: OK
# Geocoded: CEN del PRI, Cuauhtémoc: OK
# Geocoded: Palacio De Hierro, Puebla: OK
# Geocoded: Plaza Silla, Monterrey: OK
# Geocoded: Cruz Roja Mexicana, Miguel Hidalgo: OK
# Geocoded: starbucks , Coyoacán: OK
# Geocoded: Covadonga, Cuauhtémoc: OK
# Geocoded: Airport Campeche , Campeche: OK
# Geocoded: Mercado De Abastos, Guadalajara: OK
# Geocoded: CCH Sur, Álvaro Obregón: OK
# Geocoded: ITESO, Tlaquepaque: OK
# Geocoded: starbucks calle amberes, Cuauhtémoc: OK
# Geocoded: Tuxtla Gutierrez, Chiapas, Tuxtla Gutiérrez: OK
# Geocoded: Perisur, Coyoacán: OK
# Geocoded: Sanborns, Benito Juárez: OK
# Geocoded: Universidad del Valle de México Campus Puebla, San Andrés Cholula: OK
# Geocoded: el borrego viudo, Miguel Hidalgo: OK
# Geocoded: Liverpool Monterrey Centro, Monterrey: OK
# Geocoded: Operadora Fonda Garufa, Cuauhtémoc: OK
# Completed 400 of 12376 places
# Geocoded: Chilli's Galerías Cuernavaca, Cuernavaca: OK
# Geocoded: BBVA Bancomer Chedraui Coapa, Coyoacán: OK
# Geocoded: Infonavit, Álvaro Obregón: OK
# Geocoded: Cinemex Constituyentes, Querétaro., Corregidora: OK
# Geocoded: Liverpool, San Pedro Garza García: OK
# Geocoded: Ciudad Universitaria, Coyoacán: OK
# Geocoded: Esfm, Gustavo A. Madero: OK
# Geocoded: AXA Seguros, Tlalpan: OK
# Geocoded: poliforum siqueiros, Benito Juárez: OK
# Geocoded: Museo de Arte Moderno, Miguel Hidalgo: OK
# Geocoded: Facultad de Medicina, Monterrey: OK
# Geocoded: Barbaresco, Guadalajara: OK
# Geocoded: Fes Zaragoza Campus I, Iztapalapa: OK
# Geocoded: Hostal de Los Quesos, Benito Juárez: OK
# Geocoded: Instituto Nacional De Pediatria, Coyoacán: OK
# Geocoded: Sushi Roll, Benito Juárez: OK
# Geocoded: Plaza Grande, Mérida: OK
# Geocoded: El Parian, Tlaquepaque: OK
# Geocoded: Universidad del Valle de Puebla, Puebla: OK
# Geocoded: American Eagle Outfiters, Coyoacán: OK
# Geocoded: Los Remedios, Benito Juárez: OK
# Geocoded: Creperia de La Taix, Cuauhtémoc: OK
# Geocoded: Los Bisquets De Obregon, Miguel Hidalgo: OK
# Geocoded: Beer Factory, Tlalpan: OK
# Geocoded: Central de Autobuses, Irapuato: OK
# Geocoded: Rufino Tamayo, Miguel Hidalgo: OK
# Geocoded: Operadora Mama Rumba, Cuauhtémoc: OK
# Geocoded: El Universal, Cuauhtémoc: OK
# Geocoded: Tacubaya, Miguel Hidalgo: OK
# Geocoded: Instituto Tecnologico de Estudios Superiores De Monterrey Campus Toluca, Toluca: OK
# Geocoded: Viveros de Coyoacan, Coyoacán: OK
# Geocoded: Hospital Angeles del Carmen, Guadalajara: OK
# Geocoded: atlixco, Atlixco: OK
# Geocoded: Cuernavaca, Morelos: OK
# Geocoded: Starbucks Camelinas, Morelia: OK
# Geocoded: La Ostra, Cuauhtémoc: OK
# Geocoded: Chrysler, Cuajimalpa de Morelos: OK
# Geocoded: Sanborns, Cuauhtémoc: OK
# Geocoded: Aeropuerto Internacional de la Ciudad de Aguascalientes Terán Peredo, Aguascalientes: OK
# Geocoded: starbucks , Benito Juárez: OK
# Geocoded: Fraccionamiento Santa Elena, Panotla: OK
# Geocoded: chilanguita, Álvaro Obregón: OK
# Geocoded: Comite Olimpico Mexicano, Miguel Hidalgo: OK
# Geocoded: Polyforum Siqueiros, Benito Juárez: OK
# Geocoded: Mercado De La Merced, Venustiano Carranza: OK
# Geocoded: Starbucks Coffe, Cd Nezahualcóyotl, México, Nezahualcóyotl: OK
# Geocoded: teatro diana, Guadalajara: OK
# Geocoded: Santro Pez, Guadalajara: OK
# Geocoded: Palacio de Hierro Paseo Acoxpa, Tlalpan: OK
# Geocoded: Camino Real Aeropuerto, Venustiano Carranza: OK
# Geocoded: @caffenio oficinas centrales, Hermosillo: OK
# Geocoded: Restaurante San Angel Inn, Álvaro Obregón: OK
# Geocoded: Facultad de Ciencias Biologicas UANL, San Nicolás de los Garza: OK
# Geocoded: las alitas, Monterrey: OK
# Geocoded: Cinépolis Salagua, Manzanillo: OK
# Error geocoding Alan's Home, Cuajimalpa de Morelos: ZERO_RESULTS
# Geocoded: Alan's Home, Cuajimalpa de Morelos: ZERO_RESULTS
# Geocoded: FCPyS, Coyoacán: OK
# Geocoded: Falafelito, Cuauhtémoc: OK
# Geocoded: Cinemark Real Monterrey, Monterrey: OK
# Geocoded: Centro De Cultura Casa Lamm, Cuauhtémoc: OK
# Geocoded: Alameda del Sur, Coyoacán: OK
# Geocoded: Los Pinos, Miguel Hidalgo: OK
# Geocoded: Instituto Patria, Mérida: OK
# Geocoded: Corporativo Telefonica México, Cuajimalpa de Morelos: OK
# Geocoded: plaza lindavista, Gustavo A. Madero: OK
# Geocoded: ihop pericoapa, Tlalpan: OK
# Error geocoding Abraham's Condo, Monterrey: ZERO_RESULTS
# Geocoded: Abraham's Condo, Monterrey: ZERO_RESULTS
# Geocoded: Palacio De Justicia Federal, Venustiano Carranza: OK
# Geocoded: Starbucks Campestre, León: OK
# Geocoded: Sanborns Hermanos, Cuauhtémoc: OK
# Geocoded: Museo Interactivo De Economia, Cuauhtémoc: OK
# Geocoded: camino real, Álvaro Obregón: OK
# Geocoded: cinepolis deportiva, Centro: OK
# Geocoded: Paseo Tec, Monterrey: OK
# Geocoded: Escuela Superior De Medicina, Miguel Hidalgo: OK
# Geocoded: Palacio Municipal De Naucalpan, Naucalpan de Juárez: OK
# Geocoded: Marriott, Cuauhtémoc: OK
# Geocoded: sushi roll san jeronimo, La Magdalena Contreras: OK
# Geocoded: Mercado 28, Benito Juárez: OK
# Geocoded: Cinemex Ticoman, Gustavo A. Madero: OK
# Geocoded: Hospital Central, San Luis Potosí: OK
# Geocoded: Parroquia De San Agustin, Miguel Hidalgo: OK
# Geocoded: Santo Coyote, Guadalajara: OK
# Geocoded: Aeropuerto Internacional de San Luis Potosí, San Luis Potosí: OK
# Geocoded: Delegacion Venustiano Carranza, Venustiano Carranza: OK
# Geocoded: parque tabasco, Centro: OK
# Geocoded: Softtek, San Pedro Garza García: OK
# Geocoded: Karne Garibaldi, Guadalajara: OK
# Geocoded: Facultad de Psicologia, Mérida: OK
# Geocoded: corporativo santa fe 505, Cuajimalpa de Morelos: OK
# Geocoded: Clínica Mérica, Mérida: OK
# Geocoded: Cinépolis Plaza Museo, Xalapa: OK
# Geocoded: UAMI, Iztapalapa: OK
# Geocoded: sport city, Puebla: OK
# Geocoded: Televisa Radio, Coyoacán: OK
# Geocoded: Facultad de informatica, Xalapa: OK
# Geocoded: Sanborns Parque Delta, Benito Juárez: OK
# Geocoded: Universidad Anáhuac Puebla, San Andrés Cholula: OK
# Geocoded: Madero, Cuauhtémoc: OK
# Error geocoding HOLLYWOOD , Sinaloa: ZERO_RESULTS
# Geocoded: HOLLYWOOD , Sinaloa: ZERO_RESULTS
# Completed 500 of 12376 places
# Geocoded: El Palacio de Hierro, Cuauhtémoc: OK
# Geocoded: Plaza De La Rosa, Cuauhtémoc: OK
# Geocoded: hija de los apaches, Cuauhtémoc: OK
# Geocoded: Los Remedios, Miguel Hidalgo: OK
# Geocoded: Plaza Universidad, Benito Juárez: OK
# Geocoded: Delegacion Benito Juarez, Benito Juárez: OK
# Geocoded: Tgi Fridays, Tlalpan: OK
# Geocoded: Monumento a Cristobal Colón, Cuauhtémoc: OK
# Geocoded: Starbucks Cafe, Metepec: OK
# Geocoded: Plaza de Armas, Cuernavaca: OK
# Geocoded: Taco Express, Tlalpan: OK
# Geocoded: Galerias Laguna, Torreón: OK
# Geocoded: bellinis, Benito Juárez: OK
# Geocoded: Friday's, Naucalpan de Juárez: OK
# Geocoded: Mi casa , Campeche: OK
# Geocoded: Cinepolis, San Luis Potosí: OK
# Geocoded: Gran Café de La Parroquia Boca del Rio, Boca del Río: OK
# Geocoded: Irapuato, Irapuato: OK
# Geocoded: Televisa, Álvaro Obregón: OK
# Geocoded: Sam's, Benito Juárez: OK
# Geocoded: tren suburbano lecheria, Cuautitlán Izcalli: OK
# Geocoded: Restaurante Los Giros, Boca del Río: OK
# Geocoded: universidad victoria, Iztacalco: OK
# Geocoded: El Bajio Parque Delta, Benito Juárez: OK
# Geocoded: Grand Plaza Toluca, Toluca: OK
# Geocoded: Restaurante Cambalache, Benito Juárez: OK
# Geocoded: ADO Terminal Veracruz, Veracruz: OK
# Geocoded: MetroSport, Hermosillo: OK
# Geocoded: Puerto Vallarta, Puerto Vallarta: OK
# Geocoded: Bisteces, Benito Juárez: OK
# Geocoded: Starbucks Coffegomez Morin, San Pedro Garza García: OK
# Geocoded: Club de Golf Valle Escondido, Atizapán de Zaragoza: OK
# Geocoded: parque de la alamos, Benito Juárez: OK
# Geocoded: universidad, Campeche: OK
# Geocoded: Meliá Mexico Reforma, Cuauhtémoc: OK
# Geocoded: GRUPO CYB, Benito Juárez: OK
# Geocoded: Regina 18, Cuauhtémoc: OK
# Geocoded: jalpa de mendez, Jalpa de Méndez: OK
# Geocoded: Vips, Cuauhtémoc: OK
# Geocoded: Ocean Drive, Álvaro Obregón: OK
# Geocoded:  plaza torres lindavista, Gustavo A. Madero: OK
# Geocoded: metro xola, Benito Juárez: OK
# Geocoded: Cinemex Polanco, Miguel Hidalgo: OK
# Geocoded: Starbucks Coffe, Álvaro Obregón: OK
# Geocoded: starbuck pedregal, Tlalpan: OK
# Geocoded: Universidad Politécnica de San Luis Potosí , San Luis Potosí: OK
# Geocoded: Bbva Bancomer Centro Comercial Santa Fe, Cuajimalpa de Morelos: OK
# Geocoded: Sushi Roll, Cuauhtémoc: OK
# Geocoded: caav, Guadalajara: OK
# Geocoded: UPEMOR, Jiutepec: OK
# Geocoded: El Charco De Las Ranas, Álvaro Obregón: OK
# Geocoded: hospital civil , Guadalajara: OK
# Geocoded: Chilis Plaza Pabellón, Zapopan: OK
# Geocoded: costco, Boca del Río: OK
# Geocoded: Escuela Nacional de Trabajo Social, UNAM, Coyoacán: OK
# Geocoded: sport city coacalco, Coacalco de Berriozábal: OK
# Geocoded: coco grill, Boca del Río: OK
# Geocoded: Privalia, Miguel Hidalgo: OK
# Geocoded: big silver, Miguel Hidalgo: OK
# Geocoded: Las Americas, Ecatepec de Morelos: OK
# Geocoded: Banorte HEB Cumbres, Monterrey: OK
# Geocoded: Narvarte, Benito Juárez: OK
# Geocoded: Cancun, Benito Juárez: OK
# Geocoded: Coparmex Jalisco, Guadalajara: OK
# Geocoded: Hotel Alameda Centro Histórico, Morelia: OK
# Geocoded: Burger King Copilco, Coyoacán: OK
# Geocoded: Starbucks Coffee, León: OK
# Geocoded: Centro Universitario Cultural, Coyoacán: OK
# Geocoded: Centro Asturiano de México AC, Miguel Hidalgo: OK
# Geocoded: Conaculta, Cuauhtémoc: OK
# Geocoded: Stracom Mediavest, Miguel Hidalgo: OK
# Geocoded: Clínica Hospital Cemain, Tampico: OK
# Geocoded: Banobras, Álvaro Obregón: OK
# Geocoded: Universidad del Valle de México, Tlaquepaque: OK
# Geocoded: EGADE Business School, San Pedro Garza García: OK
# Geocoded: Metlife México , Miguel Hidalgo: OK
# Geocoded: Alergia Pediátrica Hospital Ángeles Villahermosa, Centro: OK
# Geocoded: Barrio 18, Xochimilco: OK
# Error geocoding secretaria de educación, Centro: ZERO_RESULTS
# Geocoded: secretaria de educación, Centro: ZERO_RESULTS
# Geocoded: Chai de las Rosas, Zapopan: OK
# Geocoded: Sedesol, Cuauhtémoc: OK
# Geocoded: Old Jacks , Zapopan: OK
# Geocoded: FAUADY, Mérida: OK
# Geocoded: malecon, Veracruz: OK
# Geocoded: Las Alitas Cumbres, Monterrey: OK
# Geocoded: GASOLINERA LAS PALMAS, Tampico: OK
# Geocoded: Secretaria de Relaciones Exteriores, Cuauhtémoc: OK
# Geocoded: Kurai, Tampico: OK
# Geocoded: La Piazza, Cuauhtémoc: OK
# Geocoded: Banamex, Oaxaca de Juárez: OK
# Geocoded: Banamex Plaza San Pedro, Puebla: OK
# Geocoded: forum del mundo imperial, Acapulco de Juárez: OK
# Geocoded: Mr Kellis, Cuauhtémoc: OK
# Geocoded: palacio de hierro, Puebla: OK
# Geocoded: Cinemex, Cuautitlán Izcalli: OK
# Geocoded: Ivoire, Miguel Hidalgo: OK
# Geocoded: Chichen Itza, Yucatan, Tinum: OK
# Geocoded: Los Sifones, Coyoacán: OK
# Geocoded: Mr Sushi, Miguel Hidalgo: OK
# Geocoded: Cielito Querido, Cuauhtémoc: OK
# Completed 600 of 12376 places
# Geocoded: Papi Fun Bar, Cuauhtémoc: OK
# Geocoded: Instituto Nacional De Rehabilitaci+N, Tlalpan: OK
# Geocoded: Starbucks Coffe, Irapuato: OK
# Geocoded: La Posada Del Sancho, Miguel Hidalgo: OK
# Geocoded: uta bar, Cuauhtémoc: OK
# Geocoded: Vida Abundante Morelia, Morelia: OK
# Geocoded: Palacio Municipal, Aguascalientes: OK
# Geocoded: progreso yucatan, Progreso: OK
# Geocoded: Costillas Al Carbón, Azcapotzalco: OK
# Geocoded: Caldos Dleo, Miguel Hidalgo: OK
# Geocoded: Capone Club Sociale, Álvaro Obregón: OK
# Geocoded: Cuadro Santa Mónica, Tlalnepantla de Baz: OK
# Geocoded: villa las fuentes, Centro: OK
# Geocoded: Universidad de Colima, Colima: OK
# Error geocoding I LOVE CEVICHE NADER #80, Benito Juárez: REQUEST_DENIED
# Geocoded: I LOVE CEVICHE NADER #80, Benito Juárez: REQUEST_DENIED
# Geocoded: Las Memorables, Benito Juárez: OK
# Geocoded: Plaza De La Tecnologia, Monterrey: OK
# Error geocoding Chop Caf+, Guadalajara: ZERO_RESULTS
# Geocoded: Chop Caf+, Guadalajara: ZERO_RESULTS
# Geocoded: cassava roots, Coyoacán: OK
# Geocoded: cinemex linda vista, Guadalupe: OK
# Geocoded: Mi gusto es, Benito Juárez: OK
# Geocoded: El Under, Cuauhtémoc: OK
# Geocoded: Starbucks, Miguel Hidalgo: OK
# Geocoded: hookah, Cuauhtémoc: OK
# Geocoded: Liverpool, León: OK
# Geocoded: La Casa Del Pastor, Miguel Hidalgo: OK
# Geocoded: Delegacion Iztacalco, Iztacalco: OK
# Geocoded: Chilis San Jerónimo, La Magdalena Contreras: OK
# Geocoded: chiapa de corzo, Chiapa de Corzo: OK
# Geocoded: Sport Training, Puebla: OK
# Geocoded: Sears, Naucalpan de Juárez: OK
# Geocoded: facultad de ciencias politicas y sociales , Toluca: OK
# Geocoded: Papa Bills, Cuauhtémoc: OK
# Geocoded: tecnologico de merida, Mérida: OK
# Geocoded: cielito querido reforma, Cuauhtémoc: OK
# Geocoded: Sanborns, Cuauhtémoc: OK
# Geocoded: Chilis Manacar, Benito Juárez: OK
# Geocoded: loiero's gym, Benito Juárez: OK
# Geocoded: centro de idiomas, Boca del Río: OK
# Geocoded: Rinc=N Argentino, Miguel Hidalgo: OK
# Geocoded: starbucks ibero ... , Álvaro Obregón: OK
# Geocoded: Starbucks Coffe Las Animas, Puebla: OK
# Geocoded: El Gran Pastor, Monterrey: OK
# Geocoded: Une, Guadalajara: OK
# Geocoded: konsushi, Mérida: OK
# Geocoded: Ángel de la Independencia, Cuauhtémoc: OK
# Geocoded: Torre del Caballito, Cuauhtémoc: OK
# Geocoded: Los Primos, Benito Juárez: OK
# Geocoded: Museo De La Ciudad De Mexico, Cuauhtémoc: OK
# Geocoded: Sirloin Stockade Super Plaza Miramontes, Coyoacán: OK
# Geocoded: Plaza De Los Fundadores, San Luis Potosí: OK
# Geocoded: Sirloin Stockade, Metepec: OK
# Geocoded: Sanborns, Boca del Río: OK
# Geocoded: Vips, Álvaro Obregón: OK
# Geocoded: kidzania cuicuilco, Tlalpan: OK
# Geocoded: Vips, Benito Juárez: OK
# Geocoded: El Tarro de Coyoacán, Coyoacán: OK
# Geocoded: Fisher, Puebla: OK
# Geocoded: Polanco, Miguel Hidalgo: OK
# Geocoded: Starbucks Fiesta Americana, Cuauhtémoc: OK
# Geocoded: San Juan Bautista Tuxtepec, Oaxaca, Oaxaca: OK
# Error geocoding Bieberlandia🌎, Sinaloa: ZERO_RESULTS
# Geocoded: Bieberlandia🌎, Sinaloa: ZERO_RESULTS
# Geocoded: uaq, Querétaro: OK
# Geocoded: teatro julio prieto, Benito Juárez: OK
# Geocoded: Centro Magno, Guadalajara: OK
# Geocoded: Mercado De Artesanias, Cuauhtémoc: OK
# Geocoded: Universidad Tecnologia de Jalisco, Guadalajara: OK
# Geocoded: Aeropuerto Internacional de Querétaro, Colón: OK
# Geocoded: Wings Factory, Miguel Hidalgo: OK
# Geocoded: Cinépolis Azcapotzalco, Azcapotzalco: OK
# Geocoded: club América , Coyoacán: OK
# Geocoded: universidad latina, Coyoacán: OK
# Geocoded: Parque las Americas, Benito Juárez: OK
# Geocoded: perisur, Coyoacán: OK
# Geocoded: Starbucks Coffe, Cuauhtémoc: OK
# Geocoded: Plaza de las 3 Culturas, Cuauhtémoc: OK
# Geocoded: WINGSTOP, Lindavista, Gustavo A. Madero: OK
# Geocoded: Starbucks Coffe, Monterrey: OK
# Geocoded: Cafetería Moheli, Coyoacán: OK
# Geocoded: UVM (Tuxtla), Tuxtla Gutiérrez: OK
# Error geocoding la chucha perez, Metepec: ZERO_RESULTS
# Geocoded: la chucha perez, Metepec: ZERO_RESULTS
# Geocoded: Italiannis, Benito Juárez: OK
# Geocoded: Carl's Jr, Monterrey: OK
# Geocoded: Estadio Azul, Benito Juárez: OK
# Geocoded: Mi Casa, Monterrey: OK
# Geocoded: La Quebreada, Acapulco de Juárez: OK
# Geocoded: Westhill University, Cuajimalpa de Morelos: OK
# Geocoded: Instituto Tecnológico de Celaya campus II, Celaya: OK
# Geocoded: Tv Azteca, Puebla: OK
# Geocoded: uam cuajimalpa, Miguel Hidalgo: OK
# Geocoded: Sanborns Hermanos, Benito Juárez: OK
# Geocoded: facultad de arquitectura , San Nicolás de los Garza: OK
# Geocoded: UJAT, Centro: OK
# Geocoded: Hotel Safi Royal Luxury Valle, San Pedro Garza García: OK
# Geocoded: Centro Comercial Villa Asunsion, Aguascalientes: OK
# Geocoded: Instituto Tecnologico de Orizaba, Orizaba: OK
# Geocoded: Contramar, Cuauhtémoc: OK
# Geocoded: FCA-UACH, Chihuahua: OK
# Geocoded: Unitec Campus Sur, Iztapalapa: OK
# Geocoded: Coco Bongo Playa del Carmen, Solidaridad: OK
# Completed 700 of 12376 places
# Geocoded: Camino Real, San Pedro Garza García: OK
# Geocoded: Chilis Izcalli, Cuautitlán Izcalli: OK
# Geocoded: UAM Xochimilco, Coyoacán: OK
# Geocoded: Italiannis, Naucalpan de Juárez: OK
# Geocoded: iShop Universidad, Benito Juárez: OK
# Geocoded: Uvm Chapultepec, Miguel Hidalgo: OK
# Geocoded: UABCS, La Paz: OK
# Geocoded: Universidad Regiomontana, Monterrey: OK
# Geocoded: The Cross, Naucalpan de Juárez: OK
# Geocoded: Tony Roma's, Miguel Hidalgo: OK
# Geocoded: UAM AZC, Azcapotzalco: OK
# Geocoded: Gelattina, Monterrey: OK
# Geocoded: Sirloin Stockade, San Nicolás de los Garza: OK
# Geocoded: Museo De Las Momias, Guanajuato: OK
# Geocoded: Fuentes del Valle, Tultitlán: OK
# Geocoded: Instituto Tecnológico de Sonora - Campus Náinari, Cajeme: OK
# Geocoded: Starbucks Coffee, Zapopan: OK
# Geocoded: feria puebla, Puebla: OK
# Geocoded: Carl's jr, Monterrey: OK
# Geocoded: Deportivo 18 De Marzo, Gustavo A. Madero: OK
# Geocoded: Sushi Itto, Cuauhtémoc: OK
# Geocoded: Bauhaus, Puebla: OK
# Geocoded: El Callejón de Los Milagros, Tampico: OK
# Geocoded: CIC, Gustavo A. Madero: OK
# Geocoded: INEGI, Aguascalientes: OK
# Geocoded: Chilis Coapa, Tlalpan: OK
# Geocoded: Monumento a Cuauhtémoc, Cuauhtémoc: OK
# Geocoded: CINEMARK Parque Tezontle, Iztacalco: OK
# Geocoded: Instituto Tecnologico de Minatitlan, Minatitlán: OK
# Geocoded: Monumental Jardin De Tequisquiapan, San Luis Potosí: OK
# Geocoded: Hooters, Benito Juárez: OK
# Geocoded: Cinépolis Plaza Cristal, Puebla: OK
# Geocoded: Hospital Real San José, Zapopan: OK
# Geocoded: Vips, Benito Juárez: OK
# Geocoded: McDonald's, Cuajimalpa de Morelos: OK
# Geocoded: Condesa , Cuauhtémoc: OK
# Error geocoding BBVA Bancomer Módulo Express Volcán, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: BBVA Bancomer Módulo Express Volcán, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Interalia, Miguel Hidalgo: OK
# Geocoded: Burger King Macroplaza Tijuana, Tijuana: OK
# Geocoded: Galerías Celaya , Celaya: OK
# Geocoded: UDLAP, San Andrés Cholula: OK
# Geocoded: Liverpool, Tuxtla Gutiérrez: OK
# Geocoded: Frank And Steins, San Pedro Garza García: OK
# Geocoded: la celestina, Coyoacán: OK
# Geocoded: Museo De San Carlos, Cuauhtémoc: OK
# Geocoded: Secretaria De Vialidad Y Transporte, Guadalajara: OK
# Geocoded: Universidad Autonoma Metropolitana Azcap, Azcapotzalco: OK
# Geocoded: Fieta Americana Grand Chapultepec, Miguel Hidalgo: OK
# Geocoded: El Colegio de México, A.C., Tlalpan: OK
# Geocoded: Starbucks Galerías planta baja!, Zapopan: OK
# Geocoded: Sanborns, Benito Juárez: OK
# Geocoded: Hospital Angeles del Pedregal, La Magdalena Contreras: OK
# Geocoded: Universidad Iberoamericana León , León: OK
# Geocoded: Ford Motor Company, Álvaro Obregón: OK
# Geocoded: Restaurante Liverpool, Puerto Vallarta: OK
# Geocoded: El Parian, Aguascalientes: OK
# Geocoded: la concordia , Naucalpan de Juárez: OK
# Geocoded: Estadio Victoria, Aguascalientes: OK
# Geocoded: Restaurante Los Farolitos Jardines, Boca del Río: OK
# Geocoded: De Cortes, Cuauhtémoc: OK
# Error geocoding Operadora Vips, Cuauhtémoc: ZERO_RESULTS
# Geocoded: Operadora Vips, Cuauhtémoc: ZERO_RESULTS
# Geocoded: plaza sendero, Hermosillo: OK
# Geocoded: Plaza del Carmen, San Luis Potosí: OK
# Geocoded: Holiday Inn Parque Fundidora, Monterrey: OK
# Geocoded: Los Campadres Arabes, Tlalnepantla de Baz: OK
# Geocoded: Toks, Tlalpan: OK
# Geocoded: Villa las Fuentes, Monterrey: OK
# Geocoded: La Chata de Guadalajara, Guadalajara: OK
# Geocoded: SERVICIO MIRAMONTES, S A, Iztapalapa: OK
# Geocoded: Centro Médico Dalinde, Cuauhtémoc: OK
# Geocoded: Starbucks Coffe, Álvaro Obregón: OK
# Geocoded: Santa Teresa, Álvaro Obregón: OK
# Error geocoding Loteria Nacional Edificio Jalisco, Cuauhtémoc: ZERO_RESULTS
# Geocoded: Loteria Nacional Edificio Jalisco, Cuauhtémoc: ZERO_RESULTS
# Geocoded: AFIRME 7 Eleven Barrio Antiguo, Monterrey: OK
# Geocoded: Isla San Marcos Parque Tematico, Aguascalientes: OK
# Geocoded: CCH Oriente, Iztapalapa: OK
# Geocoded: Colegio De Vizcaina, Cuauhtémoc: OK
# Geocoded: La Matera, Guadalajara: OK
# Geocoded: Starbucks, Benito Juárez: OK
# Geocoded: Starbucks Coffe, Zapopan: OK
# Geocoded: Reforma, Cuauhtémoc: OK
# Geocoded: Taqueria Los Parados, Benito Juárez: OK
# Geocoded: McDonald's, Benito Juárez: OK
# Geocoded: Burguer King, Cuauhtémoc: OK
# Geocoded: Starbucks Mazarik, Puebla: OK
# Geocoded: Universidad Iest, Tampico: OK
# Geocoded: Museo Diego Rivera, Coyoacán: OK
# Geocoded: Starbucks Coffe, San Pedro Garza García: OK
# Geocoded: Hospital del Sureste, Centro: OK
# Geocoded: Sevilla Palace, Cuauhtémoc: OK
# Geocoded: Restaurante El Matisse, Cuauhtémoc: OK
# Geocoded: Expreso, Hermosillo: OK
# Geocoded: City shops, Tlalnepantla de Baz: OK
# Geocoded: las alitas, Monterrey: OK
# Geocoded: Mega Comercial Mexicana, Benito Juárez: OK
# Geocoded: Centro Hospitalario Sanatorio Durango, Cuauhtémoc: OK
# Geocoded: Garabatos, Benito Juárez: OK
# Geocoded: Torre Alta, San Pedro Garza García: OK
# Geocoded: Terminal Estrella De Oro, Acapulco de Juárez: OK
# Geocoded: Galerias Reforma, Cuajimalpa de Morelos: OK
# Completed 800 of 12376 places
# Geocoded: Metro Normal, Miguel Hidalgo: OK
# Geocoded: Reforma Plus, Miguel Hidalgo: OK
# Error geocoding les sentiere's, Cuauhtémoc: ZERO_RESULTS
# Geocoded: les sentiere's, Cuauhtémoc: ZERO_RESULTS
# Geocoded: Vips Gutemberg, Miguel Hidalgo: OK
# Geocoded: Teatro Blanquita, Cuauhtémoc: OK
# Geocoded: Universidad Simon Bolivar, Benito Juárez: OK
# Geocoded: starbucks, Miguel Hidalgo: OK
# Geocoded: McDonald's, Monterrey: OK
# Geocoded: Los sopes de la nueve, Iztapalapa: OK
# Geocoded: Querétaro 2000, Querétaro: OK
# Geocoded: KIO Networks, Distrito Federal: OK
# Geocoded: las aguilas, Zapopan: OK
# Geocoded: Las Alitas Grijalva, San Pedro Garza García: OK
# Geocoded: Central de Autobuses, Tampico: OK
# Geocoded: Parrilla Danesa, Gustavo A. Madero: OK
# Geocoded: Tribunal Superior de Justicia del Dustrito Federal, Cuauhtémoc: OK
# Geocoded: El Rey del Suadero, Miguel Hidalgo: OK
# Geocoded: El Deposito de Chapultepec, Guadalajara: OK
# Geocoded: El Parian, Puebla: OK
# Geocoded: Palacio de Justicia, Aguascalientes: OK
# Geocoded: Torre Medica Dalinde, Cuauhtémoc: OK
# Geocoded: Fisher's, Miguel Hidalgo: OK
# Geocoded: Arco Triunfal de la Calzada de los Héroes, León: OK
# Geocoded: AV. CHAPULTEPEC 464 METRO  SEVILLA, Cuauhtémoc: OK
# Geocoded: Cinépolis La Paz, La Paz: OK
# Geocoded: Palmas, Miguel Hidalgo: OK
# Geocoded: Buffalitas, Tampico: OK
# Error geocoding la patrona, Cuauhtémoc: ZERO_RESULTS
# Geocoded: la patrona, Cuauhtémoc: ZERO_RESULTS
# Geocoded: fuddruckers, Centro: OK
# Geocoded: EMI MUSIC, México, Cuauhtémoc: OK
# Geocoded: El Gaucho, Monterrey: OK
# Geocoded: UPIICSA, Iztacalco: OK
# Geocoded: Restaurante Toks, Benito Juárez: OK
# Geocoded: Universidad Latina de América, Morelia: OK
# Geocoded: UNID, Saltillo: OK
# Geocoded: Martinez De La Torre, Cuauhtémoc: OK
# Geocoded: UAC, Campeche: OK
# Geocoded: Chazz San Jerónimo, La Magdalena Contreras: OK
# Geocoded: 100 % Natural, Benito Juárez: OK
# Geocoded: Burguer King, Campeche: OK
# Geocoded: Cinépolis Bucareli, Cuauhtémoc: OK
# Geocoded: Universidad Panamericana, Benito Juárez: OK
# Geocoded: Kleins, Miguel Hidalgo: OK
# Geocoded: Sanborns, Miguel Hidalgo: OK
# Geocoded: Radisson Hotel Flamingos Ciudad de México, Benito Juárez: OK
# Geocoded: Burger King, Benito Juárez: OK
# Geocoded: la barca, Monterrey: OK
# Geocoded: Gran museo del mundo maya, Mérida: OK
# Geocoded: Bol montevideo, Gustavo A. Madero: OK
# Geocoded: Universidad Insurgentes, Gustavo A. Madero: OK
# Geocoded: Banamex, Benito Juárez: OK
# Geocoded: Portika polanco, Miguel Hidalgo: OK
# Geocoded: L'Oréal , Benito Juárez: OK
# Geocoded: Fiesta Inn Periferico Sur, Coyoacán: OK
# Geocoded: Papa Bill S, Coyoacán: OK
# Geocoded: Parqe Morelos, Tuxtla Gutiérrez: OK
# Error geocoding Bondy, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Bondy, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: centro universitario mexico, Benito Juárez: OK
# Geocoded: Revolucion, Benito Juárez: OK
# Geocoded: UNIVA, Zapopan: OK
# Geocoded: Escuela De Idiomas, Guanajuato: OK
# Geocoded: doctors hospital, Monterrey: OK
# Geocoded: Vips, Cuauhtémoc: OK
# Geocoded: Spuntino, Miguel Hidalgo: OK
# Geocoded: Mcmullen's Irish Pubs, Monterrey: OK
# Geocoded: Outback, Puerto Vallarta: OK
# Geocoded: Lomas Estrella, Iztapalapa: OK
# Geocoded: Moshi Moshi, Álvaro Obregón: OK
# Geocoded: ITESM Campus León, León: OK
# Geocoded: Carl's Jr, Monterrey: OK
# Geocoded: Xtabay, Mérida: OK
# Geocoded: Copel Mercado Corona, Guadalajara: OK
# Geocoded: Plaza Cordilleras, Zapopan: OK
# Geocoded: La Choperia Metepec, Metepec: OK
# Geocoded: plaza las americas, Mérida: OK
# Geocoded: Restaurante Vittorio, Puebla: OK
# Geocoded: Starbucks, Fuentes de Satélite, Naucalpan de Juárez: OK
# Geocoded: Auditorio Luis Elizondo, Monterrey: OK
# Geocoded: Geneve, Cuauhtémoc: OK
# Geocoded: zavi pizza, Mérida: OK
# Error geocoding HΛCKprod Studios, Tlalnepantla de Baz: ZERO_RESULTS
# Geocoded: HΛCKprod Studios, Tlalnepantla de Baz: ZERO_RESULTS
# Geocoded: Fast Food La Canasta, Naucalpan de Juárez: OK
# Geocoded: Costco cumbres, Monterrey: OK
# Geocoded: Universidad Latina, Cuauhtémoc: OK
# Geocoded: Country Gym, Guadalajara: OK
# Geocoded: Mixcoac Distrito Federal, Benito Juárez: OK
# Geocoded: De Armas, Guadalajara: OK
# Geocoded: IMCI Languages, San Nicolás de los Garza: OK
# Geocoded: Sayulita, Bahía de Banderas: OK
# Geocoded: Suprema Corte De Justicia, Cuauhtémoc: OK
# Geocoded: anglo , Cuauhtémoc: OK
# Geocoded: Academia de Música Fermatta, Coyoacán: OK
# Geocoded: Hotel Gobernador, Durango: OK
# Geocoded: Starbucks Coffe, Guadalajara: OK
# Geocoded: Barrería El Compadre de Las 9 Esquinas, Guadalajara: OK
# Geocoded: CETI, Guadalajara: OK
# Geocoded: la chilanguita, Metepec: OK
# Geocoded: Delegacion Iztapalapa, Iztapalapa: OK
# Geocoded: mojito, Cuauhtémoc: OK
# Geocoded: Saks Polanco, Miguel Hidalgo: OK
# Completed 900 of 12376 places
# Geocoded: Starbucks Coffe, Miguel Hidalgo: OK
# Geocoded: Palacio Municipal De Nezahualcoyotl, Nezahualcóyotl: OK
# Geocoded: Hospital Puebla, Puebla: OK
# Geocoded: Guanajuato , Guanajuato: OK
# Geocoded: Parque Lindvista, Gustavo A. Madero: OK
# Geocoded: go! fitness, Iztapalapa: OK
# Geocoded: Vips, Benito Juárez: OK
# Geocoded: Fes Aragon, Nezahualcóyotl: OK
# Geocoded: Star Medical, Cuautitlán Izcalli: OK
# Geocoded: Galerias Coapa, Tlalpan: OK
# Geocoded: Centro Histórico Campeche , Campeche: OK
# Geocoded: Sushi Roll, Naucalpan de Juárez: OK
# Geocoded: Casino Lion Twin, Guadalajara: OK
# Geocoded: Plaza Patria, Zapopan: OK
# Geocoded: Casino Español, Cuauhtémoc: OK
# Geocoded: La Cueva del León, Cuauhtémoc: OK
# Geocoded: Freedom, Naucalpan de Juárez: OK
# Geocoded: Cinépolis VIP, Monterrey: OK
# Geocoded: Plaza Central Del Zapato, León: OK
# Geocoded: cucs, Guadalajara: OK
# Geocoded: Las Alitas Aguascalientes, Aguascalientes: OK
# Geocoded: Cinemex Cuicuilco, Tlalpan: OK
# Geocoded: Leon, León: OK
# Geocoded: Carl's Jr, Monterrey: OK
# Geocoded: Cinemex, Ixtapaluca: OK
# Geocoded: Coorporativo CEO, Cuajimalpa de Morelos: OK
# Geocoded: Sirloin Stockade, Zapopan: OK
# Geocoded: Sonora Grill, Benito Juárez: OK
# Geocoded: Blockbuster, Benito Juárez: OK
# Error geocoding Instituto Romero, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Instituto Romero, Miguel Hidalgo: ZERO_RESULTS
# Geocoded: Parque Delta, Benito Juárez: OK
# Geocoded: Plazuela De Los Sapos, Puebla: OK
# Geocoded: Carl's Jr, Zapopan: OK
# Geocoded: Sheraton Ambassador, Monterrey: OK
# Geocoded: Plaza Las Flores, Coacalco de Berriozábal: OK
# Geocoded: Sanborns, Azcapotzalco: OK
# Geocoded: Planet Gim, Monterrey: OK
# Geocoded: costera, Puebla: OK
# Geocoded: starbucks, Querétaro: OK
# Geocoded: Burguer King, Benito Juárez: OK
# Geocoded: Pedregal, La Magdalena Contreras: OK
# Geocoded: Karisma Restaurante, Miguel Hidalgo: OK
# Geocoded: mcCarthy's, Puebla: OK
# Geocoded: Centro De Estudios Universitarios Londres, Cuauhtémoc: OK
# Geocoded: Vips, Gustavo A. Madero: OK
# Geocoded: Museo De Historia Mexicana, Monterrey: OK
# Geocoded: Cruz Roja Mexicana, Naucalpan de Juárez: OK
# Geocoded: San Pedro de los Pinos, Álvaro Obregón: OK
# Geocoded: Coapa, Tlalpan: OK
# Geocoded: Hospital Galenia, Benito Juárez: OK
# Geocoded: Sat, Cuauhtémoc: OK
# Geocoded: Operadora de Restaurante Gino S, Benito Juárez: OK
# Geocoded: Italimo, Atizapán de Zaragoza: OK
# Geocoded: colonia jardin balbuena, Distrito Federal: OK
# Geocoded: Aereopuerto internacional de tapachula, Tapachula: OK
# Geocoded: sushi roll , Iztapalapa: OK
# Geocoded: Restaurante La Pesca, Monterrey: OK
# Geocoded: Sanborns, Veracruz: OK
# Geocoded: Starbucks, San Marcos, Cuautitlán Izcalli: OK
# Geocoded: el torito, Monterrey: OK
# Geocoded: Palmitas, Centro: OK
# Geocoded: Goodrich Riquelme, Cuauhtémoc: OK
# Geocoded: Asian Bistro, Benito Juárez: OK
# Geocoded: Universidad Panamericana Bonaterra, Aguascalientes: OK
# Geocoded: Office Depot, Benito Juárez: OK
# Geocoded: Restaurante Bar Café del Artista, Puebla: OK
# Geocoded: Carl's Jr, San Pedro Garza García: OK
# Geocoded: Pabellon Tec, Monterrey, Nuevo León: OK
# Geocoded: Fiesta Americana, Aguascalientes: OK
# Geocoded: Mambo Cafe, Benito Juárez: OK
# Geocoded: Benito Juarez Auditorio, Veracruz: OK
# Geocoded: Guatemala , Chiapas: OK
# Geocoded: beer factory, Gustavo A. Madero: OK
# Geocoded: televisa, Álvaro Obregón: OK
# Geocoded: La Hacienda Los Morales, Miguel Hidalgo: OK
# Geocoded: Kgf Plaza México, Monterrey: OK
# Geocoded: Instituto Nacional De Perinatologia, Miguel Hidalgo: OK
# Geocoded: Grupo Scanda, Benito Juárez: OK
# Geocoded: Taco Chotepingo, Coyoacán: OK
# Geocoded: ICSHu, Pachuca de Soto: OK
# Geocoded: Radisson Plaza Gran Hotel Ancira, Monterrey: OK
# Geocoded: Vips, Campeche: OK
# Geocoded: salón sol juarez, Cuauhtémoc: OK
# Geocoded: Chili's Grill & Bar Restaurant, Tuxtla Gutiérrez: OK
# Geocoded: plaza independencia, Guadalajara: OK
# Geocoded: Bunker PGJ, Cuauhtémoc: OK
# Geocoded: Interlomas, Huixquilucan: OK
# Geocoded: La Estación El Lulio, Guadalajara: OK
# Geocoded: Restaurante Los Arcos, Miguel Hidalgo: OK
# Geocoded: el canto de las sirenas, Miguel Hidalgo: OK
# Geocoded: Universitario Del Chopo, Cuauhtémoc: OK
# Geocoded: lomas estrella, Iztapalapa: OK
# Geocoded: Registro Publico De La Propiedad, Cuauhtémoc: OK
# Geocoded: Sanborns, Miguel Hidalgo: OK
# Geocoded: Plaza "La Luciérnaga", San Miguel de Allende: OK
# Geocoded: Edificio Kalos, Monterrey: OK
# Geocoded: Universidad, Coyoacán: OK
# ...
# Geocoded: BBVA Bancomer Ticomán, Gustavo A. Madero: OK
# Geocoded: Hotel Suites Amberes, Cuauhtémoc: OK
# Geocoded: Santander Americas Xalapa, Xalapa: OK
# Geocoded: edai freinet, Mérida: OK
# Error geocoding Lotus Thai, Xalapa: ZERO_RESULTS
# Geocoded: Lotus Thai, Xalapa: ZERO_RESULTS
# Geocoded: Pastelería Gino's: OK
# Geocoded: Museo del Niño Globo Mi Ciudad Pequeña, Guadalajara: OK
# Geocoded: Toks, Ecatepec de Morelos: OK
# Error geocoding Lórenzillos, Cancun, Benito Juárez: ZERO_RESULTS
# Geocoded: Lórenzillos, Cancun, Benito Juárez: ZERO_RESULTS
# Geocoded: Honda Escénica, Acapulco de Juárez: OK
# Geocoded: Hotel Real Santa Rosa, Morelia: OK
# Geocoded: Estadio Deportivo Oceanía, Venustiano Carranza: OK
# Geocoded: Flautas And Sopes, Mexicali: OK
# Geocoded: Villa Pacifico, Puerto Vallarta: OK
# Geocoded: Bufalo Grill, Miguel Hidalgo: OK
# Geocoded: Telmex Hub, Cuauhtémoc: OK
# Geocoded: Teatro Versalles: OK
# Geocoded: Clínica de Medicina Familiar Oriente: OK
# Geocoded: Tribunal Colegiado del Vigésimo Séptimo Circuito: OK
# Geocoded: Lux eventos: OK
# Geocoded: Pacifika: OK
# Geocoded: Sonoran sea resort: OK
# Geocoded: Cantinita POP: OK
# Geocoded: Residencial San Antonio De Ayala: OK
# Geocoded: Hotel Baez: OK
# Geocoded: Congreso del Estado: OK
# Geocoded: Barra Hidalgo: OK
# Geocoded: Hotel Xcaret Mexico: OK
# Geocoded: Hacienda De Los 5 Señores: OK
# Geocoded: Bahía: OK
# Geocoded: playa coral: OK
# Geocoded: Villas La Noria: OK
# Error geocoding Sala Elías Nandino del Ex Convento del Carmen: ZERO_RESULTS
# Geocoded: Sala Elías Nandino del Ex Convento del Carmen: ZERO_RESULTS
# Geocoded: cinepolis El Rosario, Azcapotzalco: OK
# Geocoded: BBVA Bancomer, Guadalajara: OK
# Geocoded: GOSOLINERA ANAHUAC, S A DE C V, San Nicolás de los Garza: OK
# Geocoded: Hotel Villa Lourdes, Cuernavaca: OK
# Geocoded: Panteón Municipal: OK
# Geocoded: Touché: OK
# Geocoded: Montevideo, Gustavo A. Madero: OK
# Geocoded: Centauro Automotriz Volkswagen, Chihuahua: OK
# Geocoded: Hostal de María , Guadalajara: OK
# Geocoded: ISSSTE Clínica Gustavo A Madero, Gustavo A. Madero: OK
# Geocoded: facultad de derecho, Colima: OK
# Geocoded: Clinica San Marcos, Iztapalapa: OK
# Geocoded: Guatemala, Miguel Hidalgo: OK
# Geocoded: Blanco & Negro, Benito Juárez: OK
# Geocoded: Barra Antigua, Monterrey: OK
# Geocoded: Banamex Valladolid Oaxaca, Cuauhtémoc: OK
# Geocoded: Marti, Benito Juárez: OK
# Geocoded: Playon: OK
# Geocoded: Sartoria: OK
# Geocoded: Vips Mariano Escobedo, Miguel Hidalgo: OK
# Geocoded: Embajada De Argelia, Miguel Hidalgo: OK
# Geocoded: Chiapas Touring: OK
# Geocoded: Cancha de Futbol Rapido: OK
# Geocoded: Unidad De Medicina Fisica No 1, Monterrey: OK
# Geocoded: Cd. Mexico: OK
# Geocoded: Meson De Los Deportes: OK
# Geocoded: Café Los Chicos: OK
# Geocoded: Carnitas Quiroga, Cuauhtémoc: OK
# Geocoded: Instituto Europeo, Miguel Hidalgo: OK
# Geocoded: Morelos, Venustiano Carranza: OK
# Geocoded: Servicios Escolares: OK
# Geocoded: Domino´s Pizza Acoxpa, Tlalpan: OK
# Geocoded: Corner Irish Pub, San Pedro Garza García: OK
# Geocoded: Club del Maestro, Monterrey: OK
# Geocoded: Camino Real Sumiya, Morelos, Jiutepec: OK
# Geocoded: Pabellon Mirador, Puebla: OK
# Geocoded: Promomedios de Occidente: OK
# Geocoded: Grupo Requena, Cuauhtémoc: OK
# Geocoded: Engo Travel, Boca del Río: OK
# Geocoded: Atenas 32: OK
# Geocoded: Parque 5 de mayo: OK
# Completed 12100 of 12376 places
# Geocoded: Fábricas de Francia: OK
# Geocoded: Samuel Octavio Pe Alva Rosales, Venustiano Carranza: OK
# Geocoded: Hamburguesas Mario: OK
# Geocoded: McDonald's, Reynosa: OK
# Geocoded: Isla Mujeres: OK
# Geocoded: Remis Shaolin Kung Fu, Cuautla: OK
# Geocoded: Hotel Los Amantes: OK
# Geocoded: Enigma: OK
# Geocoded: OfficeMax, Chihuahua: OK
# Geocoded: Marti, Monterrey: OK
# Geocoded: wings army, Tuxtla Gutiérrez: OK
# Geocoded: tuxtla gutierrez, Tuxtla Gutiérrez: OK
# Error geocoding CST I Santa Cecilia Tepetlapa, Xochimilco: ZERO_RESULTS
# Geocoded: CST I Santa Cecilia Tepetlapa, Xochimilco: ZERO_RESULTS
# Geocoded: Radisson Hotel Del Rey Toluca: OK
# Geocoded: Peña De Bernal: OK
# Geocoded: Famsa, Monterrey: OK
# Geocoded: Bbva Bancomer, Cuautitlán: OK
# Error geocoding prizzo , Ecatepec de Morelos: ZERO_RESULTS
# Geocoded: prizzo , Ecatepec de Morelos: ZERO_RESULTS
# Geocoded: ISSSTE Clínica Juárez, Cuauhtémoc: OK
# Geocoded: DIF Estatal: OK
# Geocoded: Uc Radio: OK
# Geocoded: Hospital de la Mujer: OK
# Geocoded: McDonald's: OK
# Geocoded: Hyatt Ziva Main Pool: OK
# Geocoded: Hospital Hidalgo, Aguascalientes: OK
# Geocoded: Clínicas Geos, Cuauhtémoc: OK
# Geocoded: Parroquia De Santa Maria Magdalena, Miguel Hidalgo: OK
# Geocoded: Hotel La Morada, San Miguel de Allende: OK
# Geocoded: Hilton Cancun Beach, Benito Juárez: OK
# Geocoded: Colonia del Valle, Benito Juárez: OK
# Geocoded: Mix Up, Naucalpan de Juárez: OK
# Geocoded: BBVA Bancomer Villahermosa Carrizales, Nacajuca: OK
# Geocoded: EMO Auto Clinica del Bajio, Leon, Guanajuato, León: OK
# Error geocoding Coppel Sade Bancoppel, Puebla: ZERO_RESULTS
# Geocoded: Coppel Sade Bancoppel, Puebla: ZERO_RESULTS
# Error geocoding Monrooe, Monterrey: ZERO_RESULTS
# Geocoded: Monrooe, Monterrey: ZERO_RESULTS
# Geocoded: Once Pueblos: OK
# Geocoded: TEATRO BELLAS ARTES: OK
# Geocoded: La Cima Club Residencial: OK
# Geocoded: Queretaro: OK
# Geocoded: Banamex Xallitic, Xalapa: OK
# Geocoded: Estacionamiento, Monterrey: OK
# Error geocoding Pamita! , Tlalpan: ZERO_RESULTS
# Geocoded: Pamita! , Tlalpan: ZERO_RESULTS
# Geocoded: Asadero El Yaqui: OK
# Geocoded: Dominos Pizza Valle Poniente, San Pedro Garza García: OK
# Geocoded: Grand Hyatt Pool: OK
# Geocoded: La Iguana, Puerto Vallarta: OK
# Geocoded: Smart Fit Paseo La Fe: OK
# Geocoded: Envy Bar: OK
# Geocoded: Av. Francisco Villa: OK
# Geocoded: Takumi Barra Sushi, Puebla: OK
# Error geocoding PRI Municipal: ZERO_RESULTS
# Geocoded: PRI Municipal: ZERO_RESULTS
# Geocoded: Casa Maya: OK
# Geocoded: Natway Nutricion: OK
# Geocoded: Palacio Municipal: OK
# Geocoded: Parque La Bombilla: OK
# Geocoded: Freedom De Cuernavaca, Cuernavaca: OK
# Geocoded: Adiction Spa, Tlalnepantla de Baz: OK
# Geocoded: Caffenio Vado del Rio, Hermosillo: OK
# Geocoded: plaza sendero, Mérida: OK
# Geocoded: COMBU Express, S A DE C V, Guadalajara: OK
# Geocoded: plaza galerias, Mérida: OK
# Geocoded: La Res Pública: OK
# Geocoded: Leonardo Bravo, Tlalnepantla de Baz: OK
# Geocoded: El Refugio: OK
# Geocoded: Auditorio Fac. De Arquitectura: OK
# Geocoded: Hotel Boutique Casa Fernanda: OK
# Geocoded: Gasolinera Picacho-Ajusco: OK
# Geocoded: Valle Alameda: OK
# Geocoded: Plaza De TOros Julian Llaguno: OK
# Geocoded: Ferrocarril Chihuahua Pacífico (Chepe) Estación Divisadero: OK
# Geocoded: Universidad Humanitas: OK
# Error geocoding Restaurante El Arbolito, José Azueta: ZERO_RESULTS
# Geocoded: Restaurante El Arbolito, José Azueta: ZERO_RESULTS
# Geocoded: La Barbacoa de la Tulum: OK
# Geocoded: Estacionamiento, Álvaro Obregón: OK
# Geocoded: Bosques de Metepec, Metepec: OK
# Error geocoding Bague, Cuauhtémoc: ZERO_RESULTS
# Geocoded: Bague, Cuauhtémoc: ZERO_RESULTS
# Geocoded: La Copa de Oro, Morelia: OK
# Geocoded: Restaurante Pardiños, Coyoacán: OK
# Geocoded: Museo del Periodismo y de las Artes Gráficas, Guadalajara: OK
# Geocoded: Banco del Bajío Cumbres, Monterrey: OK
# Geocoded: Londres 123, Cuauhtémoc: OK
# Geocoded: Chilis Polanco, Miguel Hidalgo: OK
# Geocoded: HSBC, San Pedro Garza García: OK
# Geocoded: San Isidro, La Paz: OK
# Geocoded: Santander, Matamoros: OK
# Geocoded: La Gloria, Gustavo A. Madero: OK
# Geocoded: ICSA-UACJ: OK
# Geocoded: Cerveceria Chapultepec: OK
# Geocoded: Centro Cultural Y De Convenciones De Oaxaca (Ccco): OK
# Geocoded: Averanda Mall: OK
# Geocoded: Marlin Pool Bar: OK
# Geocoded: Pirámide de la Luna: OK
# Geocoded: Arco de Seguridad Huejotzingo: OK
# Geocoded: The Coffee Cup: OK
# Geocoded: Edificio A FCPyS: OK
# Geocoded: Auditorio Ius Semper Ciudad Universitaria: OK
# Geocoded: parque sabinos san jose: OK
# Geocoded: Cancún: OK
# Geocoded: Royal Pedregal: OK
# Geocoded: Kiss Lounge: OK
# Completed 12200 of 12376 places
# Geocoded: Aldo Conti, León: OK
# Geocoded: Hospital Infantil De Las Californias, Tijuana: OK
# Geocoded: Honda Cd del Carmen, Carmen: OK
# Geocoded: Acceso Sin Limites, Monterrey: OK
# Geocoded: Unidad Medica Especializada Condesa, Cuauhtémoc: OK
# Geocoded: Vips Polanco, Miguel Hidalgo: OK
# Geocoded: Restaurante Nancy, Cuauhtémoc: OK
# Geocoded: Parroquia Santiago Apostol, Chalco: OK
# Geocoded: Café Europa Express: OK
# Geocoded: H.Cárdenas, Tabasco, Cárdenas: OK
# Geocoded: Melchor Ocampo: OK
# Geocoded: HSBC Sevilla, Cuauhtémoc: OK
# Geocoded: Tony Carrera, Álvaro Obregón: OK
# Geocoded: Suites Brisas, Benito Juárez: OK
# Geocoded: Oxxo, Puebla: OK
# Error geocoding Autocamiones La Fe, Monterrey: ZERO_RESULTS
# Geocoded: Autocamiones La Fe, Monterrey: ZERO_RESULTS
# Geocoded: Banorte, Zapopan: OK
# Geocoded: BBVA Bancomer San Bernabé, La Magdalena Contreras: OK
# Geocoded: Llegadas Nacional: OK
# Geocoded: the bebotero , Guadalajara: OK
# Geocoded: Gourmet Liverpool: OK
# Geocoded: La Diosa: OK
# Geocoded: real del sol, ojo de agua, Tecámac: OK
# Geocoded: Innovasport: OK
# Geocoded: mi casa , Atitalaquia: OK
# Geocoded: Restaurante Bar Tlacotalpan Hotel Galería Plaza Veracruz, Boca del Río: OK
# Geocoded: Pirámide del Sol: OK
# Geocoded: Tuxtla Gutiérrez, Chiapas, Tuxtla Gutiérrez: OK
# Geocoded: Banorte San Felipe, Iztapalapa: OK
# Geocoded: Mercado Iztapalapa: OK
# Geocoded: Royal Solaris Cancun: OK
# Geocoded: Autlan de Navarro, jalisco, Autlán de Navarro: OK
# Geocoded: Mr Pampas: OK
# Geocoded: Estacionamiento, Cuauhtémoc: OK
# Geocoded: Dallas, Tlalpan: OK
# Geocoded: Balletissimo: OK
# Error geocoding Trajes De Fantasia Bertha: ZERO_RESULTS
# Geocoded: Trajes De Fantasia Bertha: ZERO_RESULTS
# Geocoded: La Esmeralda Hotel Boutique And Spa: OK
# Geocoded: colonia El Órgano: OK
# Geocoded: Sala/Gate 54: OK
# Geocoded: Sala/Gate 75: OK
# Geocoded: Ciudad de Colima, Cuauhtémoc: OK
# Geocoded: Sol y Luna, Saltillo: OK
# Geocoded: 7-Eleven, Cuauhtémoc: OK
# Geocoded: Escuela De Bachilleres Venustiano Carranza, Torreón: OK
# Geocoded: Jubilee Casino: OK
# Geocoded: BBVA Bancomer San Pedro, Puebla: OK
# Geocoded: plaza patriotismo , Miguel Hidalgo: OK
# Geocoded: Regional Puebla ISSSTE, Puebla: OK
# Geocoded: Hotel Plaza Pelicanos, Puerto Vallarta: OK
# Geocoded: Laguna del Náinari: OK
# Geocoded: Estetica Unisex Hollywood, Miguel Hidalgo: OK
# Geocoded: Sonrisalud Odontologia Especializada, Álvaro Obregón: OK
# Geocoded: Plaza Cuernavaca, Cuernavaca: OK
# Geocoded: Glorieta De La Purisima Concepción: OK
# Geocoded: Los Generales: OK
# Geocoded: Puente Muyuguarda: OK
# Geocoded: Mitsubishi, Zapopan: OK
# Geocoded: Santander Serfin, Guadalajara: OK
# Error geocoding Grupo Merag, Cordoba Centro: ZERO_RESULTS
# Geocoded: Grupo Merag, Cordoba Centro: ZERO_RESULTS
# Geocoded: cobaev 35, Xalapa: OK
# Geocoded: Col. Torre Blanca, M.H. México D.F., Miguel Hidalgo: OK
# Geocoded: Tacos Plaza, Zapopan: OK
# Geocoded: La Gotita de Miel, Boca del Río: OK
# Geocoded: Mitsubishi Juárez, Juárez: OK
# Geocoded: Chevrolet Americas Motors, Benito Juárez: OK
# Geocoded: SEP, Pachuca de Soto: OK
# Geocoded: Central Gineco Obstetricia, Puebla: OK
# Geocoded: Tlalpujahua, Michoacan, Atlacomulco: OK
# Geocoded: Paseo Niños Heroes: OK
# Geocoded: BBVA Bancomer Gamesa Vallejo, Azcapotzalco: OK
# Geocoded: Carnitas Arreola, Querétaro: OK
# Geocoded: Club de Golf Valle Alto, Monterrey: OK
# Geocoded: Sociedad De Beneficencia Espanola, Miguel Hidalgo: OK
# Geocoded: Cuauhtémoc, Chihuahua, Cuauhtémoc: OK
# Geocoded: Unam Fiesta De Las Ciencias Y Humanidades 2017: OK
# Geocoded: City Express Aeropuerto CDMX: OK
# Geocoded: INACIPE. Instituto Nal. de Ciencias Penales.: OK
# Geocoded: Gran Café de la Parroquia: OK
# Geocoded: Sanborns, Cuauhtémoc: OK
# Geocoded: Restaurante Zan Woo, Tampico: OK
# Geocoded: Rain, San Pedro Cholula: OK
# Geocoded: Kiosko del Malecón: OK
# Geocoded: UVM campus Querétaro: OK
# Geocoded: AutoZone: OK
# Geocoded: Cabo Pulmo: OK
# Geocoded: Deportivo Benito Juárez Xalpa: OK
# Geocoded: Kahlo Café: OK
# Geocoded: SEMOVI CDMX: OK
# Geocoded: Palafitos Overwater Bungalows: OK
# Geocoded: Paseo de los Agaves: OK
# Geocoded: CEAPS Tezoyuca: OK
# Geocoded: USBI: OK
# Geocoded: Hotel Ibiza Plaza: OK
# Geocoded: Cumbres de Juriquilla: OK
# Geocoded: Starbucks: OK
# Geocoded: Outlet San Martín: OK
# Geocoded: Sultepec de Pedro Ascencio: OK
# Geocoded: Museo Nacional de Aguascalientes, Aguascalientes: OK
# Geocoded: Cuernavaca, Morelos: OK
# Completed 12300 of 12376 places
# Geocoded: Oxxo, Guadalupe: OK
# Geocoded: Centro Cultural Moa, Toluca: OK
# Error geocoding Hotel Hacienda Don Pedro, Boca del Río: ZERO_RESULTS
# Geocoded: Hotel Hacienda Don Pedro, Boca del Río: ZERO_RESULTS
# Geocoded: Unidad Habitacional Xalapa 2000: OK
# Geocoded: Central del Norte, Gustavo A. Madero: OK
# Geocoded: taqueria pericos, Benito Juárez: OK
# Geocoded: Hotel Don Quijote, Guadalajara: OK
# Geocoded: Estetica Unisex Valentino's, Ecatepec de Morelos: OK
# Geocoded: Franco Americano, Tlalnepantla de Baz: OK
# Geocoded: Italian Steak House, Metepec: OK
# Geocoded: Guadalupe, Cuauhtémoc: OK
# Geocoded: Hospital Medica Integra, Gustavo A. Madero: OK
# Error geocoding Candelaria, Campeche, Carmen: ZERO_RESULTS
# Geocoded: Candelaria, Campeche, Carmen: ZERO_RESULTS
# Geocoded: CST I Francisco Villa, Iztapalapa: OK
# Geocoded: Europcar, Puerto Vallarta: OK
# Geocoded: Plaza Los Pilares, Puebla: OK
# Geocoded: av. revolucion, Pachuca de Soto: OK
# Geocoded: La Porfiriana, Morelia: OK
# Geocoded: Lindavista, Mexico, Gustavo A. Madero: OK
# Geocoded: Pollos Río, Gustavo A. Madero: OK
# Geocoded: Río Blanco, Ver., Río Blanco: OK
# Geocoded: Popeye's, Irapuato: OK
# Geocoded: Banamex China Poblana, Puebla: OK
# Geocoded: ESIME AZCAPOTZALCO, Azcapotzalco: OK
# Geocoded: Hotel Posada Regis de Guadalajara, Guadalajara: OK
# Geocoded: Coatzacoalcos, Veracruz de Ignacio de la Llave, Coatzacoalcos: OK
# Geocoded: Alijadores, Tampico: OK
# Geocoded: Congreso Del Trabajo, Cuauhtémoc: OK
# Geocoded: Cinépolis Oasis Coyoacán: OK
# Geocoded: Boca Express, Miguel Hidalgo: OK
# Geocoded: Peluqueria Michael, Miguel Hidalgo: OK
# Geocoded: Costco: OK
# Error geocoding Amazon Web Services - Mexico: ZERO_RESULTS
# Geocoded: Amazon Web Services - Mexico: ZERO_RESULTS
# Geocoded: Caseta Mexico-Pachuca: OK
# Geocoded: Che Hostel: OK
# Geocoded: Leon Gto: OK
# Geocoded: Hospital Regional De Alta Especialidad José María Morelos y Pavón: OK
# Geocoded: Oxxo Ahome Norte: OK
# Geocoded: Laguna Salada: OK
# Geocoded: Templo del Carmen, San Luis Potosí: OK
# Geocoded: Plaza Cruz del Sur, Puebla: OK
# Geocoded: Gran Hotel Ancira: OK
# Geocoded: club albatros, Tehuacán: OK
# Geocoded: Estacionamiento, Benito Juárez: OK
# Geocoded: tehuacan, puebla, Tehuacán: OK
# Geocoded: Restaurante El Borrego Líder, Tuxtla Gutiérrez: OK
# Geocoded: Direccion Del Registro Civil, Monterrey: OK
# Error geocoding GASOLINERA VIDAL RODRIGUEZ GTZ Y COPS, Altamira: ZERO_RESULTS
# Geocoded: GASOLINERA VIDAL RODRIGUEZ GTZ Y COPS, Altamira: ZERO_RESULTS
# Geocoded: El Borceguí, Naucalpan de Juárez: OK
# Geocoded: TX Hotel, Jojutla: OK
# Geocoded: Restaurante La Tortuga Feliz, Tlalpan: OK
# Geocoded: Tlatelolco: OK
# Geocoded: Colonia Lázaro Cárdenas: OK
# Error geocoding EXOTIC PLANET Ã, Guadalajara: INVALID_REQUEST
# Geocoded: EXOTIC PLANET Ã, Guadalajara: INVALID_REQUEST
# Geocoded: universidad de la salle Nezahualcoyotl, Nezahualcóyotl: OK
# Geocoded: Restaurante Fritz, Cuauhtémoc: OK
# Geocoded: dui, San Luis Potosí: OK
# Geocoded: Club de Golf Santa Margarita, Irapuato: OK
# Geocoded: HSBC Plaza La Magdalena, La Magdalena Contreras: OK
# Geocoded: Cozumel, Mexico, Cozumel: OK
# Geocoded: Modelo, Tlalnepantla de Baz: OK
# Geocoded: Bbva Bancomer Sears Lindavista, Gustavo A. Madero: OK
# Geocoded: El Marinero, Ahome: OK
# Geocoded: Pizza Hut, San Nicolás de los Garza: OK
# Geocoded: Banorte, Guadalupe: OK
# Geocoded: Bancomer, San Luis Potosí: OK
# Geocoded: Oxxo, Puebla: OK
# Geocoded: super cream, Poza Rica de Hidalgo: OK
# Geocoded: Banorte, Mérida: OK
# Geocoded: Bridgestone, Cuautitlán Izcalli: OK
# Geocoded: Hotel La Abadia, Guanajuato: OK
# Error geocoding Rainforest Café, Cuajimalpa de Morelos: ZERO_RESULTS
# Geocoded: Rainforest Café, Cuajimalpa de Morelos: ZERO_RESULTS
# Geocoded: Acura, Zapopan: OK
# Geocoded: Radiología E Imagen, Mexicali: OK
# Geocoded: Liga Pequeña Restaurant, Minatitlán: OK
# Geocoded: El Coso Uruguayo, Aguascalientes: OK
# Finished geocoding all places

# %%
print('SAVE:')

# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_pickle(output_file)

print('DONE!')
# Out:
# SAVE:
# DONE!
