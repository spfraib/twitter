# %%
import os
import pandas as pd

# %%
locations=pd.read_csv('/Volumes/Elements/Documents/ArcGIS/Twitter Model/Data-fusion-project-master/2. Latin America/account-locations-identified.csv')

# %%
locations_ar = locations[locations.country_short.eq('AR')]

# %%
locations_br = locations[locations.country_short.eq('BR')]

# %%
locations_co = locations[locations.country_short.eq('CO')]

# %%
locations_mx = locations[locations.country_short.eq('MX')]

# %%
locations_br['administrative_area_level_1_long'].dropna().unique().tolist()
# Out:
# ['State of São Paulo',
#  'State of Rio de Janeiro',
#  'State of Minas Gerais',
#  'State of Rio Grande do Sul',
#  'State of Paraná',
#  'Federal District',
#  'State of Pernambuco',
#  'State of Ceará',
#  'State of Amazonas',
#  'State of Goiás',
#  'State of Bahia',
#  'State of Santa Catarina',
#  'State of Pará',
#  'State of Paraíba',
#  'State of Rio Grande do Norte',
#  'State of Mato Grosso do Sul',
#  'State of Sergipe',
#  'State of Alagoas',
#  'State of Amapá',
#  'State of Piauí',
#  'State of Espírito Santo',
#  'State of Mato Grosso',
#  'State of Maranhão',
#  'State of Rondônia',
#  'State of Roraima',
#  'State of Tocantins',
#  'State of Acre',
#  'São Paulo',
#  'Rio Grande do Sul',
#  'Minas Gerais',
#  'Paraná',
#  'Pará',
#  'Santa Catarina',
#  'Alagoas',
#  'Goiás',
#  'Rio de Janeiro',
#  'Mato Grosso do Sul',
#  'Ceará']

# %%
BRcode_admin1 = {'27': 'Alagoas',
              '23':'Ceará',
              '53' : 'Federal District',
              '52' : 'Goiás',
              '51' : 'Mato Grosso do Sul',
              '31' : 'Minas Gerais',
              '15' : 'Pará',
              '41' : 'Paraná',
              '33' : 'Rio de Janeiro',
              '43' : 'Rio Grande do Sul',
              '35' : 'São Paulo',
              '42' : 'Santa Catarina',
              '12' : 'State of Acre',
              '27' : 'State of Alagoas',
              '16' : 'State of Amapá',
              '13' : 'State of Amazonas',
              '29' : 'State of Bahia',
              '23' : 'State of Ceará',
              '32' : 'State of Espírito Santo',
              '52' : 'State of Goiás',
              '21' : 'State of Maranhão',
              '51' : 'State of Mato Grosso',
              '50' : 'State of Mato Grosso do Sul',
              '31' : 'State of Minas Gerais',
              '15' : 'State of Pará',
              '25' : 'State of Paraíba',
              '41' : 'State of Paraná',
              '26' : 'State of Pernambuco',
              '22' : 'State of Piauí',
              '33' : 'State of Rio de Janeiro',
              '24' : 'State of Rio Grande do Norte',
              '43' : 'State of Rio Grande do Sul',
              '11' : 'State of Rondônia',
              '14' : 'State of Roraima',
              '35' : 'State of São Paulo',
              '42' : 'State of Santa Catarina',
              '28' : 'State of Sergipe',
              '17' : 'State of Tocantins'
             }

# %%
locations_co['administrative_area_level_1_long'].dropna().unique().tolist()
# Out:
# ['Bogota',
#  'Atlantico',
#  'Antioquia',
#  'Santander',
#  'Valle del Cauca',
#  'Cesar',
#  'Risaralda',
#  'Magdalena',
#  'Meta',
#  'Caldas',
#  'Tolima',
#  'North Santander',
#  'Bolivar',
#  'Huila',
#  'Cordoba',
#  'Boyaca',
#  'Sucre',
#  'Cauca',
#  'La Guajira',
#  'Narino',
#  'Quindio',
#  'Cundinamarca',
#  'Casanare',
#  'Arauca',
#  'Choco',
#  'San Andrés and Providencia']

# %%
COcode_admin1 = {'5': 'Antioquia',
              '8':'Atlantico',
              '11': 'Bogota',
              '13' : 'Bolivar',
              '15' : 'Boyaca',
              '17' : 'Caldas',
              '19' : 'Cauca',
              '20' : 'Cesar',
              '27' : 'Choco',
              '23' : 'Cordoba',
              '25' : 'Cundinamarca',
              '41' : 'Huila',
              '44' : 'La Guajira',
              '47' : 'Magdalena',
              '50' : 'Meta',
              '52' : 'Narino',
              '54' : 'North Santander',
              '63' : 'Quindio',
              '66' : 'Risaralda',
              '68' : 'Santander',
              '70' : 'Sucre',
              '73' : 'Tolima',
              '76' : 'Valle del Cauca'
             }

# %%
locations_mx['administrative_area_level_1_long'].dropna().unique().tolist()
# Out:
# ['Mexico City',
#  'Nuevo Leon',
#  'Baja California',
#  'Jalisco',
#  'Puebla',
#  'Veracruz',
#  'Sonora',
#  'Yucatan',
#  'Querétaro',
#  'Quintana Roo',
#  'State of Mexico',
#  'Tabasco',
#  'Oaxaca',
#  'Chihuahua',
#  'Michoacán',
#  'Aguascalientes',
#  'San Luis Potosi',
#  'Campeche',
#  'Tamaulipas',
#  'Guanajuato',
#  'Morelos',
#  'Chiapas',
#  'Guerrero',
#  'Durango',
#  'Zacatecas',
#  'Sinaloa',
#  'Hidalgo',
#  'Coahuila',
#  'Tlaxcala',
#  'Colima',
#  'Nayarit',
#  'Estado de México',
#  'Baja California Sur',
#  'Ciudad de México']

# %%
MXcode_admin1 = {'1' : 'Aguascalientes',
              '2' : 'Baja California',
              '3' : 'Baja California Sur',
              '4' : 'Campeche',
              '7' : 'Chiapas',
              '8' : 'Chihuahua',
              '9' : 'Ciuded de México',
              '5' : 'Coahuila',
              '6' : 'Colima',
              '10' : 'Durango',
              '15' : 'Estado de México',
              '11' : 'Guanajuato',
              '12' : 'Guerrero',
              '13' : 'Hidalgo',
              '14' : 'Jalisco',
              '9' : 'Mexico City',
              '16' : 'Michoacán',
              '17' : 'Morelos',
              '18' : 'Nayarit',
              '19' : 'Nuevo Leon',
              '20' : 'Oaxaca',
              '21' : 'Puebla',
              '22' : 'Querétao',
              '23' : 'Quintana Roo',
              '24' : 'San Luis Potosi',
              '25' : 'Sinaloa',
              '26' : 'Sonora',
              '15' : 'State of Mexico',
              '27' : 'Tabasco',
              '28' : 'Tamaulipas',
              '29' : 'Tlaxcala',
              '30' : 'Veracruz',
              '31' : 'Yucatan',
              '32' : 'Zacatecas'
             }

# %%
locations_ar['locality_short'].dropna().unique().tolist()
# Out:
# ['CABA',
#  'Córdoba',
#  'Rosario',
#  'La Plata',
#  'Mar del Plata',
#  'Mendoza',
#  'Santa Fe',
#  'Quilmes',
#  'Corrientes',
#  'Bahía Blanca',
#  'Salta',
#  'Tandil',
#  'San Juan',
#  'Comodoro Rivadavia',
#  'Avellaneda',
#  'San Miguel de Tucumán',
#  'Neuquen',
#  'Berazategui',
#  'San Luis',
#  'Hurlingham',
#  'Olavarría',
#  'Lanús Oeste',
#  'Necochea',
#  'Formosa',
#  'Santiago del Estero',
#  'Lomas de Zamora',
#  'Pilar',
#  'San Miguel',
#  'Puerto Madryn',
#  'Banfield',
#  'Merlo',
#  'Ushuaia',
#  'Rio Grande',
#  'Chivilcoy',
#  'Monte Grande',
#  'Tigre',
#  'Castelar',
#  'Río Cuarto',
#  'Ramos Mejía',
#  'Moreno',
#  'San Isidro',
#  'Berisso',
#  'Posadas',
#  'San Carlos de Bariloche',
#  'Pergamino',
#  'La Rioja',
#  'Rio Gallegos',
#  'Florencio Varela',
#  'Ituzaingó',
#  'Temperley',
#  'Campana',
#  'Burzaco',
#  'Haedo',
#  'Rafaela',
#  'Tres Arroyos',
#  'Cipolletti',
#  'Bragado',
#  'Punta Alta',
#  'Zarate',
#  'Wilde',
#  'Pinamar',
# ...

# %%
ARcode_admin1 = {'33' : 'Adrogué',
              '33' : 'Alejandro Korn',
              '33' : 'Avellaneda',
              '3' : 'Bahía Blanca',
              '33' : 'Banfield',
              '33' : 'Béccar',
              '33' : 'Belén de Escobar',
              '33' : 'Benavidez',
              '33' : 'Berazategui',
              '2' : 'Berisso',
              '33' : 'Bernal',
              '33' : 'Boulogne',
              '33' : 'Burzaco',
              '32' : 'CABA',
              '33' : 'Canning',
              '4' : 'Capitán Bermúdez',
              '93' : 'Carmen de Patagones',
              '33' : 'Caseros',
              '33' : 'Castelar',
              '13' : 'Catamarca',
              '2' : 'City Bell',
              '33' : 'Ciudad Evita',
              '33' : 'Ciudad Madero',
              '33' : 'Ciudadela',
              '33' : 'Claypole',
              '9' : 'Comodoro Rivadavia',
              '14' : 'Concordia',
              '22' : 'Córdoba',
              '12' : 'Corrientes',
              '33' : 'Del Viso',
              '33' : 'Don Torcuato',
              '33' : 'El Palomar',
              '2' : 'Ensenada',
              '33' : 'Ezeiza',
              '33' : 'Florencio Varela',
              '15' : 'Formosa',
              '4' : 'Funes',
              '33' : 'Garín',
              '33' : 'General Pacheco',
              '33' : 'General Rodríguez',
              '33' : 'Gerli',
              '33' : 'Glew',
              '10' : 'Godoy Cruz',
              '33' : 'González Catán',
              '33' : 'Gregorio de Laferrère',
              '33' : 'Guernica, Buenos Aires',
              '33' : 'Haedo',
              '33' : 'Hurlingham',
              '33' : 'Isidro Casanova',
              '33' : 'Ituzaingó',
              '33' : 'José C. Paz',
              '33' : 'José Mármol',
              '19' : 'Jujuy',
              '2' : 'La Plata',
              '25' : 'La Rioja',
              '33' : 'La Tablada',
              '33' : 'Lanús Oeste',
              '33' : 'Libertad',
              '33' : 'Llavallol',
              '33' : 'Lomas de Zamora',
              '33' : 'Lomas del Mirador',
              '33' : 'Longchamps',
              '2' : 'Los Hornos',
              '33' : 'Los Polvorines',
              '33' : 'Luis Guillon',
              '10' : 'Luján de Cuyo',
              '10' : 'Maipú',
              '34' : 'Mar del Plata',
              '33' : 'Marcos Paz',
              '33' : 'Martínez',
              '10' : 'Mendoza',
              '33' : 'Merlo',
              '33' : 'Monte Grande',
              '33' : 'Moreno',
              '33' : 'Morón',
              '33' : 'Munro',
              '17' : 'Neuquen',
              '33' : 'Olivos',
              '6' : 'Parana',
              '33' : 'Pilar',
              '17' : 'Plottier',
              '7' : 'Posadas',
              '33' : 'Quilmes',
              '9' : 'Rada Tilly',
              '33' : 'Rafael Calzada',
              '33' : 'Rafael Castillo',
              '33' : 'Ramos Mejía',
              '33' : 'Ranelagh',
              '91' : 'Rawson',
              '33' : 'Remedios de Escalada',
              '8' : 'Resistencia',
              '36' : 'Río Cuarto',
              '20' : 'Rio Gallegos',
              '31' : 'Rio Grande',
              '4' : 'Rosario',
              '23' : 'Salta',
              '33' : 'San Antonio de Padua',
              '33' : 'San Fernando',
              '33' : 'San Isidro',
              '27' : 'San Juan',
              '33' : 'San Justo',
              '4' : 'San Lorenzo',
              '26' : 'San Luis',
              '33' : 'San Martín',
              '33' : 'San Miguel',
              '29' : 'San Miguel de Tucumán',
              '38' : 'San Nicolás de los Arroyos',
              '33' : 'San Vicente',
              '5' : 'Santa Fe',
              '30' : 'Santa Rosa',
              '18' : 'Santiago del Estero',
              '33' : 'Sarandí',
              '33' : 'Temperley',
              '33' : 'Tigre',
              '33' : 'Tortuguitas',
              '91' : 'Trelew',
              '31' : 'Ushuaia',
              '33' : 'Valentín Alsina',
              '33' : 'Vicente López',
              '93' : 'Viedma',
              '33' : 'Villa Adelina',
              '33' : 'Villa Ballester',
              '33' : 'Villa Bosch',
              '33' : 'Villa Domínico',
              '33' : 'Villa Luzuriaga',
              '33' : 'Wilde',
              '29' : 'Yerba Buena',
             }
