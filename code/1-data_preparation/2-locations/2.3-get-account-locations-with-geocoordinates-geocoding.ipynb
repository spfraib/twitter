# %%
import pandas as pd
import requests
import logging
import time
import re
import string

# %% [markdown]
# # Params

# %%
# Set your Google API key here. 
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/, 
# the daily limit will be 2500, but at a much faster rate.
with open('../../data/keys/google/API_KEY','r') as f:
    API_KEY=eval(f.readline())
    
# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30

# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = True

# Include country bias to increase accuracy
BIAS = False

# %%
logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)

# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# %% [markdown]
# # Load Data

# %%
path_to_data = '../../data/locations/profiles/geocoding/'
input_file   = 'account-locations-to-geocode-manually.pkl'
output_file  = 'account-locations-geocoded-manually.pkl'

# %%
locations = pd.read_pickle(path_to_data+input_file)
print('# Locations:',locations.shape[0])
# Out:
# # Locations: 659

# %%
locations.head()
# Out:
#     LOCATION                    FIXED
# 0  Liverpool            Liverpool, UK
# 1  Nederland               Netherland
# 2       Cali  Baja California, Mexico
# 3         PH              Philippines
# 4  liverpool            Liverpool, UK

# %%
# Include bias
def include_bias(x):
    if ', ' + x['BIAS'] not in x['LOCATION']:
        return x['LOCATION'] + ', ' + x['BIAS']
    else:
        return x['LOCATION']

if BIAS:
    print('Bias included')
    # Make a big list of all of the addresses to be processed.
    locations['ADDRESS'] = locations.apply(include_bias, 1).tolist()
else:
    print('Bias not included')
    if 'FIXED' not in locations.columns:
        locations['ADDRESS'] = locations['LOCATION'].tolist()
    else:
        locations['ADDRESS'] = locations['FIXED'].tolist()
# Out:
# Bias not included

# %%
print('First 10 Requests:\n\n', '\n'.join(locations['ADDRESS'][:10]))
# Out:
# First 10 Requests:
#
#  Liverpool, UK
# Netherland
# Baja California, Mexico
# Philippines
# Liverpool, UK
# Kent, UK
# Florida, USA
# USA
# Portsmouth, UK
# Baja California, Mexico

# %% [markdown]
# # Google Geocoding

# %% [markdown]
# Python script for batch geocoding of addresses using the Google Geocoding API.
#
# This script allows for massive lists of addresses to be geocoded for free by pausing when the
# geocoder hits the free rate limit set by Google (2500 per day).  If you have an API key for paid
# geocoding from Google, set it in the API key section.
#
# Addresses for geocoding can be specified in a list of strings "addresses". In this script, addresses
# come from a csv file with a column "Address". Adjust the code to your own requirements as needed.
# After every 100 successul geocode operations, a temporary file with results is recorded in case of
# script failure / loss of connection later.
#
# Addresses and data are held in memory, so this script may need to be adjusted to process files line
# by line if you are processing millions of entries.

# %%
def get_google_results(address, api_key=None, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
    logger.warning("There was an error when testing the Google Geocoder.")
    raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# %%
# Create a list to hold results
results = []

# Go through each address in turn
for idx,location in locations.iterrows():
    
    # While the address geocoding is not finished:
    geocoded = False
    
    while geocoded is not True:
        
        # Geocode the address with google
        try:
            
            geocode_result = get_google_results(location['ADDRESS'], 
                                                API_KEY, 
                                                return_full_response=RETURN_FULL_RESULTS)
            
            geocode_result['raw_string'] = location['LOCATION']
            
        except Exception as e:
            
            logger.exception(e)
            
            logger.error("Major error with {}".format(location['ADDRESS']))
            
            logger.error("Skipping!")
            
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            
            logger.info("Hit Query Limit! Backing off for a bit.")
            
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            
            geocoded = False
            
        else:
            
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                
                logger.warning("Error geocoding {}: {}".format(location['ADDRESS'], geocode_result['status']))
                
            logger.debug("Geocoded: {}: {}".format(location['ADDRESS'], geocode_result['status']))
            
            results.append(geocode_result)           
            
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
        
        logger.info("Completed {} of {} address".format(len(results), len(locations)))
            
    # Every 100 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 1000 == 0:
        
        pd.DataFrame(results).to_pickle("{}_bak".format(path_to_data+output_file))

# All done
logger.info("Finished geocoding all addresses")
# Out:
# Geocoded: Liverpool, UK: OK
# Geocoded: Netherland: OK
# Geocoded: Baja California, Mexico: OK
# Geocoded: Philippines: OK
# Geocoded: Liverpool, UK: OK
# Geocoded: Kent, UK: OK
# Geocoded: Florida, USA: OK
# Geocoded: USA: OK
# Geocoded: Portsmouth, UK: OK
# Geocoded: Baja California, Mexico: OK
# Geocoded: Netherland: OK
# Geocoded: Lincoln, UK: OK
# Geocoded: Yorkshire, UK: OK
# Geocoded: Toledo, Spain: OK
# Geocoded: Santander, Spain: OK
# Geocoded: Durham, UK: OK
# Geocoded: Austin, Texas: OK
# Geocoded: Curitiba, Brazil: OK
# Geocoded: New Jersey, USA: OK
# Geocoded: Liverpool, UK: OK
# Geocoded: Somerset, UK: OK
# Geocoded: Kent, UK: OK
# Geocoded: Baja California, Mexico: OK
# Geocoded: Antwerpen, Netherlands: OK
# Geocoded: Philippines: OK
# Geocoded: Miami, USA: OK
# Geocoded: Curitiba, Brazil: OK
# Geocoded: Japan: OK
# Geocoded: Dallas, Texas: OK
# Geocoded: Panama city, Panama: OK
# Geocoded: Portsmouth, UK: OK
# Geocoded: Curitiba, Brazil: OK
# Geocoded: Santiago, Chile: OK
# Geocoded: Borneo: OK
# Geocoded: Stafford, UK: OK
# Geocoded: Philippines: OK
# Geocoded: Salisbury, UK: OK
# Geocoded: Baja California, Mexico: OK
# Geocoded: Qatar City: OK
# Geocoded: USA: OK
# Geocoded: NY State, USA: OK
# Geocoded: Leon, Spain: OK
# Geocoded: Thailand: OK
# Geocoded: Santander, Spain: OK
# Geocoded: Maryland, USA: OK
# Geocoded: Guayaquil, Ecuador: OK
# Geocoded: England, UK: OK
# Geocoded: Toledo, Spain: OK
# Geocoded: Thailand: OK
# Geocoded: Lincoln, UK: OK
# Geocoded: Brentwood, UK: OK
# Geocoded: NY State, USA: OK
# Geocoded: Michigan, USA: OK
# Geocoded: Weymouth, UK: OK
# Geocoded: Baja California, Mexico: OK
# Geocoded: Yorkshire, UK: OK
# Geocoded: Panama city, Panama: OK
# Geocoded: Leon, Spain: OK
# Geocoded: Mexico: OK
# Geocoded: British Columbia: OK
# Geocoded: Somerset, UK: OK
# Geocoded: Panama, City, Panama: OK
# Geocoded: Kent, UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Bueno Aires: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Puerto Rico: OK
# Geocoded: Virginia, USA: OK
# Geocoded: Dundalk, Ireland: OK
# Geocoded: Quito, Ecuador: OK
# Geocoded: Indonesia: OK
# Geocoded: California, USA: OK
# Geocoded: Dubai: OK
# Geocoded: Durham, UK: OK
# Geocoded: Manilla, Philippines: OK
# Geocoded: UK: OK
# Geocoded: Liverpool, UK: OK
# Geocoded: Florida, USA: OK
# Geocoded: Canton, UK: OK
# Geocoded: Florida, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Ontario: OK
# Geocoded: Panama city, Panama: OK
# Geocoded: Dallas, Texas: OK
# Geocoded: Singapore: OK
# Geocoded: Mexico: OK
# Geocoded: Stafford, UK: OK
# Geocoded: Dominican Republic: OK
# Geocoded: Miami, USA: OK
# Geocoded: Yogyakarta: OK
# Geocoded: Portsmouth, UK: OK
# Geocoded: New Jersey, USA: OK
# Geocoded: Indiana, USA: OK
# Geocoded: Florida, USA: OK
# Geocoded: New Jersey: OK
# Geocoded: Indonesia: OK
# Geocoded: Kentucky: OK
# Geocoded: Baixada Santista, Brazil: OK
# Geocoded: Calgary, Alberta: OK
# Geocoded: Weymouth, UK: OK
# Completed 100 of 659 address
# Geocoded: Liverpool, UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Philippines: OK
# Geocoded: New Jersey: OK
# Geocoded: Saudi Arabia: OK
# Geocoded: Lincoln, UK: OK
# Geocoded: Japan: OK
# Geocoded: Guayaquil, Ecuador: OK
# Geocoded: USA: OK
# Geocoded: Baja California, Mexico: OK
# Geocoded: UK: OK
# Geocoded: California: OK
# Geocoded: London, UK: OK
# Geocoded: Florya, Istanbul, Turkey: OK
# Geocoded: Philippines: OK
# Geocoded: Chiang Mai: OK
# Geocoded: New Jersey, USA: OK
# Geocoded: Cebu City, Philippines: OK
# Geocoded: Netherland: OK
# Geocoded: Florida, USA: OK
# Geocoded: Abidjan: OK
# Geocoded: Philippines: OK
# Geocoded: Turkey: OK
# Geocoded: Davao, Philippines: OK
# Geocoded: Florida: OK
# Geocoded: Indonesia: OK
# Geocoded: Indiana: OK
# Geocoded: Malang, Indonesia: OK
# Geocoded: Durham, UK: OK
# Geocoded: Seville, Spain: OK
# Geocoded: USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Kent, UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Michigan, USA: OK
# Geocoded: Orleans, France: OK
# Geocoded: UK: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Borneo: OK
# Geocoded: Indonesia: OK
# Geocoded: Brighton, UK: OK
# Geocoded: Dubai: OK
# Geocoded: Toledo, Spain: OK
# Geocoded: Mexico: OK
# Geocoded: Antwerpen, Netherlands: OK
# Geocoded: Guayaquil, Ecuador: OK
# Geocoded: Malaysia: OK
# Geocoded: Michigan: OK
# Geocoded: Ulm, Germany: OK
# Geocoded: Tennessee: OK
# Geocoded: Yorkshire, UK: OK
# Geocoded: Spain: OK
# Geocoded: Guayaquil, Ecuador: OK
# Geocoded: Qatar City: OK
# Geocoded: England, UK: OK
# Geocoded: Dubai: OK
# Geocoded: Panama, City, Panama: OK
# Geocoded: Turkey: OK
# Geocoded: Massachussets, USA: OK
# Geocoded: Brazil: OK
# Geocoded: Maracaibo, Venezuela: OK
# Geocoded: UK: OK
# Geocoded: Saipan: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Kuwait: OK
# Geocoded: Moscow: OK
# Geocoded: Indonesia: OK
# Geocoded: Kentuky, USA: OK
# Geocoded: Middlesex, UK: OK
# Geocoded: USA: OK
# Geocoded: Salisbury, UK: OK
# Geocoded: Philippines: OK
# Geocoded: Indonesia: OK
# Geocoded: Venezuela: OK
# Geocoded: Acıbadem University: OK
# Geocoded: New York State, USA: OK
# Geocoded: Langkawi, Kedah, Malaysia: OK
# Geocoded: Indonesia: OK
# Geocoded: Kuchin, Malaysia: OK
# Geocoded: JORDAN: OK
# Geocoded: Curitiba, Brazil: OK
# Geocoded: UK: OK
# Geocoded: USA: OK
# Geocoded: Los Angeles, USA: OK
# Geocoded: Moscow: OK
# Geocoded: Chihuahua, Mexico: OK
# Geocoded: Turkey: OK
# Geocoded: Mexico City, Mexico: OK
# Geocoded: Turkey: OK
# Geocoded: Colorado, USA: OK
# Geocoded: guadalupe island, mexico: OK
# Geocoded: Florida, USA: OK
# Geocoded: Indiana, USA: OK
# Geocoded: Calgary, Alberta: OK
# Geocoded: Manilla, Philippines: OK
# Geocoded: Indonesia: OK
# Completed 200 of 659 address
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Edmonton, Canada: OK
# Geocoded: British Columbia: OK
# Geocoded: UK: OK
# Geocoded: Turkey: OK
# Geocoded: UK: OK
# Geocoded: Texas, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Kurdistan: OK
# Geocoded: Borneo: OK
# Geocoded: Winterthur, Switzerland: OK
# Geocoded: Mexico: OK
# Geocoded: Santander, Spain: OK
# Geocoded: UK: OK
# Geocoded: Turkey: OK
# Geocoded: Kurdistan: OK
# Geocoded: Malaysia: OK
# Geocoded: New Jersey, USA: OK
# Geocoded: Kuwait: OK
# Geocoded: Somerset, UK: OK
# Geocoded: kanto, Japan: OK
# Geocoded: New Jersey: OK
# Geocoded: Indonesia: OK
# Geocoded: Singapore: OK
# Geocoded: Minnesota, USA: OK
# Geocoded: Jeddah, Saudi Arabia: OK
# Geocoded: California, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Bacolod, Philippines: OK
# Geocoded: New Jersey, USA: OK
# Geocoded: Turkey: OK
# Geocoded: Japan: OK
# Geocoded: Kota Kinabalu: OK
# Geocoded: Austin, Texas: OK
# Geocoded: Baja California, Mexico: OK
# Geocoded: Indonesia: OK
# Geocoded: Dubai: OK
# Geocoded: UK: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Orleans, France: OK
# Geocoded: Toledo, Spain: OK
# Geocoded: Curitiba, Brazil: OK
# Geocoded: Miami, USA: OK
# Geocoded: Florida, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Florida, USA: OK
# Geocoded: Indonesia: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: USA: OK
# Geocoded: Philippines: OK
# Geocoded: Brentwood, UK: OK
# Geocoded: Charlotte, NC: OK
# Geocoded: UK: OK
# Geocoded: Istanbul: OK
# Geocoded: Indonesia: OK
# Geocoded: Jakarta, Indonesia: OK
# Geocoded: UK: OK
# Geocoded: USA: OK
# Geocoded: Argentina: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Netherland: OK
# Geocoded: Turkey: OK
# Geocoded: UK: OK
# Geocoded: Kent, UK: OK
# Geocoded: Canton, UK: OK
# Geocoded: Turkey: OK
# Geocoded: Merida, Mexico: OK
# Geocoded: Turkey: OK
# Geocoded: New Jersey: OK
# Geocoded: Ontario, Canada: OK
# Geocoded: Portsmouth, UK: OK
# Geocoded: UK: OK
# Geocoded: Zanzibar: OK
# Geocoded: Japan: OK
# Geocoded: Valencia, ES: OK
# Geocoded: Indonesia: OK
# Geocoded: Kota Kinabalu: OK
# Geocoded: Shanghai: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: North Carolina, USA: OK
# Geocoded: UK: OK
# Geocoded: Massachussets, USA: OK
# Geocoded: Turkey: OK
# Geocoded: UK: OK
# Geocoded: Dokdo Island, Korea: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Miami, USA: OK
# Completed 300 of 659 address
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Xixón, ES: OK
# Geocoded: Indonesia: OK
# Geocoded: Canada: OK
# Geocoded: Dundalk, Ireland: OK
# Geocoded: Panama city, Panama: OK
# Geocoded: Michigan, USA: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Quito, Ecuador: OK
# Geocoded: NY State, USA: OK
# Geocoded: Michigan, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Guayaquil, Ecuador: OK
# Geocoded: Turkey: OK
# Geocoded: UK: OK
# Geocoded: NY State, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Canada: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Texas, USA: OK
# Geocoded: Borneo: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: South Dakota: OK
# Geocoded: Florida, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Texas, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Maine, USA: OK
# Geocoded: Thailand: OK
# Geocoded: Yogyakarta: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Indonesia: OK
# Geocoded: Dallas, Texas: OK
# Geocoded: Pennsylvania, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Leon, Spain: OK
# Geocoded: Turkey: OK
# Geocoded: Istanbul: OK
# Geocoded: Miami, USA: OK
# Geocoded: North Carolina, USA: OK
# Geocoded: guadalupe island, mexico: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Jakarta: OK
# Geocoded: Mecca, Saudi Arabia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Qatar City: OK
# Geocoded: 홍대: OK
# Geocoded: Bueno Aires: OK
# Geocoded: UK: OK
# Geocoded: Curitiba, Brazil: OK
# Geocoded: Indonesia: OK
# Geocoded: Enfield, CT: OK
# Geocoded: Bandung, Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: England, UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Connecticut: OK
# Geocoded: Indonesia: OK
# Geocoded: Chiang Mai: OK
# Geocoded: Japan: OK
# Geocoded: Panama, City, Panama: OK
# Geocoded: California: OK
# Geocoded: Philadelphia, PA: OK
# Geocoded: İstanbul: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: California, USA: OK
# Geocoded: Brazil: OK
# Geocoded: Las Vegas: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Washington, DC: OK
# Geocoded: California, USA: OK
# Geocoded: Colorado, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Santander, Spain: OK
# Geocoded: Indonesia: OK
# Geocoded: Santorini Island, Greece: OK
# Geocoded: Turkey: OK
# Geocoded: Pennsylvania, USA: OK
# Geocoded: Turkey: OK
# Completed 400 of 659 address
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: California, USA: OK
# Geocoded: Salisbury, UK: OK
# Geocoded: Indonesia: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Baja California, Mexico: OK
# Geocoded: Paris, France: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Philippines: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Florida, USA: OK
# Geocoded: Dar El Salaam: OK
# Geocoded: USA: OK
# Geocoded: Malaysia: OK
# Geocoded: USA: OK
# Geocoded: USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Guatemala: OK
# Geocoded: Maryland, USA: OK
# Geocoded: Medan, Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Edmonton, Canada: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Washington, DC: OK
# Geocoded: Indonesia: OK
# Geocoded: Boekel, Netherlands: OK
# Geocoded: UK: OK
# Geocoded: Philadelphia, PA: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Panama: OK
# Geocoded: Guayaquil, Ecuador: OK
# Geocoded: Jakarta, Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Laos: OK
# Geocoded: USA: OK
# Geocoded: Philippines: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Leon, Spain: OK
# Geocoded: USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: USA: OK
# Geocoded: Nevada, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: UK: OK
# Geocoded: North Carolina, USA: OK
# Geocoded: Vancouver, Canada: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Ohio: OK
# Geocoded: Salvador, Brazil: OK
# Geocoded: Turkey: OK
# Geocoded: Sydney: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Venezuela: OK
# Geocoded: Kuwait: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Quito, Ecuador: OK
# Geocoded: l"ile de la reunion: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Florida, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Brazil: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Singapore: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Completed 500 of 659 address
# Geocoded: Texas, USA: OK
# Geocoded: Turkey: OK
# Geocoded: Mexico: OK
# Geocoded: Kota Kinabalu: OK
# Geocoded: Kentuky, USA: OK
# Geocoded: Turkey: OK
# Geocoded: Antwerpen, Netherlands: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Florida, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Minessota, USA: OK
# Geocoded: Yorkshire, UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Gading Serpong, Indonesia: OK
# Geocoded: Santiago, Chile: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Canada: OK
# Geocoded: California, USA: OK
# Geocoded: Hong Kong: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: UK: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: USA: OK
# Geocoded: Indonesia: OK
# Geocoded: USA: OK
# Geocoded: New York State, USA: OK
# Geocoded: Brentwood, UK: OK
# Geocoded: Italy: OK
# Geocoded: USA: OK
# Geocoded: Honduras: OK
# Geocoded: Turkey: OK
# Geocoded: Jamaica: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Kuwait: OK
# Geocoded: UK: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: England, UK: OK
# Error geocoding Kansai Region, JP: ZERO_RESULTS
# Geocoded: Kansai Region, JP: ZERO_RESULTS
# Geocoded: UK: OK
# Geocoded: UK: OK
# Geocoded: Moscow: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Baranquilla, CO: OK
# Geocoded: Kentuky, USA: OK
# Geocoded: Las Vegas, USA: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Kuwait: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Chicago, USA: OK
# Geocoded: USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Jamaica: OK
# Geocoded: Indonesia: OK
# Geocoded: Brighton, UK: OK
# Geocoded: England, UK: OK
# Geocoded: Dundalk, Ireland: OK
# Geocoded: Yorkshire, UK: OK
# Geocoded: NY State, USA: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Guadalajara: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Jeddah, Saudi Arabia: OK
# Geocoded: Netherland: OK
# Geocoded: Lincoln, UK: OK
# Completed 600 of 659 address
# Geocoded: Bangkok, Thailand: OK
# Geocoded: Semarang, Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: UK: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: London: OK
# Geocoded: Ohio: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Bueno Aires: OK
# Geocoded: Honduras: OK
# Geocoded: Indonesia: OK
# Geocoded: West Virginia: OK
# Geocoded: Turkey: OK
# Geocoded: Turkey: OK
# Geocoded: Singapore, Singapore: OK
# Geocoded: Baixada Santista, Brazil: OK
# Geocoded: Indonesia: OK
# Geocoded: Zanzibar: OK
# Geocoded: Somerset, UK: OK
# Geocoded: UK: OK
# Geocoded: Panama city, Panama: OK
# Geocoded: Pittsburg, USA: OK
# Geocoded: UK: OK
# Geocoded: Borispil, Ukrain: OK
# Geocoded: New York, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Curitiba: OK
# Geocoded: San Petersburg, Russia: OK
# Geocoded: UK: OK
# Geocoded: Indonesia: OK
# Geocoded: Turkey: OK
# Geocoded: Guayaquil, Ecuador: OK
# Geocoded: Indonesia: OK
# Geocoded: Dallas, Texas: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Abu Dhabi, United Arab Emirates: OK
# Geocoded: Miami, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: England, UK: OK
# Geocoded: Panama city, Panama: OK
# Geocoded: Turkey: OK
# Geocoded: Bronx, NY, USA: OK
# Geocoded: Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Manilla, Philippines: OK
# Geocoded: UK: OK
# Geocoded: Semarang, Indonesia: OK
# Geocoded: Indonesia: OK
# Geocoded: Florya, Istanbul, Turkey: OK
# Error geocoding Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Geocoded: Bumi Serpong Damai, Indonesia: ZERO_RESULTS
# Finished geocoding all addresses

# %%
print('SAVE:')

# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_pickle(path_to_data+output_file)

print('DONE!')
# Out:
# SAVE:
# DONE!
