# %%
# !pip install pyarrow --user
# Out:
# Collecting pyarrow
#   Downloading pyarrow-1.0.1-cp38-cp38-manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 6.4 MB/s eta 0:00:01     |███████████████████▎            | 10.4 MB 6.4 MB/s eta 0:00:02
# Requirement already satisfied: numpy>=1.14 in /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages (from pyarrow) (1.19.1)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-1.0.1

# %%
import transformers

# %%
from transformers import BertTokenizer, BertModel, BertConfig, BertForTokenClassification, BertForMaskedLM
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer, FillMaskPipeline
import torch
import os
import pandas as pd
import pyarrow
import time

# %%
pd.options.display.max_colwidth = 100

# %% [markdown]
# ## Utils

# %%
def get_token_in_sequence_with_most_attention(model, tokenizer, input_sequence):
    """Run an input sequence through the BERT model, collect and average attention scores per token and return token with most average attention."""
    tokenized_input_sequence = tokenizer.tokenize(input_sequence)
    input_ids = torch.tensor(tokenizer.encode(input_sequence, add_special_tokens=False)).unsqueeze(0)
    outputs = model(input_ids)
    last_hidden_states, pooler_outputs, hidden_states, attentions = outputs
    attention_tensor = torch.squeeze(torch.stack(attentions))
    attention_tensor_averaged = torch.mean(attention_tensor, (0, 1))
    attention_average_scores_per_token = torch.sum(attention_tensor_averaged, dim=0)
    attention_scores_dict = dict()
    for token_position in range(len(tokenized_input_sequence)):
        attention_scores_dict[token_position] = attention_average_scores_per_token[token_position].item()
    print('Attention scores dictionary: ', attention_scores_dict, '\n')
    return {'token_index': max(attention_scores_dict, key=attention_scores_dict.get),
            'token_str': tokenized_input_sequence[max(attention_scores_dict, key=attention_scores_dict.get)]}

# %%
def extract_keywords_from_mlm_results(mlm_results_list, K_kw_explore):
    selected_keywords_list = list()
    for rank_mlm_keyword in range(K_kw_explore):
        selected_keywords_list.append(mlm_results_list[rank_mlm_keyword]['token_str'])
    return selected_keywords_list

# %%
model_folder_path = '/scratch/mt4493/twitter_labor/trained_models/DeepPavlov_bert-base-cased-conversational_jul23_iter0_preprocessed_12207397'
data_folder_path = '/scratch/mt4493/twitter_labor/twitter-labor-data/data/inference/DeepPavlov_bert-base-cased-conversational_jul23_iter0_preprocessed_12207397-12226078/output'

# %%
column = 'job_offer'
job_offer_df = pd.read_parquet(os.path.join(data_folder_path, column, '{}_all.parquet'.format(column)))
job_offer_df = job_offer_df[~job_offer_df.text.str.contains("RT", na=False)].reset_index(drop=True)
job_offer_df = job_offer_df.sort_values(by=["score"], ascending=False).reset_index()
job_offer_df.head()
# Out:
#       index     score                                               text
# 0  25897079  0.993284  Patient Registration Representative - Patient ...
# 1  10520163  0.993020  Raleigh #NC #USA - Senior Software Engineer Us...
# 2  51369362  0.993005  #Career #opportunity for #Administrative Assis...
# 3  47480907  0.992976  We're #hiring! Click to apply: Truck Driver, C...
# 4  55766589  0.992974  Patient Services Representative(PSR) -... - Su...

# %%
top_job_offer_df = job_offer_df[:350000]
top_job_offer_df.tail(n=50)
# Out:
#            index     score  \
# 349950  34394126  0.979542
# 349951  20340313  0.979540
# 349952  38615196  0.979540
# 349953  51168110  0.979539
# 349954  24972159  0.979538
# 349998  &lt;Job Alert - UNDERWRITING OFFICER at LIB INSURANCE BROKERS LIMITED (APPLY) - https://t.co/PJk...
# 349999  We are looking for a talented Marketing Associate, who has a successful track record in market r...

# %%
top_job_offer_df.to_parquet(os.path.join(data_folder_path, column, '{}_top.parquet'.format(column)))

# %%
column = 'is_hired_1mo'
is_hired_1mo_df = pd.read_parquet(os.path.join(data_folder_path, column, '{}_all.parquet'.format(column)))
is_hired_1mo_df = is_hired_1mo_df.sort_values(by=["score"], ascending=False).reset_index()
is_hired_1mo_df.head()
# Out:
#              tweet_id     score                  text
# 0  329284724180787201  0.967185    I just got hired !
# 1  298117857798144000  0.966951  Well, I got the job!
# 2  978991385151004672  0.966510      I got the job!!!
# 3  662755069675327489  0.966293    Got hired today!!!
# 4  460953833707802624  0.966203   I got the job!!!! 🙏

# %%
    labels = ['is_hired_1mo', 'is_unemployed', 'job_offer', 'job_search', 'lost_job_1mo']
    base_rates = [
        1.7342911457049017e-05,
        0.0003534645020523677,
        0.005604641971672389,
        0.00015839552996469054,
        1.455338466552472e-05]
    N_random = 92114009
    base_ranks = [int(x * N_random) for x in base_rates]
    label2rank = dict(zip(labels, base_ranks))

# %%
    model_path = os.path.join(model_folder_path, column, 'models', 'best_model')
    config = BertConfig.from_pretrained(model_path, output_hidden_states=True, output_attentions=True)
    tokenizer = BertTokenizer.from_pretrained(model_path)
    model = BertModel.from_pretrained(model_path, config=config)

# %%
df = is_hired_1mo_df[:label2rank[column]]
df.head()
# Out:
#              tweet_id     score                  text
# 0  329284724180787201  0.967185    I just got hired !
# 1  298117857798144000  0.966951  Well, I got the job!
# 2  978991385151004672  0.966510      I got the job!!!
# 3  662755069675327489  0.966293    Got hired today!!!
# 4  460953833707802624  0.966203   I got the job!!!! 🙏

# %%
df['tokenized_text'] = df['text'].apply(tokenizer.tokenize)
df_wordcount = df.explode('tokenized_text')
df_wordcount.head(n=50)
#df.groupby('tokenized_text').count()
#df_wordcount.head()
# Out:
# <ipython-input-36-5160455473c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokenized_text'] = df['text'].apply(tokenizer.tokenize)
#              tweet_id     score                  text tokenized_text
# 0  329284724180787201  0.967185    I just got hired !              I
# 0  329284724180787201  0.967185    I just got hired !           just
# 0  329284724180787201  0.967185    I just got hired !            got
# 0  329284724180787201  0.967185    I just got hired !          hired
# 0  329284724180787201  0.967185    I just got hired !              !
# 1  298117857798144000  0.966951  Well, I got the job!           Well
# 1  298117857798144000  0.966951  Well, I got the job!              ,
# 1  298117857798144000  0.966951  Well, I got the job!              I
# 1  298117857798144000  0.966951  Well, I got the job!            got
# 1  298117857798144000  0.966951  Well, I got the job!            the
# 1  298117857798144000  0.966951  Well, I got the job!            job
# 1  298117857798144000  0.966951  Well, I got the job!              !
# 2  978991385151004672  0.966510      I got the job!!!              I
# 2  978991385151004672  0.966510      I got the job!!!            got
# 2  978991385151004672  0.966510      I got the job!!!            the
# 2  978991385151004672  0.966510      I got the job!!!            job
# 2  978991385151004672  0.966510      I got the job!!!              !
# 2  978991385151004672  0.966510      I got the job!!!              !
# 2  978991385151004672  0.966510      I got the job!!!              !
# 3  662755069675327489  0.966293    Got hired today!!!            Got
# 3  662755069675327489  0.966293    Got hired today!!!          hired
# 3  662755069675327489  0.966293    Got hired today!!!          today
# 3  662755069675327489  0.966293    Got hired today!!!              !
# 3  662755069675327489  0.966293    Got hired today!!!              !
# 3  662755069675327489  0.966293    Got hired today!!!              !
# 4  460953833707802624  0.966203   I got the job!!!! 🙏              I
# 4  460953833707802624  0.966203   I got the job!!!! 🙏            got
# 4  460953833707802624  0.966203   I got the job!!!! 🙏            the
# 4  460953833707802624  0.966203   I got the job!!!! 🙏            job
# 4  460953833707802624  0.966203   I got the job!!!! 🙏              !
# 4  460953833707802624  0.966203   I got the job!!!! 🙏              !
# 4  460953833707802624  0.966203   I got the job!!!! 🙏              !
# 4  460953833707802624  0.966203   I got the job!!!! 🙏              !
# 4  460953833707802624  0.966203   I got the job!!!! 🙏          [UNK]
# 5  557931812891013121  0.966059  I got the job!!!!!!!              I
# 5  557931812891013121  0.966059  I got the job!!!!!!!            got
# 5  557931812891013121  0.966059  I got the job!!!!!!!            the
# 5  557931812891013121  0.966059  I got the job!!!!!!!            job
# 5  557931812891013121  0.966059  I got the job!!!!!!!              !
# 5  557931812891013121  0.966059  I got the job!!!!!!!              !
# 5  557931812891013121  0.966059  I got the job!!!!!!!              !
# 5  557931812891013121  0.966059  I got the job!!!!!!!              !
# 5  557931812891013121  0.966059  I got the job!!!!!!!              !
# 5  557931812891013121  0.966059  I got the job!!!!!!!              !
# 5  557931812891013121  0.966059  I got the job!!!!!!!              !
# 6  436219024695767040  0.966053       I got the job!!              I
# 6  436219024695767040  0.966053       I got the job!!            got
# 6  436219024695767040  0.966053       I got the job!!            the
# 6  436219024695767040  0.966053       I got the job!!            job
# 6  436219024695767040  0.966053       I got the job!!              !

# %%
df_wordcount = df_wordcount['tokenized_text'].value_counts().rename_axis('word').reset_index(name='count_top_tweets')
# Out:
#      unique_values  counts
# 0                !    1264
# 1              job    1160
# 2              new     816
# 3                I     810
# 4               my     671
# ...            ...     ...
# 2477        tables       1
# 2478         begin       1
# 2479            Cl       1
# 2480        ##pool       1
# 2481      complete       1
#
# [2482 rows x 2 columns]

# %% [markdown]
# ## Data and model import

# %%
start_time = time.time()
for column in ['is_hired_1mo', 'is_unemployed', 'job_offer', 'job_search', 'lost_job_1mo']:
    print('****************{}****************'.format(column))
    #load model
    model_path = os.path.join(model_folder_path, column, 'models', 'best_model')
    config = BertConfig.from_pretrained(model_path, output_hidden_states=True, output_attentions=True)
    tokenizer = BertTokenizer.from_pretrained(model_path)
    model = BertModel.from_pretrained(model_path, config=config)
    #load data
    data_path = os.path.join(data_folder_path, column, '{}_all.parquet'.format(column))
    df = pd.read_parquet(data_path)
    df = df[~df.text.str.contains("RT", na=False)].reset_index(drop=True)
    df = df.sort_values(by=['score'], ascending=False).reset_index(drop=True)
    for tweet_index in range(10):
        print('---> Tweet #{}'.format(str(tweet_index)))
        input_sequence = df['text'][tweet_index]
        tokenized_tweet = tokenizer.tokenize(input_sequence)
        print('Tweet: {} \n'.format(input_sequence))
        print('Tokenized version of tweet: {} \n'.format(tokenized_tweet))
        #identify high attention token
        print('$$$ Attention $$$\n')
        print('')
        attention_results_dict = get_token_in_sequence_with_most_attention(model, tokenizer, input_sequence)
        attention_token_str = attention_results_dict['token_str']
        attention_token_index = attention_results_dict['token_index']
        print('Token with the most attention: "{}"'.format(attention_token_str))
    del df
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ****************is_hired_1mo****************
# ---> Tweet #0
# Tweet: I just got hired !
#
# Tokenized version of tweet: ['I', 'just', 'got', 'hired', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.448033332824707, 1: 0.82781982421875, 2: 0.7723453044891357, 3: 1.2157444953918457, 4: 0.7360572218894958}
#
# Token with the most attention: "I"
# ---> Tweet #1
# Tweet: Well, I got the job!
#
# Tokenized version of tweet: ['Well', ',', 'I', 'got', 'the', 'job', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.6094640493392944, 1: 0.776115894317627, 2: 0.8612417578697205, 3: 1.0840789079666138, 4: 0.7891156673431396, 5: 1.083493709564209, 6: 0.7964902520179749}
#
# Token with the most attention: "Well"
# ---> Tweet #2
# Tweet: I got the job!!!
#
# Tokenized version of tweet: ['I', 'got', 'the', 'job', '!', '!', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.718056082725525, 1: 1.1336854696273804, 2: 0.9232265949249268, 3: 1.216264009475708, 4: 0.680431604385376, 5: 0.6347086429595947, 6: 0.6936274766921997}
#
# Token with the most attention: "I"
# ---> Tweet #3
# Tweet: Got hired today!!!
#
# Tokenized version of tweet: ['Got', 'hired', 'today', '!', '!', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.5126817226409912, 1: 1.466439127922058, 2: 0.8879141211509705, 3: 0.6898781061172485, 4: 0.6860100626945496, 5: 0.7570767998695374}
#
# Token with the most attention: "Got"
# ---> Tweet #4
# Tweet: I got the job!!!! 🙏
#
# Tokenized version of tweet: ['I', 'got', 'the', 'job', '!', '!', '!', '!', '[UNK]']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.714089035987854, 1: 1.2876627445220947, 2: 1.0486016273498535, 3: 1.2902610301971436, 4: 0.6933004260063171, 5: 0.6199337840080261, 6: 0.6456039547920227, 7: 0.5751790404319763, 8: 1.1253676414489746}
#
# Token with the most attention: "I"
# ---> Tweet #5
# Tweet: I got the job!!!!!!!
#
# Tokenized version of tweet: ['I', 'got', 'the', 'job', '!', '!', '!', '!', '!', '!', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 2.069991111755371, 1: 1.40657377243042, 2: 1.1598124504089355, 3: 1.5267146825790405, 4: 0.7154493927955627, 5: 0.6392831802368164, 6: 0.7043580412864685, 7: 0.7428478002548218, 8: 0.6904774904251099, 9: 0.6655785441398621, 10: 0.6789134740829468}
#
# Token with the most attention: "I"
# ---> Tweet #6
# Tweet: I got the job!!
#
# Tokenized version of tweet: ['I', 'got', 'the', 'job', '!', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.606684923171997, 1: 1.0566718578338623, 2: 0.8617920279502869, 3: 1.116724967956543, 4: 0.678234338760376, 5: 0.67989182472229}
#
# Token with the most attention: "I"
# ---> Tweet #7
# Tweet: I got the job !!!!!
#
# Tokenized version of tweet: ['I', 'got', 'the', 'job', '!', '!', '!', '!', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.9087834358215332, 1: 1.270715355873108, 2: 1.0428295135498047, 3: 1.3838273286819458, 4: 0.7013636827468872, 5: 0.6399946808815002, 6: 0.7104219198226929, 7: 0.6976969242095947, 8: 0.6443672776222229}
#
# Token with the most attention: "I"
# ---> Tweet #8
# Tweet: I got the job !!!!!
#
# Tokenized version of tweet: ['I', 'got', 'the', 'job', '!', '!', '!', '!', '!']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.9087834358215332, 1: 1.270715355873108, 2: 1.0428295135498047, 3: 1.3838273286819458, 4: 0.7013636827468872, 5: 0.6399946808815002, 6: 0.7104219198226929, 7: 0.6976969242095947, 8: 0.6443672776222229}
#
# Token with the most attention: "I"
# ---> Tweet #9
# Tweet: I got the job!! 😄
#
# Tokenized version of tweet: ['I', 'got', 'the', 'job', '!', '!', '[UNK]']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.525273323059082, 1: 1.1609350442886353, 2: 0.9248442053794861, 3: 1.1027541160583496, 4: 0.6949722766876221, 5: 0.5834540128707886, 6: 1.0077673196792603}
#
# Token with the most attention: "I"
# --- 335.25111722946167 seconds ---
# ****************is_unemployed****************
# ---> Tweet #0
# Tweet: I got fired sooo I'm unemployed
#
# Tokenized version of tweet: ['I', 'got', 'fired', 'sooo', 'I', "'", 'm', 'unemployed']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.8342686891555786, 1: 0.722795307636261, 2: 0.8311421275138855, 3: 0.8996145129203796, 4: 1.096659779548645, 5: 0.5445176362991333, 6: 0.9230113625526428, 7: 1.147990107536316}
#
# Token with the most attention: "I"
# ---> Tweet #1
# Tweet: i'm funemployed https://t.co/PmC5mLMtqm
#
# Tokenized version of tweet: ['i', "'", 'm', 'fun', '##emp', '##loy', '##ed', 'https', ':', '/', '/', 't', '.', 'co', '/', 'P', '##m', '##C', '##5', '##m', '##LM', '##t', '##q', '##m']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 2.2162349224090576, 1: 0.8342434763908386, 2: 1.290282130241394, 3: 1.134124517440796, 4: 0.8941652774810791, 5: 1.041865587234497, 6: 1.240423560142517, 7: 1.2788165807724, 8: 0.5807795524597168, 9: 0.5037030577659607, 10: 0.6332367062568665, 11: 0.8963189125061035, 12: 1.0657182931900024, 13: 0.8725879192352295, 14: 0.9884940981864929, 15: 0.9039222598075867, 16: 0.9173625707626343, 17: 0.8138084411621094, 18: 1.0991780757904053, 19: 0.9042391777038574, 20: 1.0807173252105713, 21: 0.8957309722900391, 22: 1.0576022863388062, 23: 0.8564445376396179}
#
# Token with the most attention: "i"
# ---> Tweet #2
# Tweet: I #need #money #today but i'm unemployed https://t.co/WB0phub9E0
#
# Tokenized version of tweet: ['I', '#', 'need', '#', 'money', '#', 'today', 'but', 'i', "'", 'm', 'unemployed', 'https', ':', '/', '/', 't', '.', 'co', '/', 'W', '##B', '##0', '##ph', '##ub', '##9', '##E', '##0']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 2.1441781520843506, 1: 0.9061661958694458, 2: 1.1177523136138916, 3: 0.7043175101280212, 4: 0.7409524321556091, 5: 0.9825928211212158, 6: 0.9516422152519226, 7: 1.2920374870300293, 8: 1.2951600551605225, 9: 0.7740585803985596, 10: 1.2443102598190308, 11: 1.7432869672775269, 12: 1.1481467485427856, 13: 0.5731351971626282, 14: 0.4685453474521637, 15: 0.6155696511268616, 16: 1.050796627998352, 17: 0.9697333574295044, 18: 0.9335772395133972, 19: 0.9302628636360168, 20: 1.0197476148605347, 21: 0.8437085151672363, 22: 0.8674242496490479, 23: 0.9382182955741882, 24: 0.9628121852874756, 25: 0.9977462887763977, 26: 1.0358904600143433, 27: 0.7482296228408813}
#
# Token with the most attention: "I"
# ---> Tweet #3
# Tweet: I'm retired https://t.co/Coyx51aKkB
#
# Tokenized version of tweet: ['I', "'", 'm', 'retired', 'https', ':', '/', '/', 't', '.', 'co', '/', 'Co', '##yx', '##51', '##a', '##K', '##k', '##B']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 2.315903425216675, 1: 0.7285012602806091, 2: 0.9279477596282959, 3: 1.6273947954177856, 4: 1.3470863103866577, 5: 0.5888790488243103, 6: 0.5089357495307922, 7: 0.6310268044471741, 8: 0.9653069972991943, 9: 0.9620685577392578, 10: 0.8841469287872314, 11: 0.8008464574813843, 12: 0.9158241152763367, 13: 1.261966586112976, 14: 0.9038792848587036, 15: 0.9139312505722046, 16: 0.9491825699806213, 17: 0.8783133029937744, 18: 0.8888586163520813}
#
# Token with the most attention: "I"
# ---> Tweet #4
# Tweet: I am now officially unemployed lol
#
# Tokenized version of tweet: ['I', 'am', 'now', 'officially', 'unemployed', 'lol']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.6963192224502563, 1: 1.0357683897018433, 2: 0.6672985553741455, 3: 0.6793042421340942, 4: 1.0514414310455322, 5: 0.8698679208755493}
#
# Token with the most attention: "I"
# ---> Tweet #5
# Tweet: well I am officially unemployed 😊
#
# Tokenized version of tweet: ['well', 'I', 'am', 'officially', 'unemployed', '[UNK]']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.7781965732574463, 1: 0.9746010303497314, 2: 0.8062115907669067, 3: 0.6505449414253235, 4: 1.023486614227295, 5: 0.7669593095779419}
#
# Token with the most attention: "well"
# ---> Tweet #6
# Tweet: Annnnnd now I am officially unemployed.
#
# Tokenized version of tweet: ['Ann', '##nn', '##nd', 'now', 'I', 'am', 'officially', 'unemployed', '.']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 1.8389227390289307, 1: 0.6670199632644653, 2: 1.0103009939193726, 3: 0.8145293593406677, 4: 1.0463881492614746, 5: 0.9403936862945557, 6: 0.7247329354286194, 7: 1.1731760501861572, 8: 0.7845361232757568}
#
# Token with the most attention: "Ann"
# ---> Tweet #7
# Tweet: Jk government, I'm unemployed
#
# Tokenized version of tweet: ['J', '##k', 'government', ',', 'I', "'", 'm', 'unemployed']
#
# $$$ Attention $$$
# Attention scores dictionary:  {0: 2.0183258056640625, 1: 0.6758396029472351, 2: 0.7621186971664429, 3: 1.097381353378296, 4: 1.0040760040283203, 5: 0.5110704898834229, 6: 0.8319424986839294, 7: 1.099245548248291}
#
# Token with the most attention: "J"
# ---> Tweet #8
# Tweet: I'm homeless https://t.co/m28haQJToV
#
# Tokenized version of tweet: ['I', "'", 'm', 'homeless', 'https', ':', '/', '/', 't', '.', 'co', '/', 'm', '##28', '##ha', '##Q', '##J', '##To', '##V']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 2
#
# Token with the most attention: "#"
# ---> Tweet #3
# Tweet: We're #hiring! Click to apply: Truck Driver, CDL A Team Owner Operators, Class A CDL, Dedicated Lanes... - https://t.co/OWFC5uc4dz #Job
#
# Tokenized version of tweet: ['We', "'", 're', '#', 'hiring', '!', 'Click', 'to', 'apply', ':', 'Truck', 'Driver', ',', 'CD', '##L', 'A', 'Team', 'Own', '##er', 'Opera', '##tors', ',', 'Class', 'A', 'CD', '##L', ',', 'De', '##di', '##cate', '##d', 'Lane', '##s', '.', '.', '.', '-', 'https', ':', '/', '/', 't', '.', 'co', '/', 'OW', '##FC', '##5', '##uc', '##4', '##d', '##z', '#', 'Job']
#
# $$$ Attention $$$
#
#
# Attention scores dictionary:  {0: 3.4295618534088135, 1: 0.679882287979126, 2: 0.7587594389915466, 3: 0.6998435854911804, 4: 1.4920923709869385, 5: 0.9482935667037964, 6: 1.2489675283432007, 7: 0.8982141017913818, 8: 1.4982939958572388, 9: 1.116794228553772, 10: 1.1184546947479248, 11: 1.5735429525375366, 12: 1.308105230331421, 13: 0.9673304557800293, 14: 0.9144761562347412, 15: 1.020195484161377, 16: 1.1168553829193115, 17: 0.9705997705459595, 18: 0.8365854024887085, 19: 1.0864228010177612, 20: 1.1626697778701782, 21: 1.313006043434143, 22: 1.044487476348877, 23: 0.9717645645141602, 24: 0.9613590836524963, 25: 0.8782561421394348, 26: 1.266319751739502, 27: 0.693779706954956, 28: 0.6197918057441711, 29: 0.8900788426399231, 30: 0.7265989184379578, 31: 1.1984310150146484, 32: 0.815643846988678, 33: 0.8802497386932373, 34: 0.7722718119621277, 35: 0.8560238480567932, 36: 0.9592283964157104, 37: 1.0025554895401, 38: 0.6647257804870605, 39: 0.6157774329185486, 40: 0.7310267090797424, 41: 0.8912644982337952, 42: 0.8826994299888611, 43: 0.9219664931297302, 44: 0.8929859399795532, 45: 0.8807010650634766, 46: 0.939781665802002, 47: 0.8264716267585754, 48: 0.7799974083900452, 49: 0.7381163239479065, 50: 0.7385414242744446, 51: 0.8901306986808777, 52: 0.7318674325942993, 53: 1.1781582832336426}
#
# Token with the most attention: "We"
# ---> Tweet #4
# Tweet: Patient Services Representative(PSR) -... - Sutter Pacific Medical Foundation: (#SantaRosa, CA) https://t.co/Vj9HTtDPA5 #CustomerService
#
# Tokenized version of tweet: ['Pat', '##ient', 'Services', 'Representative', '(', 'PS', '##R', ')', '-', '.', '.', '.', '-', 'Su', '##tter', 'Pacific', 'Medical', 'Foundation', ':', '(', '#', 'Santa', '##R', '##osa', ',', 'CA', ')', 'https', ':', '/', '/', 't', '.', 'co', '/', 'V', '##j', '##9', '##HT', '##t', '##DP', '##A', '##5', '#', 'Custom', '##er', '##Se', '##r', '##vice']
#
# $$$ Attention $$$
#
# $$$ Attention $$$
# Attention scores dictionary:  {0: 3.5131876468658447, 1: 0.690924346446991, 2: 0.8967656493186951, 3: 0.7658674120903015, 4: 0.6766733527183533, 5: 0.6440050005912781, 6: 0.7597180008888245, 7: 1.1327658891677856, 8: 1.1024794578552246, 9: 1.1467875242233276, 10: 0.763604462146759, 11: 0.9770479202270508, 12: 0.8791464567184448, 13: 1.9595192670822144, 14: 1.0470134019851685, 15: 1.3681585788726807, 16: 0.9180591702461243, 17: 1.8195639848709106, 18: 1.1955755949020386, 19: 1.137458086013794, 20: 0.9018426537513733, 21: 0.9596684575080872, 22: 0.9891238212585449, 23: 1.1339647769927979, 24: 0.8622927665710449, 25: 1.2562669515609741, 26: 1.201363205909729, 27: 1.020580768585205, 28: 1.0250861644744873, 29: 0.9228612780570984, 30: 1.3134238719940186, 31: 0.9545947313308716, 32: 0.686636745929718, 33: 0.6280810832977295, 34: 0.7086610794067383, 35: 0.8452686667442322, 36: 0.8896167874336243, 37: 0.9595435261726379, 38: 1.1402227878570557, 39: 0.8525086045265198, 40: 0.6813849210739136, 41: 0.8078266382217407, 42: 0.7970107197761536, 43: 0.7769032120704651, 44: 0.690636932849884, 45: 0.8086256980895996, 46: 0.8515430092811584, 47: 1.0635216236114502, 48: 0.9318252205848694, 49: 0.7152774930000305, 50: 0.9442365765571594, 51: 0.9676578044891357, 52: 0.8760742545127869, 53: 1.067565679550171, 54: 0.8164304494857788, 55: 0.8539546728134155, 56: 0.899131178855896, 57: 0.6736350059509277, 58: 1.130827784538269}
#
# Token with the most attention: "t"
# --- 1059.799061536789 seconds ---
# ****************job_search****************
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-a63bd37c4f62> in <module>
#       9     #load data
#      10     data_path = os.path.join(data_folder_path, column, '{}_all.parquet'.format(column))
# ---> 11     df = pd.read_parquet(data_path)
#      12     df = df[~df.text.str.contains("RT", na=False)].reset_index(drop=True)
#      13     df = df.sort_values(by=['score'], ascending=False).reset_index(drop=True)
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, **kwargs)
#     315     """
#     316     impl = get_engine(engine)
# --> 317     return impl.read(path, columns=columns, **kwargs)
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pandas/io/parquet.py in read(self, path, columns, **kwargs)
#     139
#     140         kwargs["use_pandas_metadata"] = True
# --> 141         result = self.api.parquet.read_table(
#     142             path, columns=columns, filesystem=fs, **kwargs
#     143         ).to_pandas()
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pyarrow/parquet.py in read_table(source, columns, use_threads, metadata, use_pandas_metadata, memory_map, read_dictionary, filesystem, filters, buffer_size, partitioning, use_legacy_dataset, ignore_prefixes)
#    1563             )
#    1564         try:
# -> 1565             dataset = _ParquetDatasetV2(
#    1566                 source,
#    1567                 filesystem=filesystem,
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pyarrow/parquet.py in __init__(self, path_or_paths, filesystem, filters, partitioning, read_dictionary, buffer_size, memory_map, ignore_prefixes, **kwargs)
#    1429             filesystem = pyarrow.fs.LocalFileSystem(use_mmap=True)
#    1430
# -> 1431         self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    1432                                    format=parquet_format,
#    1433                                    partitioning=partitioning,
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pyarrow/dataset.py in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     665     # TODO(kszucs): support InMemoryDataset for a table input
#     666     if _is_path_like(source):
# --> 667         return _filesystem_dataset(source, **kwargs)
#     668     elif isinstance(source, (tuple, list)):
#     669         if all(_is_path_like(elem) for elem in source):
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pyarrow/dataset.py in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     432     factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#     433
# --> 434     return factory.finish(schema)
#     435
#     436
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pyarrow/_dataset.pyx in pyarrow._dataset.DatasetFactory.finish()
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pyarrow/error.pxi in pyarrow.lib.pyarrow_internal_check_status()
#
# /scratch/mt4493/myjupyter/penv/lib/python3.8/site-packages/pyarrow/error.pxi in pyarrow.lib.check_status()
#
# OSError: Could not open parquet input source '/scratch/mt4493/twitter_labor/twitter-labor-data/data/inference/DeepPavlov_bert-base-cased-conversational_jul23_iter0_preprocessed_12207397-12226078/output/job_search/job_search_all.parquet': Invalid: Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.

# %% [markdown]
# ### is_hired_1mo

# %%
#load inference data from random set
data_path = '/home/manuto/Documents/world_bank/bert_twitter_labor/data/inference/convBERT/it0/random'
is_hired_1mo_df = pd.read_pickle(os.path.join(data_path,'is_hired_1mo_ONNX_BERT_ST_merged_random_100m_jun22.pkl')).reset_index(drop=True)
is_hired_1mo_df = is_hired_1mo_df[~is_hired_1mo_df.text.str.contains("RT", na=False)].reset_index(drop=True)
is_hired_1mo_df = is_hired_1mo_df[['tweet_id','second','text']]
is_hired_1mo_df.columns = ['tweet_id','score','text']
is_hired_1mo_df.head()
# Out:
#              tweet_id     score  \
# 0  662755069675327489  0.985959
# 1  459847518688665600  0.985849
# 2  535195703203880961  0.985819
# 3  331873004168552448  0.985771
# 4  327479239966330881  0.985664
#
#                                                 text
# 0                                 Got hired today!!!
# 1                          Just got hired at Google.
# 2                     Just got hired at Hobby Lobby!
# 3                          Got hired at Chick Fil A!
# 4  Got hired today at the hooters on the beach! 😉...

# %%
#load model
PATH_MODEL_FOLDER = '/home/manuto/Downloads/best_model'
config = BertConfig.from_pretrained(PATH_MODEL_FOLDER, output_hidden_states=True, output_attentions=True)
tokenizer = BertTokenizer.from_pretrained(PATH_MODEL_FOLDER)
model = BertModel.from_pretrained(PATH_MODEL_FOLDER, config=config)

# %% [markdown]
# We identify the token with most attention in each of the top 40 tweets.
#
# For each of these high-attention tokens, we identify 5 most similar tokens through masked language modeling (MLM).

# %%
mlm_pipeline_custom = pipeline('fill-mask', model=PATH_MODEL_FOLDER, tokenizer=PATH_MODEL_FOLDER,
                        config=PATH_MODEL_FOLDER, topk=5)
# Out:
# Some weights of the model checkpoint at /home/manuto/Downloads/best_model were not used when initializing BertForMaskedLM: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at /home/manuto/Downloads/best_model and are newly initialized: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# #### MLM with Vanilla BERT

# %%
for tweet_index in range(10):
    print('*********** Tweet #{} ***********'.format(str(tweet_index)))
    input_sequence = is_hired_1mo_df['text'][tweet_index]
    tokenized_tweet = tokenizer.tokenize(input_sequence)
    print('Tweet: {} \n'.format(input_sequence))
    print('Tokenized version of tweet: {} \n'.format(tokenized_tweet))
    #identify high attention token
    print('$$$ Attention $$$')
    print('')
    attention_results_dict = get_token_in_sequence_with_most_attention(model, tokenizer, input_sequence)
    attention_token_str = attention_results_dict['token_str']
    attention_token_index = attention_results_dict['token_index']
    print('Token with most attention on average: {}'.format(attention_token_str))
    print('Token index with most attention on average: {} \n'.format(attention_token_index))
    #do MLM
    ## replace high-attention token by a [MASK] token
    print('$$$ MLM $$$ \n')
    tokenized_tweet[attention_token_index] = '[MASK]'
    mlm_results_list = mlm_pipeline_bert(' '.join(tokenized_tweet))
    selected_keywords_list = extract_keywords_from_mlm_results(mlm_results_list, 5)
    print('Ranked MLM selected keywords for token "{}": \n'.format(attention_results_dict['token_str']), selected_keywords_list)
    for i in range(len(mlm_results_list)):
        keyword = mlm_results_list[i]['token_str']
        print('\n MLM candidate #{} : {}'.format(str(i), keyword))
        print(mlm_results_list[i])
        tweets_containing_keyword_df = is_hired_1mo_df[is_hired_1mo_df['text'].str.contains(keyword)]
        print('Random sample of tweets containing keyword {}:'.format(keyword))
        print(tweets_containing_keyword_df.sample(n=5)[['score','text']].head())
    print('*********** End of keyword exploration on tweet #{} ***********'.format(str(tweet_index)))
# Out:
# *********** Tweet #0 ***********
# Tweet: Got hired today!!!
#
# Tokenized version of tweet: ['Got', 'hired', 'today', '!', '!', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.512681484222412, 1: 1.4664392471313477, 2: 0.8879140615463257, 3: 0.6898781657218933, 4: 0.6860101222991943, 5: 0.7570768594741821}
# Token with most attention on average: Got
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Got":
#  ['get', 'got', '"', 'i', 'just']
#
#  MLM candidate #0 : get
# {'sequence': '[CLS] get hired today!!! [SEP]', 'score': 0.18747079372406006, 'token': 2131, 'token_str': 'get'}
# Random sample of tweets containing keyword get:
#             score                                               text
# 458648   0.314845  It's officially the first weekend of the Summe...
# 2995072  0.018597  Not really wanting to get up, but it's gym tim...
# 2541645  0.022016  So happy me and Ricky get to sleep in together...
# 3111085  0.017911  i have the worst habit of getting too close to...
# 48746    0.964180  Omg I can't even! #icanteven \nWe are about to...
#
#  MLM candidate #1 : got
# {'sequence': '[CLS] got hired today!!! [SEP]', 'score': 0.09301242232322693, 'token': 2288, 'token_str': 'got'}
# Random sample of tweets containing keyword got:
#             score                                               text
# 2623076  0.021296                      Shit I got off to a bad start
# 1474589  0.041845  I got you, your time to shine is now 💻💿🎙🎧🎤🎹🎼 #...
# 3030720  0.018382       Oh and I got my Hozier ticket for October 🙌🏻
# 2229360  0.025376  Soft smiles for this girl because she just got...
# 3286361  0.016976             Totally forgot about that last night 😝
#
#  MLM candidate #2 : "
# {'sequence': '[CLS] " hired today!!! [SEP]', 'score': 0.07530694454908371, 'token': 1000, 'token_str': '"'}
# Random sample of tweets containing keyword ":
#             score                                               text
# 1498238  0.040968         I'm Releasing 6 Dimensions" Today!!!!!!!!!
# 3577409  0.015650  Going to chipotle 10 minutes before they close...
# 895955   0.089595  Good morning beautiful people! Yo, check out m...
# 638590   0.165391  Starting with a new "client" tonight! Even wro...
# 990695   0.075800  A little holiday celebration with "the boss." ...
#
#  MLM candidate #3 : i
# {'sequence': '[CLS] i hired today!!! [SEP]', 'score': 0.0667385533452034, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 1862002  0.031086                                 @bradburia THANK U
# 904291   0.088185  I have all A's!!!! :) first in like 10 years! ...
# 2846582  0.019573                                    i forgive you 😘
# 2493761  0.022464                   @savannaaallison so pretty!! Imy
# 2974579  0.018726  Oh what a night, oh what a night! Thanks to ev...
#
#  MLM candidate #4 : just
# {'sequence': '[CLS] just hired today!!! [SEP]', 'score': 0.0667184442281723, 'token': 2074, 'token_str': 'just'}
# Random sample of tweets containing keyword just:
#             score                                               text
# 3828814  0.014673  There just lucky I’m a better person than they...
# 3081351  0.018082  I was in the city all day you should have met ...
# 1001121  0.074516  @katiemucci when I first started I just wouldn...
# 2713602  0.020558                       I'm just so over everybody 🤐
# 3879025  0.014493  The setlist is on my desk and whenever I walk ...
# *********** End of keyword exploration on tweet #0 ***********
# *********** Tweet #1 ***********
# Tweet: Just got hired at Google.
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'at', 'Google', '.']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.446664571762085, 1: 0.9768638610839844, 2: 1.2318527698516846, 3: 0.6410866975784302, 4: 0.8262072801589966, 5: 0.8773250579833984}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['i', 'he', 'she', 'we', 'you']
#
#  MLM candidate #0 : i
# {'sequence': '[CLS] i got hired at google. [SEP]', 'score': 0.6487764120101929, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 3687480  0.015206   Im not going to eat salad un this school no more
# 1152681  0.059647  He got game is on Netflix !!!!!!  Yes ❤️❤️❤️❤️...
# 3476480  0.016086        @lilybraden Yeay for new schmancy tech! :-)
# 2004431  0.028471  So glad to be back in my bed &amp; so looking ...
# 2009261  0.028396  I'm at Lakeshore Mall (Gainesville, GA) http:/...
#
#  MLM candidate #1 : he
# {'sequence': '[CLS] he got hired at google. [SEP]', 'score': 0.1119442954659462, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 3152215  0.017683  Now I have to go all the way back home I regre...
# 519440   0.246998  Wow we are so honored to be used by the father...
# 521400   0.245148  Boston it's been real..my fam, it's been real!...
# 1591820  0.037824                        @Keenan_CB thanks brother 🐬
# 2512107  0.022289  Spent the day at a monastery and got a private...
#
#  MLM candidate #2 : she
# {'sequence': '[CLS] she got hired at google. [SEP]', 'score': 0.06985471397638321, 'token': 2016, 'token_str': 'she'}
# Random sample of tweets containing keyword she:
#             score                                               text
# 391436   0.422412  The work is finished and we are ready to open ...
# 3851702  0.014590  I can't explain it, she just makes me feel so ...
# 696935   0.140331  Happy birthday!! Have a good one😇 @sheilatrnjanin
# 3968153  0.014187                    she got me good some many times
# 2116702  0.026896      Thats my love tho she'll get it ONE day lol😏😁
#
#  MLM candidate #3 : we
# {'sequence': '[CLS] we got hired at google. [SEP]', 'score': 0.036718741059303284, 'token': 2057, 'token_str': 'we'}
# Random sample of tweets containing keyword we:
#            score                                               text
# 9692    0.977367  T-minus one week until I leave for #PeruSki15,...
# 59875   0.959665  Forget unfollowers, I believe in growing. 34 n...
# 331894  0.549679  @dreson00 Grazie mille for enjoying our La Ros...
# 317343  0.583952       Goodnight tweethearts!!! GOD IS WITH YOU!! ✌
# 361547  0.483326  Today stats: One new follower, One new unfollo...
#
#  MLM candidate #4 : you
# {'sequence': '[CLS] you got hired at google. [SEP]', 'score': 0.026406699791550636, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                               text
# 1033952  0.070731                    @Justin_Mante5 thank you honey🌸
# 529668   0.237827                     @SHELBYISC00L love you toooo !
# 775259   0.115398  @steffanieeunice so proud of you steph :) keep...
# 1987220  0.028763                @JamesJohnsonUSA Love you more   ♡
# 2061917  0.027714  I'm officially jealous of @BigShot_Jr 😭😭😭 I'm ...
# *********** End of keyword exploration on tweet #1 ***********
# *********** Tweet #2 ***********
# Tweet: Just got hired at Hobby Lobby!
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'at', 'Ho', '##bby', 'Lo', '##bby', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 2.003485918045044, 1: 1.0714242458343506, 2: 1.2882232666015625, 3: 0.8825027942657471, 4: 0.6916071176528931, 5: 0.911846935749054, 6: 0.6171857118606567, 7: 0.7439514994621277, 8: 0.7897726893424988}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['i', 'he', 'we', 'you', 'they']
#
#  MLM candidate #0 : i
# {'sequence': '[CLS] i got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.392181396484375, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                   text
# 3002210  0.018552                     It's windy as hell
# 2574866  0.021715                 Halftime Performance 💯
# 3015242  0.018474                                 Fish 😍
# 279496   0.674111                       Finally home 🙌👌👏
# 3551136  0.015760  @tehkurios @HeyScoops omg how magical
#
#  MLM candidate #1 : he
# {'sequence': '[CLS] he got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.11225966364145279, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 2366877  0.023761              @WWE I ❤️ the #LUCHADragons !!!  #RAW
# 631301   0.169154  For the first time in a long time, I can say t...
# 444472   0.334563  @Mr_BeatFl0w this is my first year ever going ...
# 257835   0.724027  She just told me her new year started after Ra...
# 3647277  0.015364  CONGRATS, @JessicaMMAPro and @bethecorreia #UF...
#
#  MLM candidate #2 : we
# {'sequence': '[CLS] we got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.09204914420843124, 'token': 2057, 'token_str': 'we'}
# Random sample of tweets containing keyword we:
#             score                                               text
# 321494   0.573958  I really want to wear my new clothes tomorrow,...
# 2954985  0.018850                        @Morgan_Sipp next weekend ✊
# 2481154  0.022585  I'm so old!!! I just went grocery shopping on ...
# 2950467  0.018879                @ShidaaBabiee well I take it back 😝
# 2417604  0.023221  @DesperateHearts Thank you for the Retweet!  E...
#
#  MLM candidate #3 : you
# {'sequence': '[CLS] you got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.07615595310926437, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                               text
# 2412354  0.023276  you made my 2016 hayes, i love you so fucking ...
# 2520831  0.022208                             Lebron you da real MVP
# 3258464  0.017119              Thank you!!💝💗 https://t.co/VQR0AaJHOZ
# 754192   0.121292           @WinEverUwantIT yea bruh you got it lmao
# 636880   0.166281  @Courtney_Rocha that's why you're getting a jo...
#
#  MLM candidate #4 : they
# {'sequence': '[CLS] they got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.05528402701020241, 'token': 2027, 'token_str': 'they'}
# Random sample of tweets containing keyword they:
#             score                                               text
# 1211812  0.055309  I'm so honored and definitely blessed to have ...
# 3043145  0.018308          I love the little couple, they're so cute
# 1542965  0.039410  omg. omg. omg. it's CHRISTMAS EVE😍👏 #soexcited...
# 1986788  0.028771         they gon love me for my ambition #247grind
# 3804021  0.014763  @COSMlCCHAN I totally feel u I just love babym...
# *********** End of keyword exploration on tweet #2 ***********
# *********** Tweet #3 ***********
# Tweet: Got hired at Chick Fil A!
#
# Tokenized version of tweet: ['Got', 'hired', 'at', 'Chi', '##ck', 'Fil', 'A', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.6901259422302246, 1: 1.4704525470733643, 2: 0.8817121982574463, 3: 0.8063538074493408, 4: 0.8460407853126526, 5: 0.8220968246459961, 6: 0.6992152333259583, 7: 0.7840021252632141}
# Token with most attention on average: Got
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Got":
#  ['i', 'get', 'she', 'he', '-']
#
#  MLM candidate #0 : i
# {'sequence': '[CLS] i hired at chi # # ck fil a! [SEP]', 'score': 0.10562251508235931, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 3352217  0.016658  The One Time My Heart Edition brings me to tea...
# 407336   0.393278                           God keep on blessing me!
# 3743398  0.014989  Off tomorrow and all im gonna do is literally ...
# 460882   0.311793                     Good work Eric proud of myself
# 1785149  0.032710                      6th street was so Fun tonight
#
#  MLM candidate #1 : get
# {'sequence': '[CLS] get hired at chi # # ck fil a! [SEP]', 'score': 0.10165084898471832, 'token': 2131, 'token_str': 'get'}
# Random sample of tweets containing keyword get:
#             score                                               text
# 1098573  0.064227  I hit at 11:30 tonight @RevRoomLR! Let's get t...
# 4014724  0.014033                          Bout to get in my zone 😌💨
# 2905164  0.019175            Pirates of the Caribbean never gets old
# 3331114  0.016758      Didn’t get to see my girl this thanksgiving 😕
# 1790205  0.032597  @VegasBlackMale @girlwspadetatoo an unforgetta...
#
#  MLM candidate #2 : she
# {'sequence': '[CLS] she hired at chi # # ck fil a! [SEP]', 'score': 0.02650282345712185, 'token': 2016, 'token_str': 'she'}
# Random sample of tweets containing keyword she:
#             score                                               text
# 1343206  0.047629                  @najae_lashell I'll be there in 5
# 3079560  0.018092   @SlashedBeauty @PaylessInsider thanks Miranda! 💕
# 2994690  0.018599             @shellfish_sayz thank you I'm trying 😏
# 742940   0.124678                 @sheilamikailli thanks SOOO much!!
# 2341444  0.024040  We jus, finished our formal morning prep along...
#
#  MLM candidate #3 : he
# {'sequence': '[CLS] he hired at chi # # ck fil a! [SEP]', 'score': 0.02518015168607235, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 655126   0.157551  Thanks to everyone who came yesterday! I mean,...
# 2465152  0.022743  I just want to sleep through the whole night f...
# 2318319  0.024303  Happy birthday @kamerynmckayla I hope u get al...
# 2168637  0.026178  The moment when you remember that the PGA @PGA...
# 2855218  0.019513                                      Take me there
#
#  MLM candidate #4 : -
# {'sequence': '[CLS] - hired at chi # # ck fil a! [SEP]', 'score': 0.024882640689611435, 'token': 1011, 'token_str': '-'}
# Random sample of tweets containing keyword -:
#             score                                               text
# 3846916  0.014607  Idk what bothered me more Evelyn calling me cr...
# 848535   0.098291  Tough loss to Melissa in two. Bounced back and...
# 606359   0.182874     Another wok for @UHCougarFB. 5-0 baby #gocoogs
# 2430093  0.023092  We're #hiring! Read about our latest #job open...
# 852778   0.097448  @loriellehansen thank youuu, you too!! Enjoy s...
# *********** End of keyword exploration on tweet #3 ***********
# *********** Tweet #4 ***********
# Tweet: Got hired today at the hooters on the beach! 😉😘 http://t.co/CXJwFlJBDD
#
# Tokenized version of tweet: ['Got', 'hired', 'today', 'at', 'the', 'ho', '##oter', '##s', 'on', 'the', 'beach', '!', '[UNK]', 'http', ':', '/', '/', 't', '.', 'co', '/', 'C', '##X', '##J', '##w', '##Fl', '##J', '##B', '##DD']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 2.024837017059326, 1: 2.091308355331421, 2: 1.0261682271957397, 3: 0.8227925896644592, 4: 0.8867378830909729, 5: 0.6843050122261047, 6: 0.9743086695671082, 7: 0.722823441028595, 8: 0.8818274736404419, 9: 0.5169667601585388, 10: 1.239403247833252, 11: 0.8934236764907837, 12: 0.7671450972557068, 13: 1.0015952587127686, 14: 0.8535885214805603, 15: 0.8662177324295044, 16: 0.9419586062431335, 17: 0.9503006935119629, 18: 0.9791205525398254, 19: 1.1336263418197632, 20: 0.9325909614562988, 21: 0.8440161347389221, 22: 0.949721097946167, 23: 0.952224850654602, 24: 1.0904576778411865, 25: 1.1882437467575073, 26: 0.9217448830604553, 27: 0.8995845317840576, 28: 0.9629606604576111}
# Token with most attention on average: hired
# Token index with most attention on average: 1
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "hired":
#  ['lost', 'married', 'it', 'you', 'him']
#
#  MLM candidate #0 : lost
# {'sequence': '[CLS] got lost today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.08847538381814957, 'token': 2439, 'token_str': 'lost'}
# Random sample of tweets containing keyword lost:
#             score                                               text
# 349442   0.509667    lost and insecure, you found me, you found me 🎧
# 1040167  0.070067        @lostwhenthewind YOU ARE SO CUTE I LOVE YOU
# 2559318  0.021854        @lostinthew00ds - Ahh. @Cubs it is then! 🙌🏻
# 165388   0.884636  i keep thinking about how i lost cup pong last...
# 3286179  0.016977  damn they lost o well its still #BullsNation n...
#
#  MLM candidate #1 : married
# {'sequence': '[CLS] got married today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.08536521345376968, 'token': 2496, 'token_str': 'married'}
# Random sample of tweets containing keyword married:
#             score                                               text
# 2717345  0.020529  Of course I have a terrible allergy attack aro...
# 3887671  0.014463  I wanted to say congratulation to @themattdall...
# 1795802  0.032472       We getting married on the first aint we  lol
# 2718613  0.020520  I can't wait to get married. I'm gonna be the ...
# 1199563  0.056162  Went to go make my wedding ceremony appointmen...
#
#  MLM candidate #2 : it
# {'sequence': '[CLS] got it today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.06144006550312042, 'token': 2009, 'token_str': 'it'}
# Random sample of tweets containing keyword it:
#             score                                               text
# 250466   0.740303                    new crib. Can't wait to move in
# 1702722  0.034689  happy bday to one of my fave girls @EmilyReite...
# 4019890  0.014017          Just not excited by the same shit anymore
# 3710284  0.015116                                Home, bored as shit
# 1868867  0.030952                         Can't wait for summer 💖✌🏼️
#
#  MLM candidate #3 : you
# {'sequence': '[CLS] got you today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.04706751927733421, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                 text
# 1218486  0.054855  Thank you Jesus for your provision.
# 3755287  0.014944           @teenytinyflame Thank you😜
# 917367   0.086071         @OhThatsJam3s 😭😭😭💞 thank you
# 1070397  0.066943        @AmaechiCindyUja thank you 😂😂
# 1328678  0.048371                         I want you 😋
#
#  MLM candidate #4 : him
# {'sequence': '[CLS] got him today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.03879106417298317, 'token': 2032, 'token_str': 'him'}
# Random sample of tweets containing keyword him:
#             score                                               text
# 3480593  0.016068               I'm not leaving Cali until I see him
# 3680185  0.015234  @ladywhimsy @aimeeble @pcperini ~~~THE NEW MIL...
# 1663315  0.035743  I slept in the same bed as my boyfriend and my...
# 1713653  0.034411        It's gon be like Hiroshima and Niggasaki😂😂😂
# 3592261  0.015588   Loving him was like shaking hands with the devil
# *********** End of keyword exploration on tweet #4 ***********
# *********** Tweet #5 ***********
# Tweet: Just got hired at Barnes and Noble! 😂🔥
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'at', 'Barnes', 'and', 'Noble', '!', '[UNK]']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.9725040197372437, 1: 1.0725888013839722, 2: 1.3334823846817017, 3: 0.7505266666412354, 4: 0.742843508720398, 5: 0.5759084224700928, 6: 0.8209231495857239, 7: 0.7078948020935059, 8: 1.0233280658721924}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['i', 'you', 'he', 'she', 'we']
#
#  MLM candidate #0 : i
# {'sequence': '[CLS] i got hired at barnes and noble! [UNK] [SEP]', 'score': 0.7591915726661682, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 2814273  0.019804             Oh yeah #NoGoodDeed is GOOD! Go see it
# 1447277  0.042932                            I'll be back in January
# 1055064  0.068498  @Pennnn_Ayeeee good luck y'all! Hope you come ...
# 3606429  0.015529  one day @teddyjvanity and I will go in again t...
# 1433696  0.043477  We're #hiring! Read about our latest #job open...
#
#  MLM candidate #1 : you
# {'sequence': '[CLS] you got hired at barnes and noble! [UNK] [SEP]', 'score': 0.04812704026699066, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                               text
# 1863421  0.031058                      @chlomarz thank you Chloe :-)
# 1161571  0.058949                  @RedskinsCR @Redskins Thank you!!
# 3902765  0.014411                 @emeraldrichelle lol you do tho!!!
# 3320591  0.016809            @alexiac0018 I'm ugly, but love you❤️❤️
# 1777955  0.032873  @kurtisswaggy dawhh ☺️ thanks bro! I see you h...
#
#  MLM candidate #2 : he
# {'sequence': '[CLS] he got hired at barnes and noble! [UNK] [SEP]', 'score': 0.04116682708263397, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 321163   0.574778  Winners from another big show on Sunday night ...
# 3527549  0.015861               Dude I just had the laugh of my life
# 236667   0.768923  Number crunching for the past week - 204 new f...
# 3875100  0.014507  @ShareiTweets Hello Sara, Thanks to following ...
# 172981   0.875382  Hey folks, check out my new essay up at Turnin...
#
#  MLM candidate #3 : she
# {'sequence': '[CLS] she got hired at barnes and noble! [UNK] [SEP]', 'score': 0.03248002380132675, 'token': 2016, 'token_str': 'she'}
# Random sample of tweets containing keyword she:
#             score                                               text
# 2642520  0.021133  Thank god she didn’t deserve her own show to b...
# 3780797  0.014849  she naked she soakin wettt SHAKE IT LIKE A SAL...
# 3455539  0.016178              Fake hair and eyelashes for days!!! 🙈
# 2565057  0.021803                      she got the body of a goddess
# 4008448  0.014054              Just a disclaimer: she is my real mom
#
#  MLM candidate #4 : we
# {'sequence': '[CLS] we got hired at barnes and noble! [UNK] [SEP]', 'score': 0.022459397092461586, 'token': 2057, 'token_str': 'we'}
# Random sample of tweets containing keyword we:
#             score                                               text
# 3621660  0.015467  How the hell does Preacher get renewed for a n...
# 2102149  0.027113                @leee_xoxo @tease were goals af💜💜💜💜
# 885431   0.091430    Excited to be heading to Portland for the week!
# 2412323  0.023276  32 amazing followers in the last week and ther...
# 3474060  0.016095                      this banquet gonna be weak af
# *********** End of keyword exploration on tweet #5 ***********
# *********** Tweet #6 ***********
# Tweet: I just got hired! #gloria!!
#
# Tokenized version of tweet: ['I', 'just', 'got', 'hired', '!', '#', 'gl', '##oria', '!', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.786690354347229, 1: 0.9872668981552124, 2: 0.8697118163108826, 3: 1.387384057044983, 4: 0.8119597434997559, 5: 0.948147177696228, 6: 0.8375120759010315, 7: 0.9044555425643921, 8: 0.7275987863540649, 9: 0.7392739057540894}
# Token with most attention on average: I
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "I":
#  ['i', 'you', 'we', 'he', 'they']
#
#  MLM candidate #0 : i
# {'sequence': '[CLS] i just got hired! # gl # # oria!! [SEP]', 'score': 0.7441560626029968, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 527879   0.239372  NCLEX in less than 24 hours 😧😫 #nervous #nursi...
# 3093737  0.018010                            @RinHugs 2 fucking days
# 3855499  0.014577           Happy birthday my nigga @obey_maambition
# 3352319  0.016657  Love the energy! Keep it up boys! #LETSGODEVIL...
# 3109690  0.017919                       You're like a book of poetry
#
#  MLM candidate #1 : you
# {'sequence': '[CLS] you just got hired! # gl # # oria!! [SEP]', 'score': 0.1052004024386406, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                           text
# 3185292  0.017502                              my youth is yours
# 1782183  0.032776        @arianagrande i love you mi princesa 💜🌙
# 2953571  0.018859  @Mz_Neshea hi hun i miss youuuuu how you been
# 2119026  0.026863                  @keena_britz We love you! 💛💛💛
# 422558   0.367929                 @whiteboi_2_rif I got you bruh
#
#  MLM candidate #2 : we
# {'sequence': '[CLS] we just got hired! # gl # # oria!! [SEP]', 'score': 0.07374891638755798, 'token': 2057, 'token_str': 'we'}
# Random sample of tweets containing keyword we:
#             score                                               text
# 639534   0.164950  SHOUT OUT TO my new follower @_AnthonyDG #Team...
# 1583464  0.038086  💖 You're so sweet and pretty! &amp; we need to...
# 422054   0.368753  Hell I've been on the go for like the past thr...
# 1201763  0.056006  @AllyBrooke ALLY PLEASE FOLLOW ME ILY! I met y...
# 3052957  0.018248    This season is gonna be a goodie #PowerPremiere
#
#  MLM candidate #3 : he
# {'sequence': '[CLS] he just got hired! # gl # # oria!! [SEP]', 'score': 0.024708589538931847, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 331111   0.551530  Nigga we still here‼️‼️🤘🏽👌🏽💯💯🆙〽️〽️ https://t.c...
# 2898450  0.019220  I'm at The Juice Joint (River Forest, IL) http...
# 730411   0.128626  @jenn3bell congrats on the move! You gotta try...
# 2033867  0.027998                        Happy birthday🎉🎉 @RubyWheat
# 1345566  0.047508  Qualified for Boston today. 3.27.28. Very happ...
#
#  MLM candidate #4 : they
# {'sequence': '[CLS] they just got hired! # gl # # oria!! [SEP]', 'score': 0.017412902787327766, 'token': 2027, 'token_str': 'they'}
# Random sample of tweets containing keyword they:
#             score                                               text
# 2364056  0.023790  Just registered my boys for #nerdcampjr they'r...
# 2832086  0.019677  Woke up early so I could go to the bank becaus...
# 1326167  0.048496        I love going to Kenosha they cool asf .. 😩😈
# 3555122  0.015743  I still love this show. Goofy maybe, but they ...
# 2431073  0.023082  @msulibrary they are! Truly exceptional, we ar...
# *********** End of keyword exploration on tweet #6 ***********
# *********** Tweet #7 ***********
# Tweet: Just got hired for job #3... It's grind time! 💰
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'for', 'job', '#', '3', '.', '.', '.', 'It', "'", 's', 'grind', 'time', '!', '[UNK]']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 2.066835641860962, 1: 1.4238345623016357, 2: 1.5178766250610352, 3: 1.0180002450942993, 4: 0.9141720533370972, 5: 0.7743205428123474, 6: 0.8660517930984497, 7: 0.7493153214454651, 8: 0.7959371209144592, 9: 0.846527636051178, 10: 0.7951346039772034, 11: 0.4680565297603607, 12: 0.7952996492385864, 13: 1.3199459314346313, 14: 0.9638403654098511, 15: 0.6575740575790405, 16: 1.0272771120071411}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['i', 'he', 'you', 'she', 'we']
#
#  MLM candidate #0 : i
# {'sequence': "[CLS] i got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.7822150588035583, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 34343    0.969254                       New day, new grind...get it.
# 3810058  0.014741  @KaciAitchison @DOTA2 excited to see you at #t...
# 3075300  0.018117         I slept like at 9:30 &amp; I'm so sleepy 😕
# 2310351  0.024395  We're #hiring! Read about our latest #job open...
# 2089133  0.027301                 @emiyannn lmaoooo SHE CUTE THO YAS
#
#  MLM candidate #1 : he
# {'sequence': "[CLS] he got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.03605709969997406, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 218479   0.804292  I'm excited to head back to OF today but at th...
# 942783   0.082249  The movers are here!!!! Woohoo!! HURRY UP FELL...
# 1804832  0.032280                       oh my god I love cheap gifts
# 2367730  0.023751  Sometimes I wish I was normal &amp; actually w...
# 2849575  0.019552  What a great day to enjoy the pool and have a ...
#
#  MLM candidate #2 : you
# {'sequence': "[CLS] you got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.03129549324512482, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                               text
# 1318991  0.048874  @d0natelli hi yes I just saw this but I love y...
# 1145639  0.060208                        @milkvillain you're welcome
# 1637711  0.036456              @KinkyAna_G_FKS I miss you too baby x
# 1328537  0.048378                                 Omg 343 I love you
# 2530091  0.022124                @RitterWarren you love me long time
#
#  MLM candidate #3 : she
# {'sequence': "[CLS] she got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.022958675399422646, 'token': 2016, 'token_str': 'she'}
# Random sample of tweets containing keyword she:
#             score                                               text
# 1908041  0.030181             @she_spoiled Im right here dawg!! lmao
# 3454061  0.016185  shit. pretty sure that just did it\n\n#goalacc...
# 2979805  0.018692  Body Language by Kid Ink, Usher &amp; Tinashe ...
# 3842795  0.014622               @RichardOshey I'm adding you sooooon
# 3892267  0.014447                   Makeup brushes are all clean💙💙💙💙
#
#  MLM candidate #4 : we
# {'sequence': "[CLS] we got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.022094666957855225, 'token': 2057, 'token_str': 'we'}
# Random sample of tweets containing keyword we:
#             score                                               text
# 787172   0.112298  Yay we did it!!! #pros  @ Pentagon Row Ice Ska...
# 201059   0.834387  Stopped by the new studio the night before the...
# 792863   0.110842  @fiercesnap_werk I did it. You got this home gurl
# 2617076  0.021348                  @Iowa_Country_ just followed her😊
# 3398993  0.016437  Happy Birthday to the one and only @CindyStarf...
# *********** End of keyword exploration on tweet #7 ***********
# *********** Tweet #8 ***********
# Tweet: I just got hired !
#
# Tokenized version of tweet: ['I', 'just', 'got', 'hired', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.4480329751968384, 1: 0.8278199434280396, 2: 0.7723451852798462, 3: 1.2157444953918457, 4: 0.7360571622848511}
# Token with most attention on average: I
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "I":
#  ['i', 'you', 'we', 'he', 'they']
#
#  MLM candidate #0 : i
# {'sequence': '[CLS] i just got hired! [SEP]', 'score': 0.7047503590583801, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 2115689  0.026911  after this class I'm free who wants to do some...
# 3301539  0.016900                                 i don't sleep haha
# 70375    0.955291  Days are becoming monotonous... nothing to loo...
# 2318223  0.024304  @NoSAMpling_ I go every month in NY it's the b...
# 3129169  0.017809                            Missing my other half😔😒
#
#  MLM candidate #1 : you
# {'sequence': '[CLS] you just got hired! [SEP]', 'score': 0.14556042850017548, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                               text
# 615750   0.177506                   @Shurlburt12 thank you so much!!
# 828817   0.102445  Happy birthday, Jada! I miss youuu 🎉💛🎈😊 @Dorro...
# 3647223  0.015364  I have the best family in the entire world. Ca...
# 180797   0.864945  @Bevrlygalang happy new year din beyb ! Ilovey...
# 2695356  0.020701  If you haven't joined my new group you are sur...
#
#  MLM candidate #2 : we
# {'sequence': '[CLS] we just got hired! [SEP]', 'score': 0.06953918188810349, 'token': 2057, 'token_str': 'we'}
# Random sample of tweets containing keyword we:
#             score                                               text
# 1856861  0.031191  @OGTCavendish thanks for following us! Have a ...
# 2031455  0.028037  Day 1 of Registration is done, and @NellVoorhe...
# 390299   0.424621  Starting next week I'm start running Fr Fr I g...
# 353568   0.500555  I can't wait to see so many beautiful people t...
# 1466841  0.042140  Today is the first morning since the kids got ...
#
#  MLM candidate #3 : he
# {'sequence': '[CLS] he just got hired! [SEP]', 'score': 0.03123800829052925, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 437507   0.344886  2 days left until the New Year!💥 2015 is your ...
# 1427743  0.043723  I feel unbelievably blessed to have see One Di...
# 1568261  0.038572  @MsCyn_D @TheSoulFM1 We back! http://t.co/w0ef...
# 704181   0.137614  Thank God for another day of life! You never k...
# 1530807  0.039813        #NAS in The 'Cuse 👌💕❤🎶🎧🎤👏 #newyorkstatefair
#
#  MLM candidate #4 : they
# {'sequence': '[CLS] they just got hired! [SEP]', 'score': 0.01769813522696495, 'token': 2027, 'token_str': 'they'}
# Random sample of tweets containing keyword they:
#             score                                               text
# 1717030  0.034328               Dreams come slow but they go so fast
# 3770240  0.014888      @jadepastel they are@one of my favorite bands
# 3642506  0.015383  Brought white pants last night and they didn't...
# 3323562  0.016794  I just love those two they are the best perfor...
# 4001779  0.014075  Im going to the gym tonight they not taking my...
# *********** End of keyword exploration on tweet #8 ***********
# *********** Tweet #9 ***********
# Tweet: Just got hired in the spot. #TwoJobs 💸
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'in', 'the', 'spot', '.', '#', 'Two', '##Job', '##s', '[UNK]']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.9054388999938965, 1: 1.1128920316696167, 2: 1.3489856719970703, 3: 0.738501250743866, 4: 0.6312955617904663, 5: 1.176804542541504, 6: 0.9598628878593445, 7: 0.8739089965820312, 8: 0.8465639352798462, 9: 0.9671778678894043, 10: 0.5526459217071533, 11: 0.8859226703643799}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['i', 'he', 'she', 'you', 'we']
#
#  MLM candidate #0 : i
# {'sequence': '[CLS] i got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.5319151878356934, 'token': 1045, 'token_str': 'i'}
# Random sample of tweets containing keyword i:
#             score                                               text
# 3470286  0.016112  This is the greatest thing on the internet tod...
# 1593188  0.037780              @krimsontide1911 ha!!! love it. #hype
# 1952198  0.029374  Dbacks 2-0 on the year! Wins over Duarango(4-3...
# 71034    0.955044  I'm inlove w my new hair!!! https://t.co/A9G0z...
# 2893107  0.019256                 no i dont wanna have a new account
#
#  MLM candidate #1 : he
# {'sequence': '[CLS] he got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.13496866822242737, 'token': 2002, 'token_str': 'he'}
# Random sample of tweets containing keyword he:
#             score                                               text
# 2601348  0.021484  First hat trick in @SoundersFC2 history! Darwi...
# 36786    0.968432  First time at a hookah bar, i had more fun the...
# 1475582  0.041808  Happy 175th Birthday to my favorite school and...
# 114835   0.931102  Start the week off laughing at The People's Sh...
# 2348858  0.023958  Checking out the new album by @TheLopers fanta...
#
#  MLM candidate #2 : she
# {'sequence': '[CLS] she got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.04584413766860962, 'token': 2016, 'token_str': 'she'}
# Random sample of tweets containing keyword she:
#             score                                               text
# 1758072  0.033328  Happy birthday Sehunnie~!!! I'm so proud of ev...
# 470984   0.298884  Finished Cycle with #cyclemeter, on a new rout...
# 3361236  0.016613  ha ha wow I can't believe she's wearing the sa...
# 125144   0.923449  Just finished a new song. Stoked as fuck about...
# 1396799  0.045070  I checked in at Hollingshead's on #Yelp http:/...
#
#  MLM candidate #3 : you
# {'sequence': '[CLS] you got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.040139999240636826, 'token': 2017, 'token_str': 'you'}
# Random sample of tweets containing keyword you:
#             score                                               text
# 3983327  0.014136       @kyouyagaryu thank you for being considerate
# 1229514  0.054137                 @itypetotweet you're the realest👏🏾
# 1752549  0.033460  Good luck to everyone taking the PLAN test  an...
# 2294667  0.024577  Happy birthday @maile_madsen !🎉 you're a beaut...
# 1860788  0.031110       @NimoooAbdullahi ahhhh thank you quruxlay 😊😘
#
#  MLM candidate #4 : we
# {'sequence': '[CLS] we got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.03306762874126434, 'token': 2057, 'token_str': 'we'}
# Random sample of tweets containing keyword we:
#             score                                               text
# 228253   0.785733  My daily stats: 10 new followers, 5 new unfoll...
# 2436571  0.023028  And we danced all night to the best song ever! 🎧👯
# 1119380  0.062386  @pelucachick46 Your welcome and thank you! Hav...
# 193054   0.847208  Today stats: 2 new followers via http://t.co/2...
# 1003937  0.074178  Long weekend of travel. Made it home with minu...
# *********** End of keyword exploration on tweet #9 ***********

# %% [markdown]
# #### MLM with our fine-tuned ConvBERT model

# %%
for tweet_index in range(10):
    print('*********** Tweet #{} ***********'.format(str(tweet_index)))
    input_sequence = is_hired_1mo_df['text'][tweet_index]
    tokenized_tweet = tokenizer.tokenize(input_sequence)
    print('Tweet: {} \n'.format(input_sequence))
    print('Tokenized version of tweet: {} \n'.format(tokenized_tweet))
    #identify high attention token
    print('$$$ Attention $$$')
    print('')
    attention_results_dict = get_token_in_sequence_with_most_attention(model, tokenizer, input_sequence)
    attention_token_str = attention_results_dict['token_str']
    attention_token_index = attention_results_dict['token_index']
    print('Token with most attention on average: {}'.format(attention_token_str))
    print('Token index with most attention on average: {} \n'.format(attention_token_index))
    #do MLM
    ## replace high-attention token by a [MASK] token
    print('$$$ MLM $$$ \n')
    tokenized_tweet[attention_token_index] = '[MASK]'
    mlm_results_list = mlm_pipeline_custom(' '.join(tokenized_tweet))
    selected_keywords_list = extract_keywords_from_mlm_results(mlm_results_list, 5)
    print('Ranked MLM selected keywords for token "{}": \n'.format(attention_results_dict['token_str']), selected_keywords_list)
    for i in range(len(mlm_results_list)):
        keyword = mlm_results_list[i]['token_str']
        keyword = keyword.replace('##', '')
        print('\n MLM candidate #{} : {}'.format(str(i), keyword))
        print(mlm_results_list[i])
        tweets_containing_keyword_df = is_hired_1mo_df[is_hired_1mo_df['text'].str.contains(keyword)]
        print('Random sample of tweets containing keyword {}:'.format(keyword))
        print(tweets_containing_keyword_df.sample(n=5)[['score','text']].head())
    print('*********** End of keyword exploration on tweet #{} ***********'.format(str(tweet_index)))
# Out:
# *********** Tweet #0 ***********
# Tweet: Got hired today!!!
#
# Tokenized version of tweet: ['Got', 'hired', 'today', '!', '!', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.512681484222412, 1: 1.4664392471313477, 2: 0.8879140615463257, 3: 0.6898781657218933, 4: 0.6860101222991943, 5: 0.7570768594741821}
# Token with most attention on average: Got
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Got":
#  ['h', '##ghan', '##ark', '##ahan', '##CF']
#
#  MLM candidate #0 : h
# {'sequence': '[CLS] h hired today!!! [SEP]', 'score': 0.00047591223847121, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 3954877  0.014232  Editing a hilarious @Tim__Kang. Can't stop lau...
# 2359046  0.023845  i don't work til 330, niggas should have fled ...
# 3002059  0.018553  You have a beautiful soul and that's why every...
# 187451   0.855582  We started something New @ our Last Show - We ...
# 3642673  0.015382  Lol no where near excited for my birthday, jus...
#
#  MLM candidate #1 : ghan
# {'sequence': '[CLS]ghan hired today!!! [SEP]', 'score': 0.00043608370469883084, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 3433397  0.016278  Can't. Stop. Watching. #OutlanderWedding. My p...
# 638944   0.165229  @LeighanneReena thank you for being so awesome...
# 1930773  0.029753  Just voted for #shameless on the #EWCoverBattl...
# 475523   0.293298  @LacroixDuncan Happy birthday to you! Here's t...
# 1259384  0.052246  I'm at Monaghan's in San Francisco, CA https:/...
#
#  MLM candidate #2 : ark
# {'sequence': '[CLS]ark hired today!!! [SEP]', 'score': 0.0004002558998763561, 'token': 1119, 'token_str': '##ark'}
# Random sample of tweets containing keyword ark:
#             score                                               text
# 953579   0.080726                          Saw The Bae At The Park 💕
# 1233603  0.053867           @markyropes Markyyyyyyyyu thank you bro!
# 3680445  0.015233  i will meet at least 1/5 of one direction this...
# 1383194  0.045694         I can officially parallel park YAYAYAYAYYY
# 3454846  0.016181                                 Manshark #TheFlash
#
#  MLM candidate #3 : ahan
# {'sequence': '[CLS]ahan hired today!!! [SEP]', 'score': 0.00036692561116069555, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 4005506  0.014063  Thank you for joining my family!! @KMCoady @gu...
# 3136995  0.017767  Because I want you. I want all of you, forever...
# 1259044  0.052267                          @_leahanne I lone u too 💕
# 2333288  0.024132                   @Hmm_tahania awhhhhh i love you!
# 173445   0.874775  Just arrived!!! We are so excited to introduce...
#
#  MLM candidate #4 : CF
# {'sequence': '[CLS]CF hired today!!! [SEP]', 'score': 0.0003461807791609317, 'token': 27783, 'token_str': '##CF'}
# Random sample of tweets containing keyword CF:
#             score                                               text
# 2339712  0.024059  Congratz to UT &amp; UCF for program changing ...
# 2925488  0.019042  Well the ranking are already screwed up after ...
# 2104220  0.027082  “@paullaus3: My new wine glass!!! http://t.co/...
# 606155   0.183003     @WubsNet ITS CALLED #EPICFAIL #GeneralHospital
# 2138198  0.026594  It's coming this Tuesday to Community Farmers ...
# *********** End of keyword exploration on tweet #0 ***********
# *********** Tweet #1 ***********
# Tweet: Just got hired at Google.
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'at', 'Google', '.']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.446664571762085, 1: 0.9768638610839844, 2: 1.2318527698516846, 3: 0.6410866975784302, 4: 0.8262072801589966, 5: 0.8773250579833984}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['##ghan', 'h', '##ahan', 'blank', '##ark']
#
#  MLM candidate #0 : ghan
# {'sequence': '[CLS]ghan got hired at Google. [SEP]', 'score': 0.0004367468354757875, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 1684453  0.035164  Amazing performance by @CameronMonaghan. A sta...
# 2140478  0.026561  I'm so obsessed with @Meghan_Trainor new song ...
# 1898462  0.030363  @MeghanKEdmonds @ShannonBeador  @vgunvalson @T...
# 1369352  0.046352                         @MeaghanCruz_ Thank you 💘😊
# 1238301  0.053567                                 lmao ghana i see u
#
#  MLM candidate #1 : h
# {'sequence': '[CLS] h got hired at Google. [SEP]', 'score': 0.0004349522350821644, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 48103    0.964410  A big welcome to our new staff. Their first da...
# 4020150  0.014016  Mary Jane is always here for me. We have a bon...
# 1670135  0.035554                  @Trinaahh_ it's ok lol thank you😊
# 2517769  0.022236                            I love lush I love lush
# 133432   0.916837  Arrived in Portland. I can't wait to get into ...
#
#  MLM candidate #2 : ahan
# {'sequence': '[CLS]ahan got hired at Google. [SEP]', 'score': 0.00040685373824089766, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 2466314  0.022731                    @sarahandharlow Get it girl!!!!
# 2574216  0.021721  @sophiayiraaa @jennahansenn I love you both ❤️...
# 1266145  0.051846                  Happy birthday, @kate_manahan! ☺️
# 447158   0.330644  i just have a full day of class and a day of w...
# 2203796  0.025708                 @colbycallahan2 Thank you so much!
#
#  MLM candidate #3 : blank
# {'sequence': '[CLS] blank got hired at Google. [SEP]', 'score': 0.0003779436810873449, 'token': 9153, 'token_str': 'blank'}
# Random sample of tweets containing keyword blank:
#             score                                               text
# 2272317  0.024838  Bruh I really blanked out during my presentati...
# 3943343  0.014272  Another rainy day in new york  really in need ...
# 3367592  0.016583  I got to lay in a truck bed with blankets and ...
# 2159010  0.026313  Tonight @gregory_crafts primed the stage for #...
# 242150   0.757922  Using my new blanket Claire made me!! 😍 It's h...
#
#  MLM candidate #4 : ark
# {'sequence': '[CLS]ark got hired at Google. [SEP]', 'score': 0.00036851043114438653, 'token': 1119, 'token_str': '##ark'}
# Random sample of tweets containing keyword ark:
#             score                                               text
# 3512628  0.015926  Ugh I'm in Hyde park @Amarilys181 your lucky I...
# 184244   0.860109  it's finally here! @NaturesGardenEx open tomor...
# 1699799  0.034762  We're #hiring! Read about our latest #job open...
# 2190867  0.025879  Omgggggg @PhaedraParks GOOOOO INNNNNN!!!!! #RH...
# 3412199  0.016375  Come on bulldogs!! #omahadawgs #CWS Oh, and ti...
# *********** End of keyword exploration on tweet #1 ***********
# *********** Tweet #2 ***********
# Tweet: Just got hired at Hobby Lobby!
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'at', 'Ho', '##bby', 'Lo', '##bby', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 2.003485918045044, 1: 1.0714242458343506, 2: 1.2882232666015625, 3: 0.8825027942657471, 4: 0.6916071176528931, 5: 0.911846935749054, 6: 0.6171857118606567, 7: 0.7439514994621277, 8: 0.7897726893424988}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['##ahan', 'h', '##ghan', '##ark', '##CF']
#
#  MLM candidate #0 : ahan
# {'sequence': '[CLS]ahan got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.00047332103713415563, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 3736700  0.015014  @kyliemahaney that was the sweetest thing ever...
# 131596   0.918354                  @seriahanicole You made it worse😑
# 2841410  0.019610  The #PACisBACK y'all! #evsRO on #PACERSvHAWKS ...
# 3833891  0.014654            @bailey_brew @IanCarnahan love you guys
# 2182522  0.025992                         @amandahanley47 thank lord
#
#  MLM candidate #1 : h
# {'sequence': '[CLS] h got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.0004347895155660808, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 494186   0.272275  I left high school after my junior year, finis...
# 1196689  0.056369  I could sleep all night &amp; take a nap durin...
# 925394   0.084816  Tomorrow night I've the pleasure of helping ou...
# 3499586  0.015983  I'm even packing lunch 😭😭✌🏾️ I gotta be on my ...
# 560238   0.213055                             Happy happy birthday!!
#
#  MLM candidate #2 : ghan
# {'sequence': '[CLS]ghan got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.00040407897904515266, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 2110740  0.026984                   Happy birthday @meghan_bender  😁
# 1527936  0.039915                 @meghanrobles_ you're so pretty 😩😍
# 3508494  0.015944  Always a lovely time with the ladies! @elbee38...
# 1452650  0.042711  Happy birthday @NicoleConnaghan ☺️💕 I hope you...
# 3335549  0.016737  @AngelaLanter I'm here too! Loved Meghan on #s...
#
#  MLM candidate #3 : ark
# {'sequence': '[CLS]ark got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.0003781171690206975, 'token': 1119, 'token_str': '##ark'}
# Random sample of tweets containing keyword ark:
#             score                                               text
# 106174   0.936950  @ScottTParkinson Haha! I'd pay to see that! Ho...
# 1610670  0.037250            @MarkWind_sounds Hello &amp; Thank You!
# 3162589  0.017626                         @Thaaa_BOMB evergreen park
# 1566154  0.038634  This is tomorrow at Jaycee Park in Clemson. 11...
# 289595   0.650430  Dropped in to sign copies at B&amp;N at Desert...
#
#  MLM candidate #4 : CF
# {'sequence': '[CLS]CF got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.00036139096482656896, 'token': 27783, 'token_str': '##CF'}
# Random sample of tweets containing keyword CF:
#             score                                               text
# 2517212  0.022241                           What a game. #CFBPlayoff
# 1141206  0.060571  Super excited about our (well not really ours,...
# 3015981  0.018470                                     Home as in UCF
# 2238129  0.025261  So you're tell me FSU starts at 16... Isn't th...
# 141482   0.909765  Game Started | CBC at CF10 https://t.co/w991Oj...
# *********** End of keyword exploration on tweet #2 ***********
# *********** Tweet #3 ***********
# Tweet: Got hired at Chick Fil A!
#
# Tokenized version of tweet: ['Got', 'hired', 'at', 'Chi', '##ck', 'Fil', 'A', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.6901259422302246, 1: 1.4704525470733643, 2: 0.8817121982574463, 3: 0.8063538074493408, 4: 0.8460407853126526, 5: 0.8220968246459961, 6: 0.6992152333259583, 7: 0.7840021252632141}
# Token with most attention on average: Got
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Got":
#  ['##ghan', '##ahan', 'h', '##CF', '##isi']
#
#  MLM candidate #0 : ghan
# {'sequence': '[CLS]ghan hired at Chi # # ck Fil A! [SEP]', 'score': 0.0004237811954226345, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 1606012  0.037389  .@meighan_simmons getting some shots up to get...
# 2394874  0.023460        @OfficialGeorgeS @tylerringhand AMEN!!!!!!!
# 1682084  0.035228                               You too @k_leighanna
# 1664527  0.035708               @Aye_Meaghann good luck baby girl 😌😘
# 2022019  0.028186            @meghanacheeti thanks meghana😘😘 love ya
#
#  MLM candidate #1 : ahan
# {'sequence': '[CLS]ahan hired at Chi # # ck Fil A! [SEP]', 'score': 0.0004124350962229073, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 1350723  0.047263  @xcallahanloosx @jessicattxo OMG I WASNT GONNA...
# 1966537  0.029121                       Miss my man @ChaseHanrahan 😓
# 1577237  0.038287  @ShanahanWilson yeah its my birthday :) thank ...
# 3779365  0.014854  @chelseahandler i need to meet you! 😍 i love y...
# 366444   0.472934    happy birthday @destini_trahan !!! I love you❤️
#
#  MLM candidate #2 : h
# {'sequence': '[CLS] h hired at Chi # # ck Fil A! [SEP]', 'score': 0.0003985841467510909, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 2749981  0.020278     What I would do to be in Dallas to see 5SOS! 😒
# 111645   0.933408  Tonight is the first Windfall meeting of the s...
# 3637232  0.015404  The nerve to have on the same look but I pulle...
# 584279   0.196260  We're hiring! Physician - Endocrinology - Flor...
# 1874002  0.030847      Slow down long enough to enjoy your success!!
#
#  MLM candidate #3 : CF
# {'sequence': '[CLS]CF hired at Chi # # ck Fil A! [SEP]', 'score': 0.0003779437392950058, 'token': 27783, 'token_str': '##CF'}
# Random sample of tweets containing keyword CF:
#             score                                               text
# 998304   0.074867  Almost 200 Likes for the "Happy Birthday, Dad"...
# 3124372  0.017835                                     AND A MCFLURRY
# 693183   0.141755          @CFoust90 @DopeShii_ @ckparrot we got him
# 881988   0.092038  It's In!\nOpening Day Lineup vs. Reds \n\nCarp...
# 1090344  0.064995  Love having u in @logankilgore. Pumped for ur ...
#
#  MLM candidate #4 : isi
# {'sequence': '[CLS]isi hired at Chi # # ck Fil A! [SEP]', 'score': 0.00037385764881037176, 'token': 26868, 'token_str': '##isi'}
# Random sample of tweets containing keyword isi:
#             score                                               text
# 1123329  0.062055  New #job opening at Moroch Partners, LP in #Da...
# 370043   0.465288  New #job opening at Lithia Auto Stores in #Aus...
# 1431300  0.043575  We were so blessed to have the vision of etern...
# 1168884  0.058382  2016 visit to boston to see my cocktail friend...
# 1505420  0.040703  #Obama visiting #Rochester was ALMOST as much ...
# *********** End of keyword exploration on tweet #3 ***********
# *********** Tweet #4 ***********
# Tweet: Got hired today at the hooters on the beach! 😉😘 http://t.co/CXJwFlJBDD
#
# Tokenized version of tweet: ['Got', 'hired', 'today', 'at', 'the', 'ho', '##oter', '##s', 'on', 'the', 'beach', '!', '[UNK]', 'http', ':', '/', '/', 't', '.', 'co', '/', 'C', '##X', '##J', '##w', '##Fl', '##J', '##B', '##DD']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 2.024837017059326, 1: 2.091308355331421, 2: 1.0261682271957397, 3: 0.8227925896644592, 4: 0.8867378830909729, 5: 0.6843050122261047, 6: 0.9743086695671082, 7: 0.722823441028595, 8: 0.8818274736404419, 9: 0.5169667601585388, 10: 1.239403247833252, 11: 0.8934236764907837, 12: 0.7671450972557068, 13: 1.0015952587127686, 14: 0.8535885214805603, 15: 0.8662177324295044, 16: 0.9419586062431335, 17: 0.9503006935119629, 18: 0.9791205525398254, 19: 1.1336263418197632, 20: 0.9325909614562988, 21: 0.8440161347389221, 22: 0.949721097946167, 23: 0.952224850654602, 24: 1.0904576778411865, 25: 1.1882437467575073, 26: 0.9217448830604553, 27: 0.8995845317840576, 28: 0.9629606604576111}
# Token with most attention on average: hired
# Token index with most attention on average: 1
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "hired":
#  ['##ohn', 'factor', 'Factor', '##vid', '##quer']
#
#  MLM candidate #0 : ohn
# {'sequence': '[CLS] Gotohn today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0006654902244918048, 'token': 27357, 'token_str': '##ohn'}
# Random sample of tweets containing keyword ohn:
#             score                                               text
# 3008782  0.018513                    John Legend x Ordinary People 👏
# 3264665  0.017087  @JohnSian1 im sorry :/ i logged off after a fe...
# 1729802  0.034011           I luv my bffz @audjohnsss @GauthierRenee
# 3809952  0.014741  happy homecoming to my favorites @TruckJ_AllDa...
# 3791647  0.014808  Coach Johnson just called and wished me a happ...
#
#  MLM candidate #1 : factor
# {'sequence': '[CLS] Got factor today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0006555696600116789, 'token': 5318, 'token_str': 'factor'}
# Random sample of tweets containing keyword factor:
#             score                                               text
# 170577   0.878340  #xfactorpremiere tonight!!!! Yay it's finally ...
# 2283287  0.024706              @deborahallen3 Wow factor for Monday!
# 499737   0.266312  Today was a "draw a lot, unsatisfactory" kind ...
# 2184653  0.025962                             IM DYING 😂😭😂😭 #xfactor
# 398017   0.410119       @Hazza_infection x-factor :p whatev, done :)
#
#  MLM candidate #2 : Factor
# {'sequence': '[CLS] Got Factor today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.00061025470495224, 'token': 15926, 'token_str': 'Factor'}
# Random sample of tweets containing keyword Factor:
#             score                                               text
# 156028   0.895282  Spotted at Comics Factory in Pasadena! Lookin'...
# 1308741  0.049423  Day 2 of WOW Factor! I absolutely love my chee...
# 2393060  0.023479  I can't contain my excitment!! I'm gonna be si...
# 1857443  0.031179    Love love Loooove my Dance Factory Family &lt;3
# 726837   0.129754  So confident with my @TheXFactorUSA audition :...
#
#  MLM candidate #3 : vid
# {'sequence': '[CLS] Gotvid today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0005055710789747536, 'token': 18312, 'token_str': '##vid'}
# Random sample of tweets containing keyword vid:
#             score                                               text
# 2306704  0.024437  On my way to East Providence for my kids inter...
# 2951648  0.018871  @ashlynsully23 aw thanks ashlyn💗💗 omg I'm actu...
# 916106   0.086270  TOP WORLD DАTING SITЕ ONLINE FRЕE!! JUST SEXY ...
# 245120   0.751812                                         new video.
# 1623045  0.036880                       That video is so disturbing😷
#
#  MLM candidate #4 : quer
# {'sequence': '[CLS] Gotquer today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.00046522438060492277, 'token': 19061, 'token_str': '##quer'}
# Random sample of tweets containing keyword quer:
#             score                                               text
# 686019   0.144508  The new office is coming along quickly! Countd...
# 1950623  0.029402                        I have conquered Maruniak!!
# 351227   0.505910                       I came , I saw , I conquered
# 2103472  0.027092  I’m Jamaican ! I conquer anything that comes a...
# 3683804  0.015220  The warm feeling you get watching your friends...
# *********** End of keyword exploration on tweet #4 ***********
# *********** Tweet #5 ***********
# Tweet: Just got hired at Barnes and Noble! 😂🔥
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'at', 'Barnes', 'and', 'Noble', '!', '[UNK]']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.9725040197372437, 1: 1.0725888013839722, 2: 1.3334823846817017, 3: 0.7505266666412354, 4: 0.742843508720398, 5: 0.5759084224700928, 6: 0.8209231495857239, 7: 0.7078948020935059, 8: 1.0233280658721924}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['##ghan', '##ahan', 'h', '##ark', '##CF']
#
#  MLM candidate #0 : ghan
# {'sequence': '[CLS]ghan got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.00044865658855997026, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 737056   0.126471                           @MaeghanCoco thank you!!
# 2935777  0.018974  Thank you, @changinghands, for taking my books...
# 781837   0.113698               @shighanigga your oh so very welcome
# 1569159  0.038544  @PhilKeoghan can't wait !!! Love love the show !!
# 2270167  0.024865  One more hour! Beyond proud of the homie @twis...
#
#  MLM candidate #1 : ahan
# {'sequence': '[CLS]ahan got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.00043465892667882144, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 1560413  0.038823  We're #hiring! Read about our latest #job open...
# 94549    0.943834                   @callahan_theDon you're going !?
# 1412724  0.044365                           @afrikahany Thank you 😍💖
# 665802   0.152795  Monday Funday! @Krewella @krewellayasmine @Kre...
# 3454718  0.016182   @KennedyMcMahan miss you so much. #irreplaceable
#
#  MLM candidate #2 : h
# {'sequence': '[CLS] h got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.0004327408387325704, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 457539   0.316309                    I DID IT http://t.co/co1Wc6EbLw
# 1369468  0.046346    @HardenFromEspn gonna start off fresh again tbh
# 3876068  0.014504                                         Catch this
# 498604   0.267563  @AlmightyAron that's guna be me in a few hours...
# 116184   0.930136                   Shootin new video next Sunday ..
#
#  MLM candidate #3 : ark
# {'sequence': '[CLS]ark got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.00037509272806346416, 'token': 1119, 'token_str': '##ark'}
# Random sample of tweets containing keyword ark:
#             score                                               text
# 483843   0.283813  Senior Friday continues this Fri April 11! Com...
# 1739186  0.033782  #ThePassionLive is awesome. Born in New Orlean...
# 3390370  0.016477  @HarmonyBStark i love you too harmony *smiles ...
# 2011982  0.028351                   @thesparkleking RALPH I LOVE HIM
# 52140    0.962849  Happy 4th of July! Let the fireworks mark your...
#
#  MLM candidate #4 : CF
# {'sequence': '[CLS]CF got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.0003367279714439064, 'token': 27783, 'token_str': '##CF'}
# Random sample of tweets containing keyword CF:
#             score                                               text
# 3635743  0.015410  UCF is fun and all but I'd rather be in South ...
# 2389513  0.023517  @extrabaggs isn't that how it usually goes? Th...
# 851830   0.097631             @BeccaR5Smile @ABCFsab you're welcome!
# 3648415  0.015360                   Childhood memories. #AMCFearFest
# 1273664  0.051395  I'm very PROUD of Mine! :) @trizzetrell http:/...
# *********** End of keyword exploration on tweet #5 ***********
# *********** Tweet #6 ***********
# Tweet: I just got hired! #gloria!!
#
# Tokenized version of tweet: ['I', 'just', 'got', 'hired', '!', '#', 'gl', '##oria', '!', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.786690354347229, 1: 0.9872668981552124, 2: 0.8697118163108826, 3: 1.387384057044983, 4: 0.8119597434997559, 5: 0.948147177696228, 6: 0.8375120759010315, 7: 0.9044555425643921, 8: 0.7275987863540649, 9: 0.7392739057540894}
# Token with most attention on average: I
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "I":
#  ['h', '##ahan', '##ghan', '##ark', '##CF']
#
#  MLM candidate #0 : h
# {'sequence': '[CLS] h just got hired! # gl # # oria!! [SEP]', 'score': 0.0004110034496989101, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 2872912  0.019393             I'm goin be in skool wit mad old heads
# 681974   0.146097                         @FreeMckenzie Thanks!!!!!!
# 623594   0.173175  What an amazing start to an amazing journey! #...
# 1240553  0.053422                 HAWKS WIN!!! #Blackhawks #CHIvsMTL
# 283817   0.664001             This is the last 6 weeks of school 🙄🙏🏽
#
#  MLM candidate #1 : ahan
# {'sequence': '[CLS]ahan just got hired! # gl # # oria!! [SEP]', 'score': 0.0003933983389288187, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 408769   0.390741  S\O to my new Followers @H3bK11 @InfosHumour @...
# 1057652  0.068224                    @sittitingkahan thank alsooo 😊💕
# 82309    0.950026  @SarahandUnicorn Good luck guhh. PCL's our new...
# 597866   0.187871  @NoFeelings_Tho yeah Saturday at the aldi on H...
# 992071   0.075623                           @lizzzycallahan thank u!
#
#  MLM candidate #2 : ghan
# {'sequence': '[CLS]ghan just got hired! # gl # # oria!! [SEP]', 'score': 0.0003790825139731169, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 2752398  0.020259  Completely, and pleasantly, surprised by @megh...
# 2452489  0.022868  @holdinghands93 that's not fair! Our graduatio...
# 3667668  0.015283  @SamHeughan so proud of you and Cait!  Enjoy y...
# 3289720  0.016959  I swear I love @meghantonjes she is inspiratio...
# 1316853  0.048983  Happy Birthday Beautiful!!!😃😃😃 hope it's amazi...
#
#  MLM candidate #3 : ark
# {'sequence': '[CLS]ark just got hired! # gl # # oria!! [SEP]', 'score': 0.00035571708576753736, 'token': 1119, 'token_str': '##ark'}
# Random sample of tweets containing keyword ark:
#             score                                               text
# 459831   0.313252   Good day Erik, good to meet you @SimplyAfterDark
# 1532951  0.039737  Just getting home from Cici's🍕and the park🍂.Fa...
# 3110961  0.017912  I miss middle school, when I still had best fr...
# 344121   0.521787                i found you in the darkest hour. :b
# 2879429  0.019349          @trailerparkboys @netflix can't wait!!!!!
#
#  MLM candidate #4 : CF
# {'sequence': '[CLS]CF just got hired! # gl # # oria!! [SEP]', 'score': 0.00034135315218009055, 'token': 27783, 'token_str': '##CF'}
# Random sample of tweets containing keyword CF:
#             score                                               text
# 2658813  0.020998  We're #hiring! Read about our latest #job open...
# 680653   0.146604                       @King_Of_CF_1 IT'S STILL HIM
# 2112     0.981705  Today was my first day at BCFS Health and Huma...
# 2231691  0.025345  Go Eagles, Indians, Mules, &amp; Yellow Jacket...
# 1882458  0.030679                          @MullySCFC on my own then
# *********** End of keyword exploration on tweet #6 ***********
# *********** Tweet #7 ***********
# Tweet: Just got hired for job #3... It's grind time! 💰
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'for', 'job', '#', '3', '.', '.', '.', 'It', "'", 's', 'grind', 'time', '!', '[UNK]']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 2.066835641860962, 1: 1.4238345623016357, 2: 1.5178766250610352, 3: 1.0180002450942993, 4: 0.9141720533370972, 5: 0.7743205428123474, 6: 0.8660517930984497, 7: 0.7493153214454651, 8: 0.7959371209144592, 9: 0.846527636051178, 10: 0.7951346039772034, 11: 0.4680565297603607, 12: 0.7952996492385864, 13: 1.3199459314346313, 14: 0.9638403654098511, 15: 0.6575740575790405, 16: 1.0272771120071411}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['##ahan', 'h', '##ghan', '##isi', 'blank']
#
#  MLM candidate #0 : ahan
# {'sequence': "[CLS]ahan got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.00043119757901877165, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 2600420  0.021492                               @Mahannyy exactly!!👭
# 326056   0.563331  2nd show tonite Wed 7/20 in #Albuquerque at #R...
# 541420   0.227819                   @megcallahan94 thanks love!!! :)
# 1926241  0.029837                          @SarahandNiall I love you
# 3820320  0.014703  @LovatoLover93 @itsohsodemi @m_callahan From t...
#
#  MLM candidate #1 : h
# {'sequence': "[CLS] h got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.00041112242615781724, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                              text
# 1775602  0.032928            @cborledaily I'm just so happy for him
# 1112792  0.062958    Damn these finals is crazy I'm suprised asf rn
# 3229223  0.017269        My GOD! She gave me chills Koryn #TheVoice
# 2089807  0.027290  I'm finally home and I got an amazing tan too (:
# 465357   0.306090           @KariOuellette Thank you love you too!!
#
#  MLM candidate #2 : ghan
# {'sequence': "[CLS]ghan got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.00038524941192008555, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 1045393  0.069514  I am so happy I have classes with @MeghanGlase...
# 513515   0.252582                         @cvaughan127 thank you!!😊😊
# 1186764  0.057086  Happy birthday ✌️ @meaghan_x0 wish you have a ...
# 1874802  0.030830     Junghan MY DEAR FUCKKNG PIG I LOVE YOU🐷🐽🐷🐽🐷🐽🐷🐽
# 1169150  0.058361                          @iamkayleighann Welcome!!
#
#  MLM candidate #3 : isi
# {'sequence': "[CLS]isi got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.000358663615770638, 'token': 26868, 'token_str': '##isi'}
# Random sample of tweets containing keyword isi:
#             score                                               text
# 929343   0.084184  beyond seeing my friends and Excision im so re...
# 3946958  0.014259  Another week has come to a close...Thank You t...
# 323857   0.568421  New #job opening at Petsmart in #Chicago - #Me...
# 511156   0.254849       3 more weeks &amp; I can start exercising 😁👍
# 895210   0.089721                     This will be a one day visit 😒
#
#  MLM candidate #4 : blank
# {'sequence': "[CLS] blank got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.00035114679485559464, 'token': 9153, 'token_str': 'blank'}
# Random sample of tweets containing keyword blank:
#             score                                               text
# 3188819  0.017483  I don't feel like dragging this blanket throug...
# 3443319  0.016233  i want to cuddle in like 20 blankets and watch...
# 1515003  0.040365                    I bought a new blanket today, 🌚
# 3300114  0.016907  @jackiegerstein That's so, so excited. A blank...
# 3763079  0.014914  Tonight it's me, blanket, hot Cheetos, and Bet...
# *********** End of keyword exploration on tweet #7 ***********
# *********** Tweet #8 ***********
# Tweet: I just got hired !
#
# Tokenized version of tweet: ['I', 'just', 'got', 'hired', '!']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.4480329751968384, 1: 0.8278199434280396, 2: 0.7723451852798462, 3: 1.2157444953918457, 4: 0.7360571622848511}
# Token with most attention on average: I
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "I":
#  ['h', '##ghan', '##ahan', '##ark', 'Thread']
#
#  MLM candidate #0 : h
# {'sequence': '[CLS] h just got hired! [SEP]', 'score': 0.0004200439725536853, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 554523   0.217374  WHAT! YAHS! I CAN'T DANCE LIKE THAT! DID IT! h...
# 3412646  0.016373                   Best Buy smells like heaven 24/7
# 577487   0.200815  @rurinna0022 yay! You're amazing, thank you so...
# 80030    0.951104  today's stats : 19 new followers, 12 new unfol...
# 1962277  0.029196  S/O and congrats to @mistyonpointe just announ...
#
#  MLM candidate #1 : ghan
# {'sequence': '[CLS]ghan just got hired! [SEP]', 'score': 0.00041155744111165404, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 1941835  0.029557                    @doughankins Its gonna be good!
# 2888590  0.019287                      @meghannoelxo aw miss you too
# 2726094  0.020462                 @denisameghan I'm at marble slab 🍦
# 2314275  0.024350  @pellicott1 @SamHeughan @BearStrength @MyPeakC...
# 2745755  0.020311  @meghanlinsey :-)  6013....UR loved!!  I just ...
#
#  MLM candidate #2 : ahan
# {'sequence': '[CLS]ahan just got hired! [SEP]', 'score': 0.0004005241789855063, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 3255158  0.017136  The new Roboto is open on Mahan and I cried te...
# 1266145  0.051846                  Happy birthday, @kate_manahan! ☺️
# 1668915  0.035589  10-2! I'll hang til you get there❤️ Have a goo...
# 2033640  0.028001  @RichardKahan what an amazing introduction to ...
# 946815   0.081689          @_lianakinahan miss ya too &amp; yessss 😇
#
#  MLM candidate #3 : ark
# {'sequence': '[CLS]ark just got hired! [SEP]', 'score': 0.00036279039341025054, 'token': 1119, 'token_str': '##ark'}
# Random sample of tweets containing keyword ark:
#             score                                               text
# 245437   0.751103          🗺 Going to Arch at Washington Square Park
# 705715   0.137063          @clarklab @YellowbirdSauce Done and Done!
# 703199   0.137972  I checked in at Fry's &amp; Fry's Marketplace ...
# 541003   0.228191                           happy birthday markell💚💚
# 1355338  0.047028        happy birthday mark🎉 u old man @ComMarkb856
#
#  MLM candidate #4 : Thread
# {'sequence': '[CLS] Thread just got hired! [SEP]', 'score': 0.0003311800246592611, 'token': 25286, 'token_str': 'Thread'}
# Random sample of tweets containing keyword Thread:
#             score                                               text
# 1110305  0.063171                     @MissFancyThread Love you too!
# 2844527  0.019588  I checked in at Deepa the Threading Queen on #...
# 3303100  0.016893  @SelfmadeThreads &lt;--Thanks for the Follow :...
# 2039360  0.027984                                           Threads🌺
# 422690   0.367741  @Tom_Threadgill My pleasure. Thanks back! Grea...
# *********** End of keyword exploration on tweet #8 ***********
# *********** Tweet #9 ***********
# Tweet: Just got hired in the spot. #TwoJobs 💸
#
# Tokenized version of tweet: ['Just', 'got', 'hired', 'in', 'the', 'spot', '.', '#', 'Two', '##Job', '##s', '[UNK]']
#
# $$$ Attention $$$
#
# Attention scores dictionary:  {0: 1.9054388999938965, 1: 1.1128920316696167, 2: 1.3489856719970703, 3: 0.738501250743866, 4: 0.6312955617904663, 5: 1.176804542541504, 6: 0.9598628878593445, 7: 0.8739089965820312, 8: 0.8465639352798462, 9: 0.9671778678894043, 10: 0.5526459217071533, 11: 0.8859226703643799}
# Token with most attention on average: Just
# Token index with most attention on average: 0
#
# $$$ MLM $$$
#
# Ranked MLM selected keywords for token "Just":
#  ['##ghan', 'h', '##ahan', '##ark', '##walk']
#
#  MLM candidate #0 : ghan
# {'sequence': '[CLS]ghan got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.00046301743714138865, 'token': 23136, 'token_str': '##ghan'}
# Random sample of tweets containing keyword ghan:
#             score                                               text
# 1050765  0.068941              S/O to @tania_vaughan for the love!!!
# 1225298  0.054412                             @meghanknapic I LOVE U
# 2015165  0.028298                @Meaghannnc lmfao yesyes you were 😂
# 438650   0.343174  Worked hard today, time to reward myself with ...
# 705140   0.137273  @Meghanmandel happy birthday beautiful!🌷 Love ...
#
#  MLM candidate #1 : h
# {'sequence': '[CLS] h got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.00044159695971757174, 'token': 177, 'token_str': 'h'}
# Random sample of tweets containing keyword h:
#             score                                               text
# 3684605  0.015217                  @BearCov yee haw \ngotchu big guy
# 444477   0.334557      ONE MORE DAY YESSSSSS https://t.co/VvxIQyVBx3
# 1608345  0.037319  #instacollage... Don't let the rain stop u, it...
# 1649649  0.036118                                  So much smoothie😷
# 3103740  0.017952  @TeeTwoTimez yes next time ! I won't go withou...
#
#  MLM candidate #2 : ahan
# {'sequence': '[CLS]ahan got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.0003811225469689816, 'token': 14063, 'token_str': '##ahan'}
# Random sample of tweets containing keyword ahan:
#             score                                               text
# 2198569  0.025775  Many thanks to Maxilou for the advance birthda...
# 961956   0.079575  @Kr4duh @oliviahanno WE'RE OFFICIALLY GOING 🏒❄...
# 3161356  0.017632  Opening Ceremonies for #DukesOceanFest are Aug...
# 3396974  0.016446  @haleighhberlynn @Sarahangiier @comicsfeel OMG...
# 600484   0.186277               Happy birthday!! @KrystinaMahan 😊😜🎊🎈
#
#  MLM candidate #3 : ark
# {'sequence': '[CLS]ark got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.0003690623852889985, 'token': 1119, 'token_str': '##ark'}
# Random sample of tweets containing keyword ark:
#             score                                               text
# 2219240  0.025507  New code, new video! \n\nDuring the summer I c...
# 4002223  0.014074                          Larkin is so fun to watch
# 2249455  0.025119  @Jari_2002 @kirstin_taylor @kelly_clarkson @PT...
# 1804377  0.032289  If you're in C-bus go check out the lovely @tr...
# 2570040  0.021759  Joanne's park 1:00 tomorrow be there #PrebleBa...
#
#  MLM candidate #4 : walk
# {'sequence': '[CLS]walk got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.00034984879312105477, 'token': 13868, 'token_str': '##walk'}
# Random sample of tweets containing keyword walk:
#             score                                               text
# 1400902  0.044882  I don't understand why ppl say "Congratz" to m...
# 3604684  0.015536                                      I walked into
# 2232700  0.025332                  that's it im walking to McDonalds
# 2245738  0.025166  just walked clear across campus and up two fli...
# 325922   0.563641  Such a good day: new fishing pole, went on a w...
# *********** End of keyword exploration on tweet #9 ***********
