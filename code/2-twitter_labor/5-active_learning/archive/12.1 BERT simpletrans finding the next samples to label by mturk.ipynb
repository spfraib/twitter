# %% [markdown]
# ## make sure you have all libraries installed.
# use conda environment: /scratch/da2734/twitter/worldbank_twitter_environment.yml

# %% [markdown]
# # loading random samples

# %%
# random contains 0.8G of data!!
import time
start_time = time.time()
import pyarrow.parquet as pq
from glob import glob
import os
country_code = 'US'
month = '2012-1'
path_to_data = '/scratch/spf248/twitter/data/classification/US/random_10perct_sample/'
tweets_random=pq.ParquetDataset(glob(os.path.join(path_to_data,                                           
#                                            country_code,
#                                            month,
                                           '*.parquet'))).read().to_pandas()
tweets_random['tweet_id'] = tweets_random['tweet_id'].astype(int)
print('time taken to load random sample:', str(time.time() - start_time), 'seconds')
print(tweets_random.shape)
# Out:
# time taken to load random sample: 16.70641016960144 seconds
# (9468992, 11)

# %% [markdown]
# # outputting 1M (pinky finger up) tweets by column

# %%
# outputting 1M (pinky finger up) tweets by column
import glob
import pandas as pd
import time
import pickle
import matplotlib.pyplot as plt
from scipy.special import softmax

import numpy as np
boundary_list = [i/10.0 for i in range(11)]
boundary_list.reverse()

print('boundary_list', boundary_list)


for column in ["is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]:
    print('\n\n', column)
    
#     if column != 'job_search': continue
    
    start_time = time.time()
    model_output_path = '/scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/{}/'.format(column)
    print(model_output_path)

    start_time = time.time()
    model_output_random = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'random*.csv')], ignore_index = True)
    print('time taken to load random sample:', str(time.time() - start_time), 'seconds', model_output_random.shape)

    start_time = time.time()
    merged_random = pd.merge(model_output_random, tweets_random, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_random.shape)

    start_time = time.time()
#     based on https://github.com/ThilinaRajapakse/simpletransformers/issues/30
    merged_random[['neg', 'pos_model']] = softmax(merged_random[['first', 'second']], axis=1)
    print('time softmax:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     pickle.dump( merged_random, open( "./pickles/{}_BERT_ST_merged_random_1pct.pkl".format(column), "wb" ) )
#     print('time taken to dump:', str(time.time() - start_time), 'seconds')

    merged_random   = merged_random[['tweet_id', 'pos_model', 'text']]
#     print(merged_random.head())
    
#     merged_random   = merged_random[['tweet_id', 'glove_pos_model', 'text']]
    merged_random.columns = ['tweet_id', '{}'.format(column), 'text']
    
#     print(merged_random.shape())
    
    merged_random = merged_random.drop_duplicates(['text'])
    
    
    if column == 'is_unemployed':
        multi_col_all_tweets = merged_random
    else:
        multi_col_all_tweets = pd.merge(multi_col_all_tweets, merged_random, how='inner', on = 'tweet_id')
    
    print(multi_col_all_tweets.shape)
    print(multi_col_all_tweets.head())

    
#     break
multi_col_all_tweets = multi_col_all_tweets[['tweet_id', 'text', "is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]]
multi_col_all_tweets.head()
multi_col_all_tweets.to_parquet('turk10M/multi_col_all_tweets_BERT_random.parquet')
# Out:
# boundary_list [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0]
#
#
#  is_unemployed
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_unemployed/
# time taken to load random sample: 14.539019107818604 seconds (9440641, 3)
# time taken to merge: 8.181419372558594 seconds (9440641, 13)
# time softmax: 1.479945182800293 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.662139
# 1  367932697781350400   0.189844
# 2  367935721836777472   0.095190
# 3  367937185946673153   0.070781
# 4  367937491913150464   0.316167
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# (9231120, 3)
#              tweet_id  is_unemployed  \
# 0  367919800611508224       0.662139
# 1  367932697781350400       0.189844
# 2  367935721836777472       0.095190
# 3  367937185946673153       0.070781
# 4  367937491913150464       0.316167
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
#
#
#  lost_job_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/lost_job_1mo/
# time taken to load random sample: 15.20059609413147 seconds (9440641, 3)
# time taken to merge: 8.092663526535034 seconds (9440641, 13)
# time softmax: 1.3691279888153076 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.173053
# 1  367932697781350400   0.028532
# 2  367935721836777472   0.034936
# 3  367937185946673153   0.023579
# 4  367937491913150464   0.057855
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# (9231120, 5)
#              tweet_id  is_unemployed  \
# 0  367919800611508224       0.662139
# 1  367932697781350400       0.189844
# 2  367935721836777472       0.095190
# 3  367937185946673153       0.070781
# 4  367937491913150464       0.316167
#
#                                               text_x  lost_job_1mo  \
# 0                                           There :)      0.173053
# 1  RT @ReaILilTunechi: Relationships work best wh...      0.028532
# 2  I hate when im watching a movie and I stay on ...      0.034936
# 3           @nakiyakoker_ good. What about yourself?      0.023579
# 4       If a girl can make me laugh she had my heart      0.057855
#
#                                               text_y
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
#
#
#  job_search
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_search/
# time taken to load random sample: 14.832844257354736 seconds (9440641, 3)
# time taken to merge: 8.2026686668396 seconds (9440641, 13)
# time softmax: 1.363586187362671 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.023468
# 1  367932697781350400   0.018343
# 2  367935721836777472   0.013621
# 3  367937185946673153   0.034664
# 4  367937491913150464   0.019504
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# (9231120, 7)
#              tweet_id  is_unemployed  \
# 0  367919800611508224       0.662139
# 1  367932697781350400       0.189844
# 2  367935721836777472       0.095190
# 3  367937185946673153       0.070781
# 4  367937491913150464       0.316167
#
#                                               text_x  lost_job_1mo  \
# 0                                           There :)      0.173053
# 1  RT @ReaILilTunechi: Relationships work best wh...      0.028532
# 2  I hate when im watching a movie and I stay on ...      0.034936
# 3           @nakiyakoker_ good. What about yourself?      0.023579
# 4       If a girl can make me laugh she had my heart      0.057855
#
#                                               text_y  job_search  \
# 0                                           There :)    0.023468
# 1  RT @ReaILilTunechi: Relationships work best wh...    0.018343
# 2  I hate when im watching a movie and I stay on ...    0.013621
# 3           @nakiyakoker_ good. What about yourself?    0.034664
# 4       If a girl can make me laugh she had my heart    0.019504
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
#
#
#  is_hired_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_hired_1mo/
# time taken to load random sample: 15.460733652114868 seconds (9440641, 3)
# time taken to merge: 8.13061785697937 seconds (9440641, 13)
# time softmax: 1.3787567615509033 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.183562
# 1  367932697781350400   0.072739
# 2  367935721836777472   0.172504
# 3  367937185946673153   0.054790
# 4  367937491913150464   0.199024
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# (9231120, 9)
#              tweet_id  is_unemployed  \
# 0  367919800611508224       0.662139
# 1  367932697781350400       0.189844
# 2  367935721836777472       0.095190
# 3  367937185946673153       0.070781
# 4  367937491913150464       0.316167
#
#                                               text_x  lost_job_1mo  \
# 0                                           There :)      0.173053
# 1  RT @ReaILilTunechi: Relationships work best wh...      0.028532
# 2  I hate when im watching a movie and I stay on ...      0.034936
# 3           @nakiyakoker_ good. What about yourself?      0.023579
# 4       If a girl can make me laugh she had my heart      0.057855
#
#                                               text_y  job_search  \
# 0                                           There :)    0.023468
# 1  RT @ReaILilTunechi: Relationships work best wh...    0.018343
# 2  I hate when im watching a movie and I stay on ...    0.013621
# 3           @nakiyakoker_ good. What about yourself?    0.034664
# 4       If a girl can make me laugh she had my heart    0.019504
#
#                                               text_x  is_hired_1mo  \
# 0                                           There :)      0.183562
# 1  RT @ReaILilTunechi: Relationships work best wh...      0.072739
# 2  I hate when im watching a movie and I stay on ...      0.172504
# 3           @nakiyakoker_ good. What about yourself?      0.054790
# 4       If a girl can make me laugh she had my heart      0.199024
#
#                                               text_y
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
#
#
#  job_offer
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_offer/
# time taken to load random sample: 14.37619948387146 seconds (9440641, 3)
# time taken to merge: 8.115370273590088 seconds (9440641, 13)
# time softmax: 1.4379093647003174 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.062321
# 1  367932697781350400   0.088753
# 2  367935721836777472   0.027335
# 3  367937185946673153   0.045460
# 4  367937491913150464   0.064940
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# (9231120, 11)
#              tweet_id  is_unemployed  \
# 0  367919800611508224       0.662139
# 1  367932697781350400       0.189844
# 2  367935721836777472       0.095190
# 3  367937185946673153       0.070781
# 4  367937491913150464       0.316167
#
#                                               text_x  lost_job_1mo  \
# 0                                           There :)      0.173053
# 1  RT @ReaILilTunechi: Relationships work best wh...      0.028532
# 2  I hate when im watching a movie and I stay on ...      0.034936
# 3           @nakiyakoker_ good. What about yourself?      0.023579
# 4       If a girl can make me laugh she had my heart      0.057855
#
#                                               text_y  job_search  \
# 0                                           There :)    0.023468
# 1  RT @ReaILilTunechi: Relationships work best wh...    0.018343
# 2  I hate when im watching a movie and I stay on ...    0.013621
# 3           @nakiyakoker_ good. What about yourself?    0.034664
# 4       If a girl can make me laugh she had my heart    0.019504
#
#                                               text_x  is_hired_1mo  \
# 0                                           There :)      0.183562
# 1  RT @ReaILilTunechi: Relationships work best wh...      0.072739
# 2  I hate when im watching a movie and I stay on ...      0.172504
# 3           @nakiyakoker_ good. What about yourself?      0.054790
# 4       If a girl can make me laugh she had my heart      0.199024
#
#                                               text_y  job_offer  \
# 0                                           There :)   0.062321
# 1  RT @ReaILilTunechi: Relationships work best wh...   0.088753
# 2  I hate when im watching a movie and I stay on ...   0.027335
# 3           @nakiyakoker_ good. What about yourself?   0.045460
# 4       If a girl can make me laugh she had my heart   0.064940
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart

# %%
# outputting 1M (pinky finger up) tweets by column
import glob
import pandas as pd
import time
import pickle
import matplotlib.pyplot as plt
from scipy.special import softmax

import numpy as np
boundary_list = [i/10.0 for i in range(11)]
boundary_list.reverse()

print('boundary_list', boundary_list)


for column in ["is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]:
    print('\n\n', column)
    
#     if column != 'job_search': continue
    
    start_time = time.time()
    model_output_path = '/scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/{}/'.format(column)
    print(model_output_path)

    start_time = time.time()
    model_output_random = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'random*.csv')], ignore_index = True)
    print('time taken to load random sample:', str(time.time() - start_time), 'seconds', model_output_random.shape)

    start_time = time.time()
    merged_random = pd.merge(model_output_random, tweets_random, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_random.shape)

    start_time = time.time()
#     based on https://github.com/ThilinaRajapakse/simpletransformers/issues/30
    merged_random[['neg', 'pos_model']] = softmax(merged_random[['first', 'second']], axis=1)
    print('time softmax:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     pickle.dump( merged_random, open( "./pickles/{}_BERT_ST_merged_random_1pct.pkl".format(column), "wb" ) )
#     print('time taken to dump:', str(time.time() - start_time), 'seconds')

    merged_random   = merged_random[['tweet_id', 'pos_model', 'text']]
    print(merged_random.head())
    
    
    merged_random = merged_random.drop_duplicates(['text'])
    
    fig = plt.figure()
    ax = plt.subplot(111)
    plt.hist(merged_random['pos_model'], bins=20, density = True, color = 'red', alpha = 0.2)
    plt.title(column+' random')
#     ax.set_yscale('log')
    plt.xlim(0,1.1)
    
    start_time = time.time()
    sort_merged_random = merged_random.sort_values(by=['pos_model'], ascending=False)
    print('random', sort_merged_random[['pos_model', 'text']].head())
    sort_merged_random = sort_merged_random[['tweet_id', 'pos_model', 'text']]
    sort_merged_random.to_csv('turk1M/BERT_ST_random_pos_1000_{}.csv'.format(column), index = False)
    pickle.dump( sort_merged_random, open( 'turk1M/BERT_ST_random_pos_1000_{}.pickle'.format(column), "wb" ) )
    sort_merged_random.to_parquet('turk1M/BERT_ST_random_pos_1000_{}.parquet'.format(column))
    
    print('sort', str(time.time() - start_time), 'seconds')
    break
# Out:
# boundary_list [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0]
#
#
#  is_unemployed
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_unemployed/
# time taken to load random sample: 14.329328536987305 seconds (9440641, 3)
# time taken to merge: 7.808764457702637 seconds (9440641, 13)
# time softmax: 1.4628911018371582 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.662139
# 1  367932697781350400   0.189844
# 2  367935721836777472   0.095190
# 3  367937185946673153   0.070781
# 4  367937491913150464   0.316167
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# random          pos_model                                  text
# 2441891   0.938718                  I got fired today. 😂
# 3778048   0.936386       I was fired today. I'm a badass
# 4376444   0.935609              Lol Vinny just got fired
# 4449522   0.934539     Andy Reid got fired... About time
# 9364723   0.934478  i got fired  https://t.co/FjMrgTf8kJ
# sort 74.51657938957214 seconds

# %% [markdown]
# # random steps of 0.1 boundary

# %%
# all in one loop
import glob
import pandas as pd
import time
import pickle
import matplotlib.pyplot as plt
from scipy.special import softmax

import numpy as np
boundary_list = [i/10.0 for i in range(11)]
boundary_list.reverse()

print('boundary_list', boundary_list)


for column in ["is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]:
    print('\n\n', column)
    
#     if column != 'job_search': continue
    
    start_time = time.time()
    model_output_path = '/scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/{}/'.format(column)
    print(model_output_path)

    start_time = time.time()
    model_output_random = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'random*.csv')], ignore_index = True)
    print('time taken to load random sample:', str(time.time() - start_time), 'seconds', model_output_random.shape)

    start_time = time.time()
    merged_random = pd.merge(model_output_random, tweets_random, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_random.shape)

    start_time = time.time()
#     based on https://github.com/ThilinaRajapakse/simpletransformers/issues/30
    merged_random[['neg', 'pos_model']] = softmax(merged_random[['first', 'second']], axis=1)
    print('time softmax:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     pickle.dump( merged_random, open( "./pickles/{}_BERT_ST_merged_random_1pct.pkl".format(column), "wb" ) )
#     print('time taken to dump:', str(time.time() - start_time), 'seconds')

    merged_random   = merged_random[['tweet_id', 'pos_model', 'text']]
    print(merged_random.head())
    
    
    merged_random = merged_random.drop_duplicates(['text'])
    
    fig = plt.figure()
    ax = plt.subplot(111)
    plt.hist(merged_random['pos_model'], bins=20, density = True, color = 'red', alpha = 0.2)
    plt.title(column+' random')
#     ax.set_yscale('log')
    plt.xlim(0,1.1)
    
#     start_time = time.time()
#     sort_merged_random = merged_random.sort_values(by=['pos_model'], ascending=False)
#     print('random', sort_merged_random[['pos_model', 'text']].head())
#     sort_merged_random = sort_merged_random[['tweet_id', 'pos_model', 'text']]
#     sort_merged_random.head(1000).to_csv('csv/BERT_ST_random_pos_1000_{}.csv'.format(column), index = False)
#     print('sort', str(time.time() - start_time), 'seconds')

    all_tweets_for_sam = pd.DataFrame()
    for boundary in boundary_list:
        
        print('boundary', boundary)
        
#         boundary = boundary_dict['random'][column]
        merged_random['dist_point{}'.format(boundary)] = abs(merged_random['pos_model'] - boundary)

        start_time = time.time()
        print(column, 'random subtraction time taken:', str(time.time() - start_time), 'seconds')

        start_time = time.time()
        merged_random = merged_random.sort_values(by=['dist_point{}'.format(boundary)], ascending=True)
        print(column, 'random sorting time taken:', str(time.time() - start_time), 'seconds')

        start_time = time.time()
        
        data_to_export = merged_random[:2000][['tweet_id', 'pos_model', 'text']]
        
#         del merged_random
        
        print(data_to_export.shape)
#         data_to_export.to_csv('csv_boundary_step/BERT_ST_random_{}_point_{}.csv'.format(column, boundary))
        # print(all_random_boundary['text'])
        print(column, 'random write csv time taken:', str(time.time() - start_time), 'seconds')   

        all_tweets_for_sam = pd.concat([all_tweets_for_sam, data_to_export])
    
#         break
        
    all_tweets_for_sam.to_csv('csv_boundary_step/BERT_ST_random_ALL_{}.csv'.format(column), index = False)
    
#     break
# Out:
# boundary_list [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0]
#
#
#  is_unemployed
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_unemployed/
# time taken to load random sample: 4.154649496078491 seconds (9440641, 3)
# time taken to merge: 7.946799993515015 seconds (9440641, 13)
# time softmax: 1.4108667373657227 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.662139
# 1  367932697781350400   0.189844
# 2  367935721836777472   0.095190
# 3  367937185946673153   0.070781
# 4  367937491913150464   0.316167
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# boundary 1.0
# is_unemployed random subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed random sorting time taken: 4.91493034362793 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.0023050308227539062 seconds
# boundary 0.9
# is_unemployed random subtraction time taken: 3.337860107421875e-06 seconds
# is_unemployed random sorting time taken: 1.5429856777191162 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.002295255661010742 seconds
# boundary 0.8
# is_unemployed random subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed random sorting time taken: 1.7177035808563232 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.00250244140625 seconds
# boundary 0.7
# is_unemployed random subtraction time taken: 2.384185791015625e-06 seconds
# is_unemployed random sorting time taken: 1.6707770824432373 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.002865314483642578 seconds
# boundary 0.6
# is_unemployed random subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed random sorting time taken: 1.9796242713928223 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.0023376941680908203 seconds
# boundary 0.5
# is_unemployed random subtraction time taken: 1.9073486328125e-06 seconds
# is_unemployed random sorting time taken: 2.2246181964874268 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.0025360584259033203 seconds
# boundary 0.4
# is_unemployed random subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed random sorting time taken: 2.323646306991577 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.0024747848510742188 seconds
# boundary 0.3
# is_unemployed random subtraction time taken: 2.384185791015625e-06 seconds
# is_unemployed random sorting time taken: 2.5169758796691895 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.002617359161376953 seconds
# boundary 0.2
# is_unemployed random subtraction time taken: 3.0994415283203125e-06 seconds
# is_unemployed random sorting time taken: 2.69107985496521 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.0026679039001464844 seconds
# boundary 0.1
# is_unemployed random subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed random sorting time taken: 2.767629623413086 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.0026421546936035156 seconds
# boundary 0.0
# is_unemployed random subtraction time taken: 1.9073486328125e-06 seconds
# is_unemployed random sorting time taken: 2.64609432220459 seconds
# (2000, 3)
# is_unemployed random write csv time taken: 0.0025141239166259766 seconds
#
#
#  lost_job_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/lost_job_1mo/
# time taken to load random sample: 13.050094842910767 seconds (9440641, 3)
# time taken to merge: 8.075483322143555 seconds (9440641, 13)
# time softmax: 1.3548552989959717 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.173053
# 1  367932697781350400   0.028532
# 2  367935721836777472   0.034936
# 3  367937185946673153   0.023579
# 4  367937491913150464   0.057855
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# boundary 1.0
# lost_job_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo random sorting time taken: 4.966420888900757 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0025815963745117188 seconds
# boundary 0.9
# lost_job_1mo random subtraction time taken: 2.6226043701171875e-06 seconds
# lost_job_1mo random sorting time taken: 1.6581032276153564 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0024671554565429688 seconds
# boundary 0.8
# lost_job_1mo random subtraction time taken: 1.9073486328125e-06 seconds
# lost_job_1mo random sorting time taken: 1.7477388381958008 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.002574920654296875 seconds
# boundary 0.7
# lost_job_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo random sorting time taken: 1.8208718299865723 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0023882389068603516 seconds
# boundary 0.6
# lost_job_1mo random subtraction time taken: 2.1457672119140625e-06 seconds
# lost_job_1mo random sorting time taken: 1.8722217082977295 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0025904178619384766 seconds
# boundary 0.5
# lost_job_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo random sorting time taken: 2.237452268600464 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0025687217712402344 seconds
# boundary 0.4
# lost_job_1mo random subtraction time taken: 2.86102294921875e-06 seconds
# lost_job_1mo random sorting time taken: 2.2723751068115234 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0024313926696777344 seconds
# boundary 0.3
# lost_job_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo random sorting time taken: 2.3441858291625977 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0023758411407470703 seconds
# boundary 0.2
# lost_job_1mo random subtraction time taken: 2.1457672119140625e-06 seconds
# lost_job_1mo random sorting time taken: 2.477766513824463 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.002490997314453125 seconds
# boundary 0.1
# lost_job_1mo random subtraction time taken: 2.1457672119140625e-06 seconds
# lost_job_1mo random sorting time taken: 2.5250244140625 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.0022125244140625 seconds
# boundary 0.0
# lost_job_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo random sorting time taken: 2.595656633377075 seconds
# (2000, 3)
# lost_job_1mo random write csv time taken: 0.002619028091430664 seconds
#
#
#  job_search
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_search/
# time taken to load random sample: 12.959782123565674 seconds (9440641, 3)
# time taken to merge: 8.023888111114502 seconds (9440641, 13)
# time softmax: 1.3564341068267822 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.023468
# 1  367932697781350400   0.018343
# 2  367935721836777472   0.013621
# 3  367937185946673153   0.034664
# 4  367937491913150464   0.019504
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# boundary 1.0
# job_search random subtraction time taken: 3.814697265625e-06 seconds
# job_search random sorting time taken: 4.999542236328125 seconds
# (2000, 3)
# job_search random write csv time taken: 0.002532958984375 seconds
# boundary 0.9
# job_search random subtraction time taken: 2.1457672119140625e-06 seconds
# job_search random sorting time taken: 1.5540778636932373 seconds
# (2000, 3)
# job_search random write csv time taken: 0.0024263858795166016 seconds
# boundary 0.8
# job_search random subtraction time taken: 2.384185791015625e-06 seconds
# job_search random sorting time taken: 1.7954537868499756 seconds
# (2000, 3)
# job_search random write csv time taken: 0.0025167465209960938 seconds
# boundary 0.7
# job_search random subtraction time taken: 2.384185791015625e-06 seconds
# job_search random sorting time taken: 1.7545881271362305 seconds
# (2000, 3)
# job_search random write csv time taken: 0.002541065216064453 seconds
# boundary 0.6
# job_search random subtraction time taken: 2.384185791015625e-06 seconds
# job_search random sorting time taken: 1.853661298751831 seconds
# (2000, 3)
# job_search random write csv time taken: 0.002644777297973633 seconds
# boundary 0.5
# job_search random subtraction time taken: 2.86102294921875e-06 seconds
# job_search random sorting time taken: 2.0755224227905273 seconds
# (2000, 3)
# job_search random write csv time taken: 0.0025599002838134766 seconds
# boundary 0.4
# job_search random subtraction time taken: 2.1457672119140625e-06 seconds
# job_search random sorting time taken: 2.3395872116088867 seconds
# (2000, 3)
# job_search random write csv time taken: 0.0025510787963867188 seconds
# boundary 0.3
# job_search random subtraction time taken: 2.384185791015625e-06 seconds
# job_search random sorting time taken: 2.3062314987182617 seconds
# (2000, 3)
# job_search random write csv time taken: 0.0024552345275878906 seconds
# boundary 0.2
# job_search random subtraction time taken: 2.384185791015625e-06 seconds
# job_search random sorting time taken: 2.4413108825683594 seconds
# (2000, 3)
# job_search random write csv time taken: 0.002509593963623047 seconds
# boundary 0.1
# job_search random subtraction time taken: 1.9073486328125e-06 seconds
# job_search random sorting time taken: 2.52250337600708 seconds
# (2000, 3)
# job_search random write csv time taken: 0.0025975704193115234 seconds
# boundary 0.0
# job_search random subtraction time taken: 2.384185791015625e-06 seconds
# job_search random sorting time taken: 2.6029646396636963 seconds
# (2000, 3)
# job_search random write csv time taken: 0.0024313926696777344 seconds
#
#
#  is_hired_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_hired_1mo/
# time taken to load random sample: 13.2338707447052 seconds (9440641, 3)
# time taken to merge: 8.114842176437378 seconds (9440641, 13)
# time softmax: 1.367426872253418 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.183562
# 1  367932697781350400   0.072739
# 2  367935721836777472   0.172504
# 3  367937185946673153   0.054790
# 4  367937491913150464   0.199024
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# boundary 1.0
# is_hired_1mo random subtraction time taken: 4.76837158203125e-06 seconds
# is_hired_1mo random sorting time taken: 4.900034427642822 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.0025360584259033203 seconds
# boundary 0.9
# is_hired_1mo random subtraction time taken: 2.1457672119140625e-06 seconds
# is_hired_1mo random sorting time taken: 1.5273821353912354 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.002391815185546875 seconds
# boundary 0.8
# is_hired_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo random sorting time taken: 1.7615232467651367 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.002581357955932617 seconds
# boundary 0.7
# is_hired_1mo random subtraction time taken: 2.1457672119140625e-06 seconds
# is_hired_1mo random sorting time taken: 1.7008099555969238 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.0024378299713134766 seconds
# boundary 0.6
# is_hired_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo random sorting time taken: 1.9474923610687256 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.0024690628051757812 seconds
# boundary 0.5
# is_hired_1mo random subtraction time taken: 1.9073486328125e-06 seconds
# is_hired_1mo random sorting time taken: 2.0992534160614014 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.0026061534881591797 seconds
# boundary 0.4
# is_hired_1mo random subtraction time taken: 2.1457672119140625e-06 seconds
# is_hired_1mo random sorting time taken: 2.139431953430176 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.0025489330291748047 seconds
# boundary 0.3
# is_hired_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo random sorting time taken: 2.170898199081421 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.002427339553833008 seconds
# boundary 0.2
# is_hired_1mo random subtraction time taken: 2.6226043701171875e-06 seconds
# is_hired_1mo random sorting time taken: 2.437513589859009 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.002474546432495117 seconds
# boundary 0.1
# is_hired_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo random sorting time taken: 2.564443588256836 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.0025136470794677734 seconds
# boundary 0.0
# is_hired_1mo random subtraction time taken: 2.6226043701171875e-06 seconds
# is_hired_1mo random sorting time taken: 2.9327335357666016 seconds
# (2000, 3)
# is_hired_1mo random write csv time taken: 0.002582073211669922 seconds
#
#
#  job_offer
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_offer/
# time taken to load random sample: 13.365909576416016 seconds (9440641, 3)
# time taken to merge: 8.105296850204468 seconds (9440641, 13)
# time softmax: 1.4363372325897217 seconds
#              tweet_id  pos_model  \
# 0  367919800611508224   0.062321
# 1  367932697781350400   0.088753
# 2  367935721836777472   0.027335
# 3  367937185946673153   0.045460
# 4  367937491913150464   0.064940
#
#                                                 text
# 0                                           There :)
# 1  RT @ReaILilTunechi: Relationships work best wh...
# 2  I hate when im watching a movie and I stay on ...
# 3           @nakiyakoker_ good. What about yourself?
# 4       If a girl can make me laugh she had my heart
# boundary 1.0
# job_offer random subtraction time taken: 2.384185791015625e-06 seconds
# job_offer random sorting time taken: 4.951138734817505 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.0026006698608398438 seconds
# boundary 0.9
# job_offer random subtraction time taken: 6.9141387939453125e-06 seconds
# job_offer random sorting time taken: 1.6423888206481934 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.0024149417877197266 seconds
# boundary 0.8
# job_offer random subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer random sorting time taken: 1.7693638801574707 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.0021719932556152344 seconds
# boundary 0.7
# job_offer random subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer random sorting time taken: 1.9722416400909424 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.0023970603942871094 seconds
# boundary 0.6
# job_offer random subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer random sorting time taken: 2.089492082595825 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.002973794937133789 seconds
# boundary 0.5
# job_offer random subtraction time taken: 3.337860107421875e-06 seconds
# job_offer random sorting time taken: 2.216463088989258 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.002550363540649414 seconds
# boundary 0.4
# job_offer random subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer random sorting time taken: 2.3382914066314697 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.0022902488708496094 seconds
# boundary 0.3
# job_offer random subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer random sorting time taken: 2.652069568634033 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.0025289058685302734 seconds
# boundary 0.2
# job_offer random subtraction time taken: 2.384185791015625e-06 seconds
# job_offer random sorting time taken: 2.4441261291503906 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.0024361610412597656 seconds
# boundary 0.1
# job_offer random subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer random sorting time taken: 2.6976916790008545 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.002434253692626953 seconds
# boundary 0.0
# job_offer random subtraction time taken: 2.384185791015625e-06 seconds
# job_offer random sorting time taken: 2.6617281436920166 seconds
# (2000, 3)
# job_offer random write csv time taken: 0.002426624298095703 seconds

# %% [markdown]
# # loading filtered samples

# %%
# filtered contains 0.8G of data!!
import time
start_time = time.time()
import pyarrow.parquet as pq
from glob import glob
import os
country_code = 'US'
month = '2012-1'
path_to_data = '/scratch/spf248/twitter/data/classification/US/filtered_10perct_sample/'
tweets_filtered=pq.ParquetDataset(glob(os.path.join(path_to_data,                                           
#                                            country_code,
#                                            month,
                                           '*.parquet'))).read().to_pandas()
tweets_filtered['tweet_id'] = tweets_filtered['tweet_id'].astype(int)
print('time taken to load filtered sample:', str(time.time() - start_time), 'seconds')
print(tweets_filtered.shape)
# Out:
# time taken to load filtered sample: 16.394561290740967 seconds
# (9215824, 11)

# %%
# outputting 1M (pinky finger up) tweets by column
import glob
import pandas as pd
import time
import pickle
import matplotlib.pyplot as plt
from scipy.special import softmax

import numpy as np
boundary_list = [i/10.0 for i in range(11)]
boundary_list.reverse()

print('boundary_list', boundary_list)


for column in ["is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]:
    print('\n\n', column)
    
#     if column != 'job_search': continue
    
    start_time = time.time()
    model_output_path = '/scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/{}/'.format(column)
    print(model_output_path)

    start_time = time.time()
    model_output_filtered = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'filtered*.csv')], ignore_index = True)
    print('time taken to load filtered sample:', str(time.time() - start_time), 'seconds', model_output_filtered.shape)

    start_time = time.time()
    merged_filtered = pd.merge(model_output_filtered, tweets_filtered, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_filtered.shape)

    start_time = time.time()
#     based on https://github.com/ThilinaRajapakse/simpletransformers/issues/30
    merged_filtered[['neg', 'pos_model']] = softmax(merged_filtered[['first', 'second']], axis=1)
    print('time softmax:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     pickle.dump( merged_filtered, open( "./pickles/{}_BERT_ST_merged_filtered_1pct.pkl".format(column), "wb" ) )
#     print('time taken to dump:', str(time.time() - start_time), 'seconds')

    merged_filtered   = merged_filtered[['tweet_id', 'pos_model', 'text']]
#     print(merged_filtered.head())
    
#     merged_filtered   = merged_filtered[['tweet_id', 'glove_pos_model', 'text']]
    merged_filtered.columns = ['tweet_id', '{}'.format(column), 'text']
    
#     print(merged_filtered.shape())
    
    merged_filtered = merged_filtered.drop_duplicates(['text'])
    
    
    if column == 'is_unemployed':
        multi_col_all_tweets = merged_filtered
    else:
        multi_col_all_tweets = pd.merge(multi_col_all_tweets, merged_filtered, how='inner', on = 'tweet_id')
    
    print(multi_col_all_tweets.shape)
    print(multi_col_all_tweets.head())

    
#     break
multi_col_all_tweets = multi_col_all_tweets[['tweet_id', 'text', "is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]]
multi_col_all_tweets.head()
multi_col_all_tweets.to_parquet('turk10M/multi_col_all_tweets_BERT_filtered.parquet')
# Out:
# boundary_list [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0]
#
#
#  is_unemployed
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_unemployed/
# time taken to load filtered sample: 14.733699798583984 seconds (9026993, 3)
# time taken to merge: 7.70441198348999 seconds (9026993, 13)
# time softmax: 1.3393235206604004 seconds
# (8446722, 3)
#               tweet_id  is_unemployed  \
# 0  1000001555674882048       0.094048
# 1  1000003879344336903       0.187957
# 2  1000013178112266241       0.011999
# 3  1000024729200222208       0.212617
# 4  1000026549540794368       0.085735
#
#                                                 text
# 0  A work of art. #livemoreworryless https://t.co...
# 1  Now hiring for 14 #job opportunities at Ryder ...
# 2  What Makes The Healthy Workplace Nudge Differe...
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...
# 4  RT @Evan_McMullin: A spy is an American under ...
#
#
#  lost_job_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/lost_job_1mo/
# time taken to load filtered sample: 14.772610425949097 seconds (9026993, 3)
# time taken to merge: 7.931329965591431 seconds (9026993, 13)
# time softmax: 1.3098468780517578 seconds
# (8446722, 5)
#               tweet_id  is_unemployed  \
# 0  1000001555674882048       0.094048
# 1  1000003879344336903       0.187957
# 2  1000013178112266241       0.011999
# 3  1000024729200222208       0.212617
# 4  1000026549540794368       0.085735
#
#                                               text_x  lost_job_1mo  \
# 0  A work of art. #livemoreworryless https://t.co...      0.024075
# 1  Now hiring for 14 #job opportunities at Ryder ...      0.023369
# 2  What Makes The Healthy Workplace Nudge Differe...      0.026108
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...      0.916674
# 4  RT @Evan_McMullin: A spy is an American under ...      0.028079
#
#                                               text_y
# 0  A work of art. #livemoreworryless https://t.co...
# 1  Now hiring for 14 #job opportunities at Ryder ...
# 2  What Makes The Healthy Workplace Nudge Differe...
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...
# 4  RT @Evan_McMullin: A spy is an American under ...
#
#
#  job_search
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_search/
# time taken to load filtered sample: 14.35430645942688 seconds (9026993, 3)
# time taken to merge: 7.895029783248901 seconds (9026993, 13)
# time softmax: 1.3115861415863037 seconds
# (8446722, 7)
#               tweet_id  is_unemployed  \
# 0  1000001555674882048       0.094048
# 1  1000003879344336903       0.187957
# 2  1000013178112266241       0.011999
# 3  1000024729200222208       0.212617
# 4  1000026549540794368       0.085735
#
#                                               text_x  lost_job_1mo  \
# 0  A work of art. #livemoreworryless https://t.co...      0.024075
# 1  Now hiring for 14 #job opportunities at Ryder ...      0.023369
# 2  What Makes The Healthy Workplace Nudge Differe...      0.026108
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...      0.916674
# 4  RT @Evan_McMullin: A spy is an American under ...      0.028079
#
#                                               text_y  job_search  \
# 0  A work of art. #livemoreworryless https://t.co...    0.037969
# 1  Now hiring for 14 #job opportunities at Ryder ...    0.130792
# 2  What Makes The Healthy Workplace Nudge Differe...    0.041947
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...    0.009797
# 4  RT @Evan_McMullin: A spy is an American under ...    0.027143
#
#                                                 text
# 0  A work of art. #livemoreworryless https://t.co...
# 1  Now hiring for 14 #job opportunities at Ryder ...
# 2  What Makes The Healthy Workplace Nudge Differe...
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...
# 4  RT @Evan_McMullin: A spy is an American under ...
#
#
#  is_hired_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_hired_1mo/
# time taken to load filtered sample: 14.673425912857056 seconds (9026993, 3)
# time taken to merge: 7.893347501754761 seconds (9026993, 13)
# time softmax: 1.321868658065796 seconds
# (8446722, 9)
#               tweet_id  is_unemployed  \
# 0  1000001555674882048       0.094048
# 1  1000003879344336903       0.187957
# 2  1000013178112266241       0.011999
# 3  1000024729200222208       0.212617
# 4  1000026549540794368       0.085735
#
#                                               text_x  lost_job_1mo  \
# 0  A work of art. #livemoreworryless https://t.co...      0.024075
# 1  Now hiring for 14 #job opportunities at Ryder ...      0.023369
# 2  What Makes The Healthy Workplace Nudge Differe...      0.026108
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...      0.916674
# 4  RT @Evan_McMullin: A spy is an American under ...      0.028079
#
#                                               text_y  job_search  \
# 0  A work of art. #livemoreworryless https://t.co...    0.037969
# 1  Now hiring for 14 #job opportunities at Ryder ...    0.130792
# 2  What Makes The Healthy Workplace Nudge Differe...    0.041947
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...    0.009797
# 4  RT @Evan_McMullin: A spy is an American under ...    0.027143
#
#                                               text_x  is_hired_1mo  \
# 0  A work of art. #livemoreworryless https://t.co...      0.051212
# 1  Now hiring for 14 #job opportunities at Ryder ...      0.085086
# 2  What Makes The Healthy Workplace Nudge Differe...      0.073054
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...      0.669551
# 4  RT @Evan_McMullin: A spy is an American under ...      0.094973
#
#                                               text_y
# 0  A work of art. #livemoreworryless https://t.co...
# 1  Now hiring for 14 #job opportunities at Ryder ...
# 2  What Makes The Healthy Workplace Nudge Differe...
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...
# 4  RT @Evan_McMullin: A spy is an American under ...
#
#
#  job_offer
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_offer/
# time taken to load filtered sample: 14.239366292953491 seconds (9026993, 3)
# time taken to merge: 7.833998203277588 seconds (9026993, 13)
# time softmax: 1.398198127746582 seconds
# (8446722, 11)
#               tweet_id  is_unemployed  \
# 0  1000001555674882048       0.094048
# 1  1000003879344336903       0.187957
# 2  1000013178112266241       0.011999
# 3  1000024729200222208       0.212617
# 4  1000026549540794368       0.085735
#
#                                               text_x  lost_job_1mo  \
# 0  A work of art. #livemoreworryless https://t.co...      0.024075
# 1  Now hiring for 14 #job opportunities at Ryder ...      0.023369
# 2  What Makes The Healthy Workplace Nudge Differe...      0.026108
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...      0.916674
# 4  RT @Evan_McMullin: A spy is an American under ...      0.028079
#
#                                               text_y  job_search  \
# 0  A work of art. #livemoreworryless https://t.co...    0.037969
# 1  Now hiring for 14 #job opportunities at Ryder ...    0.130792
# 2  What Makes The Healthy Workplace Nudge Differe...    0.041947
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...    0.009797
# 4  RT @Evan_McMullin: A spy is an American under ...    0.027143
#
#                                               text_x  is_hired_1mo  \
# 0  A work of art. #livemoreworryless https://t.co...      0.051212
# 1  Now hiring for 14 #job opportunities at Ryder ...      0.085086
# 2  What Makes The Healthy Workplace Nudge Differe...      0.073054
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...      0.669551
# 4  RT @Evan_McMullin: A spy is an American under ...      0.094973
#
#                                               text_y  job_offer  \
# 0  A work of art. #livemoreworryless https://t.co...   0.316132
# 1  Now hiring for 14 #job opportunities at Ryder ...   0.806504
# 2  What Makes The Healthy Workplace Nudge Differe...   0.857456
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...   0.022445
# 4  RT @Evan_McMullin: A spy is an American under ...   0.067590
#
#                                                 text
# 0  A work of art. #livemoreworryless https://t.co...
# 1  Now hiring for 14 #job opportunities at Ryder ...
# 2  What Makes The Healthy Workplace Nudge Differe...
# 3  Ahh ❤️😌😍 I told Steven that Luna was sick yest...
# 4  RT @Evan_McMullin: A spy is an American under ...

# %% [markdown]
# # filtered steps of 0.1 boundary

# %%
# all in one loop
import glob
import pandas as pd
import time
import pickle
import matplotlib.pyplot as plt
from scipy.special import softmax

import numpy as np
boundary_list = [i/10.0 for i in range(11)]
boundary_list.reverse()

print('boundary_list', boundary_list)

for column in ["is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]:
    print('\n\n', column)
    
#     if column != 'job_search': continue
    
    start_time = time.time()
    model_output_path = '/scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/{}/'.format(column)
    print(model_output_path)
    
    start_time = time.time()
    model_output_filtered = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'filtered*.csv')], ignore_index = True)
    print('time taken to load filtered sample:', str(time.time() - start_time), 'seconds', model_output_filtered.shape)

    start_time = time.time()
    merged_filtered = pd.merge(model_output_filtered, tweets_filtered, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_filtered.shape)

    start_time = time.time()
#     based on https://github.com/ThilinaRajapakse/simpletransformers/issues/30
    merged_filtered[['neg', 'pos_model']] = softmax(merged_filtered[['first', 'second']], axis=1)
    print('time softmax:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     pickle.dump( merged_filtered, open( "./pickles/{}_BERT_ST_merged_filtered_1pct.pkl".format(column), "wb" ) )
#     print('time taken to dump:', str(time.time() - start_time), 'seconds')

    merged_filtered   = merged_filtered[['tweet_id', 'pos_model', 'text']]
#     print(merged_filtered.head())
    
    
    merged_filtered = merged_filtered.drop_duplicates(['text'])
    
    fig = plt.figure()
    ax = plt.subplot(111)
    plt.hist(merged_filtered['pos_model'], bins=20, density = True, color = 'red', alpha = 0.2)
    plt.title(column+' filtered')
#     ax.set_yscale('log')
    plt.xlim(0,1.1)
    
    all_tweets_for_sam = pd.DataFrame()
    for boundary in boundary_list:
        
        print('boundary', boundary)
        
#         boundary = boundary_dict['filtered'][column]
        merged_filtered['dist_point{}'.format(boundary)] = abs(merged_filtered['pos_model'] - boundary)

        start_time = time.time()
        print(column, 'filtered subtraction time taken:', str(time.time() - start_time), 'seconds')

        start_time = time.time()
        merged_filtered = merged_filtered.sort_values(by=['dist_point{}'.format(boundary)], ascending=True)
        print(column, 'filtered sorting time taken:', str(time.time() - start_time), 'seconds')

        start_time = time.time()
        
        data_to_export = merged_filtered[:2000][['tweet_id', 'pos_model', 'text']]
#         data_to_export.to_csv('csv_boundary_step/BERT_ST_filtered_{}_point_{}.csv'.format(column, boundary))
        print(data_to_export.shape)
        print(column, 'filtered write csv time taken:', str(time.time() - start_time), 'seconds')   

        all_tweets_for_sam = pd.concat([all_tweets_for_sam, data_to_export])
    
#         break
        
    all_tweets_for_sam.to_csv('csv_boundary_step/BERT_ST_filtered_ALL_{}.csv'.format(column), index = False)
    
#     break
# Out:
# boundary_list [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0]
#
#
#  is_unemployed
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_unemployed/
# time taken to load filtered sample: 13.469018459320068 seconds (9026993, 3)
# time taken to merge: 7.485039234161377 seconds (9026993, 13)
# time softmax: 1.3290717601776123 seconds
# boundary 1.0
# is_unemployed filtered subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed filtered sorting time taken: 4.615224599838257 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.002180814743041992 seconds
# boundary 0.9
# is_unemployed filtered subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed filtered sorting time taken: 1.5814785957336426 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0024716854095458984 seconds
# boundary 0.8
# is_unemployed filtered subtraction time taken: 2.384185791015625e-06 seconds
# is_unemployed filtered sorting time taken: 1.5209355354309082 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0026764869689941406 seconds
# boundary 0.7
# is_unemployed filtered subtraction time taken: 2.86102294921875e-06 seconds
# is_unemployed filtered sorting time taken: 1.724092721939087 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.002415180206298828 seconds
# boundary 0.6
# is_unemployed filtered subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed filtered sorting time taken: 1.8408615589141846 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0024995803833007812 seconds
# boundary 0.5
# is_unemployed filtered subtraction time taken: 2.86102294921875e-06 seconds
# is_unemployed filtered sorting time taken: 1.9053356647491455 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0025043487548828125 seconds
# boundary 0.4
# is_unemployed filtered subtraction time taken: 2.6226043701171875e-06 seconds
# is_unemployed filtered sorting time taken: 2.2026901245117188 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0025322437286376953 seconds
# boundary 0.3
# is_unemployed filtered subtraction time taken: 3.0994415283203125e-06 seconds
# is_unemployed filtered sorting time taken: 2.1712958812713623 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.002466917037963867 seconds
# boundary 0.2
# is_unemployed filtered subtraction time taken: 2.384185791015625e-06 seconds
# is_unemployed filtered sorting time taken: 2.4935615062713623 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0030968189239501953 seconds
# boundary 0.1
# is_unemployed filtered subtraction time taken: 2.1457672119140625e-06 seconds
# is_unemployed filtered sorting time taken: 2.411444664001465 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0026547908782958984 seconds
# boundary 0.0
# is_unemployed filtered subtraction time taken: 2.384185791015625e-06 seconds
# is_unemployed filtered sorting time taken: 2.4650933742523193 seconds
# (2000, 3)
# is_unemployed filtered write csv time taken: 0.0026044845581054688 seconds
#
#
#  lost_job_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/lost_job_1mo/
# time taken to load filtered sample: 13.33346176147461 seconds (9026993, 3)
# time taken to merge: 8.02737832069397 seconds (9026993, 13)
# time softmax: 1.306351900100708 seconds
# boundary 1.0
# lost_job_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo filtered sorting time taken: 4.510976552963257 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0024709701538085938 seconds
# boundary 0.9
# lost_job_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo filtered sorting time taken: 1.484525203704834 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0024483203887939453 seconds
# boundary 0.8
# lost_job_1mo filtered subtraction time taken: 2.6226043701171875e-06 seconds
# lost_job_1mo filtered sorting time taken: 1.592545986175537 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0026540756225585938 seconds
# boundary 0.7
# lost_job_1mo filtered subtraction time taken: 2.6226043701171875e-06 seconds
# lost_job_1mo filtered sorting time taken: 1.6440136432647705 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.002486705780029297 seconds
# boundary 0.6
# lost_job_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo filtered sorting time taken: 1.8241796493530273 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0024230480194091797 seconds
# boundary 0.5
# lost_job_1mo filtered subtraction time taken: 2.1457672119140625e-06 seconds
# lost_job_1mo filtered sorting time taken: 1.95499849319458 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0024161338806152344 seconds
# boundary 0.4
# lost_job_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo filtered sorting time taken: 1.9995553493499756 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.002458333969116211 seconds
# boundary 0.3
# lost_job_1mo filtered subtraction time taken: 2.6226043701171875e-06 seconds
# lost_job_1mo filtered sorting time taken: 2.0216715335845947 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0025565624237060547 seconds
# boundary 0.2
# lost_job_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo filtered sorting time taken: 2.3124377727508545 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0026865005493164062 seconds
# boundary 0.1
# lost_job_1mo filtered subtraction time taken: 2.6226043701171875e-06 seconds
# lost_job_1mo filtered sorting time taken: 2.315000295639038 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0024614334106445312 seconds
# boundary 0.0
# lost_job_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo filtered sorting time taken: 2.3772857189178467 seconds
# (2000, 3)
# lost_job_1mo filtered write csv time taken: 0.0025124549865722656 seconds
#
#
#  job_search
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_search/
# time taken to load filtered sample: 12.894805669784546 seconds (9026993, 3)
# time taken to merge: 7.768731117248535 seconds (9026993, 13)
# time softmax: 1.3037967681884766 seconds
# boundary 1.0
# job_search filtered subtraction time taken: 2.1457672119140625e-06 seconds
# job_search filtered sorting time taken: 4.466330289840698 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0025637149810791016 seconds
# boundary 0.9
# job_search filtered subtraction time taken: 2.6226043701171875e-06 seconds
# job_search filtered sorting time taken: 1.483947515487671 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0023555755615234375 seconds
# boundary 0.8
# job_search filtered subtraction time taken: 2.384185791015625e-06 seconds
# job_search filtered sorting time taken: 1.6334919929504395 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0023965835571289062 seconds
# boundary 0.7
# job_search filtered subtraction time taken: 2.1457672119140625e-06 seconds
# job_search filtered sorting time taken: 1.569307804107666 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0022203922271728516 seconds
# boundary 0.6
# job_search filtered subtraction time taken: 2.1457672119140625e-06 seconds
# job_search filtered sorting time taken: 1.74418306350708 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0025110244750976562 seconds
# boundary 0.5
# job_search filtered subtraction time taken: 2.384185791015625e-06 seconds
# job_search filtered sorting time taken: 1.830690622329712 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.002209901809692383 seconds
# boundary 0.4
# job_search filtered subtraction time taken: 2.6226043701171875e-06 seconds
# job_search filtered sorting time taken: 2.121598958969116 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0023746490478515625 seconds
# boundary 0.3
# job_search filtered subtraction time taken: 2.384185791015625e-06 seconds
# job_search filtered sorting time taken: 2.1543760299682617 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.002370595932006836 seconds
# boundary 0.2
# job_search filtered subtraction time taken: 2.384185791015625e-06 seconds
# job_search filtered sorting time taken: 2.3386125564575195 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.002818584442138672 seconds
# boundary 0.1
# job_search filtered subtraction time taken: 2.384185791015625e-06 seconds
# job_search filtered sorting time taken: 2.26491641998291 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0022025108337402344 seconds
# boundary 0.0
# job_search filtered subtraction time taken: 2.1457672119140625e-06 seconds
# job_search filtered sorting time taken: 2.2889785766601562 seconds
# (2000, 3)
# job_search filtered write csv time taken: 0.0024368762969970703 seconds
#
#
#  is_hired_1mo
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/is_hired_1mo/
# time taken to load filtered sample: 13.186896562576294 seconds (9026993, 3)
# time taken to merge: 7.763822555541992 seconds (9026993, 13)
# time softmax: 1.3168296813964844 seconds
# boundary 1.0
# is_hired_1mo filtered subtraction time taken: 2.1457672119140625e-06 seconds
# is_hired_1mo filtered sorting time taken: 4.5578858852386475 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.0026693344116210938 seconds
# boundary 0.9
# is_hired_1mo filtered subtraction time taken: 2.1457672119140625e-06 seconds
# is_hired_1mo filtered sorting time taken: 1.4923651218414307 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.0024611949920654297 seconds
# boundary 0.8
# is_hired_1mo filtered subtraction time taken: 2.6226043701171875e-06 seconds
# is_hired_1mo filtered sorting time taken: 1.6342864036560059 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.0026383399963378906 seconds
# boundary 0.7
# is_hired_1mo filtered subtraction time taken: 1.9073486328125e-06 seconds
# is_hired_1mo filtered sorting time taken: 1.651595115661621 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.002518892288208008 seconds
# boundary 0.6
# is_hired_1mo filtered subtraction time taken: 2.1457672119140625e-06 seconds
# is_hired_1mo filtered sorting time taken: 1.8468754291534424 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.002611398696899414 seconds
# boundary 0.5
# is_hired_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo filtered sorting time taken: 1.88694167137146 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.0024569034576416016 seconds
# boundary 0.4
# is_hired_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo filtered sorting time taken: 1.9558181762695312 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.0023343563079833984 seconds
# boundary 0.3
# is_hired_1mo filtered subtraction time taken: 2.6226043701171875e-06 seconds
# is_hired_1mo filtered sorting time taken: 2.232348680496216 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.002478361129760742 seconds
# boundary 0.2
# is_hired_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo filtered sorting time taken: 2.249180316925049 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.0023882389068603516 seconds
# boundary 0.1
# is_hired_1mo filtered subtraction time taken: 2.6226043701171875e-06 seconds
# is_hired_1mo filtered sorting time taken: 2.430135726928711 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.002421855926513672 seconds
# boundary 0.0
# is_hired_1mo filtered subtraction time taken: 2.384185791015625e-06 seconds
# is_hired_1mo filtered sorting time taken: 2.534966468811035 seconds
# (2000, 3)
# is_hired_1mo filtered write csv time taken: 0.0024747848510742188 seconds
#
#
#  job_offer
# /scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/job_offer/
# time taken to load filtered sample: 13.283995866775513 seconds (9026993, 3)
# time taken to merge: 8.021599769592285 seconds (9026993, 13)
# time softmax: 1.3942267894744873 seconds
# boundary 1.0
# job_offer filtered subtraction time taken: 4.0531158447265625e-06 seconds
# job_offer filtered sorting time taken: 4.934360504150391 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.0024688243865966797 seconds
# boundary 0.9
# job_offer filtered subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer filtered sorting time taken: 1.5393054485321045 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.002325773239135742 seconds
# boundary 0.8
# job_offer filtered subtraction time taken: 2.384185791015625e-06 seconds
# job_offer filtered sorting time taken: 3.9227101802825928 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.01539301872253418 seconds
# boundary 0.7
# job_offer filtered subtraction time taken: 2.6226043701171875e-06 seconds
# job_offer filtered sorting time taken: 5.037857532501221 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.0024275779724121094 seconds
# boundary 0.6
# job_offer filtered subtraction time taken: 2.6226043701171875e-06 seconds
# job_offer filtered sorting time taken: 3.9448277950286865 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.0024445056915283203 seconds
# boundary 0.5
# job_offer filtered subtraction time taken: 2.6226043701171875e-06 seconds
# job_offer filtered sorting time taken: 4.529988765716553 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.0025429725646972656 seconds
# boundary 0.4
# job_offer filtered subtraction time taken: 2.6226043701171875e-06 seconds
# job_offer filtered sorting time taken: 4.7348058223724365 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.00917816162109375 seconds
# boundary 0.3
# job_offer filtered subtraction time taken: 2.384185791015625e-06 seconds
# job_offer filtered sorting time taken: 4.936073541641235 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.004569292068481445 seconds
# boundary 0.2
# job_offer filtered subtraction time taken: 2.86102294921875e-06 seconds
# job_offer filtered sorting time taken: 3.4292101860046387 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.002370595932006836 seconds
# boundary 0.1
# job_offer filtered subtraction time taken: 2.6226043701171875e-06 seconds
# job_offer filtered sorting time taken: 2.2936642169952393 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.0023908615112304688 seconds
# boundary 0.0
# job_offer filtered subtraction time taken: 2.1457672119140625e-06 seconds
# job_offer filtered sorting time taken: 2.2527518272399902 seconds
# (2000, 3)
# job_offer filtered write csv time taken: 0.002457141876220703 seconds

# %%
# exporting top 1000 and specific boundaries
import glob
import pandas as pd
import time
import pickle
import matplotlib.pyplot as plt
from scipy.special import softmax

boundary_dict = {
    'random':{
        "is_unemployed": 1.0,
         "lost_job_1mo": 1.0,
         "job_search": 0.98,
#          "job_search": 1.0,
        "is_hired_1mo": 1.0,
         "job_offer": 1.0
    },
#     'filtered': {
#         "is_unemployed": 0.8,
#          "lost_job_1mo": 0.75,
#          "job_search": 0.85,
#          "is_hired_1mo": 0.95,
#          "job_offer": 1.0
#     }
}

all_tweets_for_sam = pd.DataFrame()

for column in ["is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]:
    print('\n\n', column)
    
#     if column != 'job_search': continue
    
    start_time = time.time()
    model_output_path = '/scratch/da2734/twitter/jobs/running_on_200Msamples/pred_output_10pct_sample_BERT/{}/'.format(column)

    start_time = time.time()
    model_output_random = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'random*.csv')], ignore_index = True)
    print('time taken to load random sample:', str(time.time() - start_time), 'seconds', model_output_random.shape)

    start_time = time.time()
    merged_random = pd.merge(model_output_random, tweets_random, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_random.shape)

    start_time = time.time()
#     based on https://github.com/ThilinaRajapakse/simpletransformers/issues/30
    merged_random[['neg', 'pos_model']] = softmax(merged_random[['first', 'second']], axis=1)
    print('time softmax:', str(time.time() - start_time), 'seconds')

    start_time = time.time()
    pickle.dump( merged_random, open( "./pickles/{}_BERT_ST_merged_random_1pct.pkl".format(column), "wb" ) )
    print('time taken to dump:', str(time.time() - start_time), 'seconds')

    merged_random   = merged_random[['tweet_id', 'pos_model', 'text']]
#     print(merged_random.head())
    
    
    merged_random = merged_random.drop_duplicates(['text'])
    
    fig = plt.figure()
    ax = plt.subplot(111)
    plt.hist(merged_random['pos_model'], bins=20, density = True, color = 'red', alpha = 0.2)
    plt.title(column+' random')
#     ax.set_yscale('log')
    plt.xlim(0,1.1)


#     print(column)
#     start_time = time.time()
#     sort_merged_random = merged_random.sort_values(by=['pos_model'], ascending=False)
#     print('random', sort_merged_random[['pos_model', 'text']].head())
#     sort_merged_random = sort_merged_random[['tweet_id', 'pos_model', 'text']]
#     sort_merged_random.head(1000).to_csv('csv/BERT_ST_random_pos_1000_{}.csv'.format(column), index = False)

    ## boundary save 
    
    
    boundary = boundary_dict['random'][column]
    merged_random['dist_point{}'.format(boundary)] = abs(merged_random['pos_model'] - boundary)

    start_time = time.time()
    print(column, 'random subtraction time taken:', str(time.time() - start_time), 'seconds')

    start_time = time.time()
    merged_random = merged_random.sort_values(by=['dist_point{}'.format(boundary)], ascending=True)
    print(column, 'random sorting time taken:', str(time.time() - start_time), 'seconds')

    start_time = time.time()
    merged_random[:1000].to_csv('csv/BERT_ST_random_{}_point_{}.csv'.format(column, boundary))
    # print(all_random_boundary['text'])
    print(column, 'random write csv time taken:', str(time.time() - start_time), 'seconds')   
    
    all_tweets_for_sam = pd.concat([all_tweets_for_sam, merged_random[:1000]])
    
    
#     break
# Out:
#  is_unemployed
# time taken to load random sample: 3.2467129230499268 seconds (9440641, 3)
# time taken to merge: 7.704353094100952 seconds (9440641, 13)
# time softmax: 1.3470361232757568 seconds
# time taken to dump: 6.609426021575928 seconds
# is_unemployed random subtraction time taken: 2.384185791015625e-06 seconds
# is_unemployed random sorting time taken: 4.5028297901153564 seconds
# is_unemployed random write csv time taken: 0.011187076568603516 seconds
#
#
#  lost_job_1mo
# time taken to load random sample: 3.136655569076538 seconds (9440641, 3)
# time taken to merge: 8.098906993865967 seconds (9440641, 13)
# time softmax: 1.292982816696167 seconds
# time taken to dump: 6.134558439254761 seconds
# lost_job_1mo random subtraction time taken: 2.384185791015625e-06 seconds
# lost_job_1mo random sorting time taken: 4.491257429122925 seconds
# lost_job_1mo random write csv time taken: 0.010523319244384766 seconds
#
#
#  job_search
# time taken to load random sample: 3.110830545425415 seconds (9440641, 3)
# time taken to merge: 8.01020097732544 seconds (9440641, 13)
# time softmax: 1.2850496768951416 seconds
# time taken to dump: 6.015748977661133 seconds
# job_search random subtraction time taken: 2.6226043701171875e-06 seconds
# job_search random sorting time taken: 4.493000507354736 seconds
# job_search random write csv time taken: 0.010853052139282227 seconds
#
#
#  is_hired_1mo
# time taken to load random sample: 3.4520490169525146 seconds (9440641, 3)
# time taken to merge: 8.029442071914673 seconds (9440641, 13)
# time softmax: 1.2960374355316162 seconds
# time taken to dump: 5.786062479019165 seconds
# is_hired_1mo random subtraction time taken: 3.5762786865234375e-06 seconds
# is_hired_1mo random sorting time taken: 4.443010330200195 seconds
# is_hired_1mo random write csv time taken: 0.010917901992797852 seconds
#
#
#  job_offer
# time taken to load random sample: 3.6599185466766357 seconds (9440641, 3)
# time taken to merge: 7.970609426498413 seconds (9440641, 13)
# time softmax: 1.3640191555023193 seconds
# time taken to dump: 5.684770107269287 seconds
# job_offer random subtraction time taken: 2.6226043701171875e-06 seconds
# job_offer random sorting time taken: 4.481955051422119 seconds
# job_offer random write csv time taken: 0.010814189910888672 seconds

# %%
# entropy
import glob
import pandas as pd
import time
import pickle
import matplotlib.pyplot as plt
import numpy as np

boundary = 0.5

for column in ["is_unemployed", "lost_job_1mo", "job_search", "is_hired_1mo", "job_offer"]:
    print(column)
    start_time = time.time()
    model_output_path = '/scratch/da2734/twitter/running_on_200Msamples/pred_output/{}/'.format(column)
    model_output_filtered = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'filtered*.csv')], ignore_index = True)
    print('time taken to load filtered sample:', str(time.time() - start_time), 'seconds', model_output_filtered.shape)


    start_time = time.time()
    model_output_random = pd.concat([pd.read_csv(f) for f in glob.glob(model_output_path+'random*.csv')], ignore_index = True)
    print('time taken to load random sample:', str(time.time() - start_time), 'seconds', model_output_random.shape)


    start_time = time.time()
    merged_filtered = pd.merge(model_output_filtered, tweets_filtered, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_filtered.shape)

    start_time = time.time()
    merged_random = pd.merge(model_output_random, tweets_random, how='inner', on = 'tweet_id')
    print('time taken to merge:', str(time.time() - start_time), 'seconds', merged_filtered.shape)

    start_time = time.time()
    pickle.dump( merged_filtered, open( "./top_tweets/{}_merged_filtered.pkl".format(column), "wb" ) )
    pickle.dump( merged_random, open( "./top_tweets/{}_merged_random.pkl".format(column), "wb" ) )
    print('time taken to dump:', str(time.time() - start_time), 'seconds')

    merged_filtered = merged_filtered[['neg_model', 'pos_model', 'text']]
    merged_random   = merged_random[['neg_model', 'pos_model', 'text']]
    
#     merged_random = merged_random[merged_random['pos_model'] > 0.5 ]

    merged_filtered['entropy'] = - merged_filtered['pos_model']*(np.log(merged_filtered['pos_model']))
    merged_random['entropy'] = - merged_random['pos_model']*(np.log(merged_random['pos_model']))
    
#     merged_filtered = merged_filtered[merged_filtered['pos_model'] > 0.5 ]

    
    print(column)
    fig = plt.figure()
    ax = plt.subplot(111)
#     plt.hist(merged_filtered['pos_model'], bins=20, density = True, color = 'red', alpha = 0.2)
    plt.hist(merged_filtered['entropy'], bins=20, density = True, color = 'red', alpha = 0.2)    
    plt.title(column+' filtered')
#     ax.set_yscale('log')
#     plt.xlim(0,1.1)
    
    fig = plt.figure()
    ax = plt.subplot(111)
    plt.hist(merged_random['entropy'], bins=20, density = True, color = 'red', alpha = 0.2)
#     plt.hist(merged_random['pos_model'], bins=20, density = True, color = 'red', alpha = 0.2)
    plt.title(column+' random')
#     ax.set_yscale('log')
#     plt.xlim(0,1.1)
    
#     print(column)
#     start_time = time.time()
#     sort_merged_filtered = merged_filtered.sort_values(by=['pos_model'], ascending=False)
#     sort_merged_filtered.head(100).to_csv('top_tweets/filtered_{}_pos_100.csv'.format(column))
#     print(sort_merged_filtered.head())
    
#     sort_merged_filtered = merged_filtered.sort_values(by=['pos_model'], ascending=True)
#     sort_merged_filtered.head(100).to_csv('top_tweets/filtered_{}_neg_100.csv'.format(column))
#     print(sort_merged_filtered.head())
#     print('time taken to save csv:', str(time.time() - start_time), 'seconds')

#     print(column)
#     start_time = time.time()
#     sort_merged_random = merged_random.sort_values(by=['pos_model'], ascending=False)
#     sort_merged_random.head(100).to_csv('top_tweets/random_{}_pos_100.csv'.format(column))
#     print(sort_merged_random.head())
    
#     sort_merged_random = merged_random.sort_values(by=['pos_model'], ascending=True)
#     sort_merged_random.head(100).to_csv('top_tweets/random_{}_neg_100.csv'.format(column))
#     print(sort_merged_random.head())
#     print('time taken to save csv:', str(time.time() - start_time), 'seconds')


#     merged_filtered['dist_point5'] = abs(merged_filtered['pos_model'] - boundary)

#     start_time = time.time()
#     print(column, 'filtered subtraction time taken:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     merged_filtered = merged_filtered.sort_values(by=['dist_point5'], ascending=True)
#     print(column, 'filtered sorting time taken:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     merged_filtered[:100].to_csv('top_tweets/filtered_{}_point5.csv'.format(column))
#     # print(all_filtered_boundary['text'])
#     print(column, 'filtered write csv time taken:', str(time.time() - start_time), 'seconds')


#     merged_random['dist_point5'] = abs(merged_random['pos_model'] - boundary)

#     start_time = time.time()
#     print(column, 'random subtraction time taken:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     merged_random = merged_random.sort_values(by=['dist_point5'], ascending=True)
#     print(column, 'random sorting time taken:', str(time.time() - start_time), 'seconds')

#     start_time = time.time()
#     merged_random[:100].to_csv('top_tweets/random_{}_point5.csv'.format(column))
#     # print(all_random_boundary['text'])
#     print(column, 'random write csv time taken:', str(time.time() - start_time), 'seconds')    
    
    
#     break
