# %%
import pandas as pd
import os

# %%
path = '/home/manuto/Downloads'
df = pd.read_json(os.path.join(path, 'kskipngrams_iter_0-convbert-1122153.json'))
df.head(n=11)
# Out:
#   2grams_is_hired_1mo     3grams_is_hired_1mo  2grams_is_unemployed  \
# 0      [job, excited]         [the, job, got]         [lost, phone]
# 1        [got, hired]        [start, my, new]          [im, losing]
# 2   [start, tomorrow]        [i, paid, today]       [got, headache]
# 3      [started, new]  [tomorrow, first, day]        [m, depressed]
# 4    [first, nervous]     [finally, a, phone]        [am, hungover]
# 5       [paid, today]     [chapter, in, life]      [having, attack]
# 6      [finally, car]      [off, work, early]  [i, procrastinating]
# 7          [my, woot]  [starting, on, monday]      [have, starving]
# 8         [work, yay]   [started, this, week]         [lazy, today]
# 9     [survived, day]      [just, home, time]      [someone, dying]
#
#    3grams_is_unemployed     2grams_job_offer             3grams_job_offer  \
# 0      [i, lost, phone]  [looking, engineer]     [looking, for, engineer]
# ...

# %%
df = pd.read_json(os.path.join(path, 'kskipngrams_iter_1-convbert-2476327 (1).json'))
df.head(n=11)
# Out:
#   2grams_is_hired_1mo    3grams_is_hired_1mo 2grams_is_unemployed  \
# 0      [got, invited]          [job, i, got]         [my, asthma]
# 1        [start, job]         [real, a, get]       [am, homeless]
# 2    [accepted, into]  [start, my, tomorrow]      [unemployed, a]
# 3         [hired, at]      [just, paid, and]      [got, accident]
# 4    [new, apartment]      [first, day, new]    [i, unemployment]
# 5     [just, offered]   [called, into, work]          [lost, job]
# 6     [approved, for]      [invited, to, go]     [just, attacked]
# 7       [i, promoted]   [approved, for, the]          [stung, by]
# 8        [my, permit]  [your, number, phone]          [fired, me]
# 9        [paid, week]   [doing, surveys, so]          [car, died]
#
#     3grams_is_unemployed          2grams_job_offer           3grams_job_offer  \
# 0    [i, am, unemployed]               [los, jobs]   [job, opportunity, jobs]
# 1       [just, got, hit]  [transportation, hiring]       [ca, hiring, career]
# ...
