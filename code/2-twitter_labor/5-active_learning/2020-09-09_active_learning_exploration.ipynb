# %%
from transformers import BertTokenizer, BertModel, BertConfig, BertForTokenClassification, BertForMaskedLM
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer
import torch
import os
import pandas as pd

# %% [markdown]
# ## Utils

# %%
def get_token_in_sequence_with_most_attention(model, tokenizer, input_sequence):
    """Run an input sequence through the BERT model, collect and average attention scores per token and return token with most average attention."""
    tokenized_input_sequence = tokenizer.tokenize(input_sequence)
    input_ids = torch.tensor(tokenizer.encode(input_sequence, add_special_tokens=False)).unsqueeze(0)
    outputs = model(input_ids)
    last_hidden_states, pooler_outputs, hidden_states, attentions = outputs
    attention_tensor = torch.squeeze(torch.stack(attentions))
    attention_tensor_averaged = torch.mean(attention_tensor, (0, 1))
    attention_average_scores_per_token = torch.sum(attention_tensor_averaged, dim=0)
    attention_scores_dict = dict()
    for token_position in range(len(tokenized_input_sequence)):
        attention_scores_dict[token_position] = attention_average_scores_per_token[token_position].item()
    print('Attention scores dictionary: ', attention_scores_dict)
    return {'token_index': max(attention_scores_dict, key=attention_scores_dict.get),
            'token_str': tokenized_input_sequence[max(attention_scores_dict, key=attention_scores_dict.get)]}

# %%
def extract_keywords_from_mlm_results(mlm_results_list, K_kw_explore):
    selected_keywords_list = list()
    for rank_mlm_keyword in range(K_kw_explore):
        selected_keywords_list.append(mlm_results_list[rank_mlm_keyword]['token_str'])
    return selected_keywords_list

# %% [markdown]
# ## Data and model import

# %% [markdown]
# ### is_hired_1mo

# %%
#load inference data from random set
data_path = '/home/manuto/Documents/world_bank/bert_twitter_labor/data/inference/convBERT/it0/random'
is_hired_1mo_df = pd.read_pickle(os.path.join(data_path,'is_hired_1mo_ONNX_BERT_ST_merged_random_100m_jun22.pkl')).reset_index(drop=True)
is_hired_1mo_df.head()
# Out:
#              tweet_id     first    second  \
# 0  662755069675327489  0.014041  0.985959
# 1  459847518688665600  0.014151  0.985849
# 2  535195703203880961  0.014181  0.985819
# 3  331873004168552448  0.014229  0.985771
# 4  327479239966330881  0.014336  0.985664
#
#                                                 text
# 0                                 Got hired today!!!
# 1                          Just got hired at Google.
# 2                     Just got hired at Hobby Lobby!
# 3                          Got hired at Chick Fil A!
# 4  Got hired today at the hooters on the beach! 😉...

# %%
#load model
PATH_MODEL_FOLDER = '/home/manuto/Downloads/best_model'
config = BertConfig.from_pretrained(PATH_MODEL_FOLDER, output_hidden_states=True, output_attentions=True)
tokenizer = BertTokenizer.from_pretrained(PATH_MODEL_FOLDER)
model = BertModel.from_pretrained(PATH_MODEL_FOLDER, config=config)

# %% [markdown]
# We identify the token with most attention in each of the top 40 tweets.
#
# For each of these high-attention tokens, we identify 5 most similar tokens through masked language modeling (MLM).

# %%
mlm_pipeline_bert = pipeline('fill-mask', model='bert-base-uncased', tokenizer='bert-base-uncased',
                        config='bert-base-uncased', topk=5)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=230.0, style=ProgressStyle(description_…

# %%
mlm_pipeline_custom = pipeline('fill-mask', model=PATH_MODEL_FOLDER, tokenizer=PATH_MODEL_FOLDER,
                        config=PATH_MODEL_FOLDER, topk=5)
# Out:
# Model name '/home/manuto/Downloads/best_model' was not found in model name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-japanese, bert-base-japanese-whole-word-masking, bert-base-japanese-char, bert-base-japanese-char-whole-word-masking, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased, openai-gpt, transfo-xl-wt103, gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2, ctrl, xlnet-base-cased, xlnet-large-cased, xlm-mlm-en-2048, xlm-mlm-ende-1024, xlm-mlm-enfr-1024, xlm-mlm-enro-1024, xlm-mlm-tlm-xnli15-1024, xlm-mlm-xnli15-1024, xlm-clm-enfr-1024, xlm-clm-ende-1024, xlm-mlm-17-1280, xlm-mlm-100-1280, roberta-base, roberta-large, roberta-large-mnli, distilroberta-base, roberta-base-openai-detector, roberta-large-openai-detector, distilbert-base-uncased, distilbert-base-uncased-distilled-squad, distilbert-base-german-cased, distilbert-base-multilingual-cased, distilbert-base-uncased-finetuned-sst-2-english, albert-base-v1, albert-large-v1, albert-xlarge-v1, albert-xxlarge-v1, albert-base-v2, albert-large-v2, albert-xlarge-v2, albert-xxlarge-v2, camembert-base, umberto-commoncrawl-cased-v1, umberto-wikipedia-uncased-v1, t5-small, t5-base, t5-large, t5-3b, t5-11b, xlm-roberta-base, xlm-roberta-large, xlm-roberta-large-finetuned-conll02-dutch, xlm-roberta-large-finetuned-conll02-spanish, xlm-roberta-large-finetuned-conll03-english, xlm-roberta-large-finetuned-conll03-german, flaubert-small-cased, flaubert-base-uncased, flaubert-base-cased, flaubert-large-cased). We assumed '/home/manuto/Downloads/best_model/modelcard.json' was a path or url to a model card file named modelcard.json or a directory containing such a file but couldn't find any such file at this path or url.
# Creating an empty model card.

# %% [markdown]
# #### MLM with Vanilla BERT

# %%
for tweet_index in range(40):
    print('***********Tweet #{}***********'.format(str(tweet_index)))
    input_sequence = is_hired_1mo_df['text'][tweet_index]
    tokenized_tweet = tokenizer.tokenize(input_sequence)
    print('Tweet: {}'.format(input_sequence))
    #identify high attention token
    attention_results_dict = get_token_in_sequence_with_most_attention(model, tokenizer, input_sequence)
    attention_token_str = attention_results_dict['token_str']
    attention_token_index = attention_results_dict['token_index']
    print('Token with most attention on average: {}'.format(attention_token_str))
    print('Token index with most attention on average: {}'.format(attention_token_index))
    #do MLM
    ## replace high-attention token by a [MASK] token
    tokenized_tweet[attention_token_index] = '[MASK]'
    mlm_results_list = mlm_pipeline_bert(' '.join(tokenized_tweet))
    print('MLM results for token "{}": '.format(attention_results_dict['token_str']))
    for i in range(len(mlm_results_list)):
        print(mlm_results_list[i])
# Out:
# ***********Tweet #0***********
# Tweet: Got hired today!!!
# Attention scores dictionary:  {0: 1.5126816034317017, 1: 1.4664392471313477, 2: 0.8879139423370361, 3: 0.6898782253265381, 4: 0.6860100626945496, 5: 0.7570769786834717}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS] " hired today!!! [SEP]', 'score': 0.19336189329624176, 'token': 1000}
# {'sequence': '[CLS] get hired today!!! [SEP]', 'score': 0.1401471197605133, 'token': 2131}
# {'sequence': '[CLS] was hired today!!! [SEP]', 'score': 0.08166869729757309, 'token': 2001}
# {'sequence': '[CLS] i hired today!!! [SEP]', 'score': 0.07634694874286652, 'token': 1045}
# {'sequence': '[CLS] got hired today!!! [SEP]', 'score': 0.06446801126003265, 'token': 2288}
# ***********Tweet #1***********
# Tweet: Just got hired at Google.
# Attention scores dictionary:  {0: 1.4466649293899536, 1: 0.9768638610839844, 2: 1.231852650642395, 3: 0.6410866975784302, 4: 0.8262073397636414, 5: 0.8773249983787537}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired at google. [SEP]', 'score': 0.6601719856262207, 'token': 1045}
# {'sequence': '[CLS] he got hired at google. [SEP]', 'score': 0.16553150117397308, 'token': 2002}
# {'sequence': '[CLS] she got hired at google. [SEP]', 'score': 0.0550830215215683, 'token': 2016}
# {'sequence': '[CLS] you got hired at google. [SEP]', 'score': 0.01769147999584675, 'token': 2017}
# {'sequence': '[CLS] and got hired at google. [SEP]', 'score': 0.017665913328528404, 'token': 1998}
# ***********Tweet #2***********
# Tweet: Just got hired at Hobby Lobby!
# Attention scores dictionary:  {0: 2.003486156463623, 1: 1.0714242458343506, 2: 1.288223147392273, 3: 0.8825028538703918, 4: 0.6916070580482483, 5: 0.9118468761444092, 6: 0.6171855926513672, 7: 0.7439514398574829, 8: 0.789772629737854}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.43286028504371643, 'token': 1045}
# {'sequence': '[CLS] he got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.1800535023212433, 'token': 2002}
# {'sequence': '[CLS] you got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.05534173920750618, 'token': 2017}
# {'sequence': '[CLS] we got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.047363076359033585, 'token': 2057}
# {'sequence': '[CLS] she got hired at ho # # bby lo # # bby! [SEP]', 'score': 0.03987342119216919, 'token': 2016}
# ***********Tweet #3***********
# Tweet: Got hired at Chick Fil A!
# Attention scores dictionary:  {0: 1.6901261806488037, 1: 1.4704527854919434, 2: 0.8817123174667358, 3: 0.8063538670539856, 4: 0.8460407853126526, 5: 0.8220967650413513, 6: 0.6992152333259583, 7: 0.7840019464492798}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS] i hired at chi # # ck fil a! [SEP]', 'score': 0.13499297201633453, 'token': 1045}
# {'sequence': '[CLS] get hired at chi # # ck fil a! [SEP]', 'score': 0.0848986804485321, 'token': 2131}
# {'sequence': '[CLS] - hired at chi # # ck fil a! [SEP]', 'score': 0.07558328658342361, 'token': 1011}
# {'sequence': '[CLS] and hired at chi # # ck fil a! [SEP]', 'score': 0.062087882310152054, 'token': 1998}
# {'sequence': '[CLS] he hired at chi # # ck fil a! [SEP]', 'score': 0.04676593840122223, 'token': 2002}
# ***********Tweet #4***********
# Tweet: Got hired today at the hooters on the beach! 😉😘 http://t.co/CXJwFlJBDD
# Attention scores dictionary:  {0: 2.024837017059326, 1: 2.0913095474243164, 2: 1.0261682271957397, 3: 0.8227925300598145, 4: 0.8867377042770386, 5: 0.6843050718307495, 6: 0.9743086695671082, 7: 0.7228235006332397, 8: 0.8818275332450867, 9: 0.5169668197631836, 10: 1.239403486251831, 11: 0.8934234380722046, 12: 0.7671452164649963, 13: 1.0015947818756104, 14: 0.8535884022712708, 15: 0.8662179708480835, 16: 0.9419584274291992, 17: 0.9503005146980286, 18: 0.9791205525398254, 19: 1.1336263418197632, 20: 0.9325911402702332, 21: 0.8440160751342773, 22: 0.9497209787368774, 23: 0.952224850654602, 24: 1.090457797050476, 25: 1.1882436275482178, 26: 0.9217448234558105, 27: 0.8995845317840576, 28: 0.9629607200622559}
# Token with most attention on average: hired
# Token index with most attention on average: 1
# MLM results for token "hired":
# {'sequence': '[CLS] got it today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.13940751552581787, 'token': 2009}
# {'sequence': '[CLS] got lost today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.08266028761863708, 'token': 2439}
# {'sequence': '[CLS] got married today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.056614842265844345, 'token': 2496}
# {'sequence': '[CLS] got you today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.0464019700884819, 'token': 2017}
# {'sequence': '[CLS] got him today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / c # # x # # j # # w # # fl # # j # # b # # dd [SEP]', 'score': 0.04296739026904106, 'token': 2032}
# ***********Tweet #5***********
# Tweet: Just got hired at Barnes and Noble! 😂🔥
# Attention scores dictionary:  {0: 1.9725046157836914, 1: 1.0725886821746826, 2: 1.3334821462631226, 3: 0.7505266666412354, 4: 0.7428436279296875, 5: 0.5759084224700928, 6: 0.8209231495857239, 7: 0.7078946828842163, 8: 1.0233279466629028}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired at barnes and noble! [UNK] [SEP]', 'score': 0.769833505153656, 'token': 1045}
# {'sequence': '[CLS] he got hired at barnes and noble! [UNK] [SEP]', 'score': 0.06066092476248741, 'token': 2002}
# {'sequence': '[CLS] you got hired at barnes and noble! [UNK] [SEP]', 'score': 0.03213085979223251, 'token': 2017}
# {'sequence': '[CLS] and got hired at barnes and noble! [UNK] [SEP]', 'score': 0.025858543813228607, 'token': 1998}
# {'sequence': '[CLS] she got hired at barnes and noble! [UNK] [SEP]', 'score': 0.025522392243146896, 'token': 2016}
# ***********Tweet #6***********
# Tweet: I just got hired! #gloria!!
# Attention scores dictionary:  {0: 1.7866902351379395, 1: 0.9872668981552124, 2: 0.869711697101593, 3: 1.3873838186264038, 4: 0.8119598031044006, 5: 0.948147177696228, 6: 0.8375120759010315, 7: 0.9044555425643921, 8: 0.7275986671447754, 9: 0.7392739057540894}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': '[CLS] i just got hired! # gl # # oria!! [SEP]', 'score': 0.8060575127601624, 'token': 1045}
# {'sequence': '[CLS] you just got hired! # gl # # oria!! [SEP]', 'score': 0.07502473890781403, 'token': 2017}
# {'sequence': '[CLS] he just got hired! # gl # # oria!! [SEP]', 'score': 0.038892488926649094, 'token': 2002}
# {'sequence': '[CLS] we just got hired! # gl # # oria!! [SEP]', 'score': 0.03724052384495735, 'token': 2057}
# {'sequence': '[CLS] she just got hired! # gl # # oria!! [SEP]', 'score': 0.011873094365000725, 'token': 2016}
# ***********Tweet #7***********
# Tweet: Just got hired for job #3... It's grind time! 💰
# Attention scores dictionary:  {0: 2.066835880279541, 1: 1.4238344430923462, 2: 1.5178768634796143, 3: 1.0180003643035889, 4: 0.9141719937324524, 5: 0.7743204832077026, 6: 0.8660517334938049, 7: 0.7493154406547546, 8: 0.7959368824958801, 9: 0.8465275764465332, 10: 0.7951346039772034, 11: 0.46805641055107117, 12: 0.7952996492385864, 13: 1.3199464082717896, 14: 0.9638402462005615, 15: 0.6575741171836853, 16: 1.0272767543792725}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': "[CLS] i got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.7877305746078491, 'token': 1045}
# {'sequence': "[CLS] he got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.05276660621166229, 'token': 2002}
# {'sequence': "[CLS] and got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.0296192467212677, 'token': 1998}
# {'sequence': "[CLS] you got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.020750096067786217, 'token': 2017}
# {'sequence': "[CLS] she got hired for job # 3... it's grind time! [UNK] [SEP]", 'score': 0.017916671931743622, 'token': 2016}
# ***********Tweet #8***********
# Tweet: I just got hired !
# Attention scores dictionary:  {0: 1.448033094406128, 1: 0.8278198838233948, 2: 0.7723451852798462, 3: 1.2157444953918457, 4: 0.7360571622848511}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': '[CLS] i just got hired! [SEP]', 'score': 0.7701625227928162, 'token': 1045}
# {'sequence': '[CLS] you just got hired! [SEP]', 'score': 0.10473155230283737, 'token': 2017}
# {'sequence': '[CLS] he just got hired! [SEP]', 'score': 0.04960741475224495, 'token': 2002}
# {'sequence': '[CLS] we just got hired! [SEP]', 'score': 0.035427067428827286, 'token': 2057}
# {'sequence': '[CLS] she just got hired! [SEP]', 'score': 0.013725729659199715, 'token': 2016}
# ***********Tweet #9***********
# Tweet: Just got hired in the spot. #TwoJobs 💸
# Attention scores dictionary:  {0: 1.905438780784607, 1: 1.1128921508789062, 2: 1.3489856719970703, 3: 0.7385013699531555, 4: 0.6312955617904663, 5: 1.176804542541504, 6: 0.9598628878593445, 7: 0.8739089369773865, 8: 0.8465639352798462, 9: 0.9671778678894043, 10: 0.552645742893219, 11: 0.8859224319458008}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.541392982006073, 'token': 1045}
# {'sequence': '[CLS] he got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.19962696731090546, 'token': 2002}
# {'sequence': '[CLS] and got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.06618180125951767, 'token': 1998}
# {'sequence': '[CLS] she got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.03615875542163849, 'token': 2016}
# {'sequence': '[CLS] you got hired in the spot. # two # # job # # s [UNK] [SEP]', 'score': 0.026898978278040886, 'token': 2017}
# ***********Tweet #10***********
# Tweet: Just got hired at best buy 😏💆😌
# Attention scores dictionary:  {0: 1.6763460636138916, 1: 0.9992050528526306, 2: 1.2913012504577637, 3: 0.6323670148849487, 4: 0.6996299028396606, 5: 0.7434889078140259, 6: 0.9576617479324341}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired at best buy [UNK] [SEP]', 'score': 0.5239905118942261, 'token': 1045}
# {'sequence': '[CLS] he got hired at best buy [UNK] [SEP]', 'score': 0.16177281737327576, 'token': 2002}
# {'sequence': '[CLS] and got hired at best buy [UNK] [SEP]', 'score': 0.08552931249141693, 'token': 1998}
# {'sequence': '[CLS] she got hired at best buy [UNK] [SEP]', 'score': 0.07376301288604736, 'token': 2016}
# {'sequence': '[CLS]. got hired at best buy [UNK] [SEP]', 'score': 0.01789291948080063, 'token': 1012}
# ***********Tweet #11***********
# Tweet: just got hired at the Copper Dock :'o
# Attention scores dictionary:  {0: 1.8428473472595215, 1: 1.1160138845443726, 2: 1.3442131280899048, 3: 0.6547653079032898, 4: 0.6001117825508118, 5: 0.7279141545295715, 6: 0.8660165667533875, 7: 1.0258369445800781, 8: 0.8260997533798218, 9: 0.9961816072463989}
# Token with most attention on average: just
# Token index with most attention on average: 0
# MLM results for token "just":
# {'sequence': "[CLS] i got hired at the copper dock :'o [SEP]", 'score': 0.4392911493778229, 'token': 1045}
# {'sequence': "[CLS] he got hired at the copper dock :'o [SEP]", 'score': 0.33019670844078064, 'token': 2002}
# {'sequence': "[CLS] we got hired at the copper dock :'o [SEP]", 'score': 0.03576045110821724, 'token': 2057}
# {'sequence': "[CLS] she got hired at the copper dock :'o [SEP]", 'score': 0.03554486855864525, 'token': 2016}
# {'sequence': "[CLS] you got hired at the copper dock :'o [SEP]", 'score': 0.022889360785484314, 'token': 2017}
# ***********Tweet #12***********
# Tweet: Just got hired for a second job. =)
# Attention scores dictionary:  {0: 1.9588974714279175, 1: 1.1255855560302734, 2: 1.2566630840301514, 3: 0.8671053051948547, 4: 0.4781137704849243, 5: 1.0461726188659668, 6: 0.7967631816864014, 7: 0.809714138507843, 8: 0.9673491716384888, 9: 0.6936358213424683}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired for a second job. = ) [SEP]', 'score': 0.39140450954437256, 'token': 1045}
# {'sequence': '[CLS] he got hired for a second job. = ) [SEP]', 'score': 0.27197620272636414, 'token': 2002}
# {'sequence': '[CLS] and got hired for a second job. = ) [SEP]', 'score': 0.17309552431106567, 'token': 1998}
# {'sequence': '[CLS] she got hired for a second job. = ) [SEP]', 'score': 0.046061865985393524, 'token': 2016}
# {'sequence': '[CLS] then got hired for a second job. = ) [SEP]', 'score': 0.01537556853145361, 'token': 2059}
# ***********Tweet #13***********
# Tweet: Just got hired at Camp Bow Wow. #Sweet.
# Attention scores dictionary:  {0: 1.9970202445983887, 1: 1.1321396827697754, 2: 1.3568525314331055, 3: 0.7910979986190796, 4: 0.9024330973625183, 5: 0.8361329436302185, 6: 0.7186444401741028, 7: 0.8492363691329956, 8: 0.8574963808059692, 9: 0.8460490107536316, 10: 0.7128970623016357}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired at camp bow wow. # sweet. [SEP]', 'score': 0.4440888464450836, 'token': 1045}
# {'sequence': '[CLS] he got hired at camp bow wow. # sweet. [SEP]', 'score': 0.17020636796951294, 'token': 2002}
# {'sequence': '[CLS] " got hired at camp bow wow. # sweet. [SEP]', 'score': 0.07684192061424255, 'token': 1000}
# {'sequence': '[CLS] and got hired at camp bow wow. # sweet. [SEP]', 'score': 0.06653253734111786, 'token': 1998}
# {'sequence': '[CLS] she got hired at camp bow wow. # sweet. [SEP]', 'score': 0.05299258604645729, 'token': 2016}
# ***********Tweet #14***********
# Tweet: Just got hired as a personal trainer at Fitness DK in Copenhagen!
# Attention scores dictionary:  {0: 2.2612524032592773, 1: 1.2444549798965454, 2: 1.643334984779358, 3: 0.9314596652984619, 4: 0.6492533683776855, 5: 0.7070528864860535, 6: 0.9515090584754944, 7: 0.7531241178512573, 8: 0.9198614358901978, 9: 0.7482291460037231, 10: 0.721075177192688, 11: 0.6683940887451172, 12: 0.972585141658783, 13: 0.8284134864807129}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired as a personal trainer at fitness d # # k in copenhagen! [SEP]', 'score': 0.5856566429138184, 'token': 1045}
# {'sequence': '[CLS] he got hired as a personal trainer at fitness d # # k in copenhagen! [SEP]', 'score': 0.17466919124126434, 'token': 2002}
# {'sequence': '[CLS] she got hired as a personal trainer at fitness d # # k in copenhagen! [SEP]', 'score': 0.1315307468175888, 'token': 2016}
# {'sequence': '[CLS] and got hired as a personal trainer at fitness d # # k in copenhagen! [SEP]', 'score': 0.03542660176753998, 'token': 1998}
# {'sequence': '[CLS] you got hired as a personal trainer at fitness d # # k in copenhagen! [SEP]', 'score': 0.013331561349332333, 'token': 2017}
# ***********Tweet #15***********
# Tweet: Just got hired at TJ Maxx 😎
# Attention scores dictionary:  {0: 1.9093445539474487, 1: 0.9964953660964966, 2: 1.3861947059631348, 3: 0.8965185880661011, 4: 0.6256743669509888, 5: 0.9441564083099365, 6: 0.7403448820114136, 7: 0.6225660443305969, 8: 0.8787049055099487}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired at t # # j max # # x [UNK] [SEP]', 'score': 0.38306018710136414, 'token': 1045}
# {'sequence': '[CLS] he got hired at t # # j max # # x [UNK] [SEP]', 'score': 0.31420159339904785, 'token': 2002}
# {'sequence': '[CLS] she got hired at t # # j max # # x [UNK] [SEP]', 'score': 0.07736220955848694, 'token': 2016}
# {'sequence': '[CLS] and got hired at t # # j max # # x [UNK] [SEP]', 'score': 0.06070471554994583, 'token': 1998}
# {'sequence': '[CLS] you got hired at t # # j max # # x [UNK] [SEP]', 'score': 0.02041548117995262, 'token': 2017}
# ***********Tweet #16***********
# Tweet: Got hired on the spot😂😈
# Attention scores dictionary:  {0: 1.253964900970459, 1: 1.2943854331970215, 2: 0.8540881872177124, 3: 0.6148845553398132, 4: 0.9826771020889282}
# Token with most attention on average: hired
# Token index with most attention on average: 1
# MLM results for token "hired":
# {'sequence': '[CLS] got it on the [UNK] [SEP]', 'score': 0.15435484051704407, 'token': 2009}
# {'sequence': '[CLS] got started on the [UNK] [SEP]', 'score': 0.062848761677742, 'token': 2318}
# {'sequence': '[CLS] got lost on the [UNK] [SEP]', 'score': 0.04173465073108673, 'token': 2439}
# {'sequence': '[CLS] got him on the [UNK] [SEP]', 'score': 0.03428862988948822, 'token': 2032}
# {'sequence': '[CLS] got one on the [UNK] [SEP]', 'score': 0.028909051790833473, 'token': 2028}
# ***********Tweet #17***********
# Tweet: Got hired at the Gulf. #YesYesYes
# Attention scores dictionary:  {0: 1.992775559425354, 1: 1.6423070430755615, 2: 0.6975770592689514, 3: 0.5735028386116028, 4: 1.0287569761276245, 5: 0.8721883296966553, 6: 0.8654198050498962, 7: 0.9259864091873169, 8: 0.80129075050354, 9: 0.8213381767272949, 10: 0.9719569683074951, 11: 0.8069007396697998}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS] and hired at the gulf. # yes # # y # # es # # y # # es [SEP]', 'score': 0.08975149691104889, 'token': 1998}
# {'sequence': '[CLS] " hired at the gulf. # yes # # y # # es # # y # # es [SEP]', 'score': 0.06754028797149658, 'token': 1000}
# {'sequence': '[CLS] was hired at the gulf. # yes # # y # # es # # y # # es [SEP]', 'score': 0.059309616684913635, 'token': 2001}
# {'sequence': '[CLS] i hired at the gulf. # yes # # y # # es # # y # # es [SEP]', 'score': 0.05118577554821968, 'token': 1045}
# {'sequence': '[CLS] he hired at the gulf. # yes # # y # # es # # y # # es [SEP]', 'score': 0.042256467044353485, 'token': 2002}
# ***********Tweet #18***********
# Tweet: Just got hired at Olive Garden ✔️
# Attention scores dictionary:  {0: 1.7673919200897217, 1: 0.9163364171981812, 2: 1.2997117042541504, 3: 0.6286437511444092, 4: 0.6396015882492065, 5: 0.6670652627944946, 6: 1.081249713897705}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] i got hired at olive garden [UNK] [SEP]', 'score': 0.3421357572078705, 'token': 1045}
# {'sequence': '[CLS] he got hired at olive garden [UNK] [SEP]', 'score': 0.27388015389442444, 'token': 2002}
# {'sequence': '[CLS] and got hired at olive garden [UNK] [SEP]', 'score': 0.1009732261300087, 'token': 1998}
# {'sequence': '[CLS] she got hired at olive garden [UNK] [SEP]', 'score': 0.05770695209503174, 'token': 2016}
# {'sequence': '[CLS] then got hired at olive garden [UNK] [SEP]', 'score': 0.022742411121726036, 'token': 2059}
# ***********Tweet #19***********
# Tweet: i got hired at the spirit store in the hub!!! :)
# Attention scores dictionary:  {0: 2.235973358154297, 1: 1.2311465740203857, 2: 1.5457109212875366, 3: 0.8086987733840942, 4: 0.6504694223403931, 5: 0.9284740686416626, 6: 0.976057231426239, 7: 0.7882581353187561, 8: 0.5873992443084717, 9: 1.2527601718902588, 10: 0.8112443685531616, 11: 0.7440286874771118, 12: 0.7331650853157043, 13: 0.7405610084533691, 14: 0.966052770614624}
# Token with most attention on average: i
# Token index with most attention on average: 0
# MLM results for token "i":
# {'sequence': '[CLS] i got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.6613478660583496, 'token': 1045}
# {'sequence': '[CLS] he got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.11710155755281448, 'token': 2002}
# {'sequence': '[CLS] and got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.05226587876677513, 'token': 1998}
# {'sequence': '[CLS] she got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.029405979439616203, 'token': 2016}
# {'sequence': '[CLS] you got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.026896486058831215, 'token': 2017}
# ***********Tweet #20***********
# Tweet: Got hired at North County MMA!!!!! OMG 🙄 I'm so happy 😋
# Attention scores dictionary:  {0: 2.4943244457244873, 1: 2.1048123836517334, 2: 0.94046550989151, 3: 0.6207968592643738, 4: 1.0046098232269287, 5: 1.365416169166565, 6: 0.7722797989845276, 7: 0.7158159017562866, 8: 0.6979694962501526, 9: 0.6486483812332153, 10: 0.6513867974281311, 11: 1.1927971839904785, 12: 0.7861584424972534, 13: 0.7486388087272644, 14: 0.6136422157287598, 15: 0.5475655198097229, 16: 0.6750344634056091, 17: 1.349496841430664, 18: 1.0701408386230469}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': "[CLS] get hired at north county mma!!!!! omg [UNK] i'm so happy [UNK] [SEP]", 'score': 0.16022337973117828, 'token': 2131}
# {'sequence': "[CLS] - hired at north county mma!!!!! omg [UNK] i'm so happy [UNK] [SEP]", 'score': 0.08142457157373428, 'token': 1011}
# {'sequence': "[CLS] i hired at north county mma!!!!! omg [UNK] i'm so happy [UNK] [SEP]", 'score': 0.06156342476606369, 'token': 1045}
# {'sequence': "[CLS] now hired at north county mma!!!!! omg [UNK] i'm so happy [UNK] [SEP]", 'score': 0.049286022782325745, 'token': 2085}
# {'sequence': "[CLS] currently hired at north county mma!!!!! omg [UNK] i'm so happy [UNK] [SEP]", 'score': 0.04026215896010399, 'token': 2747}
# ***********Tweet #21***********
# Tweet: RT @yomixedchick: Got hired on the spot !
# Attention scores dictionary:  {0: 1.8179945945739746, 1: 0.7367821931838989, 2: 0.7493699789047241, 3: 0.755091667175293, 4: 0.9126898050308228, 5: 0.7672845721244812, 6: 0.8321616649627686, 7: 1.3140417337417603, 8: 1.0624698400497437, 9: 1.705833077430725, 10: 0.8442808389663696, 11: 0.6134726405143738, 12: 1.1365208625793457, 13: 0.7520067691802979}
# Token with most attention on average: RT
# Token index with most attention on average: 0
# MLM results for token "RT":
# {'sequence': '[CLS] # @ yo # # mi # # xed # # chi # # ck : got hired on the spot! [SEP]', 'score': 0.1550043821334839, 'token': 1001}
# {'sequence': '[CLS] y @ yo # # mi # # xed # # chi # # ck : got hired on the spot! [SEP]', 'score': 0.026793479919433594, 'token': 1061}
# {'sequence': '[CLS] the @ yo # # mi # # xed # # chi # # ck : got hired on the spot! [SEP]', 'score': 0.02464553341269493, 'token': 1996}
# {'sequence': '[CLS] x @ yo # # mi # # xed # # chi # # ck : got hired on the spot! [SEP]', 'score': 0.019071238115429878, 'token': 1060}
# {'sequence': '[CLS]. @ yo # # mi # # xed # # chi # # ck : got hired on the spot! [SEP]', 'score': 0.018661193549633026, 'token': 1012}
# ***********Tweet #22***********
# Tweet: I just got hired at Tilly's!! Hell yeah!!
# Attention scores dictionary:  {0: 2.1405367851257324, 1: 1.139622449874878, 2: 1.0873925685882568, 3: 1.6099159717559814, 4: 1.0125110149383545, 5: 0.8485730290412903, 6: 0.7511700987815857, 7: 0.7005934715270996, 8: 0.9510619044303894, 9: 0.7661877870559692, 10: 0.7293860912322998, 11: 0.9310598969459534, 12: 1.0700886249542236, 13: 0.5687373876571655, 14: 0.6931627988815308}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': "[CLS] i just got hired at till # # y's!! hell yeah!! [SEP]", 'score': 0.8102927207946777, 'token': 1045}
# {'sequence': "[CLS] he just got hired at till # # y's!! hell yeah!! [SEP]", 'score': 0.05739370733499527, 'token': 2002}
# {'sequence': "[CLS] you just got hired at till # # y's!! hell yeah!! [SEP]", 'score': 0.03912757337093353, 'token': 2017}
# {'sequence': "[CLS] we just got hired at till # # y's!! hell yeah!! [SEP]", 'score': 0.018261447548866272, 'token': 2057}
# {'sequence': '[CLS] " just got hired at till # # y\'s!! hell yeah!! [SEP]', 'score': 0.018056880682706833, 'token': 1000}
# ***********Tweet #23***********
# Tweet: just got hired at Kohl’s lol
# Attention scores dictionary:  {0: 1.9981051683425903, 1: 1.161868929862976, 2: 1.2041054964065552, 3: 0.8532512187957764, 4: 0.8008482456207275, 5: 0.9661829471588135, 6: 0.46284082531929016, 7: 0.7188224792480469, 8: 0.8339739441871643}
# Token with most attention on average: just
# Token index with most attention on average: 0
# MLM results for token "just":
# {'sequence': '[CLS] he got hired at ko # # hl ’ s lol [SEP]', 'score': 0.6138142347335815, 'token': 2002}
# {'sequence': '[CLS] she got hired at ko # # hl ’ s lol [SEP]', 'score': 0.10744082927703857, 'token': 2016}
# {'sequence': '[CLS] i got hired at ko # # hl ’ s lol [SEP]', 'score': 0.05983850732445717, 'token': 1045}
# {'sequence': '[CLS] and got hired at ko # # hl ’ s lol [SEP]', 'score': 0.0515361987054348, 'token': 1998}
# {'sequence': '[CLS] then got hired at ko # # hl ’ s lol [SEP]', 'score': 0.01392978336662054, 'token': 2059}
# ***********Tweet #24***********
# Tweet: Yes sir!!! Just got hired for wingstop!!! God is good!
# Attention scores dictionary:  {0: 2.286463737487793, 1: 1.2548853158950806, 2: 0.6242220401763916, 3: 0.6680631041526794, 4: 0.90364670753479, 5: 1.3377630710601807, 6: 1.116016149520874, 7: 1.5826884508132935, 8: 1.0574780702590942, 9: 0.8496884703636169, 10: 0.8255758881568909, 11: 0.7160632610321045, 12: 0.6977587342262268, 13: 0.7380958199501038, 14: 1.096549153327942, 15: 0.7700022459030151, 16: 0.9022258520126343, 17: 0.5728140473365784}
# Token with most attention on average: Yes
# Token index with most attention on average: 0
# MLM results for token "Yes":
# {'sequence': '[CLS] " sir!!! just got hired for wings # # top!!! god is good! [SEP]', 'score': 0.256998747587204, 'token': 1000}
# {'sequence': '[CLS] yes sir!!! just got hired for wings # # top!!! god is good! [SEP]', 'score': 0.09004872292280197, 'token': 2748}
# {'sequence': '[CLS] no sir!!! just got hired for wings # # top!!! god is good! [SEP]', 'score': 0.0898791030049324, 'token': 2053}
# {'sequence': '[CLS] - sir!!! just got hired for wings # # top!!! god is good! [SEP]', 'score': 0.048455677926540375, 'token': 1011}
# {'sequence': '[CLS] and sir!!! just got hired for wings # # top!!! god is good! [SEP]', 'score': 0.0474591962993145, 'token': 1998}
# ***********Tweet #25***********
# Tweet: Got a new job today and started on the spot!  Doing some real work!!
# Attention scores dictionary:  {0: 2.066157341003418, 1: 0.9446656107902527, 2: 1.0775426626205444, 3: 1.1994777917861938, 4: 0.8793065547943115, 5: 1.0466992855072021, 6: 1.2806215286254883, 7: 0.8468508720397949, 8: 0.6319315433502197, 9: 1.178275227546692, 10: 0.8223013281822205, 11: 1.1083741188049316, 12: 0.6953713893890381, 13: 0.8366166949272156, 14: 1.001132845878601, 15: 0.6766977310180664, 16: 0.707977294921875}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS] got a new job today and started on the spot! doing some real work!! [SEP]', 'score': 0.5299140214920044, 'token': 2288}
# {'sequence': '[CLS] found a new job today and started on the spot! doing some real work!! [SEP]', 'score': 0.2625945508480072, 'token': 2179}
# {'sequence': '[CLS] started a new job today and started on the spot! doing some real work!! [SEP]', 'score': 0.13163936138153076, 'token': 2318}
# {'sequence': '[CLS] landed a new job today and started on the spot! doing some real work!! [SEP]', 'score': 0.011581219732761383, 'token': 5565}
# {'sequence': '[CLS] took a new job today and started on the spot! doing some real work!! [SEP]', 'score': 0.007115561980754137, 'token': 2165}
# ***********Tweet #26***********
# Tweet: Applied 2 days ago and was hired on the spot today! Craigslist rocks! I start my new job tomorrow, wish me good luck! 🍀😊😁
# Attention scores dictionary:  {0: 2.5439810752868652, 1: 0.5972791910171509, 2: 1.1146010160446167, 3: 1.0263832807540894, 4: 1.1184475421905518, 5: 0.9497688412666321, 6: 1.7238953113555908, 7: 0.8270929455757141, 8: 0.5948663949966431, 9: 1.2401114702224731, 10: 0.8192051649093628, 11: 1.0022680759429932, 12: 0.9408514499664307, 13: 0.4033448100090027, 14: 0.865966260433197, 15: 0.9850254654884338, 16: 0.9084862470626831, 17: 1.0118941068649292, 18: 1.332174301147461, 19: 0.7810649275779724, 20: 1.028007984161377, 21: 1.0990099906921387, 22: 0.9172815084457397, 23: 0.8492493629455566, 24: 1.2960838079452515, 25: 0.7335415482521057, 26: 0.7438902854919434, 27: 0.7952611446380615, 28: 0.6670078039169312, 29: 1.0839589834213257}
# Token with most attention on average: Applied
# Token index with most attention on average: 0
# MLM results for token "Applied":
# {'sequence': '[CLS] just 2 days ago and was hired on the spot today! craig # # s # # list rocks! i start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.18237121403217316, 'token': 2074}
# {'sequence': '[CLS] signed 2 days ago and was hired on the spot today! craig # # s # # list rocks! i start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.12920159101486206, 'token': 2772}
# {'sequence': '[CLS] hired 2 days ago and was hired on the spot today! craig # # s # # list rocks! i start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.11180474609136581, 'token': 5086}
# {'sequence': '[CLS] started 2 days ago and was hired on the spot today! craig # # s # # list rocks! i start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.06978310644626617, 'token': 2318}
# {'sequence': '[CLS] quit 2 days ago and was hired on the spot today! craig # # s # # list rocks! i start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.03641163185238838, 'token': 8046}
# ***********Tweet #27***********
# Tweet: I got hired at American Eagle!!! 😄🎉🎊🎈
# Attention scores dictionary:  {0: 1.9628069400787354, 1: 1.1302497386932373, 2: 1.393890380859375, 3: 0.9235032200813293, 4: 0.6433350443840027, 5: 0.8259020447731018, 6: 0.7240637540817261, 7: 0.7438327670097351, 8: 0.5906373262405396, 9: 1.0617785453796387}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': '[CLS] i got hired at american eagle!!! [UNK] [SEP]', 'score': 0.42209112644195557, 'token': 1045}
# {'sequence': '[CLS] he got hired at american eagle!!! [UNK] [SEP]', 'score': 0.3682278096675873, 'token': 2002}
# {'sequence': '[CLS] and got hired at american eagle!!! [UNK] [SEP]', 'score': 0.05894533544778824, 'token': 1998}
# {'sequence': '[CLS] she got hired at american eagle!!! [UNK] [SEP]', 'score': 0.04742356762290001, 'token': 2016}
# {'sequence': '[CLS] you got hired at american eagle!!! [UNK] [SEP]', 'score': 0.016440602019429207, 'token': 2017}
# ***********Tweet #28***********
# Tweet: Just been hired as a PT cashier at Sears in Jefferson Mall! Will start as soon as I pass drug test, background check.
# Attention scores dictionary:  {0: 2.309258460998535, 1: 1.3257185220718384, 2: 1.718119740486145, 3: 0.9299182891845703, 4: 0.729774534702301, 5: 0.9957663416862488, 6: 0.7425462007522583, 7: 0.8576821684837341, 8: 0.7776150107383728, 9: 0.9435948133468628, 10: 0.747683584690094, 11: 0.6433034539222717, 12: 0.7801647186279297, 13: 1.11190664768219, 14: 1.067413568496704, 15: 1.364040493965149, 16: 0.53275066614151, 17: 0.8281121850013733, 18: 0.7340365648269653, 19: 0.9515392780303955, 20: 1.488388180732727, 21: 0.9807153940200806, 22: 0.8721585869789124, 23: 1.1129268407821655, 24: 0.8162550926208496, 25: 0.777398943901062, 26: 0.8612107634544373}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS] has been hired as a pt cash # # ier at sears in jefferson mall! will start as soon as i pass drug test, background check. [SEP]', 'score': 0.36820879578590393, 'token': 2038}
# {'sequence': '[CLS] have been hired as a pt cash # # ier at sears in jefferson mall! will start as soon as i pass drug test, background check. [SEP]', 'score': 0.15217871963977814, 'token': 2031}
# {'sequence': '[CLS] just been hired as a pt cash # # ier at sears in jefferson mall! will start as soon as i pass drug test, background check. [SEP]', 'score': 0.14605103433132172, 'token': 2074}
# {'sequence': '[CLS] i been hired as a pt cash # # ier at sears in jefferson mall! will start as soon as i pass drug test, background check. [SEP]', 'score': 0.0754501149058342, 'token': 1045}
# {'sequence': '[CLS] had been hired as a pt cash # # ier at sears in jefferson mall! will start as soon as i pass drug test, background check. [SEP]', 'score': 0.07202117145061493, 'token': 2018}
# ***********Tweet #29***********
# Tweet: Got hired for 2 server jobs in wildwood today! #CantWaitForSummer
# Attention scores dictionary:  {0: 2.5975589752197266, 1: 1.9260715246200562, 2: 0.9841775894165039, 3: 0.7959757447242737, 4: 0.8007948994636536, 5: 0.9740767478942871, 6: 0.7263240218162537, 7: 0.6076979637145996, 8: 0.7716761827468872, 9: 1.0719220638275146, 10: 0.7861866354942322, 11: 0.902882993221283, 12: 1.2057353258132935, 13: 0.6273699998855591, 14: 0.8597532510757446, 15: 0.9184005856513977, 16: 0.6785638332366943, 17: 0.8338161110877991, 18: 0.9310155510902405}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS] he hired for 2 server jobs in wild # # wood today! # cant # # w # # ait # # for # # s # # um # # mer [SEP]', 'score': 0.10073888301849365, 'token': 2002}
# {'sequence': '[CLS] i hired for 2 server jobs in wild # # wood today! # cant # # w # # ait # # for # # s # # um # # mer [SEP]', 'score': 0.09597036242485046, 'token': 1045}
# {'sequence': '[CLS] and hired for 2 server jobs in wild # # wood today! # cant # # w # # ait # # for # # s # # um # # mer [SEP]', 'score': 0.09314225614070892, 'token': 1998}
# {'sequence': '[CLS] was hired for 2 server jobs in wild # # wood today! # cant # # w # # ait # # for # # s # # um # # mer [SEP]', 'score': 0.04432428628206253, 'token': 2001}
# {'sequence': '[CLS] - hired for 2 server jobs in wild # # wood today! # cant # # w # # ait # # for # # s # # um # # mer [SEP]', 'score': 0.041148606687784195, 'token': 1011}
# ***********Tweet #30***********
# Tweet: First day at the new yab!
# Attention scores dictionary:  {0: 1.5690275430679321, 1: 1.218014121055603, 2: 0.8930929899215698, 3: 0.7307674288749695, 4: 1.2033594846725464, 5: 0.8260961174964905, 6: 0.7348130941390991, 7: 0.8248294591903687}
# Token with most attention on average: First
# Token index with most attention on average: 0
# MLM results for token "First":
# {'sequence': '[CLS] a day at the new ya # # b! [SEP]', 'score': 0.1623542755842209, 'token': 1037}
# {'sequence': '[CLS] good day at the new ya # # b! [SEP]', 'score': 0.12272664159536362, 'token': 2204}
# {'sequence': '[CLS] first day at the new ya # # b! [SEP]', 'score': 0.11132828891277313, 'token': 2034}
# {'sequence': '[CLS] all day at the new ya # # b! [SEP]', 'score': 0.060143712908029556, 'token': 2035}
# {'sequence': '[CLS] the day at the new ya # # b! [SEP]', 'score': 0.0589086152613163, 'token': 1996}
# ***********Tweet #31***********
# Tweet: Was hired on to a new job today. Hope it goes well.
# Attention scores dictionary:  {0: 1.8963210582733154, 1: 1.3329483270645142, 2: 1.022910237312317, 3: 0.9498006701469421, 4: 0.7221141457557678, 5: 1.0568573474884033, 6: 1.1116896867752075, 7: 0.9277344942092896, 8: 0.9968269467353821, 9: 0.8822914958000183, 10: 0.7221673130989075, 11: 0.7866895198822021, 12: 0.8074938058853149, 13: 0.7841547727584839}
# Token with most attention on average: Was
# Token index with most attention on average: 0
# MLM results for token "Was":
# {'sequence': '[CLS] get hired on to a new job today. hope it goes well. [SEP]', 'score': 0.5580984354019165, 'token': 2131}
# {'sequence': '[CLS] got hired on to a new job today. hope it goes well. [SEP]', 'score': 0.2617955803871155, 'token': 2288}
# {'sequence': '[CLS] getting hired on to a new job today. hope it goes well. [SEP]', 'score': 0.037400003522634506, 'token': 2893}
# {'sequence': '[CLS] " hired on to a new job today. hope it goes well. [SEP]', 'score': 0.028088131919503212, 'token': 1000}
# {'sequence': '[CLS] be hired on to a new job today. hope it goes well. [SEP]', 'score': 0.019777797162532806, 'token': 2022}
# ***********Tweet #32***********
# Tweet: Start my new job tomorrow at 2!
# Attention scores dictionary:  {0: 1.6256535053253174, 1: 0.8992180824279785, 2: 1.0544120073318481, 3: 1.0394339561462402, 4: 0.9535702466964722, 5: 0.7780277729034424, 6: 0.9144979119300842, 7: 0.7351862192153931}
# Token with most attention on average: Start
# Token index with most attention on average: 0
# MLM results for token "Start":
# {'sequence': '[CLS] start my new job tomorrow at 2! [SEP]', 'score': 0.1538209617137909, 'token': 2707}
# {'sequence': '[CLS] in my new job tomorrow at 2! [SEP]', 'score': 0.07410646229982376, 'token': 1999}
# {'sequence': '[CLS] get my new job tomorrow at 2! [SEP]', 'score': 0.06408268958330154, 'token': 2131}
# {'sequence': '[CLS] " my new job tomorrow at 2! [SEP]', 'score': 0.055639296770095825, 'token': 1000}
# {'sequence': '[CLS] open my new job tomorrow at 2! [SEP]', 'score': 0.0506381094455719, 'token': 2330}
# ***********Tweet #33***********
# Tweet: Just started at #UIFIKI #uifi2014. Let's do it. http://t.co/knBK657Aaw
# Attention scores dictionary:  {0: 2.0200371742248535, 1: 1.915666103363037, 2: 0.9757499694824219, 3: 0.9019858837127686, 4: 0.8560076951980591, 5: 0.8595513105392456, 6: 0.765491783618927, 7: 0.8632155060768127, 8: 0.9964633584022522, 9: 0.9636867642402649, 10: 1.239399790763855, 11: 1.1158162355422974, 12: 0.9469090700149536, 13: 1.0333988666534424, 14: 0.9254617691040039, 15: 0.4110928177833557, 16: 0.7886349558830261, 17: 0.9506558179855347, 18: 0.683941662311554, 19: 0.867717981338501, 20: 1.067295789718628, 21: 0.7762137651443481, 22: 0.7508362531661987, 23: 0.8788192272186279, 24: 1.098353624343872, 25: 0.9531998634338379, 26: 1.20845627784729, 27: 0.9141677021980286, 28: 1.1045376062393188, 29: 0.8762695789337158, 30: 0.9155499935150146, 31: 1.1199265718460083, 32: 1.0339009761810303, 33: 1.1222730875015259, 34: 1.0993144512176514}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': "[CLS] it started at # ui # # fi # # k # # i # u # # ifi # # 20 # # 14. let's do it. http : / / t. co / kn # # b # # k # # 65 # # 7 # # a # # aw [SEP]", 'score': 0.6251033544540405, 'token': 2009}
# {'sequence': "[CLS] i started at # ui # # fi # # k # # i # u # # ifi # # 20 # # 14. let's do it. http : / / t. co / kn # # b # # k # # 65 # # 7 # # a # # aw [SEP]", 'score': 0.10691646486520767, 'token': 1045}
# {'sequence': "[CLS] they started at # ui # # fi # # k # # i # u # # ifi # # 20 # # 14. let's do it. http : / / t. co / kn # # b # # k # # 65 # # 7 # # a # # aw [SEP]", 'score': 0.05206010863184929, 'token': 2027}
# {'sequence': "[CLS] he started at # ui # # fi # # k # # i # u # # ifi # # 20 # # 14. let's do it. http : / / t. co / kn # # b # # k # # 65 # # 7 # # a # # aw [SEP]", 'score': 0.02749885618686676, 'token': 2002}
# {'sequence': "[CLS] and started at # ui # # fi # # k # # i # u # # ifi # # 20 # # 14. let's do it. http : / / t. co / kn # # b # # k # # 65 # # 7 # # a # # aw [SEP]", 'score': 0.014952309429645538, 'token': 1998}
# ***********Tweet #34***********
# Tweet: RT @jayboi93: Got hired at Academy on the spot! :)
# Attention scores dictionary:  {0: 2.078007459640503, 1: 0.8528658151626587, 2: 0.7201181650161743, 3: 0.699449896812439, 4: 0.8333907723426819, 5: 0.6023377776145935, 6: 0.9277788996696472, 7: 1.539118766784668, 8: 1.3410940170288086, 9: 1.6097546815872192, 10: 0.8734671473503113, 11: 1.0817668437957764, 12: 0.8674831390380859, 13: 0.6000611186027527, 14: 1.1549186706542969, 15: 0.7712576985359192, 16: 0.6221018433570862, 17: 0.8250271081924438}
# Token with most attention on average: RT
# Token index with most attention on average: 0
# MLM results for token "RT":
# {'sequence': '[CLS] ( @ ja # # y # # bo # # i # # 93 : got hired at academy on the spot! : ) [SEP]', 'score': 0.4222303330898285, 'token': 1006}
# {'sequence': '[CLS] y @ ja # # y # # bo # # i # # 93 : got hired at academy on the spot! : ) [SEP]', 'score': 0.043414607644081116, 'token': 1061}
# {'sequence': '[CLS] # @ ja # # y # # bo # # i # # 93 : got hired at academy on the spot! : ) [SEP]', 'score': 0.03328311815857887, 'token': 1001}
# {'sequence': '[CLS]. @ ja # # y # # bo # # i # # 93 : got hired at academy on the spot! : ) [SEP]', 'score': 0.031541530042886734, 'token': 1012}
# {'sequence': '[CLS] - @ ja # # y # # bo # # i # # 93 : got hired at academy on the spot! : ) [SEP]', 'score': 0.02472047321498394, 'token': 1011}
# ***********Tweet #35***********
# Tweet: just got new job!
# Attention scores dictionary:  {0: 1.3237202167510986, 1: 0.9203872084617615, 2: 0.9882594347000122, 3: 0.9540395736694336, 4: 0.8135936856269836}
# Token with most attention on average: just
# Token index with most attention on average: 0
# MLM results for token "just":
# {'sequence': '[CLS] i got new job! [SEP]', 'score': 0.5533037781715393, 'token': 1045}
# {'sequence': '[CLS] " got new job! [SEP]', 'score': 0.24769996106624603, 'token': 1000}
# {'sequence': '[CLS] you got new job! [SEP]', 'score': 0.07219384610652924, 'token': 2017}
# {'sequence': '[CLS] just got new job! [SEP]', 'score': 0.024015024304389954, 'token': 2074}
# {'sequence': '[CLS] he got new job! [SEP]', 'score': 0.01804550178349018, 'token': 2002}
# ***********Tweet #36***********
# Tweet: Got hired on the spot at my interview 2day!! Now I need 2 more jobs so I can have 4 total..
# Attention scores dictionary:  {0: 2.564220905303955, 1: 1.8344769477844238, 2: 0.9754607677459717, 3: 0.653286337852478, 4: 1.2562029361724854, 5: 0.8278435468673706, 6: 0.9025553464889526, 7: 1.2542957067489624, 8: 1.1266649961471558, 9: 0.7778411507606506, 10: 0.7046743035316467, 11: 0.7297952175140381, 12: 0.9090254306793213, 13: 0.7243320941925049, 14: 1.5344566106796265, 15: 0.7118069529533386, 16: 0.6597216725349426, 17: 0.8396849632263184, 18: 1.0097413063049316, 19: 0.6681457757949829, 20: 0.8051666617393494, 21: 0.9283831119537354, 22: 0.8641493916511536, 23: 1.2244359254837036, 24: 0.6777385473251343, 25: 0.8358938097953796}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS] was hired on the spot at my interview 2d # # ay!! now i need 2 more jobs so i can have 4 total.. [SEP]', 'score': 0.19530834257602692, 'token': 2001}
# {'sequence': '[CLS]. hired on the spot at my interview 2d # # ay!! now i need 2 more jobs so i can have 4 total.. [SEP]', 'score': 0.1627408117055893, 'token': 1012}
# {'sequence': '[CLS] i hired on the spot at my interview 2d # # ay!! now i need 2 more jobs so i can have 4 total.. [SEP]', 'score': 0.15623684227466583, 'token': 1045}
# {'sequence': '[CLS] got hired on the spot at my interview 2d # # ay!! now i need 2 more jobs so i can have 4 total.. [SEP]', 'score': 0.09708911180496216, 'token': 2288}
# {'sequence': '[CLS] - hired on the spot at my interview 2d # # ay!! now i need 2 more jobs so i can have 4 total.. [SEP]', 'score': 0.07103679329156876, 'token': 1011}
# ***********Tweet #37***********
# Tweet: Got hired at best buy mobile last week &amp;amp; today I have an interview with FedEx for a customer service rep position! #needthat
# Attention scores dictionary:  {0: 2.451568126678467, 1: 2.4593515396118164, 2: 1.011380910873413, 3: 0.8046233057975769, 4: 0.9342045187950134, 5: 1.0449730157852173, 6: 1.0444341897964478, 7: 1.1438586711883545, 8: 0.9918031096458435, 9: 0.742372989654541, 10: 0.7891494035720825, 11: 0.9352538585662842, 12: 0.8444757461547852, 13: 1.083548665046692, 14: 0.858732283115387, 15: 0.905475914478302, 16: 0.7715875506401062, 17: 1.296288251876831, 18: 0.804690957069397, 19: 0.6597017645835876, 20: 0.6982892751693726, 21: 1.0510209798812866, 22: 0.6705811619758606, 23: 0.7652428150177002, 24: 0.6990610957145691, 25: 0.8288096189498901, 26: 0.9379563927650452, 27: 1.0600669384002686, 28: 0.9595183730125427, 29: 1.1375473737716675, 30: 1.0491234064102173, 31: 0.5653067827224731}
# Token with most attention on average: hired
# Token index with most attention on average: 1
# MLM results for token "hired":
# {'sequence': '[CLS] got it at best buy mobile last week & amp ; amp ; today i have an interview with fed # # ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.11429913341999054, 'token': 2009}
# {'sequence': '[CLS] got work at best buy mobile last week & amp ; amp ; today i have an interview with fed # # ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.0958925262093544, 'token': 2147}
# {'sequence': '[CLS] got job at best buy mobile last week & amp ; amp ; today i have an interview with fed # # ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.040336139500141144, 'token': 3105}
# {'sequence': '[CLS] got you at best buy mobile last week & amp ; amp ; today i have an interview with fed # # ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.03065808117389679, 'token': 2017}
# {'sequence': '[CLS] got me at best buy mobile last week & amp ; amp ; today i have an interview with fed # # ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.029629698023200035, 'token': 2033}
# ***********Tweet #38***********
# Tweet: Start my new job today start my new job today start my new job today https://t.co/3fA36OKu1e
# Attention scores dictionary:  {0: 2.5467605590820312, 1: 0.9486736059188843, 2: 1.0718388557434082, 3: 1.0792768001556396, 4: 0.9526790976524353, 5: 1.2701438665390015, 6: 0.8888204097747803, 7: 1.077450156211853, 8: 1.134616732597351, 9: 0.986646831035614, 10: 1.1542030572891235, 11: 0.8719887733459473, 12: 1.0079599618911743, 13: 1.1203019618988037, 14: 0.9629437327384949, 15: 1.0488450527191162, 16: 0.6147999167442322, 17: 0.6486280560493469, 18: 0.711828351020813, 19: 0.949111819267273, 20: 0.885382890701294, 21: 1.049824833869934, 22: 0.8552781939506531, 23: 0.7980548143386841, 24: 1.0252622365951538, 25: 0.7214197516441345, 26: 1.0610153675079346, 27: 0.9662884473800659, 28: 0.7869267463684082, 29: 0.8964064717292786, 30: 0.9066222906112671}
# Token with most attention on average: Start
# Token index with most attention on average: 0
# MLM results for token "Start":
# {'sequence': '[CLS] start my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # a # # 36 # # ok # # u # # 1 # # e [SEP]', 'score': 0.9627187848091125, 'token': 2707}
# {'sequence': '[CLS] get my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # a # # 36 # # ok # # u # # 1 # # e [SEP]', 'score': 0.009657117538154125, 'token': 2131}
# {'sequence': '[CLS] do my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # a # # 36 # # ok # # u # # 1 # # e [SEP]', 'score': 0.0028482507914304733, 'token': 2079}
# {'sequence': '[CLS] finish my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # a # # 36 # # ok # # u # # 1 # # e [SEP]', 'score': 0.002617800375446677, 'token': 3926}
# {'sequence': '[CLS] starting my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # a # # 36 # # ok # # u # # 1 # # e [SEP]', 'score': 0.0019582612439990044, 'token': 3225}
# ***********Tweet #39***********
# Tweet: Got hired on at Francesca's for a second job 😊
# Attention scores dictionary:  {0: 1.917273759841919, 1: 1.6446563005447388, 2: 1.0589815378189087, 3: 0.9127634167671204, 4: 0.6268473267555237, 5: 0.7146026492118835, 6: 0.6649272441864014, 7: 1.0365824699401855, 8: 1.1601476669311523, 9: 0.610913872718811, 10: 0.9365875124931335, 11: 0.8651805520057678, 12: 0.8505356311798096}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': "[CLS] got hired on at frances # # ca's for a second job [UNK] [SEP]", 'score': 0.13191719353199005, 'token': 2288}
# {'sequence': "[CLS] he hired on at frances # # ca's for a second job [UNK] [SEP]", 'score': 0.10766100138425827, 'token': 2002}
# {'sequence': "[CLS] was hired on at frances # # ca's for a second job [UNK] [SEP]", 'score': 0.10579721629619598, 'token': 2001}
# {'sequence': "[CLS] and hired on at frances # # ca's for a second job [UNK] [SEP]", 'score': 0.07590842992067337, 'token': 1998}
# {'sequence': "[CLS] get hired on at frances # # ca's for a second job [UNK] [SEP]", 'score': 0.06925902515649796, 'token': 2131}

# %% [markdown]
# #### MLM with our fine-tuned ConvBERT model

# %%
for tweet_index in range(40):
    print('***********Tweet #{}***********'.format(str(tweet_index)))
    input_sequence = is_hired_1mo_df['text'][tweet_index]
    tokenized_tweet = tokenizer.tokenize(input_sequence)
    print('Tweet: {}'.format(input_sequence))
    #identify high attention token
    attention_results_dict = get_token_in_sequence_with_most_attention(model, tokenizer, input_sequence)
    attention_token_str = attention_results_dict['token_str']
    attention_token_index = attention_results_dict['token_index']
    print('Token with most attention on average: {}'.format(attention_token_str))
    print('Token index with most attention on average: {}'.format(attention_token_index))
    #do MLM
    ## replace high-attention token by a [MASK] token
    tokenized_tweet[attention_token_index] = '[MASK]'
    mlm_results_list = mlm_pipeline_custom(' '.join(tokenized_tweet))
    print('MLM results for token "{}": '.format(attention_results_dict['token_str']))
    for i in range(len(mlm_results_list)):
        print(mlm_results_list[i])
# Out:
# ***********Tweet #0***********
# Tweet: Got hired today!!!
# Attention scores dictionary:  {0: 1.5126816034317017, 1: 1.4664392471313477, 2: 0.8879139423370361, 3: 0.6898782253265381, 4: 0.6860100626945496, 5: 0.7570769786834717}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS]All hired today!!! [SEP]', 'score': 0.0008348205592483282, 'token': 27644}
# {'sequence': '[CLS] needles hired today!!! [SEP]', 'score': 0.0006449052598327398, 'token': 20625}
# {'sequence': '[CLS]blem hired today!!! [SEP]', 'score': 0.0006268700235523283, 'token': 24151}
# {'sequence': '[CLS]row hired today!!! [SEP]', 'score': 0.0006059640436433256, 'token': 6607}
# {'sequence': '[CLS]uno hired today!!! [SEP]', 'score': 0.0005076837260276079, 'token': 26761}
# ***********Tweet #1***********
# Tweet: Just got hired at Google.
# Attention scores dictionary:  {0: 1.4466649293899536, 1: 0.9768638610839844, 2: 1.231852650642395, 3: 0.6410866975784302, 4: 0.8262073397636414, 5: 0.8773249983787537}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired at Google. [SEP]', 'score': 0.0009074014378711581, 'token': 27644}
# {'sequence': '[CLS]hari got hired at Google. [SEP]', 'score': 0.000646119297016412, 'token': 16234}
# {'sequence': '[CLS]wing got hired at Google. [SEP]', 'score': 0.0005253625568002462, 'token': 7635}
# {'sequence': '[CLS] needles got hired at Google. [SEP]', 'score': 0.0005208536167629063, 'token': 20625}
# {'sequence': '[CLS]blem got hired at Google. [SEP]', 'score': 0.0005029392777942121, 'token': 24151}
# ***********Tweet #2***********
# Tweet: Just got hired at Hobby Lobby!
# Attention scores dictionary:  {0: 2.003486156463623, 1: 1.0714242458343506, 2: 1.288223147392273, 3: 0.8825028538703918, 4: 0.6916070580482483, 5: 0.9118468761444092, 6: 0.6171855926513672, 7: 0.7439514398574829, 8: 0.789772629737854}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.0009216844919137657, 'token': 27644}
# {'sequence': '[CLS] needles got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.0005895060021430254, 'token': 20625}
# {'sequence': '[CLS]blem got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.0005577853880822659, 'token': 24151}
# {'sequence': '[CLS]hari got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.0004864198272116482, 'token': 16234}
# {'sequence': '[CLS]wing got hired at Ho # # bby Lo # # bby! [SEP]', 'score': 0.00046680375817231834, 'token': 7635}
# ***********Tweet #3***********
# Tweet: Got hired at Chick Fil A!
# Attention scores dictionary:  {0: 1.6901261806488037, 1: 1.4704527854919434, 2: 0.8817123174667358, 3: 0.8063538670539856, 4: 0.8460407853126526, 5: 0.8220967650413513, 6: 0.6992152333259583, 7: 0.7840019464492798}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS]All hired at Chi # # ck Fil A! [SEP]', 'score': 0.0008046372095122933, 'token': 27644}
# {'sequence': '[CLS] needles hired at Chi # # ck Fil A! [SEP]', 'score': 0.0006390315247699618, 'token': 20625}
# {'sequence': '[CLS]blem hired at Chi # # ck Fil A! [SEP]', 'score': 0.0005926091107539833, 'token': 24151}
# {'sequence': '[CLS]row hired at Chi # # ck Fil A! [SEP]', 'score': 0.0005724509828723967, 'token': 6607}
# {'sequence': '[CLS]hari hired at Chi # # ck Fil A! [SEP]', 'score': 0.0005225684144534171, 'token': 16234}
# ***********Tweet #4***********
# Tweet: Got hired today at the hooters on the beach! 😉😘 http://t.co/CXJwFlJBDD
# Attention scores dictionary:  {0: 2.024837017059326, 1: 2.0913095474243164, 2: 1.0261682271957397, 3: 0.8227925300598145, 4: 0.8867377042770386, 5: 0.6843050718307495, 6: 0.9743086695671082, 7: 0.7228235006332397, 8: 0.8818275332450867, 9: 0.5169668197631836, 10: 1.239403486251831, 11: 0.8934234380722046, 12: 0.7671452164649963, 13: 1.0015947818756104, 14: 0.8535884022712708, 15: 0.8662179708480835, 16: 0.9419584274291992, 17: 0.9503005146980286, 18: 0.9791205525398254, 19: 1.1336263418197632, 20: 0.9325911402702332, 21: 0.8440160751342773, 22: 0.9497209787368774, 23: 0.952224850654602, 24: 1.090457797050476, 25: 1.1882436275482178, 26: 0.9217448234558105, 27: 0.8995845317840576, 28: 0.9629607200622559}
# Token with most attention on average: hired
# Token index with most attention on average: 1
# MLM results for token "hired":
# {'sequence': '[CLS] Gothaving today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0008148110355250537, 'token': 22300}
# {'sequence': '[CLS] Got ALD today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0007546799024567008, 'token': 23079}
# {'sequence': '[CLS] Gotogo today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0007458694744855165, 'token': 26205}
# {'sequence': '[CLS] Gotograph today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0006812131614424288, 'token': 16609}
# {'sequence': '[CLS] Gotynx today at the ho # # oter # # s on the beach! [UNK] http : / / t. co / C # # X # # J # # w # # Fl # # J # # B # # DD [SEP]', 'score': 0.0006660382496193051, 'token': 22093}
# ***********Tweet #5***********
# Tweet: Just got hired at Barnes and Noble! 😂🔥
# Attention scores dictionary:  {0: 1.9725046157836914, 1: 1.0725886821746826, 2: 1.3334821462631226, 3: 0.7505266666412354, 4: 0.7428436279296875, 5: 0.5759084224700928, 6: 0.8209231495857239, 7: 0.7078946828842163, 8: 1.0233279466629028}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.00088585598859936, 'token': 27644}
# {'sequence': '[CLS]blem got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.0006398935220204294, 'token': 24151}
# {'sequence': '[CLS] needles got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.00055404455633834, 'token': 20625}
# {'sequence': '[CLS]hari got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.0005017380462959409, 'token': 16234}
# {'sequence': '[CLS]row got hired at Barnes and Noble! [UNK] [SEP]', 'score': 0.0004552037862595171, 'token': 6607}
# ***********Tweet #6***********
# Tweet: I just got hired! #gloria!!
# Attention scores dictionary:  {0: 1.7866902351379395, 1: 0.9872668981552124, 2: 0.869711697101593, 3: 1.3873838186264038, 4: 0.8119598031044006, 5: 0.948147177696228, 6: 0.8375120759010315, 7: 0.9044555425643921, 8: 0.7275986671447754, 9: 0.7392739057540894}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': '[CLS]All just got hired! # gl # # oria!! [SEP]', 'score': 0.000894836091902107, 'token': 27644}
# {'sequence': '[CLS]blem just got hired! # gl # # oria!! [SEP]', 'score': 0.0006416004616767168, 'token': 24151}
# {'sequence': '[CLS] needles just got hired! # gl # # oria!! [SEP]', 'score': 0.0005679436144419014, 'token': 20625}
# {'sequence': '[CLS]row just got hired! # gl # # oria!! [SEP]', 'score': 0.0005169330397620797, 'token': 6607}
# {'sequence': '[CLS]uno just got hired! # gl # # oria!! [SEP]', 'score': 0.0004934564349241555, 'token': 26761}
# ***********Tweet #7***********
# Tweet: Just got hired for job #3... It's grind time! 💰
# Attention scores dictionary:  {0: 2.066835880279541, 1: 1.4238344430923462, 2: 1.5178768634796143, 3: 1.0180003643035889, 4: 0.9141719937324524, 5: 0.7743204832077026, 6: 0.8660517334938049, 7: 0.7493154406547546, 8: 0.7959368824958801, 9: 0.8465275764465332, 10: 0.7951346039772034, 11: 0.46805641055107117, 12: 0.7952996492385864, 13: 1.3199464082717896, 14: 0.9638402462005615, 15: 0.6575741171836853, 16: 1.0272767543792725}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': "[CLS]All got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.0009599571931175888, 'token': 27644}
# {'sequence': "[CLS]blem got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.0006586964009329677, 'token': 24151}
# {'sequence': "[CLS] needles got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.0005743009969592094, 'token': 20625}
# {'sequence': "[CLS]anu got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.0005115466774441302, 'token': 19762}
# {'sequence': "[CLS] Month got hired for job # 3... It's grind time! [UNK] [SEP]", 'score': 0.00045270868577063084, 'token': 17545}
# ***********Tweet #8***********
# Tweet: I just got hired !
# Attention scores dictionary:  {0: 1.448033094406128, 1: 0.8278198838233948, 2: 0.7723451852798462, 3: 1.2157444953918457, 4: 0.7360571622848511}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': '[CLS]All just got hired! [SEP]', 'score': 0.0008282139315269887, 'token': 27644}
# {'sequence': '[CLS]blem just got hired! [SEP]', 'score': 0.0006213507731445134, 'token': 24151}
# {'sequence': '[CLS] needles just got hired! [SEP]', 'score': 0.0005338346236385405, 'token': 20625}
# {'sequence': '[CLS]row just got hired! [SEP]', 'score': 0.0005058784736320376, 'token': 6607}
# {'sequence': '[CLS]hari just got hired! [SEP]', 'score': 0.0004994095070287585, 'token': 16234}
# ***********Tweet #9***********
# Tweet: Just got hired in the spot. #TwoJobs 💸
# Attention scores dictionary:  {0: 1.905438780784607, 1: 1.1128921508789062, 2: 1.3489856719970703, 3: 0.7385013699531555, 4: 0.6312955617904663, 5: 1.176804542541504, 6: 0.9598628878593445, 7: 0.8739089369773865, 8: 0.8465639352798462, 9: 0.9671778678894043, 10: 0.552645742893219, 11: 0.8859224319458008}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.0008871526224538684, 'token': 27644}
# {'sequence': '[CLS] needles got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.000580411811824888, 'token': 20625}
# {'sequence': '[CLS]blem got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.0005397737841121852, 'token': 24151}
# {'sequence': '[CLS]hari got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.0005042810225859284, 'token': 16234}
# {'sequence': '[CLS]row got hired in the spot. # Two # # Job # # s [UNK] [SEP]', 'score': 0.0004819829191546887, 'token': 6607}
# ***********Tweet #10***********
# Tweet: Just got hired at best buy 😏💆😌
# Attention scores dictionary:  {0: 1.6763460636138916, 1: 0.9992050528526306, 2: 1.2913012504577637, 3: 0.6323670148849487, 4: 0.6996299028396606, 5: 0.7434889078140259, 6: 0.9576617479324341}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired at best buy [UNK] [SEP]', 'score': 0.0008542651194147766, 'token': 27644}
# {'sequence': '[CLS]blem got hired at best buy [UNK] [SEP]', 'score': 0.0006360388360917568, 'token': 24151}
# {'sequence': '[CLS] needles got hired at best buy [UNK] [SEP]', 'score': 0.0005877195508219302, 'token': 20625}
# {'sequence': '[CLS]hari got hired at best buy [UNK] [SEP]', 'score': 0.0004952771705575287, 'token': 16234}
# {'sequence': '[CLS]row got hired at best buy [UNK] [SEP]', 'score': 0.000470866885734722, 'token': 6607}
# ***********Tweet #11***********
# Tweet: just got hired at the Copper Dock :'o
# Attention scores dictionary:  {0: 1.8428473472595215, 1: 1.1160138845443726, 2: 1.3442131280899048, 3: 0.6547653079032898, 4: 0.6001117825508118, 5: 0.7279141545295715, 6: 0.8660165667533875, 7: 1.0258369445800781, 8: 0.8260997533798218, 9: 0.9961816072463989}
# Token with most attention on average: just
# Token index with most attention on average: 0
# MLM results for token "just":
# {'sequence': "[CLS]All got hired at the Copper Dock :'o [SEP]", 'score': 0.0009537325822748244, 'token': 27644}
# {'sequence': "[CLS]blem got hired at the Copper Dock :'o [SEP]", 'score': 0.0005963108851574361, 'token': 24151}
# {'sequence': "[CLS] needles got hired at the Copper Dock :'o [SEP]", 'score': 0.0005276493029668927, 'token': 20625}
# {'sequence': "[CLS]hari got hired at the Copper Dock :'o [SEP]", 'score': 0.0004903178778477013, 'token': 16234}
# {'sequence': "[CLS]wing got hired at the Copper Dock :'o [SEP]", 'score': 0.00045736157335340977, 'token': 7635}
# ***********Tweet #12***********
# Tweet: Just got hired for a second job. =)
# Attention scores dictionary:  {0: 1.9588974714279175, 1: 1.1255855560302734, 2: 1.2566630840301514, 3: 0.8671053051948547, 4: 0.4781137704849243, 5: 1.0461726188659668, 6: 0.7967631816864014, 7: 0.809714138507843, 8: 0.9673491716384888, 9: 0.6936358213424683}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired for a second job. = ) [SEP]', 'score': 0.0008872179314494133, 'token': 27644}
# {'sequence': '[CLS] needles got hired for a second job. = ) [SEP]', 'score': 0.0005902533303014934, 'token': 20625}
# {'sequence': '[CLS]blem got hired for a second job. = ) [SEP]', 'score': 0.0005495237419381738, 'token': 24151}
# {'sequence': '[CLS]hari got hired for a second job. = ) [SEP]', 'score': 0.0005264462670311332, 'token': 16234}
# {'sequence': '[CLS]wing got hired for a second job. = ) [SEP]', 'score': 0.0004920072387903929, 'token': 7635}
# ***********Tweet #13***********
# Tweet: Just got hired at Camp Bow Wow. #Sweet.
# Attention scores dictionary:  {0: 1.9970202445983887, 1: 1.1321396827697754, 2: 1.3568525314331055, 3: 0.7910979986190796, 4: 0.9024330973625183, 5: 0.8361329436302185, 6: 0.7186444401741028, 7: 0.8492363691329956, 8: 0.8574963808059692, 9: 0.8460490107536316, 10: 0.7128970623016357}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired at Camp Bow Wow. # Sweet. [SEP]', 'score': 0.0008717083837836981, 'token': 27644}
# {'sequence': '[CLS]blem got hired at Camp Bow Wow. # Sweet. [SEP]', 'score': 0.000592013995628804, 'token': 24151}
# {'sequence': '[CLS]hari got hired at Camp Bow Wow. # Sweet. [SEP]', 'score': 0.0005767704569734633, 'token': 16234}
# {'sequence': '[CLS] needles got hired at Camp Bow Wow. # Sweet. [SEP]', 'score': 0.0005370902945287526, 'token': 20625}
# {'sequence': '[CLS]row got hired at Camp Bow Wow. # Sweet. [SEP]', 'score': 0.00046481378376483917, 'token': 6607}
# ***********Tweet #14***********
# Tweet: Just got hired as a personal trainer at Fitness DK in Copenhagen!
# Attention scores dictionary:  {0: 2.2612524032592773, 1: 1.2444549798965454, 2: 1.643334984779358, 3: 0.9314596652984619, 4: 0.6492533683776855, 5: 0.7070528864860535, 6: 0.9515090584754944, 7: 0.7531241178512573, 8: 0.9198614358901978, 9: 0.7482291460037231, 10: 0.721075177192688, 11: 0.6683940887451172, 12: 0.972585141658783, 13: 0.8284134864807129}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired as a personal trainer at Fitness D # # K in Copenhagen! [SEP]', 'score': 0.000944838800933212, 'token': 27644}
# {'sequence': '[CLS]hari got hired as a personal trainer at Fitness D # # K in Copenhagen! [SEP]', 'score': 0.0006152450805529952, 'token': 16234}
# {'sequence': '[CLS]blem got hired as a personal trainer at Fitness D # # K in Copenhagen! [SEP]', 'score': 0.0005643157637678087, 'token': 24151}
# {'sequence': '[CLS] needles got hired as a personal trainer at Fitness D # # K in Copenhagen! [SEP]', 'score': 0.0005496366648003459, 'token': 20625}
# {'sequence': '[CLS]hl got hired as a personal trainer at Fitness D # # K in Copenhagen! [SEP]', 'score': 0.0004899242194369435, 'token': 8495}
# ***********Tweet #15***********
# Tweet: Just got hired at TJ Maxx 😎
# Attention scores dictionary:  {0: 1.9093445539474487, 1: 0.9964953660964966, 2: 1.3861947059631348, 3: 0.8965185880661011, 4: 0.6256743669509888, 5: 0.9441564083099365, 6: 0.7403448820114136, 7: 0.6225660443305969, 8: 0.8787049055099487}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired at T # # J Max # # x [UNK] [SEP]', 'score': 0.000920166028663516, 'token': 27644}
# {'sequence': '[CLS]blem got hired at T # # J Max # # x [UNK] [SEP]', 'score': 0.0006095596472732723, 'token': 24151}
# {'sequence': '[CLS] needles got hired at T # # J Max # # x [UNK] [SEP]', 'score': 0.0005934489308856428, 'token': 20625}
# {'sequence': '[CLS]row got hired at T # # J Max # # x [UNK] [SEP]', 'score': 0.0005015396163798869, 'token': 6607}
# {'sequence': '[CLS]hari got hired at T # # J Max # # x [UNK] [SEP]', 'score': 0.00048420546227134764, 'token': 16234}
# ***********Tweet #16***********
# Tweet: Got hired on the spot😂😈
# Attention scores dictionary:  {0: 1.253964900970459, 1: 1.2943854331970215, 2: 0.8540881872177124, 3: 0.6148845553398132, 4: 0.9826771020889282}
# Token with most attention on average: hired
# Token index with most attention on average: 1
# MLM results for token "hired":
# {'sequence': '[CLS] Gotiability on the [UNK] [SEP]', 'score': 0.0006406349129974842, 'token': 26468}
# {'sequence': '[CLS] Gotcible on the [UNK] [SEP]', 'score': 0.0005870336899533868, 'token': 16240}
# {'sequence': '[CLS] Gotciation on the [UNK] [SEP]', 'score': 0.0005519474507309496, 'token': 15253}
# {'sequence': '[CLS] Got ignited on the [UNK] [SEP]', 'score': 0.0004603257402777672, 'token': 25092}
# {'sequence': '[CLS] Gotalytic on the [UNK] [SEP]', 'score': 0.00044706507469527423, 'token': 23672}
# ***********Tweet #17***********
# Tweet: Got hired at the Gulf. #YesYesYes
# Attention scores dictionary:  {0: 1.992775559425354, 1: 1.6423070430755615, 2: 0.6975770592689514, 3: 0.5735028386116028, 4: 1.0287569761276245, 5: 0.8721883296966553, 6: 0.8654198050498962, 7: 0.9259864091873169, 8: 0.80129075050354, 9: 0.8213381767272949, 10: 0.9719569683074951, 11: 0.8069007396697998}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS]All hired at the Gulf. # Yes # # Y # # es # # Y # # es [SEP]', 'score': 0.0006648480775766075, 'token': 27644}
# {'sequence': '[CLS] needles hired at the Gulf. # Yes # # Y # # es # # Y # # es [SEP]', 'score': 0.0006135276053100824, 'token': 20625}
# {'sequence': '[CLS]hari hired at the Gulf. # Yes # # Y # # es # # Y # # es [SEP]', 'score': 0.0005542254075407982, 'token': 16234}
# {'sequence': '[CLS]row hired at the Gulf. # Yes # # Y # # es # # Y # # es [SEP]', 'score': 0.0005023052799515426, 'token': 6607}
# {'sequence': '[CLS]blem hired at the Gulf. # Yes # # Y # # es # # Y # # es [SEP]', 'score': 0.00048550040810368955, 'token': 24151}
# ***********Tweet #18***********
# Tweet: Just got hired at Olive Garden ✔️
# Attention scores dictionary:  {0: 1.7673919200897217, 1: 0.9163364171981812, 2: 1.2997117042541504, 3: 0.6286437511444092, 4: 0.6396015882492065, 5: 0.6670652627944946, 6: 1.081249713897705}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All got hired at Olive Garden ✔️ [SEP]', 'score': 0.0008946493617258966, 'token': 27644}
# {'sequence': '[CLS]blem got hired at Olive Garden ✔️ [SEP]', 'score': 0.0006503029144369066, 'token': 24151}
# {'sequence': '[CLS] needles got hired at Olive Garden ✔️ [SEP]', 'score': 0.000587108195759356, 'token': 20625}
# {'sequence': '[CLS]row got hired at Olive Garden ✔️ [SEP]', 'score': 0.0005137626430951059, 'token': 6607}
# {'sequence': '[CLS]hari got hired at Olive Garden ✔️ [SEP]', 'score': 0.0005122373113408685, 'token': 16234}
# ***********Tweet #19***********
# Tweet: i got hired at the spirit store in the hub!!! :)
# Attention scores dictionary:  {0: 2.235973358154297, 1: 1.2311465740203857, 2: 1.5457109212875366, 3: 0.8086987733840942, 4: 0.6504694223403931, 5: 0.9284740686416626, 6: 0.976057231426239, 7: 0.7882581353187561, 8: 0.5873992443084717, 9: 1.2527601718902588, 10: 0.8112443685531616, 11: 0.7440286874771118, 12: 0.7331650853157043, 13: 0.7405610084533691, 14: 0.966052770614624}
# Token with most attention on average: i
# Token index with most attention on average: 0
# MLM results for token "i":
# {'sequence': '[CLS]All got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.0008813764434307814, 'token': 27644}
# {'sequence': '[CLS]blem got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.0006299561937339604, 'token': 24151}
# {'sequence': '[CLS] needles got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.0005866248975507915, 'token': 20625}
# {'sequence': '[CLS]uno got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.0004941407823935151, 'token': 26761}
# {'sequence': '[CLS]HL got hired at the spirit store in the hub!!! : ) [SEP]', 'score': 0.00043641377124004066, 'token': 9530}
# ***********Tweet #20***********
# Tweet: Got hired at North County MMA!!!!! OMG 🙄 I'm so happy 😋
# Attention scores dictionary:  {0: 2.4943244457244873, 1: 2.1048123836517334, 2: 0.94046550989151, 3: 0.6207968592643738, 4: 1.0046098232269287, 5: 1.365416169166565, 6: 0.7722797989845276, 7: 0.7158159017562866, 8: 0.6979694962501526, 9: 0.6486483812332153, 10: 0.6513867974281311, 11: 1.1927971839904785, 12: 0.7861584424972534, 13: 0.7486388087272644, 14: 0.6136422157287598, 15: 0.5475655198097229, 16: 0.6750344634056091, 17: 1.349496841430664, 18: 1.0701408386230469}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': "[CLS]All hired at North County MMA!!!!! OMG [UNK] I'm so happy [UNK] [SEP]", 'score': 0.0007246101158671081, 'token': 27644}
# {'sequence': "[CLS] needles hired at North County MMA!!!!! OMG [UNK] I'm so happy [UNK] [SEP]", 'score': 0.0005731267156079412, 'token': 20625}
# {'sequence': "[CLS]hari hired at North County MMA!!!!! OMG [UNK] I'm so happy [UNK] [SEP]", 'score': 0.0005645118071697652, 'token': 16234}
# {'sequence': "[CLS]row hired at North County MMA!!!!! OMG [UNK] I'm so happy [UNK] [SEP]", 'score': 0.0005422125686891377, 'token': 6607}
# {'sequence': "[CLS]rid hired at North County MMA!!!!! OMG [UNK] I'm so happy [UNK] [SEP]", 'score': 0.0005161199951544404, 'token': 10132}
# ***********Tweet #21***********
# Tweet: RT @yomixedchick: Got hired on the spot !
# Attention scores dictionary:  {0: 1.8179945945739746, 1: 0.7367821931838989, 2: 0.7493699789047241, 3: 0.755091667175293, 4: 0.9126898050308228, 5: 0.7672845721244812, 6: 0.8321616649627686, 7: 1.3140417337417603, 8: 1.0624698400497437, 9: 1.705833077430725, 10: 0.8442808389663696, 11: 0.6134726405143738, 12: 1.1365208625793457, 13: 0.7520067691802979}
# Token with most attention on average: RT
# Token index with most attention on average: 0
# MLM results for token "RT":
# {'sequence': '[CLS] needles @ yo # # mi # # xed # # chi # # ck : Got hired on the spot! [SEP]', 'score': 0.0006732430774718523, 'token': 20625}
# {'sequence': '[CLS]blem @ yo # # mi # # xed # # chi # # ck : Got hired on the spot! [SEP]', 'score': 0.0006260298541747034, 'token': 24151}
# {'sequence': '[CLS]rid @ yo # # mi # # xed # # chi # # ck : Got hired on the spot! [SEP]', 'score': 0.000586787995416671, 'token': 10132}
# {'sequence': '[CLS]All @ yo # # mi # # xed # # chi # # ck : Got hired on the spot! [SEP]', 'score': 0.0005783025990240276, 'token': 27644}
# {'sequence': '[CLS]anu @ yo # # mi # # xed # # chi # # ck : Got hired on the spot! [SEP]', 'score': 0.0005314037553034723, 'token': 19762}
# ***********Tweet #22***********
# Tweet: I just got hired at Tilly's!! Hell yeah!!
# Attention scores dictionary:  {0: 2.1405367851257324, 1: 1.139622449874878, 2: 1.0873925685882568, 3: 1.6099159717559814, 4: 1.0125110149383545, 5: 0.8485730290412903, 6: 0.7511700987815857, 7: 0.7005934715270996, 8: 0.9510619044303894, 9: 0.7661877870559692, 10: 0.7293860912322998, 11: 0.9310598969459534, 12: 1.0700886249542236, 13: 0.5687373876571655, 14: 0.6931627988815308}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': "[CLS]All just got hired at Till # # y's!! Hell yeah!! [SEP]", 'score': 0.0008706656517460942, 'token': 27644}
# {'sequence': "[CLS]blem just got hired at Till # # y's!! Hell yeah!! [SEP]", 'score': 0.0005778407212346792, 'token': 24151}
# {'sequence': "[CLS] needles just got hired at Till # # y's!! Hell yeah!! [SEP]", 'score': 0.0005633619730360806, 'token': 20625}
# {'sequence': "[CLS]hari just got hired at Till # # y's!! Hell yeah!! [SEP]", 'score': 0.00048061864799819887, 'token': 16234}
# {'sequence': "[CLS]uno just got hired at Till # # y's!! Hell yeah!! [SEP]", 'score': 0.00046966245281510055, 'token': 26761}
# ***********Tweet #23***********
# Tweet: just got hired at Kohl’s lol
# Attention scores dictionary:  {0: 1.9981051683425903, 1: 1.161868929862976, 2: 1.2041054964065552, 3: 0.8532512187957764, 4: 0.8008482456207275, 5: 0.9661829471588135, 6: 0.46284082531929016, 7: 0.7188224792480469, 8: 0.8339739441871643}
# Token with most attention on average: just
# Token index with most attention on average: 0
# MLM results for token "just":
# {'sequence': '[CLS]All got hired at Ko # # hl ’ s lol [SEP]', 'score': 0.0009323988924734294, 'token': 27644}
# {'sequence': '[CLS] needles got hired at Ko # # hl ’ s lol [SEP]', 'score': 0.0006240757065825164, 'token': 20625}
# {'sequence': '[CLS]blem got hired at Ko # # hl ’ s lol [SEP]', 'score': 0.0005912527558393776, 'token': 24151}
# {'sequence': '[CLS]hari got hired at Ko # # hl ’ s lol [SEP]', 'score': 0.0004831645346712321, 'token': 16234}
# {'sequence': '[CLS]wing got hired at Ko # # hl ’ s lol [SEP]', 'score': 0.00046640445361845195, 'token': 7635}
# ***********Tweet #24***********
# Tweet: Yes sir!!! Just got hired for wingstop!!! God is good!
# Attention scores dictionary:  {0: 2.286463737487793, 1: 1.2548853158950806, 2: 0.6242220401763916, 3: 0.6680631041526794, 4: 0.90364670753479, 5: 1.3377630710601807, 6: 1.116016149520874, 7: 1.5826884508132935, 8: 1.0574780702590942, 9: 0.8496884703636169, 10: 0.8255758881568909, 11: 0.7160632610321045, 12: 0.6977587342262268, 13: 0.7380958199501038, 14: 1.096549153327942, 15: 0.7700022459030151, 16: 0.9022258520126343, 17: 0.5728140473365784}
# Token with most attention on average: Yes
# Token index with most attention on average: 0
# MLM results for token "Yes":
# {'sequence': '[CLS]All sir!!! Just got hired for wings # # top!!! God is good! [SEP]', 'score': 0.0007019881159067154, 'token': 27644}
# {'sequence': '[CLS] needles sir!!! Just got hired for wings # # top!!! God is good! [SEP]', 'score': 0.000612558564171195, 'token': 20625}
# {'sequence': '[CLS]SL sir!!! Just got hired for wings # # top!!! God is good! [SEP]', 'score': 0.0005858248914591968, 'token': 13726}
# {'sequence': '[CLS]row sir!!! Just got hired for wings # # top!!! God is good! [SEP]', 'score': 0.0005164553294889629, 'token': 6607}
# {'sequence': '[CLS]rid sir!!! Just got hired for wings # # top!!! God is good! [SEP]', 'score': 0.0004862633941229433, 'token': 10132}
# ***********Tweet #25***********
# Tweet: Got a new job today and started on the spot!  Doing some real work!!
# Attention scores dictionary:  {0: 2.066157341003418, 1: 0.9446656107902527, 2: 1.0775426626205444, 3: 1.1994777917861938, 4: 0.8793065547943115, 5: 1.0466992855072021, 6: 1.2806215286254883, 7: 0.8468508720397949, 8: 0.6319315433502197, 9: 1.178275227546692, 10: 0.8223013281822205, 11: 1.1083741188049316, 12: 0.6953713893890381, 13: 0.8366166949272156, 14: 1.001132845878601, 15: 0.6766977310180664, 16: 0.707977294921875}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS]All a new job today and started on the spot! Doing some real work!! [SEP]', 'score': 0.0008680002647452056, 'token': 27644}
# {'sequence': '[CLS] needles a new job today and started on the spot! Doing some real work!! [SEP]', 'score': 0.0007051388965919614, 'token': 20625}
# {'sequence': '[CLS]blem a new job today and started on the spot! Doing some real work!! [SEP]', 'score': 0.0005598025163635612, 'token': 24151}
# {'sequence': '[CLS]anu a new job today and started on the spot! Doing some real work!! [SEP]', 'score': 0.0004934784956276417, 'token': 19762}
# {'sequence': '[CLS]uno a new job today and started on the spot! Doing some real work!! [SEP]', 'score': 0.0004795341519638896, 'token': 26761}
# ***********Tweet #26***********
# Tweet: Applied 2 days ago and was hired on the spot today! Craigslist rocks! I start my new job tomorrow, wish me good luck! 🍀😊😁
# Attention scores dictionary:  {0: 2.5439810752868652, 1: 0.5972791910171509, 2: 1.1146010160446167, 3: 1.0263832807540894, 4: 1.1184475421905518, 5: 0.9497688412666321, 6: 1.7238953113555908, 7: 0.8270929455757141, 8: 0.5948663949966431, 9: 1.2401114702224731, 10: 0.8192051649093628, 11: 1.0022680759429932, 12: 0.9408514499664307, 13: 0.4033448100090027, 14: 0.865966260433197, 15: 0.9850254654884338, 16: 0.9084862470626831, 17: 1.0118941068649292, 18: 1.332174301147461, 19: 0.7810649275779724, 20: 1.028007984161377, 21: 1.0990099906921387, 22: 0.9172815084457397, 23: 0.8492493629455566, 24: 1.2960838079452515, 25: 0.7335415482521057, 26: 0.7438902854919434, 27: 0.7952611446380615, 28: 0.6670078039169312, 29: 1.0839589834213257}
# Token with most attention on average: Applied
# Token index with most attention on average: 0
# MLM results for token "Applied":
# {'sequence': '[CLS] needles 2 days ago and was hired on the spot today! Craig # # s # # list rocks! I start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.0008002269896678627, 'token': 20625}
# {'sequence': '[CLS]All 2 days ago and was hired on the spot today! Craig # # s # # list rocks! I start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.0007308192434720695, 'token': 27644}
# {'sequence': '[CLS]row 2 days ago and was hired on the spot today! Craig # # s # # list rocks! I start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.0005807274719700217, 'token': 6607}
# {'sequence': '[CLS]blem 2 days ago and was hired on the spot today! Craig # # s # # list rocks! I start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.0004948683199472725, 'token': 24151}
# {'sequence': '[CLS]wing 2 days ago and was hired on the spot today! Craig # # s # # list rocks! I start my new job tomorrow, wish me good luck! [UNK] [SEP]', 'score': 0.0004940063809044659, 'token': 7635}
# ***********Tweet #27***********
# Tweet: I got hired at American Eagle!!! 😄🎉🎊🎈
# Attention scores dictionary:  {0: 1.9628069400787354, 1: 1.1302497386932373, 2: 1.393890380859375, 3: 0.9235032200813293, 4: 0.6433350443840027, 5: 0.8259020447731018, 6: 0.7240637540817261, 7: 0.7438327670097351, 8: 0.5906373262405396, 9: 1.0617785453796387}
# Token with most attention on average: I
# Token index with most attention on average: 0
# MLM results for token "I":
# {'sequence': '[CLS]All got hired at American Eagle!!! [UNK] [SEP]', 'score': 0.0009003904415294528, 'token': 27644}
# {'sequence': '[CLS]blem got hired at American Eagle!!! [UNK] [SEP]', 'score': 0.0006234502070583403, 'token': 24151}
# {'sequence': '[CLS] needles got hired at American Eagle!!! [UNK] [SEP]', 'score': 0.0005605991464108229, 'token': 20625}
# {'sequence': '[CLS]hari got hired at American Eagle!!! [UNK] [SEP]', 'score': 0.00046712844050489366, 'token': 16234}
# {'sequence': '[CLS]uno got hired at American Eagle!!! [UNK] [SEP]', 'score': 0.0004626225563697517, 'token': 26761}
# ***********Tweet #28***********
# Tweet: Just been hired as a PT cashier at Sears in Jefferson Mall! Will start as soon as I pass drug test, background check.
# Attention scores dictionary:  {0: 2.309258460998535, 1: 1.3257185220718384, 2: 1.718119740486145, 3: 0.9299182891845703, 4: 0.729774534702301, 5: 0.9957663416862488, 6: 0.7425462007522583, 7: 0.8576821684837341, 8: 0.7776150107383728, 9: 0.9435948133468628, 10: 0.747683584690094, 11: 0.6433034539222717, 12: 0.7801647186279297, 13: 1.11190664768219, 14: 1.067413568496704, 15: 1.364040493965149, 16: 0.53275066614151, 17: 0.8281121850013733, 18: 0.7340365648269653, 19: 0.9515392780303955, 20: 1.488388180732727, 21: 0.9807153940200806, 22: 0.8721585869789124, 23: 1.1129268407821655, 24: 0.8162550926208496, 25: 0.777398943901062, 26: 0.8612107634544373}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': '[CLS]All been hired as a PT cash # # ier at Sears in Jefferson Mall! Will start as soon as I pass drug test, background check. [SEP]', 'score': 0.0009306616266258061, 'token': 27644}
# {'sequence': '[CLS]wing been hired as a PT cash # # ier at Sears in Jefferson Mall! Will start as soon as I pass drug test, background check. [SEP]', 'score': 0.0006645622779615223, 'token': 7635}
# {'sequence': '[CLS]anu been hired as a PT cash # # ier at Sears in Jefferson Mall! Will start as soon as I pass drug test, background check. [SEP]', 'score': 0.0006234877509996295, 'token': 19762}
# {'sequence': '[CLS]SL been hired as a PT cash # # ier at Sears in Jefferson Mall! Will start as soon as I pass drug test, background check. [SEP]', 'score': 0.0005321824573911726, 'token': 13726}
# {'sequence': '[CLS]rid been hired as a PT cash # # ier at Sears in Jefferson Mall! Will start as soon as I pass drug test, background check. [SEP]', 'score': 0.000515046005602926, 'token': 10132}
# ***********Tweet #29***********
# Tweet: Got hired for 2 server jobs in wildwood today! #CantWaitForSummer
# Attention scores dictionary:  {0: 2.5975589752197266, 1: 1.9260715246200562, 2: 0.9841775894165039, 3: 0.7959757447242737, 4: 0.8007948994636536, 5: 0.9740767478942871, 6: 0.7263240218162537, 7: 0.6076979637145996, 8: 0.7716761827468872, 9: 1.0719220638275146, 10: 0.7861866354942322, 11: 0.902882993221283, 12: 1.2057353258132935, 13: 0.6273699998855591, 14: 0.8597532510757446, 15: 0.9184005856513977, 16: 0.6785638332366943, 17: 0.8338161110877991, 18: 0.9310155510902405}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS]All hired for 2 server jobs in wild # # wood today! # Cant # # W # # ait # # For # # S # # um # # mer [SEP]', 'score': 0.0006319264066405594, 'token': 27644}
# {'sequence': '[CLS] needles hired for 2 server jobs in wild # # wood today! # Cant # # W # # ait # # For # # S # # um # # mer [SEP]', 'score': 0.0005821320810355246, 'token': 20625}
# {'sequence': '[CLS]hp hired for 2 server jobs in wild # # wood today! # Cant # # W # # ait # # For # # S # # um # # mer [SEP]', 'score': 0.0005408974247984588, 'token': 16194}
# {'sequence': '[CLS]hoe hired for 2 server jobs in wild # # wood today! # Cant # # W # # ait # # For # # S # # um # # mer [SEP]', 'score': 0.0005284738726913929, 'token': 10061}
# {'sequence': '[CLS]hari hired for 2 server jobs in wild # # wood today! # Cant # # W # # ait # # For # # S # # um # # mer [SEP]', 'score': 0.0005136096151545644, 'token': 16234}
# ***********Tweet #30***********
# Tweet: First day at the new yab!
# Attention scores dictionary:  {0: 1.5690275430679321, 1: 1.218014121055603, 2: 0.8930929899215698, 3: 0.7307674288749695, 4: 1.2033594846725464, 5: 0.8260961174964905, 6: 0.7348130941390991, 7: 0.8248294591903687}
# Token with most attention on average: First
# Token index with most attention on average: 0
# MLM results for token "First":
# {'sequence': '[CLS] Abd day at the new ya # # b! [SEP]', 'score': 0.0005861363024450839, 'token': 22358}
# {'sequence': '[CLS]row day at the new ya # # b! [SEP]', 'score': 0.0005497192614711821, 'token': 6607}
# {'sequence': '[CLS]wing day at the new ya # # b! [SEP]', 'score': 0.000510037993080914, 'token': 7635}
# {'sequence': '[CLS]All day at the new ya # # b! [SEP]', 'score': 0.00048541664727963507, 'token': 27644}
# {'sequence': '[CLS]rid day at the new ya # # b! [SEP]', 'score': 0.00045374920591712, 'token': 10132}
# ***********Tweet #31***********
# Tweet: Was hired on to a new job today. Hope it goes well.
# Attention scores dictionary:  {0: 1.8963210582733154, 1: 1.3329483270645142, 2: 1.022910237312317, 3: 0.9498006701469421, 4: 0.7221141457557678, 5: 1.0568573474884033, 6: 1.1116896867752075, 7: 0.9277344942092896, 8: 0.9968269467353821, 9: 0.8822914958000183, 10: 0.7221673130989075, 11: 0.7866895198822021, 12: 0.8074938058853149, 13: 0.7841547727584839}
# Token with most attention on average: Was
# Token index with most attention on average: 0
# MLM results for token "Was":
# {'sequence': '[CLS]All hired on to a new job today. Hope it goes well. [SEP]', 'score': 0.0008517606183886528, 'token': 27644}
# {'sequence': '[CLS]hari hired on to a new job today. Hope it goes well. [SEP]', 'score': 0.000688530330080539, 'token': 16234}
# {'sequence': '[CLS] needles hired on to a new job today. Hope it goes well. [SEP]', 'score': 0.0005947520257905126, 'token': 20625}
# {'sequence': '[CLS]blem hired on to a new job today. Hope it goes well. [SEP]', 'score': 0.0005583846941590309, 'token': 24151}
# {'sequence': '[CLS]anu hired on to a new job today. Hope it goes well. [SEP]', 'score': 0.0005385387339629233, 'token': 19762}
# ***********Tweet #32***********
# Tweet: Start my new job tomorrow at 2!
# Attention scores dictionary:  {0: 1.6256535053253174, 1: 0.8992180824279785, 2: 1.0544120073318481, 3: 1.0394339561462402, 4: 0.9535702466964722, 5: 0.7780277729034424, 6: 0.9144979119300842, 7: 0.7351862192153931}
# Token with most attention on average: Start
# Token index with most attention on average: 0
# MLM results for token "Start":
# {'sequence': '[CLS]All my new job tomorrow at 2! [SEP]', 'score': 0.000954578397795558, 'token': 27644}
# {'sequence': '[CLS] needles my new job tomorrow at 2! [SEP]', 'score': 0.0007678490364924073, 'token': 20625}
# {'sequence': '[CLS]blem my new job tomorrow at 2! [SEP]', 'score': 0.0005693560815416276, 'token': 24151}
# {'sequence': '[CLS]hari my new job tomorrow at 2! [SEP]', 'score': 0.0005628775106742978, 'token': 16234}
# {'sequence': '[CLS]wing my new job tomorrow at 2! [SEP]', 'score': 0.0005241246544755995, 'token': 7635}
# ***********Tweet #33***********
# Tweet: Just started at #UIFIKI #uifi2014. Let's do it. http://t.co/knBK657Aaw
# Attention scores dictionary:  {0: 2.0200371742248535, 1: 1.915666103363037, 2: 0.9757499694824219, 3: 0.9019858837127686, 4: 0.8560076951980591, 5: 0.8595513105392456, 6: 0.765491783618927, 7: 0.8632155060768127, 8: 0.9964633584022522, 9: 0.9636867642402649, 10: 1.239399790763855, 11: 1.1158162355422974, 12: 0.9469090700149536, 13: 1.0333988666534424, 14: 0.9254617691040039, 15: 0.4110928177833557, 16: 0.7886349558830261, 17: 0.9506558179855347, 18: 0.683941662311554, 19: 0.867717981338501, 20: 1.067295789718628, 21: 0.7762137651443481, 22: 0.7508362531661987, 23: 0.8788192272186279, 24: 1.098353624343872, 25: 0.9531998634338379, 26: 1.20845627784729, 27: 0.9141677021980286, 28: 1.1045376062393188, 29: 0.8762695789337158, 30: 0.9155499935150146, 31: 1.1199265718460083, 32: 1.0339009761810303, 33: 1.1222730875015259, 34: 1.0993144512176514}
# Token with most attention on average: Just
# Token index with most attention on average: 0
# MLM results for token "Just":
# {'sequence': "[CLS]yr started at # UI # # FI # # K # # I # u # # ifi # # 20 # # 14. Let's do it. http : / / t. co / kn # # B # # K # # 65 # # 7 # # A # # aw [SEP]", 'score': 0.0007192083285190165, 'token': 12577}
# {'sequence': "[CLS]unity started at # UI # # FI # # K # # I # u # # ifi # # 20 # # 14. Let's do it. http : / / t. co / kn # # B # # K # # 65 # # 7 # # A # # aw [SEP]", 'score': 0.0006602584035135806, 'token': 22534}
# {'sequence': "[CLS]umin started at # UI # # FI # # K # # I # u # # ifi # # 20 # # 14. Let's do it. http : / / t. co / kn # # B # # K # # 65 # # 7 # # A # # aw [SEP]", 'score': 0.0004368728259578347, 'token': 28077}
# {'sequence': "[CLS]nst started at # UI # # FI # # K # # I # u # # ifi # # 20 # # 14. Let's do it. http : / / t. co / kn # # B # # K # # 65 # # 7 # # A # # aw [SEP]", 'score': 0.0004138352524023503, 'token': 22399}
# {'sequence': "[CLS]ogo started at # UI # # FI # # K # # I # u # # ifi # # 20 # # 14. Let's do it. http : / / t. co / kn # # B # # K # # 65 # # 7 # # A # # aw [SEP]", 'score': 0.0003970960096921772, 'token': 26205}
# ***********Tweet #34***********
# Tweet: RT @jayboi93: Got hired at Academy on the spot! :)
# Attention scores dictionary:  {0: 2.078007459640503, 1: 0.8528658151626587, 2: 0.7201181650161743, 3: 0.699449896812439, 4: 0.8333907723426819, 5: 0.6023377776145935, 6: 0.9277788996696472, 7: 1.539118766784668, 8: 1.3410940170288086, 9: 1.6097546815872192, 10: 0.8734671473503113, 11: 1.0817668437957764, 12: 0.8674831390380859, 13: 0.6000611186027527, 14: 1.1549186706542969, 15: 0.7712576985359192, 16: 0.6221018433570862, 17: 0.8250271081924438}
# Token with most attention on average: RT
# Token index with most attention on average: 0
# MLM results for token "RT":
# {'sequence': '[CLS] needles @ ja # # y # # bo # # i # # 93 : Got hired at Academy on the spot! : ) [SEP]', 'score': 0.000715073139872402, 'token': 20625}
# {'sequence': '[CLS]rid @ ja # # y # # bo # # i # # 93 : Got hired at Academy on the spot! : ) [SEP]', 'score': 0.000622997002210468, 'token': 10132}
# {'sequence': '[CLS]blem @ ja # # y # # bo # # i # # 93 : Got hired at Academy on the spot! : ) [SEP]', 'score': 0.0006146671366877854, 'token': 24151}
# {'sequence': '[CLS]SL @ ja # # y # # bo # # i # # 93 : Got hired at Academy on the spot! : ) [SEP]', 'score': 0.0005990306963212788, 'token': 13726}
# {'sequence': '[CLS]xious @ ja # # y # # bo # # i # # 93 : Got hired at Academy on the spot! : ) [SEP]', 'score': 0.0005357425543479621, 'token': 25459}
# ***********Tweet #35***********
# Tweet: just got new job!
# Attention scores dictionary:  {0: 1.3237202167510986, 1: 0.9203872084617615, 2: 0.9882594347000122, 3: 0.9540395736694336, 4: 0.8135936856269836}
# Token with most attention on average: just
# Token index with most attention on average: 0
# MLM results for token "just":
# {'sequence': '[CLS]All got new job! [SEP]', 'score': 0.0007914468296803534, 'token': 27644}
# {'sequence': '[CLS]blem got new job! [SEP]', 'score': 0.0006387466564774513, 'token': 24151}
# {'sequence': '[CLS]hari got new job! [SEP]', 'score': 0.0005556668620556593, 'token': 16234}
# {'sequence': '[CLS] needles got new job! [SEP]', 'score': 0.000541080953553319, 'token': 20625}
# {'sequence': '[CLS] Month got new job! [SEP]', 'score': 0.0004574996419250965, 'token': 17545}
# ***********Tweet #36***********
# Tweet: Got hired on the spot at my interview 2day!! Now I need 2 more jobs so I can have 4 total..
# Attention scores dictionary:  {0: 2.564220905303955, 1: 1.8344769477844238, 2: 0.9754607677459717, 3: 0.653286337852478, 4: 1.2562029361724854, 5: 0.8278435468673706, 6: 0.9025553464889526, 7: 1.2542957067489624, 8: 1.1266649961471558, 9: 0.7778411507606506, 10: 0.7046743035316467, 11: 0.7297952175140381, 12: 0.9090254306793213, 13: 0.7243320941925049, 14: 1.5344566106796265, 15: 0.7118069529533386, 16: 0.6597216725349426, 17: 0.8396849632263184, 18: 1.0097413063049316, 19: 0.6681457757949829, 20: 0.8051666617393494, 21: 0.9283831119537354, 22: 0.8641493916511536, 23: 1.2244359254837036, 24: 0.6777385473251343, 25: 0.8358938097953796}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': '[CLS]hp hired on the spot at my interview 2d # # ay!! Now I need 2 more jobs so I can have 4 total.. [SEP]', 'score': 0.0007082642987370491, 'token': 16194}
# {'sequence': '[CLS] needles hired on the spot at my interview 2d # # ay!! Now I need 2 more jobs so I can have 4 total.. [SEP]', 'score': 0.000664290739223361, 'token': 20625}
# {'sequence': '[CLS]hoe hired on the spot at my interview 2d # # ay!! Now I need 2 more jobs so I can have 4 total.. [SEP]', 'score': 0.0005518795805983245, 'token': 10061}
# {'sequence': '[CLS]jos hired on the spot at my interview 2d # # ay!! Now I need 2 more jobs so I can have 4 total.. [SEP]', 'score': 0.0004926463589072227, 'token': 22343}
# {'sequence': '[CLS] Month hired on the spot at my interview 2d # # ay!! Now I need 2 more jobs so I can have 4 total.. [SEP]', 'score': 0.000457944959634915, 'token': 17545}
# ***********Tweet #37***********
# Tweet: Got hired at best buy mobile last week &amp;amp; today I have an interview with FedEx for a customer service rep position! #needthat
# Attention scores dictionary:  {0: 2.451568126678467, 1: 2.4593515396118164, 2: 1.011380910873413, 3: 0.8046233057975769, 4: 0.9342045187950134, 5: 1.0449730157852173, 6: 1.0444341897964478, 7: 1.1438586711883545, 8: 0.9918031096458435, 9: 0.742372989654541, 10: 0.7891494035720825, 11: 0.9352538585662842, 12: 0.8444757461547852, 13: 1.083548665046692, 14: 0.858732283115387, 15: 0.905475914478302, 16: 0.7715875506401062, 17: 1.296288251876831, 18: 0.804690957069397, 19: 0.6597017645835876, 20: 0.6982892751693726, 21: 1.0510209798812866, 22: 0.6705811619758606, 23: 0.7652428150177002, 24: 0.6990610957145691, 25: 0.8288096189498901, 26: 0.9379563927650452, 27: 1.0600669384002686, 28: 0.9595183730125427, 29: 1.1375473737716675, 30: 1.0491234064102173, 31: 0.5653067827224731}
# Token with most attention on average: hired
# Token index with most attention on average: 1
# MLM results for token "hired":
# {'sequence': '[CLS] Gothaving at best buy mobile last week & amp ; amp ; today I have an interview with Fed # # Ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.000864081084728241, 'token': 22300}
# {'sequence': '[CLS] Gotuin at best buy mobile last week & amp ; amp ; today I have an interview with Fed # # Ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.000700585835147649, 'token': 14846}
# {'sequence': '[CLS] Got ALD at best buy mobile last week & amp ; amp ; today I have an interview with Fed # # Ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.0006700473604723811, 'token': 23079}
# {'sequence': '[CLS] Gotunta at best buy mobile last week & amp ; amp ; today I have an interview with Fed # # Ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.0006272747414186597, 'token': 19529}
# {'sequence': '[CLS] Gotogo at best buy mobile last week & amp ; amp ; today I have an interview with Fed # # Ex for a customer service rep position! # need # # tha # # t [SEP]', 'score': 0.0006003573653288186, 'token': 26205}
# ***********Tweet #38***********
# Tweet: Start my new job today start my new job today start my new job today https://t.co/3fA36OKu1e
# Attention scores dictionary:  {0: 2.5467605590820312, 1: 0.9486736059188843, 2: 1.0718388557434082, 3: 1.0792768001556396, 4: 0.9526790976524353, 5: 1.2701438665390015, 6: 0.8888204097747803, 7: 1.077450156211853, 8: 1.134616732597351, 9: 0.986646831035614, 10: 1.1542030572891235, 11: 0.8719887733459473, 12: 1.0079599618911743, 13: 1.1203019618988037, 14: 0.9629437327384949, 15: 1.0488450527191162, 16: 0.6147999167442322, 17: 0.6486280560493469, 18: 0.711828351020813, 19: 0.949111819267273, 20: 0.885382890701294, 21: 1.049824833869934, 22: 0.8552781939506531, 23: 0.7980548143386841, 24: 1.0252622365951538, 25: 0.7214197516441345, 26: 1.0610153675079346, 27: 0.9662884473800659, 28: 0.7869267463684082, 29: 0.8964064717292786, 30: 0.9066222906112671}
# Token with most attention on average: Start
# Token index with most attention on average: 0
# MLM results for token "Start":
# {'sequence': '[CLS]All my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # A # # 36 # # OK # # u # # 1 # # e [SEP]', 'score': 0.0008770209387876093, 'token': 27644}
# {'sequence': '[CLS] needles my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # A # # 36 # # OK # # u # # 1 # # e [SEP]', 'score': 0.0007610775064677, 'token': 20625}
# {'sequence': '[CLS]row my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # A # # 36 # # OK # # u # # 1 # # e [SEP]', 'score': 0.0005784571985714138, 'token': 6607}
# {'sequence': '[CLS]uno my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # A # # 36 # # OK # # u # # 1 # # e [SEP]', 'score': 0.0005468588788062334, 'token': 26761}
# {'sequence': '[CLS]blem my new job today start my new job today start my new job today https : / / t. co / 3 # # f # # A # # 36 # # OK # # u # # 1 # # e [SEP]', 'score': 0.0005146995536051691, 'token': 24151}
# ***********Tweet #39***********
# Tweet: Got hired on at Francesca's for a second job 😊
# Attention scores dictionary:  {0: 1.917273759841919, 1: 1.6446563005447388, 2: 1.0589815378189087, 3: 0.9127634167671204, 4: 0.6268473267555237, 5: 0.7146026492118835, 6: 0.6649272441864014, 7: 1.0365824699401855, 8: 1.1601476669311523, 9: 0.610913872718811, 10: 0.9365875124931335, 11: 0.8651805520057678, 12: 0.8505356311798096}
# Token with most attention on average: Got
# Token index with most attention on average: 0
# MLM results for token "Got":
# {'sequence': "[CLS]All hired on at Frances # # ca's for a second job [UNK] [SEP]", 'score': 0.0007322229794226587, 'token': 27644}
# {'sequence': "[CLS] needles hired on at Frances # # ca's for a second job [UNK] [SEP]", 'score': 0.0006399750127457082, 'token': 20625}
# {'sequence': "[CLS]hari hired on at Frances # # ca's for a second job [UNK] [SEP]", 'score': 0.0005497685633599758, 'token': 16234}
# {'sequence': "[CLS]blem hired on at Frances # # ca's for a second job [UNK] [SEP]", 'score': 0.0005436716601252556, 'token': 24151}
# {'sequence': "[CLS]uno hired on at Frances # # ca's for a second job [UNK] [SEP]", 'score': 0.00050399947213009, 'token': 26761}
